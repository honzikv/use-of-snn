# %%
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical
import numpy as np
import os
from tensorflow.python.keras import Sequential
from tensorflow.python.keras.layers import Dense, Flatten

MNIST_PATH = os.path.join(os.getcwd(), 'dataset', 'mnist')
MNIST_FILE = os.path.join(MNIST_PATH, 'mnist.npz')

# load dataset from tensorflow
(x_train, y_train), (x_test, y_test) = mnist.load_data(path=MNIST_FILE)

classes = 10
x_train , x_test = x_train/255.0 , x_test/255.0
y_train, y_test = to_categorical(y_train, classes), to_categorical(y_test, classes)

np.savez_compressed(os.path.join(MNIST_PATH, 'x_test'), x_test)
np.savez_compressed(os.path.join(MNIST_PATH, 'y_test'), y_test)
np.savez_compressed(os.path.join(MNIST_PATH, 'x_norm'), x_train[::10])

# %%
# nn_model = tf.keras.Sequential([
#     layers.Flatten(input_shape=[28, 28]),
#     layers.Dense(128, activation='relu'),
#     layers.Dense(256, activation='relu'),
#     layers.Dense(units=10, activation='softmax')
# ])
input_shape = x_train.shape[1:]
ann_model = Sequential([
    Flatten(input_shape=[28, 28]),
    Dense(units=784, activation='relu'),
    Dense(units=784*2, activation='relu'),
    Dense(units=classes, activation='sigmoid')
])

ann_model.compile(optimizer='adam', loss='categorical_crossentropy',
                 metrics=['accuracy'])

ann_model.fit(x_train, y_train, epochs=6, batch_size=256)
# Out:
# Epoch 1/6
#  - ETA: 3s - loss: 0.3694 - accuracy: 0.8939
# Epoch 2/6
# 235/235 [==============================] - 6s 24ms/step - loss: 0.0839 - accuracy: 0.9743
# Epoch 3/6
#  - ETA: 0s - loss: 0.0527 - accuracy: 0.9837
# Epoch 4/6
# 235/235 [==============================] - 6s 26ms/step - loss: 0.0353 - accuracy: 0.9890
# Epoch 5/6
# 235/235 [==============================] - 6s 28ms/step - loss: 0.0253 - accuracy: 0.9917
# Epoch 6/6
# 235/235 [==============================] - 6s 27ms/step - loss: 0.0237 - accuracy: 0.9923

# %%
test_loss,test_acc = ann_model.evaluate(x_test,y_test)
print('Accuracy:',test_acc) # cca 96.67%
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0772 - accuracy: 0.9776
# Accuracy: 0.9775999784469604

# %%
model_directory = os.path.join(os.getcwd(), 'model',)
if not os.path.exists(model_directory):
    os.makedirs(model_directory)

model_save_path = os.path.join(model_directory, 'mnist_ann_model.h5')
ann_model.save(filepath=str(model_save_path))
print('model saved')
# Out:
# model saved

# %%
# https://github.com/NeuromorphicProcessorProject/snn_toolbox/blob/master/examples/mnist_keras_INI.py
from snntoolbox.bin.run import main
from snntoolbox.utils.utils import import_configparser

config_parser = import_configparser()
config = config_parser.ConfigParser()

config['paths'] = {
    'path-wd': os.path.join(os.getcwd(), 'model'),
    'dataset_path': MNIST_PATH,
    'filename_ann': os.path.join(os.getcwd(), 'model', 'mnist_ann_model')
}

config['tools'] = {
    'evaluate_ann': True,
    'normalize': True
}

config['simulation'] = {
    'simulator': 'INI',
    'duration': 30,
    'num_to_test': 10000,
    'batch_size': 512,
    'dt': .1,
    'keras_backed': 'tensorflow'
}

config['output'] = {
    'plot_vars': {                  # Various plots (slows down simulation).
        'spiketrains',              # Leave section empty to turn off plots.
        'spikerates',
        'activations',
        'correlation',
        'v_mem',
        'error_t'
    }
}

path = os.getcwd() + '\\config\\'
if not os.path.exists(path):
    os.makedirs(path)

# this for some reason doesnt create the directory
config_filepath = os.getcwd() + '\\config\\mnist-snn-config'
with open(config_filepath, 'w+') as config_file:
    config.write(config_file)

main(config_filepath)
# Out:
# Initializing INI simulator...
#
# Loading scale factors from disk instead of recalculating.
# Loading data set from '.npz' files in C:\Users\itznu\PycharmProjects\use-of-snn\snn-toolbox-examples\dataset\mnist.
#
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_1 (Flatten)          (None, 784)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 784)               615440
# _________________________________________________________________
# dense_4 (Dense)              (None, 1568)              1230880
# _________________________________________________________________
# dense_5 (Dense)              (None, 10)                15690
# =================================================================
# Total params: 1,862,010
# Trainable params: 1,862,010
# Non-trainable params: 0
# _________________________________________________________________
# Evaluating input model on 10000 samples...
# Top-1 accuracy: 97.76%
# Top-5 accuracy: 99.98%
#
# Parsing input model...
# Parsing layer Flatten.
# Parsing layer Dense.
# Using activation relu.
# Parsing layer Dense.
# Using activation relu.
# Parsing layer Dense.
# Using activation sigmoid.
#
# Building parsed model...
#
# Compiling parsed model...
#
# Model: "functional_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(512, 28, 28)]           0
# _________________________________________________________________
# 00Flatten_784 (Flatten)      (512, 784)                0
# _________________________________________________________________
# 01Dense_784 (Dense)          (512, 784)                615440
# _________________________________________________________________
# 02Dense_1568 (Dense)         (512, 1568)               1230880
# _________________________________________________________________
# 03Dense_10 (Dense)           (512, 10)                 15690
# =================================================================
# Total params: 1,862,010
# Trainable params: 1,862,010
# Non-trainable params: 0
# _________________________________________________________________
# Normalizing parameters...
#
# Evaluating parsed model on 10000 samples...
# Top-1 accuracy: 95.47%
# Top-5 accuracy: 97.64%
#
# Building spiking model...
# Building layer: 00Flatten_784
# Building layer: 01Dense_784
# Building layer: 02Dense_1568
# Building layer: 03Dense_10
# Compiling spiking model...
#
# Detected layer with biases: 01Dense_784
# Detected layer with biases: 02Dense_1568
# Detected layer with biases: 03Dense_10
# Number of operations of ANN: 3721658
# Number of neurons: 2362
# Number of synapses: 1859648
#
# Saving model to C:\Users\itznu\PycharmProjects\use-of-snn\snn-toolbox-examples\model\mnist_ann_model_INI.h5...
#
#
# Starting new simulation...
#
# Current accuracy of batch:
#  91.99%0.00%_0.20%_16.41%_61.13%_82.81%_90.43%_91.21%_91.80%_91.99%_91.99%_91.99%_91.99%_91.99%_91.99%_91.99%_91.99%_91.99%_91.99%_91.99%_91.99%_91.99%_91.99%_91.99%_91.99%_91.99%_91.99%_91.99%_91.99%_91.99%_91.99%_Average spike rate: 0.0 spikes per simulation time step.
#
# Batch 1 of 19 completed (5.3%)
# Moving accuracy of SNN (top-1, top-1): 91.99%, 94.73%.
# Moving accuracy of ANN (top-1, top-1): 98.05%, 99.80%.
#
#
# Starting new simulation...
#
# Current accuracy of batch:
#  93.55%0.00%_0.00%_18.75%_63.48%_86.33%_91.41%_92.77%_93.55%_93.55%_93.55%_93.55%_93.55%_93.55%_93.55%_93.55%_93.55%_93.55%_93.55%_93.55%_93.55%_93.55%_93.55%_93.55%_93.55%_93.55%_93.55%_93.55%_93.55%_93.55%_93.55%_Average spike rate: 0.0 spikes per simulation time step.
#
# Batch 2 of 19 completed (10.5%)
# Moving accuracy of SNN (top-1, top-1): 92.77%, 94.73%.
# Moving accuracy of ANN (top-1, top-1): 97.85%, 99.90%.
#
#
# Starting new simulation...
#
# Current accuracy of batch:
#  90.82%0.00%_0.00%_16.21%_58.01%_81.25%_88.48%_90.23%_90.82%_90.82%_90.82%_90.82%_90.82%_90.82%_90.82%_90.82%_90.82%_90.82%_90.82%_90.82%_90.82%_90.82%_90.82%_90.82%_90.82%_90.82%_90.82%_90.82%_90.82%_90.82%_90.82%_Average spike rate: 0.0 spikes per simulation time step.
#
# Batch 3 of 19 completed (15.8%)
# Moving accuracy of SNN (top-1, top-1): 92.12%, 93.95%.
# Moving accuracy of ANN (top-1, top-1): 97.07%, 99.87%.
#
#
# Starting new simulation...
#
# Current accuracy of batch:
#  90.82%0.00%_0.20%_16.21%_57.62%_79.69%_87.89%_90.04%_90.82%_90.82%_90.82%_90.82%_90.82%_90.82%_90.82%_90.82%_90.82%_90.82%_90.82%_90.82%_90.82%_90.82%_90.82%_90.82%_90.82%_90.82%_90.82%_90.82%_90.82%_90.82%_90.82%_Average spike rate: 0.0 spikes per simulation time step.
#
# Batch 4 of 19 completed (21.1%)
# Moving accuracy of SNN (top-1, top-1): 91.80%, 93.41%.
# Moving accuracy of ANN (top-1, top-1): 96.88%, 99.90%.
#
#
# Starting new simulation...
#
# Current accuracy of batch:
#  91.41%0.00%_0.20%_19.73%_59.96%_81.64%_90.23%_91.02%_91.21%_91.41%_91.41%_91.41%_91.41%_91.41%_91.41%_91.41%_91.41%_91.41%_91.41%_91.41%_91.41%_91.41%_91.41%_91.41%_91.41%_91.41%_91.41%_91.41%_91.41%_91.41%_91.41%_Average spike rate: 0.0 spikes per simulation time step.
#
# Batch 5 of 19 completed (26.3%)
# Moving accuracy of SNN (top-1, top-1): 91.72%, 93.12%.
# Moving accuracy of ANN (top-1, top-1): 96.72%, 99.92%.
#
#
# Starting new simulation...
#
# Current accuracy of batch:
#  92.58%0.00%_0.00%_20.31%_58.98%_84.57%_89.45%_91.21%_91.99%_92.19%_92.38%_92.58%_92.58%_92.58%_92.58%_92.58%_92.58%_92.58%_92.58%_92.58%_92.58%_92.58%_92.58%_92.58%_92.58%_92.58%_92.58%_92.58%_92.58%_92.58%_92.58%_Average spike rate: 0.0 spikes per simulation time step.
#
# Batch 6 of 19 completed (31.6%)
# Moving accuracy of SNN (top-1, top-1): 91.86%, 93.55%.
# Moving accuracy of ANN (top-1, top-1): 96.81%, 99.93%.
#
#
# Starting new simulation...
#
# Current accuracy of batch:
#  93.36%0.00%_0.20%_19.53%_63.67%_85.74%_91.99%_92.97%_93.36%_93.36%_93.36%_93.36%_93.36%_93.36%_93.36%_93.36%_93.36%_93.36%_93.36%_93.36%_93.36%_93.36%_93.36%_93.36%_93.36%_93.36%_93.36%_93.36%_93.36%_93.36%_93.36%_Average spike rate: 0.0 spikes per simulation time step.
#
# Batch 7 of 19 completed (36.8%)
# Moving accuracy of SNN (top-1, top-1): 92.08%, 93.55%.
# Moving accuracy of ANN (top-1, top-1): 96.90%, 99.94%.
#
#
# Starting new simulation...
#
# Current accuracy of batch:
#  92.19%0.00%_0.20%_18.75%_61.33%_83.79%_90.43%_91.60%_91.80%_91.99%_91.99%_92.19%_92.19%_92.19%_92.19%_92.19%_92.19%_92.19%_92.19%_92.19%_92.19%_92.19%_92.19%_92.19%_92.19%_92.19%_92.19%_92.19%_92.19%_92.19%_92.19%_Average spike rate: 0.0 spikes per simulation time step.
#
# Batch 8 of 19 completed (42.1%)
# Moving accuracy of SNN (top-1, top-1): 92.09%, 93.63%.
# Moving accuracy of ANN (top-1, top-1): 96.85%, 99.95%.
#
#
# Starting new simulation...
#
# Current accuracy of batch:
#  90.62%0.00%_0.20%_17.19%_57.81%_82.03%_89.06%_90.23%_90.43%_90.62%_90.62%_90.62%_90.62%_90.62%_90.62%_90.62%_90.62%_90.62%_90.62%_90.62%_90.62%_90.62%_90.62%_90.62%_90.62%_90.62%_90.62%_90.62%_90.62%_90.62%_90.62%_Average spike rate: 0.0 spikes per simulation time step.
#
# Batch 9 of 19 completed (47.4%)
# Moving accuracy of SNN (top-1, top-1): 91.93%, 93.58%.
# Moving accuracy of ANN (top-1, top-1): 96.83%, 99.96%.
#
#
# Starting new simulation...
#
# Current accuracy of batch:
#  94.92%0.00%_0.20%_20.70%_66.02%_87.89%_93.95%_94.92%_94.92%_94.92%_94.92%_94.92%_94.92%_94.92%_94.92%_94.92%_94.92%_94.92%_94.92%_94.92%_94.92%_94.92%_94.92%_94.92%_94.92%_94.92%_94.92%_94.92%_94.92%_94.92%_94.92%_Average spike rate: 0.0 spikes per simulation time step.
#
# Batch 10 of 19 completed (52.6%)
# Moving accuracy of SNN (top-1, top-1): 92.23%, 93.81%.
# Moving accuracy of ANN (top-1, top-1): 96.93%, 99.96%.
#
#
# Starting new simulation...
#
# Current accuracy of batch:
#  98.44%0.00%_0.00%_33.01%_76.17%_95.70%_97.85%_98.44%_98.44%_98.44%_98.44%_98.44%_98.44%_98.44%_98.44%_98.44%_98.44%_98.44%_98.44%_98.44%_98.44%_98.44%_98.44%_98.44%_98.44%_98.44%_98.44%_98.44%_98.44%_98.44%_98.44%_Average spike rate: 0.0 spikes per simulation time step.
#
# Batch 11 of 19 completed (57.9%)
# Moving accuracy of SNN (top-1, top-1): 92.79%, 94.23%.
# Moving accuracy of ANN (top-1, top-1): 97.16%, 99.96%.
#
#
# Starting new simulation...
#
# Current accuracy of batch:
#  92.58%0.00%_0.78%_28.71%_69.14%_88.09%_91.41%_92.19%_92.58%_92.58%_92.58%_92.58%_92.58%_92.58%_92.58%_92.58%_92.58%_92.58%_92.58%_92.58%_92.58%_92.58%_92.58%_92.58%_92.58%_92.58%_92.58%_92.58%_92.58%_92.58%_92.58%_Average spike rate: 0.0 spikes per simulation time step.
#
# Batch 12 of 19 completed (63.2%)
# Moving accuracy of SNN (top-1, top-1): 92.77%, 94.12%.
# Moving accuracy of ANN (top-1, top-1): 97.18%, 99.97%.
#
#
# Starting new simulation...
#
# Current accuracy of batch:
#  96.48%0.00%_0.20%_30.66%_76.37%_91.80%_95.90%_96.09%_96.48%_96.48%_96.48%_96.48%_96.48%_96.48%_96.48%_96.48%_96.48%_96.48%_96.48%_96.48%_96.48%_96.48%_96.48%_96.48%_96.48%_96.48%_96.48%_96.48%_96.48%_96.48%_96.48%_Average spike rate: 0.0 spikes per simulation time step.
#
# Batch 13 of 19 completed (68.4%)
# Moving accuracy of SNN (top-1, top-1): 93.06%, 94.37%.
# Moving accuracy of ANN (top-1, top-1): 97.30%, 99.97%.
#
#
# Starting new simulation...
#
# Current accuracy of batch:
#  97.07%0.00%_0.20%_30.47%_78.12%_93.16%_96.29%_96.68%_97.07%_97.07%_97.07%_97.07%_97.07%_97.07%_97.07%_97.07%_97.07%_97.07%_97.07%_97.07%_97.07%_97.07%_97.07%_97.07%_97.07%_97.07%_97.07%_97.07%_97.07%_97.07%_97.07%_Average spike rate: 0.0 spikes per simulation time step.
#
# Batch 14 of 19 completed (73.7%)
# Moving accuracy of SNN (top-1, top-1): 93.35%, 94.59%.
# Moving accuracy of ANN (top-1, top-1): 97.42%, 99.97%.
#
#
# Starting new simulation...
#
# Current accuracy of batch:
#  96.68%0.00%_0.00%_23.05%_72.85%_92.58%_95.51%_96.09%_96.29%_96.48%_96.68%_96.68%_96.68%_96.68%_96.68%_96.68%_96.68%_96.68%_96.68%_96.68%_96.68%_96.68%_96.68%_96.68%_96.68%_96.68%_96.68%_96.68%_96.68%_96.68%_96.68%_Average spike rate: 0.0 spikes per simulation time step.
#
# Batch 15 of 19 completed (78.9%)
# Moving accuracy of SNN (top-1, top-1): 93.57%, 94.75%.
# Moving accuracy of ANN (top-1, top-1): 97.57%, 99.97%.
#
#
# Starting new simulation...
#
# Current accuracy of batch:
#  95.70%0.00%_0.20%_39.26%_81.64%_91.60%_94.92%_95.70%_95.70%_95.70%_95.70%_95.70%_95.70%_95.70%_95.70%_95.70%_95.70%_95.70%_95.70%_95.70%_95.70%_95.70%_95.70%_95.70%_95.70%_95.70%_95.70%_95.70%_95.70%_95.70%_95.70%_Average spike rate: 0.0 spikes per simulation time step.
#
# Batch 16 of 19 completed (84.2%)
# Moving accuracy of SNN (top-1, top-1): 93.70%, 94.79%.
# Moving accuracy of ANN (top-1, top-1): 97.66%, 99.98%.
#
#
# Starting new simulation...
#
# Current accuracy of batch:
#  92.97%0.00%_0.39%_27.73%_79.49%_91.21%_92.77%_92.77%_92.97%_92.97%_92.97%_92.97%_92.97%_92.97%_92.97%_92.97%_92.97%_92.97%_92.97%_92.97%_92.97%_92.97%_92.97%_92.97%_92.97%_92.97%_92.97%_92.97%_92.97%_92.97%_92.97%_Average spike rate: 0.0 spikes per simulation time step.
#
# Batch 17 of 19 completed (89.5%)
# Moving accuracy of SNN (top-1, top-1): 93.66%, 94.72%.
# Moving accuracy of ANN (top-1, top-1): 97.71%, 99.98%.
#
#
# Starting new simulation...
#
# Current accuracy of batch:
#  98.24%0.00%_0.78%_43.16%_88.48%_97.66%_98.24%_98.24%_98.24%_98.24%_98.24%_98.24%_98.24%_98.24%_98.24%_98.24%_98.24%_98.24%_98.24%_98.24%_98.24%_98.24%_98.24%_98.24%_98.24%_98.24%_98.24%_98.24%_98.24%_98.24%_98.24%_Average spike rate: 0.0 spikes per simulation time step.
#
# Batch 18 of 19 completed (94.7%)
# Moving accuracy of SNN (top-1, top-1): 93.91%, 94.91%.
# Moving accuracy of ANN (top-1, top-1): 97.80%, 99.98%.
#
#
# Starting new simulation...
#
# Current accuracy of batch:
#  97.07%0.00%_0.39%_31.25%_78.52%_93.16%_96.29%_96.68%_97.07%_97.07%_97.07%_97.07%_97.07%_97.07%_97.07%_97.07%_97.07%_97.07%_97.07%_97.07%_97.07%_97.07%_97.07%_97.07%_97.07%_97.07%_97.07%_97.07%_97.07%_97.07%_97.07%_Average spike rate: 0.0 spikes per simulation time step.
#
# Batch 19 of 19 completed (100.0%)
# Moving accuracy of SNN (top-1, top-1): 94.08%, 95.03%.
# Moving accuracy of ANN (top-1, top-1): 97.85%, 99.98%.
#
# Simulation finished.
#
#
# Total accuracy: 94.08% on 9728 test samples.
#
#
# Accuracy averaged by class size: 94.05%
