# %%
import os
import numpy as np
import tensorflow as tf
import keras
import nengo_dl
import random
from tensorflow.python.keras import Input, Model, Sequential
import nengo
from tensorflow.python.keras.callbacks import EarlyStopping
from tensorflow.python.keras.layers import Conv2D, Dropout, AveragePooling2D, Flatten, Dense, BatchNormalization, \
    Conv3D, LSTM
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split, KFold
from keras import backend as K

# %%
dataset_file = os.path.join('..', 'dataset_result', 'bci_dataset.npz')
dataset = np.load(dataset_file)

features, labels = dataset['features'], dataset['labels']
features = features.reshape((features.shape[0], 14, -1))

labels = labels.reshape((-1, 1))
labels = OneHotEncoder().fit_transform(labels).toarray()

# set seed to produce consistent result
seed = 2
np.random.seed(seed)
tf.random.set_seed(seed)

# %%
def lstm_model():
    model = Sequential([
        LSTM(124, input_shape=(features.shape[1:]), activation=tf.nn.relu, return_sequences=True),
        Dropout(0.4),
        BatchNormalization(),
        LSTM(124, activation=tf.nn.relu),
        Dropout(0.3),
        BatchNormalization(),
        Dense(64, activation=tf.nn.relu),
        Dropout(0.2),
        Dense(2, activation=tf.nn.softmax, name='output_layer')
    ])

    return model

# %%
def run_network(model, train, valid, test, iteration, epochs=30):
    x_train, y_train = train[0], train[1]
    x_val, y_val = valid[0], valid[1]
    x_test, y_test = test[0], test[1]

    model.compile(
        optimizer=tf.keras.optimizers.Adam(),
        loss=tf.losses.BinaryCrossentropy(),
        metrics=['accuracy']
    )

    model.fit(x_train, y_train, epochs=epochs, validation_data=(x_val, y_val),
              callbacks=[EarlyStopping(patience=8, verbose=1, restore_best_weights=True)]
              )
    eval = model.evaluate(x_test, y_test)
    print('{}. Accuracy: '.format(iteration), eval[1] * 100)
    return eval[1]

# %%
results = []

num_splits = 10
iteration = 1

x_train, x_test, y_train, y_test = train_test_split(features, labels, test_size=0.25)
for train_idx, val_idx in KFold(n_splits=num_splits).split(x_train):
    x_train_curr, y_train_curr = x_train[train_idx], y_train[train_idx]
    x_val, y_val = x_train[val_idx], y_train[val_idx]

    model = lstm_model()
    results.append(run_network(model, (x_train_curr, y_train_curr), (x_val, y_val), (x_test, y_test), iteration))
    K.clear_session()

    iteration += 1
# Out:
# Epoch 1/30
# 63/63 [==============================] - 13s 124ms/step - loss: 0.9451 - accuracy: 0.4778 - val_loss: 0.9269 - val_accuracy: 0.6027
# Epoch 2/30
# 63/63 [==============================] - 7s 118ms/step - loss: 0.8436 - accuracy: 0.5086 - val_loss: 0.8073 - val_accuracy: 0.4955
# Epoch 3/30
# 63/63 [==============================] - 8s 120ms/step - loss: 0.7768 - accuracy: 0.4969 - val_loss: 0.7553 - val_accuracy: 0.5089
# Epoch 4/30
# 63/63 [==============================] - 8s 125ms/step - loss: 0.7545 - accuracy: 0.5337 - val_loss: 0.6814 - val_accuracy: 0.5357
# Epoch 5/30
# 63/63 [==============================] - 7s 118ms/step - loss: 0.7322 - accuracy: 0.5372 - val_loss: 0.7292 - val_accuracy: 0.4911
# Epoch 6/30
# 63/63 [==============================] - 8s 122ms/step - loss: 0.7150 - accuracy: 0.5391 - val_loss: 0.6917 - val_accuracy: 0.5312
# Epoch 7/30
# 63/63 [==============================] - 8s 125ms/step - loss: 0.6870 - accuracy: 0.5690 - val_loss: 0.8539 - val_accuracy: 0.4911
# Epoch 8/30
# 63/63 [==============================] - 8s 120ms/step - loss: 0.7068 - accuracy: 0.5556 - val_loss: 0.7002 - val_accuracy: 0.5357
# Epoch 9/30
# 63/63 [==============================] - 8s 125ms/step - loss: 0.
30
# 63/63 [==============================] - 8s 127ms/step - loss: 0.7377 - accuracy: 0.5142 - val_loss: 0.7332 - val_accuracy: 0.4529
# Epoch 7/30
# 63/63 [==============================] - 8s 133ms/step - loss: 0.7192 - accuracy: 0.5207 - val_loss: 0.6935 - val_accuracy: 0.4574
# Epoch 8/30
# 63/63 [==============================] - 8s 130ms/step - loss: 0.7345 - accuracy: 0.4913 - val_loss: 0.6898 - val_accuracy: 0.5112
# Epoch 9/30
# 63/63 [==============================] - 8s 131ms/step - loss: 0.7154 - accuracy: 0.4974 - val_loss: 0.7087 - val_accuracy: 0.4619
# Epoch 10/30
# 63/63 [==============================] - 8s 131ms/step - loss: 0.6988 - accuracy: 0.5227 - val_loss: 0.7102 - val_accuracy: 0.4215
# Epoch 11/30
# 63/63 [==============================] - 8s 125ms/step - loss: 0.7004 - accuracy: 0.5164 - val_loss: 0.7116 - val_accuracy: 0.4350
# Epoch 12/30
# 63/63 [==============================] - 8s 128ms/step - loss: 0.7065 - accuracy: 0.5055 - val_loss: 0.7117 - val_accuracy: 0.4395
# Epoch 13/30
# 63/63 [==============================] - 8s 125ms/step - loss: 0.6966 - accuracy: 0.5409 - val_loss: 0.7111 - val_accuracy: 0.4081
# Epoch 14/30
# 63/63 [==============================] - 8s 126ms/step - loss: 0.6861 - accuracy: 0.5532 - val_loss: 0.7190 - val_accuracy: 0.4305
# Epoch 15/30
# 63/63 [==============================] - 8s 129ms/step - loss: 0.6814 - accuracy: 0.5596 - val_loss: 0.7225 - val_accuracy: 0.4350
# Epoch 16/30
# 63/63 [==============================] - 8s 132ms/step - loss: 0.6755 - accuracy: 0.5565 - val_loss: 0.7196 - val_accuracy: 0.4215
# Restoring model weights from the end of the best epoch.
# Epoch 00016: early stopping
# 24/24 [==============================] - 0s 15ms/step - loss: 0.6974 - accuracy: 0.5000
# 8. Accuracy:  50.0
# Epoch 1/30
# 63/63 [==============================] - 14s 135ms/step - loss: 0.8936 - accuracy: 0.5032 - val_loss: 1.0006 - val_accuracy: 0.4843
# Epoch 2/30
# 63/63 [==============================] - 8s 128ms/step - loss: 0.7874 - accuracy: 0.5074 - val_loss: 0.8069 - val_accuracy: 0.4798
# Epoch 3/30
# 63/63 [==============================] - 8s 124ms/step - loss: 0.7410 - accuracy: 0.5043 - val_loss: 0.8491 - val_accuracy: 0.5112
# Epoch 4/30
# 63/63 [==============================] - 8s 122ms/step - loss: 0.7108 - accuracy: 0.5501 - val_loss: 0.6929 - val_accuracy: 0.5157
# Epoch 5/30
# 63/63 [==============================] - 8s 128ms/step - loss: 0.7125 - accuracy: 0.5657 - val_loss: 0.7045 - val_accuracy: 0.5022
# Epoch 6/30
# 63/63 [==============================] - 8s 129ms/step - loss: 0.7001 - accuracy: 0.5520 - val_loss: 0.7220 - val_accuracy: 0.5112
# Epoch 7/30
# 63/63 [==============================] - 8s 132ms/step - loss: 0.7011 - accuracy: 0.5404 - val_loss: 0.7337 - val_accuracy: 0.5067
# Epoch 8/30
# 63/63 [==============================] - 8s 126ms/step - loss: 0.6937 - accuracy: 0.5436 - val_loss: 0.7193 - val_accuracy: 0.5112
# Epoch 9/30
# 63/63 [==============================] - 8s 130ms/step - loss: 0.6766 - accuracy: 0.5753 - val_loss: 0.7320 - val_accuracy: 0.5336
# Epoch 10/30
# 63/63 [==============================] - 8s 132ms/step - loss: 0.6202 - accuracy: 0.6399 - val_loss: 0.7630 - val_accuracy: 0.5022
# Epoch 11/30
# 63/63 [==============================] - 8s 127ms/step - loss: 0.5781 - accuracy: 0.6751 - val_loss: 0.8114 - val_accuracy: 0.5381
# Epoch 12/30
# 63/63 [==============================] - 8s 127ms/step - loss: 0.5461 - accuracy: 0.7002 - val_loss: 0.8257 - val_accuracy: 0.4888
# Restoring model weights from the end of the best epoch.
# Epoch 00012: early stopping
# 24/24 [==============================] - 0s 14ms/step - loss: 0.6991 - accuracy: 0.5349
# 9. Accuracy:  53.49462628364563
# Epoch 1/30
# 63/63 [==============================] - 13s 135ms/step - loss: 0.8857 - accuracy: 0.5061 - val_loss: 0.8398 - val_accuracy: 0.5291
# Epoch 2/30
# 63/63 [==============================] - 8s 127ms/step - loss: 0.7891 - accuracy: 0.5098 - val_loss: 0.7427 - val_accuracy: 0.5247
# Epoch 3/30
# 63/63 [==============================] - 9s 141ms/step - loss: 0.7541 - accuracy: 0.5151 - val_loss: 0.7450 - val_accuracy: 0.4888
# Epoch 4/30
# 63/63 [==============================] - 9s 138ms/step - loss: 0.7307 - accuracy: 0.5294 - val_loss: 0.7167 - val_accuracy: 0.5247
# Epoch 5/30
# 63/63 [==============================] - 8s 133ms/step - loss: 0.7143 - accuracy: 0.5384 - val_loss: 0.7175 - val_accuracy: 0.5202
# Epoch 6/30
# 63/63 [==============================] - 8s 126ms/step - loss: 0.7383 - accuracy: 0.5294 - val_loss: 0.7521 - val_accuracy: 0.4888
# Epoch 7/30
# 63/63 [==============================] - 8s 124ms/step - loss: 0.7076 - accuracy: 0.5641 - val_loss: 0.7345 - val_accuracy: 0.5605
# Epoch 8/30
# 63/63 [==============================] - 8s 130ms/step - loss: 0.7183 - accuracy: 0.5126 - val_loss: 0.7080 - val_accuracy: 0.4709
# Epoch 9/30
# 63/63 [==============================] - 8s 134ms/step - loss: 0.7004 - accuracy: 0.5656 - val_loss: 0.7401 - val_accuracy: 0.4843
# Epoch 10/30
# 63/63 [==============================] - 8s 133ms/step - loss: 0.6799 - accuracy: 0.5779 - val_loss: 0.7126 - val_accuracy: 0.5291
# Epoch 11/30
# 63/63 [==============================] - 8s 127ms/step - loss: 0.6958 - accuracy: 0.5417 - val_loss: 0.6852 - val_accuracy: 0.5740
# Epoch 12/30
# 63/63 [==============================] - 9s 135ms/step - loss: 0.6864 - accuracy: 0.5587 - val_loss: 0.7058 - val_accuracy: 0.5067
# Epoch 13/30
# 63/63 [==============================] - 8s 127ms/step - loss: 0.6684 - accuracy: 0.5910 - val_loss: 0.7085 - val_accuracy: 0.4843
# Epoch 14/30
# 63/63 [==============================] - 8s 132ms/step - loss: 0.6625 - accuracy: 0.5856 - val_loss: 0.7012 - val_accuracy: 0.5067
# Epoch 15/30
# 63/63 [==============================] - 9s 139ms/step - loss: 0.6336 - accuracy: 0.6327 - val_loss: 0.7422 - val_accuracy: 0.5022
# Epoch 16/30
# 63/63 [==============================] - 8s 131ms/step - loss: 0.6205 - accuracy: 0.6412 - val_loss: 0.6940 - val_accuracy: 0.5247
# Epoch 17/30
# 63/63 [==============================] - 8s 131ms/step - loss: 0.5595 - accuracy: 0.6890 - val_loss: 0.7612 - val_accuracy: 0.5426
# Epoch 18/30
# 63/63 [==============================] - 8s 133ms/step - loss: 0.5443 - accuracy: 0.6969 - val_loss: 0.7768 - val_accuracy: 0.5157
# Epoch 19/30
# 63/63 [==============================] - 8s 131ms/step - loss: 0.4975 - accuracy: 0.7354 - val_loss: 0.8059 - val_accuracy: 0.5202
# Restoring model weights from the end of the best epoch.
# Epoch 00019: early stopping
# 24/24 [==============================] - 0s 14ms/step - loss: 0.7065 - accuracy: 0.4866
# 10. Accuracy:  48.65591526031494

# %%
print('RESULTS:')
for result in results:
    print(result)

print('Average:', np.average(results))
print('Max:', max(results))
# Out:
# RESULTS:
# 0.47983869910240173
# 0.4973118305206299
# 0.5255376100540161
# 0.4973118305206299
# 0.46639785170555115
# 0.5013440847396851
# 0.48521506786346436
# 0.5
# 0.5349462628364563
# 0.4865591526031494
# Average: 0.4974462389945984
# Max: 0.5349462628364563
