# %%
import os
import nengo
import numpy as np
import tensorflow as tf
import keras
import nengo_dl
from tensorflow.python.keras import Input, Model
from tensorflow.python.keras.callbacks import EarlyStopping
from tensorflow.python.keras.layers import Conv2D, Dropout, AveragePooling2D, Flatten, Dense
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split, KFold
from keras import backend as K

# %%
# Dataset path is by default saved in dataset_result/bci_dataset.npz
dataset_path = os.path.join('..', 'dataset_result', 'men_only.npz')

# Load the numpy file containing the dataset
dataset = np.load(dataset_path)
features, labels = dataset['features'], dataset['labels'] # get features and labels

print('Features shape:', features.shape)
print('Labels shape:', labels.shape)
# Out:
# Features shape: (1296, 14, 36, 10)
# Labels shape: (1296,)

# %%
# Set seed for consistency
seed = 23
np.random.seed(seed)
tf.random.set_seed(seed)

# %%
# Convert labels to one hot encoding
cat = OneHotEncoder()
labels = labels.reshape(-1, 1)
labels = cat.fit_transform(labels).toarray()
labels = labels.reshape((labels.shape[0], 1, -1))
print(labels)
print('Labels shape:', labels.shape)

# Reshape features for the NN
features = features.reshape((features.shape[0], 1, -1))
print('Features shape:', features.shape)
# Out:
# [[[0. 1.]]
#
#  [[0. 1.]]
#
#  [[0. 1.]]
#
#  ...
#
#  [[1. 0.]]
#
#  [[1. 0.]]
#
#  [[1. 0.]]]
# Labels shape: (1296, 1, 2)
# Features shape: (1296, 1, 5040)

# %%
def cnn_model():
    inp = Input(shape=(14, 36, 10), name='input_layer')
    conv1 = Conv2D(filters=32, kernel_size=(5, 5), activation=tf.nn.relu, padding='same')(inp)
    dropout1 = Dropout(0.2, seed=seed)(conv1)
    avg_pool1 = AveragePooling2D(pool_size=(2, 2))(dropout1)
    conv2 = Conv2D(filters=64, kernel_size=(3, 3), activation=tf.nn.relu)(avg_pool1)
    dropout2 = Dropout(0.2, seed=seed)(conv2)
    avg_pool2 = AveragePooling2D(pool_size=(2, 2))(dropout2)
    flatten = Flatten()(avg_pool2)
    dense1 = Dense(512, activation=tf.nn.relu)(flatten)
    dropout3 = Dropout(0.2, seed=seed)(dense1)
    dense2 = Dense(256, activation=tf.nn.relu)(dropout3)
    output = Dense(2, activation=tf.nn.softmax, name='output_layer')(dense2)

    return Model(inputs=inp, outputs=output)

# %%
def run_ann(model, train, valid, test, params_save_path, iteration, shuffle_training=True, num_epochs=5):
    x_train, y_train = train[0], train[1]
    x_valid, y_valid = valid[0], valid[1]
    x_test, y_test = test[0], test[1]

    converter = nengo_dl.Converter(model)

    with nengo_dl.Simulator(converter.net, minibatch_size=16) as simulator:
        simulator.compile(optimizer=keras.optimizers.Adam(),
                          loss=keras.losses.BinaryCrossentropy(),
                          metrics=['accuracy'])

        input_layer = converter.inputs[model.get_layer('input_layer')]
        output_layer = converter.outputs[model.get_layer('output_layer')]

        hist = simulator.fit(
            x={ input_layer: x_train }, y={ output_layer: y_train },
            validation_data=(
                { input_layer: x_valid }, { output_layer: y_valid }
            ),
            epochs=num_epochs,
            shuffle=shuffle_training,
            callbacks=[EarlyStopping(patience=8, verbose=1, restore_best_weights=True)] # early stop to avoid overfitting
        )
        print(hist.history)

        simulator.save_params(params_save_path)
        ann_eval = simulator.evaluate(x={ input_layer: x_test }, y={ output_layer: y_test }) # evaluate accuracy
        print('{}. ann accuracy: {:5f}%'.format(iteration, ann_eval['probe_accuracy'] * 100)) # log accuracy
        return ann_eval['probe_accuracy'] # return accuracy


def run_snn(model, x_test, y_test, params_load_path, iteration, timesteps=50, scale_firing_rates=1000, synapse=0.01):
    converter = nengo_dl.Converter(
        model,
        swap_activations={ tf.nn.relu: nengo.SpikingRectifiedLinear() },
        scale_firing_rates=scale_firing_rates,
        synapse=synapse
    ) # create a Nengo converter object and swap all relu activations with spiking relu

    with converter.net:
        nengo_dl.configure_settings(stateful=False)

    input_layer = converter.inputs[model.get_layer('input_layer')] # input layer for simulator
    output_layer = converter.outputs[model.get_layer('output_layer')] # output layer for simulator

    x_test_tiled = np.tile(x_test, (1, timesteps, 1)) # tile test data to timesteps

    with nengo_dl.Simulator(converter.net) as simulator:
        simulator.load_params(params_load_path)

        predictions = simulator.predict({ input_layer: x_test_tiled })[output_layer] # get results from prediction
        predictions = predictions[:,-1,:] # get last time step

        predictions = np.argmax(predictions, axis=-1) # get argmax
        y_test = np.squeeze(y_test, axis=1) # remove time dimension from labels since its not relevant
        y_test = np.argmax(y_test, axis=-1) # get argmax of y test as well for comparison

        snn_acc = (predictions == y_test).mean()

    print('{}. SNN accuracy: {:5f}%'.format(
            iteration, snn_acc * 100
        ))

    return snn_acc

# %%
x_train, x_test, y_train, y_test = train_test_split(features, labels, test_size=0.25, random_state=seed, shuffle=True)
print('x_train shape: {}, y_train shape: {}'.format(x_train.shape, y_train.shape))
print('x_test shape: {}, y_test shape: {}'.format(x_test.shape, y_test.shape))


# Create directory for ANN parameters used to construct the spiking network for Nengo
os.makedirs('nengo_params', exist_ok=True)
ann, snn = [], []

num_iterations = 10 # Number of cross validation iterations
iteration = 1 # Current iteration

for train, valid in KFold(n_splits=num_iterations).split(x_train):
    print('Current iteration: ', iteration)
    x_train_curr, y_train_curr = x_train[train], y_train[train]
    x_valid_curr, y_valid_curr = x_train[valid], y_train[valid]

    params_path = os.path.join('nengo_params', 'params_{}'.format(iteration))
    model = cnn_model()

    # run ann
    ann_result = run_ann(model=model,
                         train=(x_train_curr, y_train_curr),
                         valid=(x_valid_curr, y_valid_curr),
                         test=(x_test, y_test),
                         params_save_path=params_path,
                         iteration=iteration,
                         num_epochs=30
                         )

    # run snn
    snn_result = run_snn(model=model,
                         x_test=x_test,
                         y_test=y_test,
                         params_load_path=params_path,
                         iteration=iteration)

    ann.append(ann_result)
    snn.append(snn_result)
    iteration += 1

    K.clear_session()
    del model
# Out:
# x_train shape: (972, 1, 5040), y_train shape: (972, 1, 2)
# x_test shape: (324, 1, 5040), y_test shape: (324, 1, 2)
# Current iteration:  1
# Build finished in 0:00:00
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Epoch 1/30
# 54/54 [==============================] - 7s 42ms/step - loss: 0.9211 - probe_loss: 0.9211 - probe_accuracy: 0.4904 - val_loss: 0.6994 - val_probe_loss: 0.6994 - val_probe_accuracy: 0.5000
# Epoch 2/30
# 54/54 [==============================] - 1s 11ms/step - loss: 0.6858 - probe_loss: 0.6858 - probe_accuracy: 0.5674 - val_loss: 0.6969 - val_probe_loss: 0.6969 - val_probe_accuracy: 0.5000
# Epoch 3/30
# 54/54 [==============================] - 1s 12ms/step - loss: 0.6910 - probe_loss: 0.6910 - probe_accuracy: 0.5392 - val_loss: 0.6984 - val_probe_loss: 0.6984 - val_probe_accuracy: 0.5208
# Epoch 4/30
# 54/54 [==============================] - 1s 11ms/step - loss: 0.
30
# 54/54 [==============================] - 1s 12ms/step - loss: 0.6464 - probe_loss: 0.6464 - probe_accuracy: 0.6108 - val_loss: 0.8335 - val_probe_loss: 0.8335 - val_probe_accuracy: 0.5208
# Restoring model weights from the end of the best epoch.
# Epoch 00010: early stopping
# {'loss': [0.7594358921051025, 0.6959195137023926, 0.6897485256195068, 0.6866943836212158, 0.6923050880432129, 0.6834937930107117, 0.6767051219940186, 0.6674311757087708, 0.6676598787307739, 0.6460562348365784], 'probe_loss': [0.7594358921051025, 0.6959195137023926, 0.6897485256195068, 0.6866943836212158, 0.6923050880432129, 0.6834937930107117, 0.6767051219940186, 0.6674311757087708, 0.6676598787307739, 0.6460562348365784], 'probe_accuracy': [0.5023148059844971, 0.5462962985038757, 0.5289351940155029, 0.5416666865348816, 0.5393518805503845, 0.5520833134651184, 0.5868055820465088, 0.6006944179534912, 0.5983796119689941, 0.6122685074806213], 'val_loss': [0.6894362568855286, 0.6664758324623108, 0.7077104449272156, 0.7259392738342285, 0.7021205425262451, 0.6780723929405212, 0.7398284077644348, 0.7981436848640442, 0.7124126553535461, 0.8334730267524719], 'val_probe_loss': [0.6894362568855286, 0.6664758324623108, 0.7077104449272156, 0.7259392738342285, 0.7021205425262451, 0.6780723929405212, 0.7398284077644348, 0.7981436848640442, 0.7124126553535461, 0.8334730267524719], 'val_probe_accuracy': [0.5833333134651184, 0.6666666865348816, 0.40625, 0.4166666567325592, 0.5520833134651184, 0.6145833134651184, 0.5520833134651184, 0.4895833432674408, 0.5, 0.5208333134651184]}
# 20/20 [==============================] - 0s 5ms/step - loss: 0.7089 - probe_loss: 0.7089 - probe_accuracy: 0.4750
# 4. ann accuracy: 47.499999%
# Build finished in 0:00:00
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# 4. SNN accuracy: 48.456790%tage finished in 0:00:00
# Current iteration:  5
# Build finished in 0:00:00
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Epoch 1/30
# 54/54 [==============================] - 5s 26ms/step - loss: 1.2263 - probe_loss: 1.2263 - probe_accuracy: 0.5144 - val_loss: 0.6813 - val_probe_loss: 0.6813 - val_probe_accuracy: 0.5729
# Epoch 2/30
# 54/54 [==============================] - 1s 11ms/step - loss: 0.6942 - probe_loss: 0.6942 - probe_accuracy: 0.5256 - val_loss: 0.6880 - val_probe_loss: 0.6880 - val_probe_accuracy: 0.5729
# Epoch 3/30
# 54/54 [==============================] - 1s 12ms/step - loss: 0.6868 - probe_loss: 0.6868 - probe_accuracy: 0.5501 - val_loss: 0.6786 - val_probe_loss: 0.6786 - val_probe_accuracy: 0.6250
# Epoch 4/30
# 54/54 [==============================] - 1s 11ms/step - loss: 0.6989 - probe_loss: 0.6989 - probe_accuracy: 0.5218 - val_loss: 0.6973 - val_probe_loss: 0.6973 - val_probe_accuracy: 0.4792
# Epoch 5/30
# 54/54 [==============================] - 1s 11ms/step - loss: 0.6882 - probe_loss: 0.6882 - probe_accuracy: 0.5736 - val_loss: 0.6871 - val_probe_loss: 0.6871 - val_probe_accuracy: 0.5000
# Epoch 6/30
# 54/54 [==============================] - 1s 12ms/step - loss: 0.6824 - probe_loss: 0.6824 - probe_accuracy: 0.5791 - val_loss: 0.6717 - val_probe_loss: 0.6717 - val_probe_accuracy: 0.5938
# Epoch 7/30
# 54/54 [==============================] - 1s 11ms/step - loss: 0.6922 - probe_loss: 0.6922 - probe_accuracy: 0.5227 - val_loss: 0.6709 - val_probe_loss: 0.6709 - val_probe_accuracy: 0.5000
# Epoch 8/30
# 54/54 [==============================] - 1s 11ms/step - loss: 0.6735 - probe_loss: 0.6735 - probe_accuracy: 0.5747 - val_loss: 0.7036 - val_probe_loss: 0.7036 - val_probe_accuracy: 0.4688
# Epoch 9/30
# 54/54 [==============================] - 1s 12ms/step - loss: 0.6618 - probe_loss: 0.6618 - probe_accuracy: 0.6240 - val_loss: 0.6988 - val_probe_loss: 0.6988 - val_probe_accuracy: 0.5417
# Epoch 10/30
# 54/54 [==============================] - 1s 11ms/step - loss: 0.
# Build finished in 0:00:00
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Epoch 1/30
# 54/54 [==============================] - 5s 26ms/step - loss: 1.1908 - probe_loss: 1.1908 - probe_accuracy: 0.4959 - val_loss: 0.6952 - val_probe_loss: 0.6952 - val_probe_accuracy: 0.4167
# Epoch 2/30
# 54/54 [==============================] - 1s 11ms/step - loss: 0.7000 - probe_loss: 0.7000 - probe_accuracy: 0.5272 - val_loss: 0.7166 - val_probe_loss: 0.7166 - val_probe_accuracy: 0.4167
# Epoch 3/30
# 54/54 [==============================] - 1s 11ms/step - loss: 0.6816 - probe_loss: 0.6816 - probe_accuracy: 0.5389 - val_loss: 0.7094 - val_probe_loss: 0.7094 - val_probe_accuracy: 0.4167
# Epoch 4/30
# 54/54 [==============================] - 1s 12ms/step - loss: 0.6867 - probe_loss: 0.6867 - probe_accuracy: 0.5509 - val_loss: 0.6961 - val_probe_loss: 0.6961 - val_probe_accuracy: 0.4479
# Epoch 5/30
# 54/54 [==============================] - 1s 11ms/step - loss: 0.6915 - probe_loss: 0.6915 - probe_accuracy: 0.5280 - val_loss: 0.6878 - val_probe_loss: 0.6878 - val_probe_accuracy: 0.5729
# Epoch 6/30
# 54/54 [==============================] - 1s 12ms/step - loss: 0.6882 - probe_loss: 0.6882 - probe_accuracy: 0.5480 - val_loss: 0.7077 - val_probe_loss: 0.7077 - val_probe_accuracy: 0.4271
# Epoch 7/30
# 54/54 [==============================] - 1s 11ms/step - loss: 0.6769 - probe_loss: 0.6769 - probe_accuracy: 0.5718 - val_loss: 0.7119 - val_probe_loss: 0.7119 - val_probe_accuracy: 0.4583
# Epoch 8/30
# 54/54 [==============================] - 1s 11ms/step - loss: 0.6814 - probe_loss: 0.6814 - probe_accuracy: 0.5535 - val_loss: 0.6891 - val_probe_loss: 0.6891 - val_probe_accuracy: 0.4792
# Epoch 9/30
# 54/54 [==============================] - 1s 11ms/step - loss: 0.6834 - probe_loss: 0.6834 - probe_accuracy: 0.5580 - val_loss: 0.7098 - val_probe_loss: 0.7098 - val_probe_accuracy: 0.4375
# Epoch 10/30
# 54/54 [==============================] - 1s 11ms/step - loss: 0.6771 - probe_loss: 0.6771 - probe_accuracy: 0.5676 - val_loss: 0.6992 - val_probe_loss: 0.6992 - val_probe_accuracy: 0.5312
# Epoch 11/30
# 54/54 [==============================] - 1s 11ms/step - loss: 0.6643 - probe_loss: 0.6643 - probe_accuracy: 0.6087 - val_loss: 0.7274 - val_probe_loss: 0.7274 - val_probe_accuracy: 0.5312
# Epoch 12/30
# 54/54 [==============================] - 1s 12ms/step - loss: 0.6749 - probe_loss: 0.6749 - probe_accuracy: 0.6117 - val_loss: 0.7164 - val_probe_loss: 0.7164 - val_probe_accuracy: 0.4583
# Epoch 13/30
# 54/54 [==============================] - 1s 11ms/step - loss: 0.6558 - probe_loss: 0.6558 - probe_accuracy: 0.6225 - val_loss: 0.7109 - val_probe_loss: 0.7109 - val_probe_accuracy: 0.5417
# Restoring model weights from the end of the best epoch.
# Epoch 00013: early stopping
# {'loss': [0.887035071849823, 0.6926528811454773, 0.6873161196708679, 0.6885131001472473, 0.6903555989265442, 0.6877758502960205, 0.6808615326881409, 0.690863311290741, 0.6823357343673706, 0.681637167930603, 0.6655382513999939, 0.6825047135353088, 0.6607562899589539], 'probe_loss': [0.887035071849823, 0.6926528811454773, 0.6873161196708679, 0.6885131001472473, 0.6903555989265442, 0.6877758502960205, 0.6808615326881409, 0.690863311290741, 0.6823357343673706, 0.681637167930603, 0.6655382513999939, 0.6825047135353088, 0.6607562899589539], 'probe_accuracy': [0.5046296119689941, 0.5347222089767456, 0.5520833134651184, 0.5486111044883728, 0.5347222089767456, 0.5428240895271301, 0.5462962985038757, 0.5416666865348816, 0.5717592835426331, 0.5648148059844971, 0.6053240895271301, 0.5972222089767456, 0.6192129850387573], 'val_loss': [0.695152223110199, 0.7165501117706299, 0.7093620896339417, 0.6960732340812683, 0.6878154873847961, 0.7076948285102844, 0.7118621468544006, 0.6890876293182373, 0.7097539305686951, 0.6992089152336121, 0.7273941040039062, 0.7164202332496643, 0.7109358310699463], 'val_probe_loss': [0.695152223110199, 0.7165501117706299, 0.7093620896339417, 0.6960732340812683, 0.6878154873847961, 0.7076948285102844, 0.7118621468544006, 0.6890876293182373, 0.7097539305686951, 0.6992089152336121, 0.7273941040039062, 0.7164202332496643, 0.7109358310699463], 'val_probe_accuracy': [0.4166666567325592, 0.4166666567325592, 0.4166666567325592, 0.4479166567325592, 0.5729166865348816, 0.4270833432674408, 0.4583333432674408, 0.4791666567325592, 0.4375, 0.53125, 0.53125, 0.4583333432674408, 0.5416666865348816]}
# 20/20 [==============================] - 0s 5ms/step - loss: 0.6941 - probe_loss: 0.6941 - probe_accuracy: 0.5406
# 6. ann accuracy: 54.062498%
# Build finished in 0:00:00
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# 6. SNN accuracy: 54.012346%tage finished in 0:00:00
# Current iteration:  7
# Build finished in 0:00:00
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Epoch 1/30
# 54/54 [==============================] - 5s 27ms/step - loss: 0.9386 - probe_loss: 0.9386 - probe_accuracy: 0.5242 - val_loss: 0.6913 - val_probe_loss: 0.6913 - val_probe_accuracy: 0.5521
# Epoch 2/30
# 54/54 [==============================] - 1s 12ms/step - loss: 0.6913 - probe_loss: 0.6913 - probe_accuracy: 0.5203 - val_loss: 0.7047 - val_probe_loss: 0.7047 - val_probe_accuracy: 0.5521
# Epoch 3/30
# 54/54 [==============================] - 1s 11ms/step - loss: 0.6944 - probe_loss: 0.6944 - probe_accuracy: 0.5521 - val_loss: 0.6883 - val_probe_loss: 0.6883 - val_probe_accuracy: 0.5729
# Epoch 4/30
# 54/54 [==============================] - 1s 11ms/step - loss: 0.6949 - probe_loss: 0.6949 - probe_accuracy: 0.5487 - val_loss: 0.7065 - val_probe_loss: 0.7065 - val_probe_accuracy: 0.5208
# Epoch 5/30
# 54/54 [==============================] - 1s 11ms/step - loss: 0.6884 - probe_loss: 0.6884 - probe_accuracy: 0.5429 - val_loss: 0.7016 - val_probe_loss: 0.7016 - val_probe_accuracy: 0.4688
# Epoch 6/30
# 54/54 [==============================] - 1s 11ms/step - loss: 0.6836 - probe_loss: 0.6836 - probe_accuracy: 0.5505 - val_loss: 0.7016 - val_probe_loss: 0.7016 - val_probe_accuracy: 0.5521
# Epoch 7/30
# 54/54 [==============================] - 1s 12ms/step - loss: 0.6802 - probe_loss: 0.6802 - probe_accuracy: 0.5721 - val_loss: 0.6881 - val_probe_loss: 0.6881 - val_probe_accuracy: 0.5833
# Epoch 8/30
# 54/54 [==============================] - 1s 11ms/step - loss: 0.6738 - probe_loss: 0.6738 - probe_accuracy: 0.5977 - val_loss: 0.7064 - val_probe_loss: 0.7064 - val_probe_accuracy: 0.5208
# Epoch 9/30
# 54/54 [==============================] - 1s 11ms/step - loss: 0.6607 - probe_loss: 0.6607 - probe_accuracy: 0.5969 - val_loss: 0.7013 - val_probe_loss: 0.7013 - val_probe_accuracy: 0.4896
# Epoch 10/30
# 54/54 [==============================] - 1s 11ms/step - loss: 0.6703 - probe_loss: 0.6703 - probe_accuracy: 0.5853 - val_loss: 0.7037 - val_probe_loss: 0.7037 - val_probe_accuracy: 0.5000
# Epoch 11/30
# 54/54 [==============================] - 1s 11ms/step - loss: 0.6663 - probe_loss: 0.6663 - probe_accuracy: 0.6135 - val_loss: 0.7202 - val_probe_loss: 0.7202 - val_probe_accuracy: 0.4479
# Epoch 12/30
# 54/54 [==============================] - 1s 11ms/step - loss: 0.6563 - probe_loss: 0.6563 - probe_accuracy: 0.6471 - val_loss: 0.7818 - val_probe_loss: 0.7818 - val_probe_accuracy: 0.4167
# Epoch 13/30
# 54/54 [==============================] - 1s 11ms/step - loss: 0.6456 - probe_loss: 0.6456 - probe_accuracy: 0.6193 - val_loss: 0.7252 - val_probe_loss: 0.7252 - val_probe_accuracy: 0.4375
# Epoch 14/30
# 54/54 [==============================] - 1s 11ms/step - loss: 0.
}
# 20/20 [==============================] - 0s 5ms/step - loss: 0.7007 - probe_loss: 0.7007 - probe_accuracy: 0.4844
# 8. ann accuracy: 48.437500%
# Build finished in 0:00:00
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# 8. SNN accuracy: 52.160494%tage finished in 0:00:00
# Current iteration:  9
# Build finished in 0:00:00
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Epoch 1/30
# 54/54 [==============================] - 5s 25ms/step - loss: 1.0588 - probe_loss: 1.0588 - probe_accuracy: 0.4697 - val_loss: 0.6977 - val_probe_loss: 0.6977 - val_probe_accuracy: 0.4896
# Epoch 2/30
# 54/54 [==============================] - 1s 11ms/step - loss: 0.6948 - probe_loss: 0.6948 - probe_accuracy: 0.5324 - val_loss: 0.7173 - val_probe_loss: 0.7173 - val_probe_accuracy: 0.5000
# Epoch 3/30
# 54/54 [==============================] - 1s 11ms/step - loss: 0.6891 - probe_loss: 0.6891 - probe_accuracy: 0.5349 - val_loss: 0.7293 - val_probe_loss: 0.7293 - val_probe_accuracy: 0.4792
# Epoch 4/30
# 54/54 [==============================] - 1s 11ms/step - loss: 0.6939 - probe_loss: 0.6939 - probe_accuracy: 0.5457 - val_loss: 0.6977 - val_probe_loss: 0.6977 - val_probe_accuracy: 0.5208
# Epoch 5/30
# 54/54 [==============================] - 1s 11ms/step - loss: 0.6950 - probe_loss: 0.6950 - probe_accuracy: 0.5519 - val_loss: 0.7452 - val_probe_loss: 0.7452 - val_probe_accuracy: 0.4688
# Epoch 6/30
# 54/54 [==============================] - 1s 11ms/step - loss: 0.6945 - probe_loss: 0.6945 - probe_accuracy: 0.5443 - val_loss: 0.7032 - val_probe_loss: 0.7032 - val_probe_accuracy: 0.4896
# Epoch 7/30
# 54/54 [==============================] - 1s 11ms/step - loss: 0.6820 - probe_loss: 0.6820 - probe_accuracy: 0.5764 - val_loss: 0.7207 - val_probe_loss: 0.7207 - val_probe_accuracy: 0.5000
# Epoch 8/30
# 54/54 [==============================] - 1s 11ms/step - loss: 0.6964 - probe_loss: 0.6964 - probe_accuracy: 0.5734 - val_loss: 0.7068 - val_probe_loss: 0.7068 - val_probe_accuracy: 0.4479
# Epoch 9/30
# 54/54 [==============================] - 1s 11ms/step - loss: 0.6697 - probe_loss: 0.6697 - probe_accuracy: 0.5632 - val_loss: 0.7257 - val_probe_loss: 0.7257 - val_probe_accuracy: 0.4479
# Epoch 10/30
# 54/54 [==============================] - 1s 11ms/step - loss: 0.6517 - probe_loss: 0.6517 - probe_accuracy: 0.6048 - val_loss: 0.7043 - val_probe_loss: 0.7043 - val_probe_accuracy: 0.4688
# Epoch 11/30
# 54/54 [==============================] - 1s 12ms/step - loss: 0.6592 - probe_loss: 0.6592 - probe_accuracy: 0.6039 - val_loss: 0.9012 - val_probe_loss: 0.9012 - val_probe_accuracy: 0.4583
# Epoch 12/30
# 54/54 [==============================] - 1s 12ms/step - loss: 0.6582 - probe_loss: 0.6582 - probe_accuracy: 0.6455 - val_loss: 0.8121 - val_probe_loss: 0.8121 - val_probe_accuracy: 0.4583
# Restoring model weights from the end of the best epoch.
# Epoch 00012: early stopping
# {'loss': [0.8037903308868408, 0.6932485103607178, 0.6998211741447449, 0.6942115426063538, 0.700774610042572, 0.6949507594108582, 0.6866607666015625, 0.6959271430969238, 0.6766669750213623, 0.6634113192558289, 0.6541151404380798, 0.6517164707183838], 'probe_loss': [0.8037903308868408, 0.6932485103607178, 0.6998211741447449, 0.6942115426063538, 0.700774610042572, 0.6949507594108582, 0.6866607666015625, 0.6959271430969238, 0.6766669750213623, 0.6634113192558289, 0.6541151404380798, 0.6517164707183838], 'probe_accuracy': [0.49537035822868347, 0.5324074029922485, 0.5462962985038757, 0.5509259104728699, 0.5462962985038757, 0.5509259104728699, 0.5555555820465088, 0.5798611044883728, 0.5798611044883728, 0.5787037014961243, 0.6134259104728699, 0.6493055820465088], 'val_loss': [0.697722852230072, 0.7172830700874329, 0.729288637638092, 0.6976776123046875, 0.7451645731925964, 0.7032225131988525, 0.7207260727882385, 0.706829845905304, 0.7257491946220398, 0.7042520642280579, 0.9011767506599426, 0.8121370673179626], 'val_probe_loss': [0.697722852230072, 0.7172830700874329, 0.729288637638092, 0.6976776123046875, 0.7451645731925964, 0.7032225131988525, 0.7207260727882385, 0.706829845905304, 0.7257491946220398, 0.7042520642280579, 0.9011767506599426, 0.8121370673179626], 'val_probe_accuracy': [0.4895833432674408, 0.5, 0.4791666567325592, 0.5208333134651184, 0.46875, 0.4895833432674408, 0.5, 0.4479166567325592, 0.4479166567325592, 0.46875, 0.4583333432674408, 0.4583333432674408]}
# 20/20 [==============================] - 0s 5ms/step - loss: 0.7002 - probe_loss: 0.7002 - probe_accuracy: 0.4594
# 9. ann accuracy: 45.937499%
# Build finished in 0:00:00
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# 9. SNN accuracy: 48.765432%tage finished in 0:00:00
# Current iteration:  10
# Build finished in 0:00:00
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Epoch 1/30
# 54/54 [==============================] - 5s 25ms/step - loss: 0.9679 - probe_loss: 0.9679 - probe_accuracy: 0.4986 - val_loss: 0.7089 - val_probe_loss: 0.7089 - val_probe_accuracy: 0.5521
# Epoch 2/30
# 54/54 [==============================] - 1s 12ms/step - loss: 0.7160 - probe_loss: 0.7160 - probe_accuracy: 0.5136 - val_loss: 0.7178 - val_probe_loss: 0.7178 - val_probe_accuracy: 0.4688
# Epoch 3/30
# 54/54 [==============================] - 1s 12ms/step - loss: 0.6968 - probe_loss: 0.6968 - probe_accuracy: 0.5120 - val_loss: 0.6995 - val_probe_loss: 0.6995 - val_probe_accuracy: 0.4271
# Epoch 4/30
# 54/54 [==============================] - 1s 11ms/step - loss: 0.6841 - probe_loss: 0.6841 - probe_accuracy: 0.5526 - val_loss: 0.6923 - val_probe_loss: 0.6923 - val_probe_accuracy: 0.5729
# Epoch 5/30
# 54/54 [==============================] - 1s 11ms/step - loss: 0.6880 - probe_loss: 0.6880 - probe_accuracy: 0.5298 - val_loss: 0.7255 - val_probe_loss: 0.7255 - val_probe_accuracy: 0.4583
# Epoch 6/30
# 54/54 [==============================] - 1s 11ms/step - loss: 0.6847 - probe_loss: 0.6847 - probe_accuracy: 0.5546 - val_loss: 0.6900 - val_probe_loss: 0.6900 - val_probe_accuracy: 0.5521
# Epoch 7/30
#  - ETA: 0s - loss: 0.6795 - probe_loss: 0.6795 - probe_accuracy: 0.5723
# Epoch 8/30
# 54/54 [==============================] - 1s 11ms/step - loss: 0.6648 - probe_loss: 0.6648 - probe_accuracy: 0.5822 - val_loss: 0.7100 - val_probe_loss: 0.7100 - val_probe_accuracy: 0.3646
# Epoch 9/30
# 54/54 [==============================] - 1s 12ms/step - loss: 0.6640 - probe_loss: 0.6640 - probe_accuracy: 0.6357 - val_loss: 0.7134 - val_probe_loss: 0.7134 - val_probe_accuracy: 0.4896
# Epoch 10/30
# 54/54 [==============================] - 1s 11ms/step - loss: 0.6357 - probe_loss: 0.6357 - probe_accuracy: 0.6630 - val_loss: 0.7677 - val_probe_loss: 0.7677 - val_probe_accuracy: 0.4479
# Epoch 11/30
# 54/54 [==============================] - 1s 11ms/step - loss: 0.6296 - probe_loss: 0.6296 - probe_accuracy: 0.6659 - val_loss: 0.7140 - val_probe_loss: 0.7140 - val_probe_accuracy: 0.4688
# Epoch 12/30
# 54/54 [==============================] - 1s 11ms/step - loss: 0.6544 - probe_loss: 0.6544 - probe_accuracy: 0.6489 - val_loss: 0.7528 - val_probe_loss: 0.7528 - val_probe_accuracy: 0.4792
# Epoch 13/30
# 54/54 [==============================] - 1s 11ms/step - loss: 0.