# %%
import os
import nengo
import numpy as np
import tensorflow as tf
import keras
import nengo_dl
from tensorflow.python.keras import Input, Model
from tensorflow.python.keras.callbacks import EarlyStopping
from tensorflow.python.keras.layers import Conv2D, Dropout, AveragePooling2D, Flatten, Dense, BatchNormalization, \
    Conv3D, MaxPooling2D, Conv1D, AveragePooling1D, LSTM
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
from sklearn.model_selection import train_test_split, ShuffleSplit, KFold
from keras import backend as K
from sklearn.utils import shuffle

# %%
# Data from males is by default saved in dataset_result/men_only.npz
men_dataset_path = os.path.join('dataset_result', 'men_only.npz')
dataset = np.load(men_dataset_path)

features, labels = dataset['features'], dataset['labels']

print('Features shape:', features.shape)
print('Labels shape:', labels.shape)
# Out:
# Features shape: (1296, 14, 36, 10)
# Labels shape: (1296,)

# %%
# Set seed for consistency
seed = 23
np.random.seed(seed)
tf.random.set_seed(seed)

# %%
# Reshape features for the NN
features = features.reshape((features.shape[0], 1, -1))
print('Features shape:', features.shape)

# Convert labels to one hot encoding
labels = labels.reshape(-1, 1)
labels = OneHotEncoder().fit_transform(labels).toarray()
labels = labels.reshape((labels.shape[0], 1, -1))
print('Labels shape:', labels.shape)
# Out:
# Features shape: (1296, 1, 5040)
# Labels shape: (1296, 1, 2)

# %%
# Function to create the CNN model for classification
def cnn_model():
    inp = Input(shape=(14, 36, 10), name='input_layer')
    conv1 = Conv2D(filters=32, kernel_size=(5, 5), activation=tf.nn.relu)(inp)
    dropout1 = Dropout(0.2, seed=seed)(conv1)
    avg_pool1 = AveragePooling2D(pool_size=(2, 2))(dropout1)
    conv2 = Conv2D(filters=64, kernel_size=(3, 3), activation=tf.nn.relu)(avg_pool1)
    dropout2 = Dropout(0.2, seed=seed)(conv2)
    avg_pool2 = AveragePooling2D(pool_size=(2, 2))(dropout2)
    flatten = Flatten()(avg_pool2)
    dense1 = Dense(512, activation=tf.nn.relu)(flatten)
    dropout3 = Dropout(0.2, seed=seed)(dense1)
    dense2 = Dense(256, activation=tf.nn.relu)(dropout3)
    output = Dense(2, activation=tf.nn.softmax, name='output_layer')(dense2)

    return Model(inputs=inp, outputs=output)

# %%
def run_ann(model, train, val, test,
            params_save_path,
            iteration,
            shuffle_training=True,
            num_epochs=30,
            minibatch_size=10,
            early_stopping=False):
    x_train, y_train = train[0], train[1]
    x_test, y_test = test[0], test[1]
    x_val, y_val = val[0], val[1]

    converter = nengo_dl.Converter(model)

    with nengo_dl.Simulator(converter.net, minibatch_size=minibatch_size) as simulator:
        simulator.compile(optimizer=keras.optimizers.Adam(),
                          loss=keras.losses.BinaryCrossentropy(),
                          metrics=['accuracy'])

        input_layer = converter.inputs[model.get_layer('input_layer')]
        output_layer = converter.outputs[model.get_layer('output_layer')]

        simulator.fit(
            x={ input_layer: x_train }, y={ output_layer: y_train },
            validation_data=(
                { input_layer: x_val }, { output_layer: y_val }
            ),
            epochs=num_epochs,
            shuffle=shuffle_training,
            callbacks=[EarlyStopping(patience=8, verbose=1, restore_best_weights=True)] if early_stopping else None
            # early stop to avoid overfitting
        )

        simulator.save_params(params_save_path)
        ann_eval = simulator.evaluate(x={ input_layer: x_test }, y={ output_layer: y_test }) # evaluate accuracy
        print('{}. ann accuracy: {:5f}%'.format(iteration, ann_eval['probe_accuracy'] * 100)) # log accuracy
        return ann_eval['probe_accuracy'] # return accuracy


def run_snn(model, x_test, y_test, params_load_path, iteration, timesteps=50, scale_firing_rates=1000, synapse=0.01):
    converter = nengo_dl.Converter(
        model,
        swap_activations={ tf.nn.relu: nengo.SpikingRectifiedLinear() },
        scale_firing_rates=scale_firing_rates,
        synapse=synapse
    ) # create a Nengo converter object and swap all relu activations with spiking relu

    with converter.net:
        nengo_dl.configure_settings(stateful=False)

    input_layer = converter.inputs[model.get_layer('input_layer')] # input layer for simulator
    output_layer = converter.outputs[model.get_layer('output_layer')] # output layer for simulator

    x_test_tiled = np.tile(x_test, (1, timesteps, 1)) # tile test data to timesteps

    with nengo_dl.Simulator(converter.net) as simulator:
        simulator.load_params(params_load_path)

        predictions = simulator.predict({ input_layer: x_test_tiled })[output_layer] # get results from prediction
        predictions = predictions[:,-1,:] # get last time step

        predictions = np.argmax(predictions, axis=-1) # get argmax
        y_test = np.squeeze(y_test, axis=1) # remove time dimension from labels since its not relevant
        y_test = np.argmax(y_test, axis=-1) # get argmax of y test as well for comparison

        snn_acc = (predictions == y_test).mean()

    print('{}. SNN accuracy: {:5f}%'.format(
            iteration, snn_acc * 100
        ))

    return snn_acc

# %%
os.makedirs('male_nengo_params', exist_ok=True)
ann, snn = [], []

num_splits = 10
iteration = 1

features, labels = shuffle(features, labels, random_state=seed)
x_train, x_test, y_train, y_test = train_test_split(features, labels, test_size=0.1, shuffle=False)


for train, val in KFold(n_splits=num_splits).split(x_train):
    x_train_curr, y_train_curr = x_train[train], y_train[train]
    x_val, y_val = x_train[val], y_train[val]

    print(x_test.shape)

    params_path = os.path.join('male_nengo_params', 'params_{}'.format(iteration))
    model = cnn_model()

    # run ann
    ann_result = run_ann(model=model,
                      train=(x_train_curr, y_train_curr),
                      val=(x_val, y_val),
                      test=(x_test, y_test),
                      params_save_path=params_path,
                      iteration=iteration,
                      early_stopping=True,
                      num_epochs=50)

    # run snn
    snn_result = run_snn(model=model,
                         x_test=x_test,
                         y_test=y_test,
                         params_load_path=params_path,
                         iteration=iteration)

    ann.append(ann_result)
    snn.append(snn_result)
    iteration += 1

    K.clear_session()
    del model
# Out:
# (130, 1, 5040)
# Build finished in 0:00:00
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Epoch 1/50
# 104/104 [==============================] - 5s 17ms/step - loss: 0.8261 - probe_loss: 0.8261 - probe_accuracy: 0.5209 - val_loss: 0.6965 - val_probe_loss: 0.6965 - val_probe_accuracy: 0.4727
# Epoch 2/50
# 104/104 [==============================] - 1s 10ms/step - loss: 0.6913 - probe_loss: 0.6913 - probe_accuracy: 0.5357 - val_loss: 0.6961 - val_probe_loss: 0.6961 - val_probe_accuracy: 0.5000
# Epoch 3/50
# 104/104 [==============================] - 1s 10ms/step - loss: 0.6975 - probe_loss: 0.6975 - probe_accuracy: 0.4975 - val_loss: 0.6949 - val_probe_loss: 0.6949 - val_probe_accuracy: 0.4727
# Epoch 4/50
# 104/104 [==============================] - 1s 10ms/step - loss: 0.6949 - probe_loss: 0.6949 - probe_accuracy: 0.5054 - val_loss: 0.6953 - val_probe_loss: 0.6953 - val_probe_accuracy: 0.4727
# Epoch 5/50
# 104/104 [==============================] - 1s 11ms/step - loss: 0.6927 - probe_loss: 0.6927 - probe_accuracy: 0.5335 - val_loss: 0.7004 - val_probe_loss: 0.7004 - val_probe_accuracy: 0.4364
# Epoch 6/50
# 104/104 [==============================] - 1s 10ms/step - loss: 0.6916 - probe_loss: 0.6916 - probe_accuracy: 0.5346 - val_loss: 0.6998 - val_probe_loss: 0.6998 - val_probe_accuracy: 0.4364
# Epoch 7/50
# 104/104 [==============================] - 1s 11ms/step - loss: 0.6998 - probe_loss: 0.6998 - probe_accuracy: 0.4937 - val_loss: 0.6967 - val_probe_loss: 0.6967 - val_probe_accuracy: 0.4727
# Epoch 8/50
#  - ETA: 0s - loss: 0.6931 - probe_loss: 0.6931 - probe_accuracy: 0.5360
# Epoch 9/50
# 104/104 [==============================] - 2s 17ms/step - loss: 0.6896 - probe_loss: 0.6896 - probe_accuracy: 0.5278 - val_loss: 0.7447 - val_probe_loss: 0.7447 - val_probe_accuracy: 0.4545
# Epoch 10/50
# 104/104 [==============================] - 1s 10ms/step - loss: 0.6930 - probe_loss: 0.6930 - probe_accuracy: 0.5349 - val_loss: 0.7017 - val_probe_loss: 0.7017 - val_probe_accuracy: 0.4455
# Epoch 11/50
# 104/104 [==============================] - 1s 10ms/step - loss: 0.6965 - probe_loss: 0.6965 - probe_accuracy: 0.5465 - val_loss: 0.7200 - val_probe_loss: 0.7200 - val_probe_accuracy: 0.4455
# Restoring model weights from the end of the best epoch.
# Epoch 00011: early stopping
# 13/13 [==============================] - 0s 5ms/step - loss: 0.6915 - probe_loss: 0.6915 - probe_accuracy: 0.5462
# 1. ann accuracy: 54.615384%
# Build finished in 0:00:00
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# 1. SNN accuracy: 53.076923%tage finished in 0:00:00
# (130, 1, 5040)
# Build finished in 0:00:00
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Epoch 1/50
# 104/104 [==============================] - 5s 17ms/step - loss: 0.8437 - probe_loss: 0.8437 - probe_accuracy: 0.5325 - val_loss: 0.6924 - val_probe_loss: 0.6924 - val_probe_accuracy: 0.5636
# Epoch 2/50
# 104/104 [==============================] - 1s 10ms/step - loss: 0.6932 - probe_loss: 0.6932 - probe_accuracy: 0.5201 - val_loss: 0.6938 - val_probe_loss: 0.6938 - val_probe_accuracy: 0.4636
# Epoch 3/50
# 104/104 [==============================] - 1s 10ms/step - loss: 0.6964 - probe_loss: 0.6964 - probe_accuracy: 0.4974 - val_loss: 0.6935 - val_probe_loss: 0.6935 - val_probe_accuracy: 0.4727
# Epoch 4/50
#  - ETA: 1s - loss: 0.6893 - probe_loss: 0.6893 - probe_accuracy: 0.5358
# Epoch 5/50
# 104/104 [==============================] - 1s 10ms/step - loss: 0.6939 - probe_loss: 0.6939 - probe_accuracy: 0.5083 - val_loss: 0.7014 - val_probe_loss: 0.7014 - val_probe_accuracy: 0.4727
# Epoch 6/50
# 104/104 [==============================] - 1s 11ms/step - loss: 0.7047 - probe_loss: 0.7047 - probe_accuracy: 0.5185 - val_loss: 0.8076 - val_probe_loss: 0.8076 - val_probe_accuracy: 0.4727
# Epoch 7/50
# 104/104 [==============================] - 1s 10ms/step - loss: 0.6995 - probe_loss: 0.6995 - probe_accuracy: 0.5155 - val_loss: 0.6984 - val_probe_loss: 0.6984 - val_probe_accuracy: 0.4818
# Epoch 8/50
# 104/104 [==============================] - 1s 10ms/step - loss: 0.6939 - probe_loss: 0.6939 - probe_accuracy: 0.5609 - val_loss: 0.6962 - val_probe_loss: 0.6962 - val_probe_accuracy: 0.4545
# Epoch 9/50
# 104/104 [==============================] - 1s 10ms/step - loss: 0.6934 - probe_loss: 0.6934 - probe_accuracy: 0.5030 - val_loss: 0.7207 - val_probe_loss: 0.7207 - val_probe_accuracy: 0.4727
# Restoring model weights from the end of the best epoch.
# Epoch 00009: early stopping
# 13/13 [==============================] - 0s 4ms/step - loss: 0.6942 - probe_loss: 0.6942 - probe_accuracy: 0.4462
# 2. ann accuracy: 44.615385%
# Build finished in 0:00:00
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# 2. SNN accuracy: 43.076923%tage finished in 0:00:00
# (130, 1, 5040)
# Build finished in 0:00:00
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Epoch 1/50
# 104/104 [==============================] - 5s 17ms/step - loss: 0.8580 - probe_loss: 0.8580 - probe_accuracy: 0.4924 - val_loss: 0.6894 - val_probe_loss: 0.6894 - val_probe_accuracy: 0.5636
# Epoch 2/50
# 104/104 [==============================] - 1s 10ms/step - loss: 0.6986 - probe_loss: 0.6986 - probe_accuracy: 0.5562 - val_loss: 0.7740 - val_probe_loss: 0.7740 - val_probe_accuracy: 0.4818
# Epoch 3/50
# 104/104 [==============================] - 1s 10ms/step - loss: 0.7107 - probe_loss: 0.7107 - probe_accuracy: 0.5260 - val_loss: 0.6931 - val_probe_loss: 0.6931 - val_probe_accuracy: 0.4818
# Epoch 4/50
# 104/104 [==============================] - 1s 10ms/step - loss: 0.6971 - probe_loss: 0.6971 - probe_accuracy: 0.5044 - val_loss: 0.6939 - val_probe_loss: 0.6939 - val_probe_accuracy: 0.4909
# Epoch 5/50
# 104/104 [==============================] - 1s 10ms/step - loss: 0.6938 - probe_loss: 0.6938 - probe_accuracy: 0.5215 - val_loss: 0.6966 - val_probe_loss: 0.6966 - val_probe_accuracy: 0.4909
# Epoch 6/50
# 104/104 [==============================] - 1s 10ms/step - loss: 0.6974 - probe_loss: 0.6974 - probe_accuracy: 0.5173 - val_loss: 0.6976 - val_probe_loss: 0.6976 - val_probe_accuracy: 0.4818
# Epoch 7/50
# 104/104 [==============================] - 1s 10ms/step - loss: 0.6926 - probe_loss: 0.6926 - probe_accuracy: 0.5342 - val_loss: 0.7140 - val_probe_loss: 0.7140 - val_probe_accuracy: 0.5091
# Epoch 8/50
# 104/104 [==============================] - 1s 10ms/step - loss: 0.7015 - probe_loss: 0.7015 - probe_accuracy: 0.5160 - val_loss: 0.6941 - val_probe_loss: 0.6941 - val_probe_accuracy: 0.4727
# Epoch 9/50
#  - ETA: 0s - loss: 0.6908 - probe_loss: 0.6908 - probe_accuracy: 0.5243
# Restoring model weights from the end of the best epoch.
# Epoch 00009: early stopping
# 13/13 [==============================] - 0s 5ms/step - loss: 0.6976 - probe_loss: 0.6976 - probe_accuracy: 0.4769
# 3. ann accuracy: 47.692308%
# Build finished in 0:00:00
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# 3. SNN accuracy: 45.384615%tage finished in 0:00:00
# (130, 1, 5040)
# Build finished in 0:00:00
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Epoch 1/50
# 104/104 [==============================] - 5s 17ms/step - loss: 0.8823 - probe_loss: 0.8823 - probe_accuracy: 0.4828 - val_loss: 0.6932 - val_probe_loss: 0.6932 - val_probe_accuracy: 0.5455
# Epoch 2/50
# 104/104 [==============================] - 1s 10ms/step - loss: 0.6958 - probe_loss: 0.6958 - probe_accuracy: 0.4918 - val_loss: 0.6930 - val_probe_loss: 0.6930 - val_probe_accuracy: 0.5091
# Epoch 3/50
# 104/104 [==============================] - 1s 10ms/step - loss: 0.6918 - probe_loss: 0.6918 - probe_accuracy: 0.5292 - val_loss: 0.6960 - val_probe_loss: 0.6960 - val_probe_accuracy: 0.4727
# Epoch 4/50
# 104/104 [==============================] - 1s 10ms/step - loss: 0.6934 - probe_loss: 0.6934 - probe_accuracy: 0.5001 - val_loss: 0.6907 - val_probe_loss: 0.6907 - val_probe_accuracy: 0.5000
# Epoch 5/50
# 104/104 [==============================] - 1s 10ms/step - loss: 0.6930 - probe_loss: 0.6930 - probe_accuracy: 0.5312 - val_loss: 0.6965 - val_probe_loss: 0.6965 - val_probe_accuracy: 0.4818
# Epoch 6/50
# 104/104 [==============================] - 1s 11ms/step - loss: 0.6986 - probe_loss: 0.6986 - probe_accuracy: 0.5287 - val_loss: 0.6968 - val_probe_loss: 0.6968 - val_probe_accuracy: 0.4818
# Epoch 7/50
# 104/104 [==============================] - 1s 11ms/step - loss: 0.6962 - probe_loss: 0.6962 - probe_accuracy: 0.4859 - val_loss: 0.6960 - val_probe_loss: 0.6960 - val_probe_accuracy: 0.4364
# Epoch 8/50
# 104/104 [==============================] - 1s 10ms/step - loss: 0.6931 - probe_loss: 0.6931 - probe_accuracy: 0.5332 - val_loss: 0.6994 - val_probe_loss: 0.6994 - val_probe_accuracy: 0.4455
# Epoch 9/50
# 104/104 [==============================] - 1s 10ms/step - loss: 0.6924 - probe_loss: 0.6924 - probe_accuracy: 0.5365 - val_loss: 0.6961 - val_probe_loss: 0.6961 - val_probe_accuracy: 0.4545
# Epoch 10/50
# 104/104 [==============================] - 1s 10ms/step - loss: 0.6967 - probe_loss: 0.6967 - probe_accuracy: 0.5102 - val_loss: 0.7014 - val_probe_loss: 0.7014 - val_probe_accuracy: 0.4727
# Epoch 11/50
# 104/104 [==============================] - 1s 10ms/step - loss: 0.6861 - probe_loss: 0.6861 - probe_accuracy: 0.5470 - val_loss: 0.6985 - val_probe_loss: 0.6985 - val_probe_accuracy: 0.5000
# Epoch 12/50
# 104/104 [==============================] - 1s 10ms/step - loss: 0.6944 - probe_loss: 0.6944 - probe_accuracy: 0.5502 - val_loss: 0.6962 - val_probe_loss: 0.6962 - val_probe_accuracy: 0.5182
# Restoring model weights from the end of the best epoch.
# Epoch 00012: early stopping
# 13/13 [==============================] - 0s 5ms/step - loss: 0.6950 - probe_loss: 0.6950 - probe_accuracy: 0.5462
# 4. ann accuracy: 54.615384%
# Build finished in 0:00:00
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# 4. SNN accuracy: 43.846154%tage finished in 0:00:00
# (130, 1, 5040)
# Build finished in 0:00:00
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Epoch 1/50
# 104/104 [==============================] - 5s 16ms/step - loss: 0.9338 - probe_loss: 0.9338 - probe_accuracy: 0.5031 - val_loss: 0.6952 - val_probe_loss: 0.6952 - val_probe_accuracy: 0.4636
# Epoch 2/50
# 104/104 [==============================] - 1s 11ms/step - loss: 0.6931 - probe_loss: 0.6931 - probe_accuracy: 0.5348 - val_loss: 0.6971 - val_probe_loss: 0.6971 - val_probe_accuracy: 0.4727
# Epoch 3/50
# 104/104 [==============================] - 1s 10ms/step - loss: 0.6965 - probe_loss: 0.6965 - probe_accuracy: 0.5280 - val_loss: 0.6989 - val_probe_loss: 0.6989 - val_probe_accuracy: 0.4455
# Epoch 4/50
# 104/104 [==============================] - 1s 11ms/step - loss: 0.6941 - probe_loss: 0.6941 - probe_accuracy: 0.5478 - val_loss: 0.6968 - val_probe_loss: 0.6968 - val_probe_accuracy: 0.4818
# Epoch 5/50
# 104/104 [==============================] - 1s 10ms/step - loss: 0.7036 - probe_loss: 0.7036 - probe_accuracy: 0.5528 - val_loss: 0.6939 - val_probe_loss: 0.6939 - val_probe_accuracy: 0.4909
# Epoch 6/50
# 104/104 [==============================] - 1s 10ms/step - loss: 0.7021 - probe_loss: 0.7021 - probe_accuracy: 0.5167 - val_loss: 0.6976 - val_probe_loss: 0.6976 - val_probe_accuracy: 0.4636
# Epoch 7/50
# 104/104 [==============================] - 1s 10ms/step - loss: 0.6941 - probe_loss: 0.6941 - probe_accuracy: 0.5134 - val_loss: 0.7003 - val_probe_loss: 0.7003 - val_probe_accuracy: 0.4636
# Epoch 8/50
# 104/104 [==============================] - 1s 10ms/step - loss: 0.6932 - probe_loss: 0.6932 - probe_accuracy: 0.5488 - val_loss: 0.6959 - val_probe_loss: 0.6959 - val_probe_accuracy: 0.4636
# Epoch 9/50
# 104/104 [==============================] - 1s 10ms/step - loss: 0.6931 - probe_loss: 0.6931 - probe_accuracy: 0.5229 - val_loss: 0.6972 - val_probe_loss: 0.6972 - val_probe_accuracy: 0.4636
# Epoch 10/50
# 104/104 [==============================] - 1s 10ms/step - loss: 0.6929 - probe_loss: 0.6929 - probe_accuracy: 0.5144 - val_loss: 0.7003 - val_probe_loss: 0.7003 - val_probe_accuracy: 0.4636
# Epoch 11/50
# 104/104 [==============================] - 1s 10ms/step - loss: 0.6923 - probe_loss: 0.6923 - probe_accuracy: 0.5252 - val_loss: 0.6979 - val_probe_loss: 0.6979 - val_probe_accuracy: 0.4636
# Epoch 12/50
# 104/104 [==============================] - 1s 10ms/step - loss: 0.6931 - probe_loss: 0.6931 - probe_accuracy: 0.5182 - val_loss: 0.6983 - val_probe_loss: 0.6983 - val_probe_accuracy: 0.4364
# Epoch 13/50
# 104/104 [==============================] - 1s 10ms/step - loss: 0.6940 - probe_loss: 0.6940 - probe_accuracy: 0.4913 - val_loss: 0.6999 - val_probe_loss: 0.6999 - val_probe_accuracy: 0.4636
# Restoring model weights from the end of the best epoch.
# Epoch 00013: early stopping
# 13/13 [==============================] - 0s 4ms/step - loss: 0.6910 - probe_loss: 0.6910 - probe_accuracy: 0.5538
# 5. ann accuracy: 55.384618%
# Build finished in 0:00:00
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# 5. SNN accuracy: 39.230769%tage finished in 0:00:00
# (130, 1, 5040)
# Build finished in 0:00:00
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Epoch 1/50
# 104/104 [==============================] - 5s 17ms/step - loss: 0.9340 - probe_loss: 0.9340 - probe_accuracy: 0.5195 - val_loss: 0.6672 - val_probe_loss: 0.6672 - val_probe_accuracy: 0.6455
# Epoch 2/50
# 104/104 [==============================] - 1s 10ms/step - loss: 0.7028 - probe_loss: 0.7028 - probe_accuracy: 0.4727 - val_loss: 0.6829 - val_probe_loss: 0.6829 - val_probe_accuracy: 0.6455
# Epoch 3/50
# 104/104 [==============================] - 1s 11ms/step - loss: 0.6922 - probe_loss: 0.6922 - probe_accuracy: 0.5232 - val_loss: 0.7045 - val_probe_loss: 0.7045 - val_probe_accuracy: 0.3545
# Epoch 4/50
# 104/104 [==============================] - 1s 11ms/step - loss: 0.6994 - probe_loss: 0.6994 - probe_accuracy: 0.5012 - val_loss: 0.6917 - val_probe_loss: 0.6917 - val_probe_accuracy: 0.6273
# Epoch 5/50
# 104/104 [==============================] - 1s 11ms/step - loss: 0.6945 - probe_loss: 0.6945 - probe_accuracy: 0.5027 - val_loss: 0.6977 - val_probe_loss: 0.6977 - val_probe_accuracy: 0.3909
# Epoch 6/50
# 104/104 [==============================] - 1s 10ms/step - loss: 0.6952 - probe_loss: 0.6952 - probe_accuracy: 0.5321 - val_loss: 0.6954 - val_probe_loss: 0.6954 - val_probe_accuracy: 0.4182
# Epoch 7/50
# 104/104 [==============================] - 1s 10ms/step - loss: 0.6947 - probe_loss: 0.6947 - probe_accuracy: 0.5089 - val_loss: 0.7024 - val_probe_loss: 0.7024 - val_probe_accuracy: 0.3818
# Epoch 8/50
# 104/104 [==============================] - 1s 10ms/step - loss: 0.7004 - probe_loss: 0.7004 - probe_accuracy: 0.5267 - val_loss: 0.6857 - val_probe_loss: 0.6857 - val_probe_accuracy: 0.6273
# Epoch 9/50
# 104/104 [==============================] - 1s 11ms/step - loss: 0.6962 - probe_loss: 0.6962 - probe_accuracy: 0.5086 - val_loss: 0.6964 - val_probe_loss: 0.6964 - val_probe_accuracy: 0.3727
# Restoring model weights from the end of the best epoch.
# Epoch 00009: early stopping
# 13/13 [==============================] - 0s 5ms/step - loss: 0.7097 - probe_loss: 0.7097 - probe_accuracy: 0.5538
# 6. ann accuracy: 55.384618%
# Build finished in 0:00:00
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# 6. SNN accuracy: 56.923077%tage finished in 0:00:00
# (130, 1, 5040)
# Build finished in 0:00:00
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Epoch 1/50
# 105/105 [==============================] - 5s 18ms/step - loss: 1.0624 - probe_loss: 1.0624 - probe_accuracy: 0.4804 - val_loss: 0.6940 - val_probe_loss: 0.6940 - val_probe_accuracy: 0.4636
# Epoch 2/50
# 105/105 [==============================] - 1s 10ms/step - loss: 0.6975 - probe_loss: 0.6975 - probe_accuracy: 0.5390 - val_loss: 0.6972 - val_probe_loss: 0.6972 - val_probe_accuracy: 0.4545
# Epoch 3/50
# 105/105 [==============================] - 1s 11ms/step - loss: 0.6914 - probe_loss: 0.6914 - probe_accuracy: 0.5405 - val_loss: 0.6832 - val_probe_loss: 0.6832 - val_probe_accuracy: 0.5636
# Epoch 4/50
# 105/105 [==============================] - 1s 10ms/step - loss: 0.6948 - probe_loss: 0.6948 - probe_accuracy: 0.5540 - val_loss: 0.6941 - val_probe_loss: 0.6941 - val_probe_accuracy: 0.3909
# Epoch 5/50
# 105/105 [==============================] - 1s 10ms/step - loss: 0.6958 - probe_loss: 0.6958 - probe_accuracy: 0.5345 - val_loss: 0.6856 - val_probe_loss: 0.6856 - val_probe_accuracy: 0.5455
# Epoch 6/50
# 105/105 [==============================] - 1s 10ms/step - loss: 0.6887 - probe_loss: 0.6887 - probe_accuracy: 0.5580 - val_loss: 0.6978 - val_probe_loss: 0.6978 - val_probe_accuracy: 0.4545
# Epoch 7/50
#  - ETA: 0s - loss: 0.6913 - probe_loss: 0.6913 - probe_accuracy: 0.5900
# Epoch 8/50
# 105/105 [==============================] - 1s 10ms/step - loss: 0.6824 - probe_loss: 0.6824 - probe_accuracy: 0.5927 - val_loss: 0.6875 - val_probe_loss: 0.6875 - val_probe_accuracy: 0.5909
# Epoch 9/50
# 105/105 [==============================] - 1s 10ms/step - loss: 0.6847 - probe_loss: 0.6847 - probe_accuracy: 0.5657 - val_loss: 0.6892 - val_probe_loss: 0.6892 - val_probe_accuracy: 0.5727
# Epoch 10/50
# 105/105 [==============================] - 1s 10ms/step - loss: 0.6799 - probe_loss: 0.6799 - probe_accuracy: 0.5931 - val_loss: 0.6909 - val_probe_loss: 0.6909 - val_probe_accuracy: 0.5818
# Epoch 11/50
# 105/105 [==============================] - 1s 10ms/step - loss: 0.6678 - probe_loss: 0.6678 - probe_accuracy: 0.6051 - val_loss: 0.6916 - val_probe_loss: 0.6916 - val_probe_accuracy: 0.5545
# Restoring model weights from the end of the best epoch.
# Epoch 00011: early stopping
# 13/13 [==============================] - 0s 5ms/step - loss: 0.6952 - probe_loss: 0.6952 - probe_accuracy: 0.5462
# 7. ann accuracy: 54.615384%
# Build finished in 0:00:00
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# 7. SNN accuracy: 51.538462%tage finished in 0:00:00
# (130, 1, 5040)
# Build finished in 0:00:00
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Epoch 1/50
# 105/105 [==============================] - 5s 17ms/step - loss: 0.9404 - probe_loss: 0.9404 - probe_accuracy: 0.5229 - val_loss: 0.6957 - val_probe_loss: 0.6957 - val_probe_accuracy: 0.5000
# Epoch 2/50
# 105/105 [==============================] - 1s 10ms/step - loss: 0.6990 - probe_loss: 0.6990 - probe_accuracy: 0.4848 - val_loss: 0.6934 - val_probe_loss: 0.6934 - val_probe_accuracy: 0.4636
# Epoch 3/50
# 105/105 [==============================] - 1s 10ms/step - loss: 0.6933 - probe_loss: 0.6933 - probe_accuracy: 0.5494 - val_loss: 0.6918 - val_probe_loss: 0.6918 - val_probe_accuracy: 0.4636
# Epoch 4/50
# 105/105 [==============================] - 1s 10ms/step - loss: 0.6961 - probe_loss: 0.6961 - probe_accuracy: 0.5175 - val_loss: 0.6941 - val_probe_loss: 0.6941 - val_probe_accuracy: 0.4727
# Epoch 5/50
# 105/105 [==============================] - 1s 10ms/step - loss: 0.6958 - probe_loss: 0.6958 - probe_accuracy: 0.5381 - val_loss: 0.6953 - val_probe_loss: 0.6953 - val_probe_accuracy: 0.4636
# Epoch 6/50
# 105/105 [==============================] - 1s 10ms/step - loss: 0.6948 - probe_loss: 0.6948 - probe_accuracy: 0.5511 - val_loss: 0.7007 - val_probe_loss: 0.7007 - val_probe_accuracy: 0.4636
# Epoch 7/50
# 105/105 [==============================] - 1s 10ms/step - loss: 0.6935 - probe_loss: 0.6935 - probe_accuracy: 0.5282 - val_loss: 0.6986 - val_probe_loss: 0.6986 - val_probe_accuracy: 0.4636
# Epoch 8/50
# 105/105 [==============================] - 1s 10ms/step - loss: 0.6873 - probe_loss: 0.6873 - probe_accuracy: 0.5555 - val_loss: 0.7111 - val_probe_loss: 0.7111 - val_probe_accuracy: 0.5182
# Epoch 9/50
#  - ETA: 0s - loss: 0.6816 - probe_loss: 0.6816 - probe_accuracy: 0.5588
# Epoch 10/50
# 105/105 [==============================] - 1s 11ms/step - loss: 0.6865 - probe_loss: 0.6865 - probe_accuracy: 0.5705 - val_loss: 0.7597 - val_probe_loss: 0.7597 - val_probe_accuracy: 0.5000
# Epoch 11/50
# 105/105 [==============================] - 1s 10ms/step - loss: 0.6760 - probe_loss: 0.6760 - probe_accuracy: 0.5767 - val_loss: 0.7230 - val_probe_loss: 0.7230 - val_probe_accuracy: 0.4455
# Restoring model weights from the end of the best epoch.
# Epoch 00011: early stopping
# 13/13 [==============================] - 0s 5ms/step - loss: 0.7012 - probe_loss: 0.7012 - probe_accuracy: 0.5077
# 8. ann accuracy: 50.769234%
# Build finished in 0:00:00
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# 8. SNN accuracy: 56.153846%tage finished in 0:00:00
# (130, 1, 5040)
# Build finished in 0:00:00
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Epoch 1/50
# 105/105 [==============================] - 5s 17ms/step - loss: 0.9414 - probe_loss: 0.9414 - probe_accuracy: 0.5034 - val_loss: 0.7070 - val_probe_loss: 0.7070 - val_probe_accuracy: 0.5364
# Epoch 2/50
# 105/105 [==============================] - 1s 10ms/step - loss: 0.6972 - probe_loss: 0.6972 - probe_accuracy: 0.5063 - val_loss: 0.6902 - val_probe_loss: 0.6902 - val_probe_accuracy: 0.5455
# Epoch 3/50
# 105/105 [==============================] - 1s 10ms/step - loss: 0.6976 - probe_loss: 0.6976 - probe_accuracy: 0.5039 - val_loss: 0.6937 - val_probe_loss: 0.6937 - val_probe_accuracy: 0.5455
# Epoch 4/50
# 105/105 [==============================] - 1s 10ms/step - loss: 0.6942 - probe_loss: 0.6942 - probe_accuracy: 0.5168 - val_loss: 0.6923 - val_probe_loss: 0.6923 - val_probe_accuracy: 0.5455
# Epoch 5/50
# 105/105 [==============================] - 1s 10ms/step - loss: 0.6956 - probe_loss: 0.6956 - probe_accuracy: 0.5196 - val_loss: 0.6960 - val_probe_loss: 0.6960 - val_probe_accuracy: 0.5455
# Epoch 6/50
# 105/105 [==============================] - 1s 10ms/step - loss: 0.6950 - probe_loss: 0.6950 - probe_accuracy: 0.5135 - val_loss: 0.6916 - val_probe_loss: 0.6916 - val_probe_accuracy: 0.5455
# Epoch 7/50
# 105/105 [==============================] - 1s 10ms/step - loss: 0.6930 - probe_loss: 0.6930 - probe_accuracy: 0.5047 - val_loss: 0.6976 - val_probe_loss: 0.6976 - val_probe_accuracy: 0.5455
# Epoch 8/50
# 105/105 [==============================] - 1s 10ms/step - loss: 0.7055 - probe_loss: 0.7055 - probe_accuracy: 0.5241 - val_loss: 0.6912 - val_probe_loss: 0.6912 - val_probe_accuracy: 0.5545
# Epoch 9/50
# 105/105 [==============================] - 1s 10ms/step - loss: 0.6929 - probe_loss: 0.6929 - probe_accuracy: 0.5127 - val_loss: 0.6917 - val_probe_loss: 0.6917 - val_probe_accuracy: 0.5455
# Epoch 10/50
# 105/105 [==============================] - 1s 11ms/step - loss: 0.6915 - probe_loss: 0.6915 - probe_accuracy: 0.5445 - val_loss: 0.6924 - val_probe_loss: 0.6924 - val_probe_accuracy: 0.5455
# Restoring model weights from the end of the best epoch.
# Epoch 00010: early stopping
# 13/13 [==============================] - 0s 5ms/step - loss: 0.6984 - probe_loss: 0.6984 - probe_accuracy: 0.5462
# 9. ann accuracy: 54.615384%
# Build finished in 0:00:00
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# 9. SNN accuracy: 54.615385%tage finished in 0:00:00
# (130, 1, 5040)
# Build finished in 0:00:00
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Epoch 1/50
# 105/105 [==============================] - 6s 17ms/step - loss: 0.8835 - probe_loss: 0.8835 - probe_accuracy: 0.5013 - val_loss: 0.6973 - val_probe_loss: 0.6973 - val_probe_accuracy: 0.4909
# Epoch 2/50
# 105/105 [==============================] - 1s 10ms/step - loss: 0.6992 - probe_loss: 0.6992 - probe_accuracy: 0.5245 - val_loss: 0.6945 - val_probe_loss: 0.6945 - val_probe_accuracy: 0.5091
# Epoch 3/50
# 105/105 [==============================] - 1s 10ms/step - loss: 0.6992 - probe_loss: 0.6992 - probe_accuracy: 0.4950 - val_loss: 0.6931 - val_probe_loss: 0.6931 - val_probe_accuracy: 0.5000
# Epoch 4/50
# 105/105 [==============================] - 1s 10ms/step - loss: 0.6925 - probe_loss: 0.6925 - probe_accuracy: 0.5590 - val_loss: 0.6929 - val_probe_loss: 0.6929 - val_probe_accuracy: 0.4727
# Epoch 5/50
# 105/105 [==============================] - 1s 10ms/step - loss: 0.7016 - probe_loss: 0.7016 - probe_accuracy: 0.5508 - val_loss: 0.6916 - val_probe_loss: 0.6916 - val_probe_accuracy: 0.4909
# Epoch 6/50
# 105/105 [==============================] - 1s 10ms/step - loss: 0.6928 - probe_loss: 0.6928 - probe_accuracy: 0.5183 - val_loss: 0.7596 - val_probe_loss: 0.7596 - val_probe_accuracy: 0.5000
# Epoch 7/50
# 105/105 [==============================] - 1s 10ms/step - loss: 0.7052 - probe_loss: 0.7052 - probe_accuracy: 0.5143 - val_loss: 0.6941 - val_probe_loss: 0.6941 - val_probe_accuracy: 0.4636
# Epoch 8/50
# 105/105 [==============================] - 1s 10ms/step - loss: 0.6946 - probe_loss: 0.6946 - probe_accuracy: 0.4790 - val_loss: 0.6931 - val_probe_loss: 0.6931 - val_probe_accuracy: 0.4909
# Epoch 9/50
# 105/105 [==============================] - 1s 11ms/step - loss: 0.6897 - probe_loss: 0.6897 - probe_accuracy: 0.5408 - val_loss: 0.6963 - val_probe_loss: 0.6963 - val_probe_accuracy: 0.5000
# Epoch 10/50
# 105/105 [==============================] - 1s 10ms/step - loss: 0.6960 - probe_loss: 0.6960 - probe_accuracy: 0.5312 - val_loss: 0.6980 - val_probe_loss: 0.6980 - val_probe_accuracy: 0.4909
# Epoch 11/50
# 105/105 [==============================] - 1s 10ms/step - loss: 0.6805 - probe_loss: 0.6805 - probe_accuracy: 0.5827 - val_loss: 0.7039 - val_probe_loss: 0.7039 - val_probe_accuracy: 0.4545
# Epoch 12/50
# 105/105 [==============================] - 1s 10ms/step - loss: 0.6866 - probe_loss: 0.6866 - probe_accuracy: 0.5388 - val_loss: 0.6961 - val_probe_loss: 0.6961 - val_probe_accuracy: 0.5000
# Epoch 13/50
# 105/105 [==============================] - 1s 10ms/step - loss: 0.6781 - probe_loss: 0.6781 - probe_accuracy: 0.5606 - val_loss: 0.6912 - val_probe_loss: 0.6912 - val_probe_accuracy: 0.5091
# Epoch 14/50
#  - ETA: 0s - loss: 0.6949 - probe_loss: 0.6949 - probe_accuracy: 0.5161
# Epoch 15/50
# 105/105 [==============================] - 1s 10ms/step - loss: 0.6643 - probe_loss: 0.6643 - probe_accuracy: 0.5943 - val_loss: 0.7159 - val_probe_loss: 0.7159 - val_probe_accuracy: 0.4364
# Epoch 16/50
#  - ETA: 0s - loss: 0.6686 - probe_loss: 0.6686 - probe_accuracy: 0.5499
# Epoch 17/50
# 105/105 [==============================] - 1s 11ms/step - loss: 0.6653 - probe_loss: 0.6653 - probe_accuracy: 0.5554 - val_loss: 0.7432 - val_probe_loss: 0.7432 - val_probe_accuracy: 0.4636
# Epoch 18/50
# 105/105 [==============================] - 1s 10ms/step - loss: 0.6449 - probe_loss: 0.6449 - probe_accuracy: 0.6232 - val_loss: 0.7459 - val_probe_loss: 0.7459 - val_probe_accuracy: 0.4545
# Epoch 19/50
# 105/105 [==============================] - 1s 10ms/step - loss: 0.6345 - probe_loss: 0.6345 - probe_accuracy: 0.6436 - val_loss: 0.7670 - val_probe_loss: 0.7670 - val_probe_accuracy: 0.5000
# Epoch 20/50
# 105/105 [==============================] - 1s 10ms/step - loss: 0.6373 - probe_loss: 0.6373 - probe_accuracy: 0.6426 - val_loss: 0.7426 - val_probe_loss: 0.7426 - val_probe_accuracy: 0.4909
# Epoch 21/50
# 105/105 [==============================] - 1s 11ms/step - loss: 0.6212 - probe_loss: 0.6212 - probe_accuracy: 0.6274 - val_loss: 0.7565 - val_probe_loss: 0.7565 - val_probe_accuracy: 0.4636
# Restoring model weights from the end of the best epoch.
# Epoch 00021: early stopping
# 13/13 [==============================] - 0s 6ms/step - loss: 0.7074 - probe_loss: 0.7074 - probe_accuracy: 0.4462
# 10. ann accuracy: 44.615385%
# Build finished in 0:00:00
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# 10. SNN accuracy: 44.615385%age finished in 0:00:00
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: Layer type Dropout does not have a registered converter. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:588: UserWarning: Activation type <function softmax_v2 at 0x000002095DAAC940> does not have a native Nengo equivalent; falling back to a TensorNode
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\simulator.py:1921: UserWarning: Number of elements in input data (117) is not evenly divisible by Simulator.minibatch_size (10); input data will be truncated.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\simulator.py:1921: UserWarning: Number of elements in input data (1049) is not evenly divisible by Simulator.minibatch_size (10); input data will be truncated.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\simulator.py:1921: UserWarning: Number of elements in input data (116) is not evenly divisible by Simulator.minibatch_size (10); input data will be truncated.
#   warnings.warn(

# %%
print(ann)
print(snn)


print('Max ANN:', max(ann))
print('Max SNN:', max(ann))
print('Avg ANN:', np.average(ann))
print('Avg SNN:', np.average(snn))
# Out:
# [0.5461538434028625, 0.446153849363327, 0.4769230782985687, 0.5461538434028625, 0.5538461804389954, 0.5538461804389954, 0.5461538434028625, 0.5076923370361328, 0.5461538434028625, 0.446153849363327]
# [0.5307692307692308, 0.4307692307692308, 0.45384615384615384, 0.43846153846153846, 0.3923076923076923, 0.5692307692307692, 0.5153846153846153, 0.5615384615384615, 0.5461538461538461, 0.4461538461538462]
# Max ANN: 0.5538461804389954
# Max SNN: 0.5538461804389954
# Avg ANN: 0.5169230848550797
# Avg SNN: 0.4884615384615385
