# %% [markdown]
# The notebook requires a preprocessed dataset. This can be done either by executing the notebook
# **data_preprocessing.ipynb** or by running the **data_preprocessing.py** Python script, which can be easily executed like so:
# ```
# python data_preprocessing.py
# ```
#
# Also, make sure that the **bnci_utils.py** file is in the same directory as this notebook as it contains part of the
# functionality. The resulting preprocessed data should not be renamed unless you also change their names in the
# notebook.

# %%
import os
import numpy as np
import tensorflow as tf
import keras
import nengo_dl
from tensorflow.python.keras import Input, Model
import nengo
from tensorflow.python.keras.callbacks import EarlyStopping
from tensorflow.python.keras.layers import Conv2D, Dropout, AveragePooling2D, Flatten, Dense, BatchNormalization, Conv3D
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
from keras import backend as K
import pandas as pd
from sklearn import metrics
import bnci_utils as utils

# %% [markdown]
# Two models for the simulation are available - change the value of the **model** variable to either 'default_cnn' or
# 'p300_exp_cnn'. E.g:
# ```
# model = 'p300_exp_cnn'
# ```
#
# The name of the output files can be changed as well - change the value of the **iteration_data_file_name** variable to
# rename the output file for each iteration, and the value of the **iteration_stats_file_name** to rename the output file
# for statistics from the entire simulation. Note that both names **need** to have the .xlsx extension. E.g:
#
# ```
# iteration_data_file_name = 'simulation_output.xlsx'
# ```

# %%
num_participants = 18

# List of files with samples from each participant
dataset_path = os.path.join('dataset_result')
files = [os.path.join(dataset_path, 'P{:02d}.npz'.format(i+1)) for i in range(num_participants)] # P01 - P18 files

data_output_folder = 'output' # output path for statistics from the simulation
iteration_data_file_name = 'cnn_p300_individuals_data.xlsx' # file name of excel file with data from each iteration
iteration_stats_file_name = 'cnn_p300_individuals_stats.xlsx' # file name for statistics from the simulation (i.e

# List of tested models - default CNN is the originally tested network, p300_exp_cnn is the CNN from the P300 experiment
models = {
    'default_cnn': utils.cnn_model,
    'p300_exp_cnn': utils.original_p300_model
}

# Model function to create the model for simulation
model_fn = models['p300_exp_cnn']

# %%
# set seed to produce a consistent result
seed = 2
np.random.seed(seed)
tf.random.set_seed(seed)

# %%
def run_individual(file, particip_num, model, params_save_path, test_size=0.25, epochs=30, scale_firing_rates=1000,
                   synapse=0.01, timesteps=50):
    print(f'Running ANN and SNN for file: {file}')

    dataset = np.load(file) # load numpy file containing the preprocessed data for specific participant
    features, labels = dataset['features'], dataset['labels'] # get features and labels from the numpy file

    # Transform numpy arrays to be usable with Nengo
    features, labels = utils.reshape_dataset(features, labels)

    # Split the data into 75% training and 25% testing
    x_train, x_test, y_train, y_test = train_test_split(features, labels, test_size=test_size, random_state=seed,
                                                        shuffle=True)
    print('X (train) shape:', x_train.shape, 'Y (train) shape:', y_train.shape)
    print('X (test) shape:', x_test.shape, 'Y (test) shape:', y_test.shape)

    ann_stats = utils.run_ann(model, (x_train, y_train), (x_test, y_test), params_save_path, particip_num, num_epochs=epochs,
                              optimizer=keras.optimizers.Adam(), loss=keras.losses.BinaryCrossentropy(), batch_size=1,
                              callbacks=[EarlyStopping(monitor='loss', patience=8, verbose=1, restore_best_weights=True)])
    snn_stats = utils.run_snn(model, x_test,  y_test, params_save_path, particip_num, batch_size=1,
                      timesteps=timesteps, synapse=synapse, scale_firing_rates=scale_firing_rates)

    return ann_stats, snn_stats

# %%
ann, snn = [], []
participant_no = 1

params_save_dir = 'cnn_individuals_nengo_params'
os.makedirs(params_save_dir, exist_ok=True)

for file in files:
    file_name = 'P{:02d}'.format(participant_no)
    model = model_fn(seed=seed)
    params_save_path = os.path.join(params_save_dir, file_name)

    ann_stats, snn_stats = run_individual(file, participant_no, model, params_save_path)

    ann.append(ann_stats) # append statistics to the list
    snn.append(snn_stats)

    participant_no += 1 # increase participant number

    # Delete model and clear session to prevent memory leaks
    K.clear_session()
    del model
# Out:
# Running ANN and SNN for file: dataset_result\P01.npz
# X (train) shape: (90, 1, 5040) Y (train) shape: (90, 1, 2)
# X (test) shape: (30, 1, 5040) Y (test) shape: (30, 1, 2)
# Build finished in 0:00:00
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Epoch 1/30
# 90/90 [==============================] - 4s 7ms/step - loss: 0.6808 - probe_loss: 0.6808 - probe_accuracy: 0.6134
# Epoch 2/30
# 90/90 [==============================] - 1s 7ms/step - loss: 0.6660 - probe_loss: 0.6660 - probe_accuracy: 0.6357
# Epoch 3/30
# 90/90 [==============================] - 1s 7ms/step - loss: 0.6533 - probe_loss: 0.6533 - probe_accuracy: 0.6630
# Epoch 4/30
# 90/90 [==============================] - 1s 7ms/step - loss: 0.6671 - probe_loss: 0.6671 - probe_accuracy: 0.6171
# Epoch 5/30
# 90/90 [==============================] - 1s 7ms/step - loss: 0.6662 - probe_loss: 0.6662 - probe_accuracy: 0.6250
# Epoch 6/30
# 90/90 [==============================] - 1s 7ms/step - loss: 0.6846 - probe_loss: 0.6846 - probe_accuracy: 0.5755
# Epoch 7/30
# 90/90 [==============================] - 1s 7ms/step - loss: 0.6552 - probe_loss: 0.6552 - probe_accuracy: 0.6543
# Epoch 8/30
# 90/90 [==============================] - 1s 7ms/step - loss: 0.6802 - probe_loss: 0.6802 - probe_accuracy: 0.5963
# Epoch 9/30
#  - ETA: 0s - loss: 0.6889 - probe_loss: 0.6889 - probe_accuracy: 0.5776
# Epoch 10/30
# 90/90 [==============================] - 1s 7ms/step - loss: 0.6726 - probe_loss: 0.6726 - probe_accuracy: 0.6010
# Epoch 11/30
# 90/90 [==============================] - 1s 7ms/step - loss: 0.6444 - probe_loss: 0.6444 - probe_accuracy: 0.6671
# Epoch 12/30
# 90/90 [==============================] - 1s 7ms/step - loss: 0.6786 - probe_loss: 0.6786 - probe_accuracy: 0.5997
# Epoch 13/30
# 90/90 [==============================] - 1s 7ms/step - loss: 0.7119 - probe_loss: 0.7119 - probe_accuracy: 0.5264
# Epoch 14/30
# 90/90 [==============================] - 1s 7ms/step - loss: 0.6970 - probe_loss: 0.6970 - probe_accuracy: 0.5603
# Epoch 15/30
# 90/90 [==============================] - 1s 7ms/step - loss: 0.6611 - probe_loss: 0.6611 - probe_accuracy: 0.6335
# Epoch 16/30
# 90/90 [==============================] - 1s 7ms/step - loss: 0.6776 - probe_loss: 0.6776 - probe_accuracy: 0.5687
# Epoch 17/30
# 90/90 [==============================] - 1s 7ms/step - loss: 0.6483 - probe_loss: 0.6483 - probe_accuracy: 0.6640
# Epoch 18/30
# 90/90 [==============================] - 1s 8ms/step - loss: 0.6841 - probe_loss: 0.6841 - probe_accuracy: 0.5716
# Epoch 19/30
# 90/90 [==============================] - 1s 8ms/step - loss: 0.6340 - probe_loss: 0.6340 - probe_accuracy: 0.6921
# Epoch 20/30
# 90/90 [==============================] - 1s 8ms/step - loss: 0.6760 - probe_loss: 0.6760 - probe_accuracy: 0.6116
# Restoring model weights from the end of the best epoch.
# Epoch 00020: early stopping
# 1. CNN: accuracy = 40.0%, precision = 0.5, recall = 0.16666666666666666, f1 = 0.25
# Confusion matrix:
# [[ 9  3]
#  [15  3]]
# Build finished in 0:00:00
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# 1. CNN (SNN conversion): accuracy = 40.0%, precision = 0.5, recall = 0.2222222222222222, f1 = 0.30769230769230765
# Confusion matrix:
# [[ 8  4]
#  [14  4]]
# Running ANN and SNN for file: dataset_result\P02.npz
# X (train) shape: (126, 1, 5040) Y (train) shape: (126, 1, 2)
# X (test) shape: (42, 1, 5040) Y (test) shape: (42, 1, 2)
# Build finished in 0:00:00
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Epoch 1/30
# 126/126 [==============================] - 4s 8ms/step - loss: 0.6941 - probe_loss: 0.6941 - probe_accuracy: 0.4972
# Epoch 2/30
# 126/126 [==============================] - 1s 7ms/step - loss: 0.6960 - probe_loss: 0.6960 - probe_accuracy: 0.4988
# Epoch 3/30
# 126/126 [==============================] - 1s 7ms/step - loss: 0.6910 - probe_loss: 0.6910 - probe_accuracy: 0.5444
# Epoch 4/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6890 - probe_loss: 0.6890 - probe_accuracy: 0.5452
# Epoch 5/30
# 126/126 [==============================] - 1s 7ms/step - loss: 0.6874 - probe_loss: 0.6874 - probe_accuracy: 0.5627
# Epoch 6/30
# 126/126 [==============================] - 1s 7ms/step - loss: 0.7038 - probe_loss: 0.7038 - probe_accuracy: 0.4731
# Epoch 7/30
# 126/126 [==============================] - 1s 7ms/step - loss: 0.7046 - probe_loss: 0.7046 - probe_accuracy: 0.4843
# Epoch 8/30
# 126/126 [==============================] - 1s 7ms/step - loss: 0.6777 - probe_loss: 0.6777 - probe_accuracy: 0.6054
# Epoch 9/30
# 126/126 [==============================] - 1s 7ms/step - loss: 0.6806 - probe_loss: 0.6806 - probe_accuracy: 0.5750
# Epoch 10/30
#  - ETA: 0s - loss: 0.6883 - probe_loss: 0.6883 - probe_accuracy: 0.5276
# Epoch 11/30
# 126/126 [==============================] - 1s 7ms/step - loss: 0.6862 - probe_loss: 0.6862 - probe_accuracy: 0.5829
# Epoch 12/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.7001 - probe_loss: 0.7001 - probe_accuracy: 0.4633
# Epoch 13/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6818 - probe_loss: 0.6818 - probe_accuracy: 0.6034
# Epoch 14/30
#  - ETA: 0s - loss: 0.6905 - probe_loss: 0.6905 - probe_accuracy: 0.5517
# Epoch 15/30
# 126/126 [==============================] - 1s 7ms/step - loss: 0.7036 - probe_loss: 0.7036 - probe_accuracy: 0.4436
# Epoch 16/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6807 - probe_loss: 0.6807 - probe_accuracy: 0.6019
# Epoch 17/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6866 - probe_loss: 0.6866 - probe_accuracy: 0.5498
# Epoch 18/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6863 - probe_loss: 0.6863 - probe_accuracy: 0.5768
# Restoring model weights from the end of the best epoch.
# Epoch 00018: early stopping
# 2. CNN: accuracy = 40.476190476190474%, precision = 0.3684210526315789, recall = 0.35, f1 = 0.358974358974359
# Confusion matrix:
# [[10 12]
#  [13  7]]
# Build finished in 0:00:00
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# 2. CNN (SNN conversion): accuracy = 33.33333333333333%, precision = 0.25, recall = 0.2, f1 = 0.22222222222222224
# Confusion matrix:
# [[10 12]
#  [16  4]]
# Running ANN and SNN for file: dataset_result\P03.npz
# X (train) shape: (126, 1, 5040) Y (train) shape: (126, 1, 2)
# X (test) shape: (42, 1, 5040) Y (test) shape: (42, 1, 2)
# Build finished in 0:00:00
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Epoch 1/30
# 126/126 [==============================] - 4s 7ms/step - loss: 0.6953 - probe_loss: 0.6953 - probe_accuracy: 0.5237
# Epoch 2/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6912 - probe_loss: 0.6912 - probe_accuracy: 0.5893
# Epoch 3/30
# 126/126 [==============================] - 1s 7ms/step - loss: 0.6931 - probe_loss: 0.6931 - probe_accuracy: 0.4920
# Epoch 4/30
# 126/126 [==============================] - 1s 7ms/step - loss: 0.6912 - probe_loss: 0.6912 - probe_accuracy: 0.5215
# Epoch 5/30
# 126/126 [==============================] - 1s 7ms/step - loss: 0.6979 - probe_loss: 0.6979 - probe_accuracy: 0.3851
# Epoch 6/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6881 - probe_loss: 0.6881 - probe_accuracy: 0.5965
# Epoch 7/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6941 - probe_loss: 0.6941 - probe_accuracy: 0.4926
# Epoch 8/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6981 - probe_loss: 0.6981 - probe_accuracy: 0.4834
# Epoch 9/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6914 - probe_loss: 0.6914 - probe_accuracy: 0.5206
# Epoch 10/30
# 126/126 [==============================] - 1s 7ms/step - loss: 0.6958 - probe_loss: 0.6958 - probe_accuracy: 0.4844
# Epoch 11/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6946 - probe_loss: 0.6946 - probe_accuracy: 0.5065
# Epoch 12/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6976 - probe_loss: 0.6976 - probe_accuracy: 0.4509
# Epoch 13/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6970 - probe_loss: 0.6970 - probe_accuracy: 0.5366
# Epoch 14/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6967 - probe_loss: 0.6967 - probe_accuracy: 0.4909
# Epoch 15/30
#  - 1s 8ms/step - loss: 0.6989 - probe_loss: 0.6989 - probe_accuracy: 0.4996
# Restoring model weights from the end of the best epoch.
# Epoch 00015: early stopping
# 3. CNN: accuracy = 47.61904761904761%, precision = 0.47619047619047616, recall = 0.47619047619047616, f1 = 0.47619047619047616
# Confusion matrix:
# [[10 11]
#  [11 10]]
# Build finished in 0:00:00
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# 3. CNN (SNN conversion): accuracy = 38.095238095238095%, precision = 0.3684210526315789, recall = 0.3333333333333333, f1 = 0.35
# Confusion matrix:
# [[ 9 12]
#  [14  7]]
# Running ANN and SNN for file: dataset_result\P04.npz
# X (train) shape: (126, 1, 5040) Y (train) shape: (126, 1, 2)
# X (test) shape: (42, 1, 5040) Y (test) shape: (42, 1, 2)
# Build finished in 0:00:00
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Epoch 1/30
# 126/126 [==============================] - 4s 8ms/step - loss: 0.6969 - probe_loss: 0.6969 - probe_accuracy: 0.4735
# Epoch 2/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6954 - probe_loss: 0.6954 - probe_accuracy: 0.4954
# Epoch 3/30
# 126/126 [==============================] - 1s 7ms/step - loss: 0.6987 - probe_loss: 0.6987 - probe_accuracy: 0.4795
# Epoch 4/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6957 - probe_loss: 0.6957 - probe_accuracy: 0.5265
# Epoch 5/30
#  - ETA: 0s - loss: 0.6941 - probe_loss: 0.6941 - probe_accuracy: 0.4641
# Epoch 6/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6861 - probe_loss: 0.6861 - probe_accuracy: 0.6272
# Epoch 7/30
# 126/126 [==============================] - 1s 7ms/step - loss: 0.6921 - probe_loss: 0.6921 - probe_accuracy: 0.5202
# Epoch 8/30
# 126/126 [==============================] - 1s 7ms/step - loss: 0.6947 - probe_loss: 0.6947 - probe_accuracy: 0.4705
# Epoch 9/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6933 - probe_loss: 0.6933 - probe_accuracy: 0.5372
# Epoch 10/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6927 - probe_loss: 0.6927 - probe_accuracy: 0.5533
# Epoch 11/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6992 - probe_loss: 0.6992 - probe_accuracy: 0.4733
# Epoch 12/30
# 126/126 [==============================] - 1s 7ms/step - loss: 0.6960 - probe_loss: 0.6960 - probe_accuracy: 0.4812
# Epoch 13/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6930 - probe_loss: 0.6930 - probe_accuracy: 0.5366
# Restoring model weights from the end of the best epoch.
# Epoch 00013: early stopping
# 4. CNN: accuracy = 47.61904761904761%, precision = 0.42857142857142855, recall = 0.3, f1 = 0.3529411764705882
# Confusion matrix:
# [[14  8]
#  [14  6]]
# Build finished in 0:00:00
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# 4. CNN (SNN conversion): accuracy = 50.0%, precision = 0.46153846153846156, recall = 0.3, f1 = 0.3636363636363637
# Confusion matrix:
# [[15  7]
#  [14  6]]
# Running ANN and SNN for file: dataset_result\P05.npz
# X (train) shape: (126, 1, 5040) Y (train) shape: (126, 1, 2)
# X (test) shape: (42, 1, 5040) Y (test) shape: (42, 1, 2)
# Build finished in 0:00:00
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Epoch 1/30
# 126/126 [==============================] - 4s 8ms/step - loss: 0.6954 - probe_loss: 0.6954 - probe_accuracy: 0.4437
# Epoch 2/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6903 - probe_loss: 0.6903 - probe_accuracy: 0.5507
# Epoch 3/30
# 126/126 [==============================] - 1s 7ms/step - loss: 0.6970 - probe_loss: 0.6970 - probe_accuracy: 0.4268
# Epoch 4/30
# 126/126 [==============================] - 1s 7ms/step - loss: 0.6978 - probe_loss: 0.6978 - probe_accuracy: 0.5228
# Epoch 5/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6966 - probe_loss: 0.6966 - probe_accuracy: 0.4578
# Epoch 6/30
# 126/126 [==============================] - 1s 7ms/step - loss: 0.6966 - probe_loss: 0.6966 - probe_accuracy: 0.4385
# Epoch 7/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6926 - probe_loss: 0.6926 - probe_accuracy: 0.5322
# Epoch 8/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6900 - probe_loss: 0.6900 - probe_accuracy: 0.5440
# Epoch 9/30
# 126/126 [==============================] - 1s 7ms/step - loss: 0.6961 - probe_loss: 0.6961 - probe_accuracy: 0.4357
# Epoch 10/30
# 126/126 [==============================] - 1s 7ms/step - loss: 0.6931 - probe_loss: 0.6931 - probe_accuracy: 0.5250
# Epoch 11/30
# 126/126 [==============================] - 1s 7ms/step - loss: 0.6953 - probe_loss: 0.6953 - probe_accuracy: 0.4725
# Epoch 12/30
#  - ETA: 0s - loss: 0.6975 - probe_loss: 0.6975 - probe_accuracy: 0.4672
# Epoch 13/30
# 126/126 [==============================] - 1s 7ms/step - loss: 0.7019 - probe_loss: 0.7019 - probe_accuracy: 0.4537
# Epoch 14/30
#  - ETA: 0s - loss: 0.6505 - probe_loss: 0.6505 - probe_accuracy: 0.7402
# Epoch 15/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6941 - probe_loss: 0.6941 - probe_accuracy: 0.5131
# Epoch 16/30
# 126/126 [==============================] - 1s 7ms/step - loss: 0.6990 - probe_loss: 0.6990 - probe_accuracy: 0.4468
# Epoch 17/30
#  - ETA: 0s - loss: 0.6810 - probe_loss: 0.6810 - probe_accuracy: 0.6243
# Epoch 18/30
# 126/126 [==============================] - 1s 7ms/step - loss: 0.6874 - probe_loss: 0.6874 - probe_accuracy: 0.5368
# Epoch 19/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6961 - probe_loss: 0.6961 - probe_accuracy: 0.4524
# Epoch 20/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6970 - probe_loss: 0.6970 - probe_accuracy: 0.4828
# Epoch 21/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6902 - probe_loss: 0.6902 - probe_accuracy: 0.5422
# Epoch 22/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.7113 - probe_loss: 0.7113 - probe_accuracy: 0.4357
# Epoch 23/30
# 126/126 [==============================] - 1s 7ms/step - loss: 0.6964 - probe_loss: 0.6964 - probe_accuracy: 0.4968
# Epoch 24/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6949 - probe_loss: 0.6949 - probe_accuracy: 0.4896
# Epoch 25/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.7032 - probe_loss: 0.7032 - probe_accuracy: 0.4237
# Restoring model weights from the end of the best epoch.
# Epoch 00025: early stopping
# 5. CNN: accuracy = 57.14285714285714%, precision = 0.5555555555555556, recall = 0.5, f1 = 0.5263157894736842
# Confusion matrix:
# [[14  8]
#  [10 10]]
# Build finished in 0:00:00
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# 5. CNN (SNN conversion): accuracy = 52.38095238095239%, precision = 0.5, recall = 0.45, f1 = 0.4736842105263158
# Confusion matrix:
# [[13  9]
#  [11  9]]
# Running ANN and SNN for file: dataset_result\P06.npz
# X (train) shape: (126, 1, 5040) Y (train) shape: (126, 1, 2)
# X (test) shape: (42, 1, 5040) Y (test) shape: (42, 1, 2)
# Build finished in 0:00:00
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Epoch 1/30
# 126/126 [==============================] - 4s 7ms/step - loss: 0.6961 - probe_loss: 0.6961 - probe_accuracy: 0.4684
# Epoch 2/30
# 126/126 [==============================] - 1s 7ms/step - loss: 0.6928 - probe_loss: 0.6928 - probe_accuracy: 0.5843
# Epoch 3/30
# 126/126 [==============================] - 1s 7ms/step - loss: 0.6904 - probe_loss: 0.6904 - probe_accuracy: 0.6581
# Epoch 4/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6965 - probe_loss: 0.6965 - probe_accuracy: 0.4389
# Epoch 5/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6903 - probe_loss: 0.6903 - probe_accuracy: 0.5150
# Epoch 6/30
# 126/126 [==============================] - 1s 7ms/step - loss: 0.6937 - probe_loss: 0.6937 - probe_accuracy: 0.4968
# Epoch 7/30
# 126/126 [==============================] - 1s 7ms/step - loss: 0.7018 - probe_loss: 0.7018 - probe_accuracy: 0.3399
# Epoch 8/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6911 - probe_loss: 0.6911 - probe_accuracy: 0.5720
# Epoch 9/30
# 126/126 [==============================] - 1s 7ms/step - loss: 0.6956 - probe_loss: 0.6956 - probe_accuracy: 0.4684
# Epoch 10/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6897 - probe_loss: 0.6897 - probe_accuracy: 0.5405
# Restoring model weights from the end of the best epoch.
# Epoch 00010: early stopping
# 6. CNN: accuracy = 54.761904761904766%, precision = 0.6, recall = 0.5217391304347826, f1 = 0.5581395348837209
# Confusion matrix:
# [[11  8]
#  [11 12]]
# Build finished in 0:00:00
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# 6. CNN (SNN conversion): accuracy = 54.761904761904766%, precision = 0.6111111111111112, recall = 0.4782608695652174, f1 = 0.5365853658536586
# Confusion matrix:
# [[12  7]
#  [12 11]]
# Running ANN and SNN for file: dataset_result\P07.npz
# X (train) shape: (126, 1, 5040) Y (train) shape: (126, 1, 2)
# X (test) shape: (42, 1, 5040) Y (test) shape: (42, 1, 2)
# Build finished in 0:00:00
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Epoch 1/30
# 126/126 [==============================] - 4s 7ms/step - loss: 0.6932 - probe_loss: 0.6932 - probe_accuracy: 0.5813
# Epoch 2/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6930 - probe_loss: 0.6930 - probe_accuracy: 0.5173
# Epoch 3/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6926 - probe_loss: 0.6926 - probe_accuracy: 0.5126
# Epoch 4/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6967 - probe_loss: 0.6967 - probe_accuracy: 0.4149
# Epoch 5/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6966 - probe_loss: 0.6966 - probe_accuracy: 0.4845
# Epoch 6/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6956 - probe_loss: 0.6956 - probe_accuracy: 0.4672
# Epoch 7/30
#  - ETA: 0s - loss: 0.7006 - probe_loss: 0.7006 - probe_accuracy: 0.4323
# Epoch 8/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6922 - probe_loss: 0.6922 - probe_accuracy: 0.4680
# Epoch 9/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.7029 - probe_loss: 0.7029 - probe_accuracy: 0.3518
# Epoch 10/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6934 - probe_loss: 0.6934 - probe_accuracy: 0.5181
# Epoch 11/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6916 - probe_loss: 0.6916 - probe_accuracy: 0.5760
# Restoring model weights from the end of the best epoch.
# Epoch 00011: early stopping
# 7. CNN: accuracy = 52.38095238095239%, precision = 0.5333333333333333, recall = 0.38095238095238093, f1 = 0.4444444444444444
# Confusion matrix:
# [[14  7]
#  [13  8]]
# Build finished in 0:00:00
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# 7. CNN (SNN conversion): accuracy = 52.38095238095239%, precision = 0.5333333333333333, recall = 0.38095238095238093, f1 = 0.4444444444444444
# Confusion matrix:
# [[14  7]
#  [13  8]]
# Running ANN and SNN for file: dataset_result\P08.npz
# X (train) shape: (126, 1, 5040) Y (train) shape: (126, 1, 2)
# X (test) shape: (42, 1, 5040) Y (test) shape: (42, 1, 2)
# Build finished in 0:00:00
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Epoch 1/30
# 126/126 [==============================] - 4s 7ms/step - loss: 0.6948 - probe_loss: 0.6948 - probe_accuracy: 0.4987
# Epoch 2/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6936 - probe_loss: 0.6936 - probe_accuracy: 0.5265
# Epoch 3/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6945 - probe_loss: 0.6945 - probe_accuracy: 0.5094
# Epoch 4/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6988 - probe_loss: 0.6988 - probe_accuracy: 0.4857
# Epoch 5/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6983 - probe_loss: 0.6983 - probe_accuracy: 0.5188
# Epoch 6/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6934 - probe_loss: 0.6934 - probe_accuracy: 0.5443
# Epoch 7/30
#  - ETA: 0s - loss: 0.6937 - probe_loss: 0.6937 - probe_accuracy: 0.5169
# Epoch 8/30
#  - ETA: 0s - loss: 0.6895 - probe_loss: 0.6895 - probe_accuracy: 0.5913
# Epoch 9/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6871 - probe_loss: 0.6871 - probe_accuracy: 0.6052
# Epoch 10/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6910 - probe_loss: 0.6910 - probe_accuracy: 0.5499
# Epoch 11/30
#  - ETA: 0s - loss: 0.6992 - probe_loss: 0.6992 - probe_accuracy: 0.4742
# Epoch 12/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6899 - probe_loss: 0.6899 - probe_accuracy: 0.5521
# Epoch 13/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.7037 - probe_loss: 0.7037 - probe_accuracy: 0.4297
# Epoch 14/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6894 - probe_loss: 0.6894 - probe_accuracy: 0.5406
# Epoch 15/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6928 - probe_loss: 0.6928 - probe_accuracy: 0.5348
# Epoch 16/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6956 - probe_loss: 0.6956 - probe_accuracy: 0.5031
# Epoch 17/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6992 - probe_loss: 0.6992 - probe_accuracy: 0.5115
# Epoch 18/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6828 - probe_loss: 0.6828 - probe_accuracy: 0.5841
# Epoch 19/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6967 - probe_loss: 0.6967 - probe_accuracy: 0.4636
# Epoch 20/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6956 - probe_loss: 0.6956 - probe_accuracy: 0.5060
# Epoch 21/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6872 - probe_loss: 0.6872 - probe_accuracy: 0.5653
# Epoch 22/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6860 - probe_loss: 0.6860 - probe_accuracy: 0.5568
# Restoring model weights from the end of the best epoch.
# Epoch 00022: early stopping
# 8. CNN: accuracy = 38.095238095238095%, precision = 0.36363636363636365, recall = 0.4, f1 = 0.380952380952381
# Confusion matrix:
# [[ 8 14]
#  [12  8]]
# Build finished in 0:00:00
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# 8. CNN (SNN conversion): accuracy = 42.857142857142854%, precision = 0.4090909090909091, recall = 0.45, f1 = 0.4285714285714286
# Confusion matrix:
# [[ 9 13]
#  [11  9]]
# Running ANN and SNN for file: dataset_result\P09.npz
# X (train) shape: (126, 1, 5040) Y (train) shape: (126, 1, 2)
# X (test) shape: (42, 1, 5040) Y (test) shape: (42, 1, 2)
# Build finished in 0:00:00
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Epoch 1/30
# 126/126 [==============================] - 4s 8ms/step - loss: 0.6962 - probe_loss: 0.6962 - probe_accuracy: 0.4790
# Epoch 2/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6917 - probe_loss: 0.6917 - probe_accuracy: 0.6603
# Epoch 3/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6918 - probe_loss: 0.6918 - probe_accuracy: 0.5728
# Epoch 4/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6947 - probe_loss: 0.6947 - probe_accuracy: 0.5336
# Epoch 5/30
#  - ETA: 0s - loss: 0.7009 - probe_loss: 0.7009 - probe_accuracy: 0.3767
# Epoch 6/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6965 - probe_loss: 0.6965 - probe_accuracy: 0.4406
# Epoch 7/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6987 - probe_loss: 0.6987 - probe_accuracy: 0.4519
# Epoch 8/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6857 - probe_loss: 0.6857 - probe_accuracy: 0.5865
# Epoch 9/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6870 - probe_loss: 0.6870 - probe_accuracy: 0.5648
# Epoch 10/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6980 - probe_loss: 0.6980 - probe_accuracy: 0.4099
# Epoch 11/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6905 - probe_loss: 0.6905 - probe_accuracy: 0.5338
# Epoch 12/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6875 - probe_loss: 0.6875 - probe_accuracy: 0.5975
# Epoch 13/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6917 - probe_loss: 0.6917 - probe_accuracy: 0.4566
# Epoch 14/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6938 - probe_loss: 0.6938 - probe_accuracy: 0.5064
# Epoch 15/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6932 - probe_loss: 0.6932 - probe_accuracy: 0.5146
# Epoch 16/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6960 - probe_loss: 0.6960 - probe_accuracy: 0.5278
# Epoch 17/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6860 - probe_loss: 0.6860 - probe_accuracy: 0.5180
# Epoch 18/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6994 - probe_loss: 0.6994 - probe_accuracy: 0.4784
# Epoch 19/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6915 - probe_loss: 0.6915 - probe_accuracy: 0.4786
# Epoch 20/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6917 - probe_loss: 0.6917 - probe_accuracy: 0.5202
# Epoch 21/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.7006 - probe_loss: 0.7006 - probe_accuracy: 0.4181
# Epoch 22/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6973 - probe_loss: 0.6973 - probe_accuracy: 0.4174
# Epoch 23/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6951 - probe_loss: 0.6951 - probe_accuracy: 0.4656
# Epoch 24/30
#  - ETA: 0s - loss: 0.6944 - probe_loss: 0.6944 - probe_accuracy: 0.4805
# Epoch 25/30
#  - ETA: 0s - loss: 0.6824 - probe_loss: 0.6824 - probe_accuracy: 0.6356
# Epoch 26/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6851 - probe_loss: 0.6851 - probe_accuracy: 0.6421
# Epoch 27/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6910 - probe_loss: 0.6910 - probe_accuracy: 0.4721
# Restoring model weights from the end of the best epoch.
# Epoch 00027: early stopping
# 9. CNN: accuracy = 42.857142857142854%, precision = 0.36363636363636365, recall = 0.19047619047619047, f1 = 0.25
# Confusion matrix:
# [[14  7]
#  [17  4]]
# Build finished in 0:00:00
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# 9. CNN (SNN conversion): accuracy = 40.476190476190474%, precision = 0.3333333333333333, recall = 0.19047619047619047, f1 = 0.24242424242424246
# Confusion matrix:
# [[13  8]
#  [17  4]]
# Running ANN and SNN for file: dataset_result\P10.npz
# X (train) shape: (126, 1, 5040) Y (train) shape: (126, 1, 2)
# X (test) shape: (42, 1, 5040) Y (test) shape: (42, 1, 2)
# Build finished in 0:00:00
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Epoch 1/30
# 126/126 [==============================] - 4s 8ms/step - loss: 0.6955 - probe_loss: 0.6955 - probe_accuracy: 0.4207
# Epoch 2/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6964 - probe_loss: 0.6964 - probe_accuracy: 0.4509
# Epoch 3/30
#  - ETA: 0s - loss: 0.6991 - probe_loss: 0.6991 - probe_accuracy: 0.4348
# Epoch 4/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6875 - probe_loss: 0.6875 - probe_accuracy: 0.6061
# Epoch 5/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6899 - probe_loss: 0.6899 - probe_accuracy: 0.5266
# Epoch 6/30
#  - ETA: 0s - loss: 0.6997 - probe_loss: 0.6997 - probe_accuracy: 0.4175
# Epoch 7/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6984 - probe_loss: 0.6984 - probe_accuracy: 0.4253
# Epoch 8/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6873 - probe_loss: 0.6873 - probe_accuracy: 0.5844
# Epoch 9/30
#  - ETA: 0s - loss: 0.6950 - probe_loss: 0.6950 - probe_accuracy: 0.4046
# Epoch 10/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.7024 - probe_loss: 0.7024 - probe_accuracy: 0.3774
# Epoch 11/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6981 - probe_loss: 0.6981 - probe_accuracy: 0.5052
# Epoch 12/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6972 - probe_loss: 0.6972 - probe_accuracy: 0.5371
# Epoch 13/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6903 - probe_loss: 0.6903 - probe_accuracy: 0.5624
# Restoring model weights from the end of the best epoch.
# Epoch 00013: early stopping
# 10. CNN: accuracy = 35.714285714285715%, precision = 0.36363636363636365, recall = 0.38095238095238093, f1 = 0.37209302325581395
# Confusion matrix:
# [[ 7 14]
#  [13  8]]
# Build finished in 0:00:00
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# 10. CNN (SNN conversion): accuracy = 40.476190476190474%, precision = 0.4, recall = 0.38095238095238093, f1 = 0.3902439024390244
# Confusion matrix:
# [[ 9 12]
#  [13  8]]
# Running ANN and SNN for file: dataset_result\P11.npz
# X (train) shape: (126, 1, 5040) Y (train) shape: (126, 1, 2)
# X (test) shape: (42, 1, 5040) Y (test) shape: (42, 1, 2)
# Build finished in 0:00:00
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Epoch 1/30
# 126/126 [==============================] - 4s 8ms/step - loss: 0.6974 - probe_loss: 0.6974 - probe_accuracy: 0.5304
# Epoch 2/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6946 - probe_loss: 0.6946 - probe_accuracy: 0.4665
# Epoch 3/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6957 - probe_loss: 0.6957 - probe_accuracy: 0.4192
# Epoch 4/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6960 - probe_loss: 0.6960 - probe_accuracy: 0.4942
# Epoch 5/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6945 - probe_loss: 0.6945 - probe_accuracy: 0.5139
# Epoch 6/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6925 - probe_loss: 0.6925 - probe_accuracy: 0.5443
# Epoch 7/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6931 - probe_loss: 0.6931 - probe_accuracy: 0.5704
# Epoch 8/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6940 - probe_loss: 0.6940 - probe_accuracy: 0.5519
# Epoch 9/30
#  - ETA: 0s - loss: 0.7043 - probe_loss: 0.7043 - probe_accuracy: 0.3458
# Epoch 10/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6889 - probe_loss: 0.6889 - probe_accuracy: 0.6257
# Epoch 11/30
#  - ETA: 0s - loss: 0.6953 - probe_loss: 0.6953 - probe_accuracy: 0.5109
# Epoch 12/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6966 - probe_loss: 0.6966 - probe_accuracy: 0.5348
# Epoch 13/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6932 - probe_loss: 0.6932 - probe_accuracy: 0.4698
# Epoch 14/30
#  - ETA: 0s - loss: 0.6939 - probe_loss: 0.6939 - probe_accuracy: 0.4633
# Epoch 15/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6958 - probe_loss: 0.6958 - probe_accuracy: 0.4695
# Epoch 16/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6897 - probe_loss: 0.6897 - probe_accuracy: 0.5543
# Epoch 17/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6944 - probe_loss: 0.6944 - probe_accuracy: 0.4783
# Epoch 18/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6936 - probe_loss: 0.6936 - probe_accuracy: 0.5683
# Epoch 19/30
#  - ETA: 0s - loss: 0.6891 - probe_loss: 0.6891 - probe_accuracy: 0.5030
# Epoch 20/30
#  - ETA: 0s - loss: 0.6797 - probe_loss: 0.6797 - probe_accuracy: 0.6122
# Epoch 21/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6925 - probe_loss: 0.6925 - probe_accuracy: 0.4966
# Epoch 22/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6929 - probe_loss: 0.6929 - probe_accuracy: 0.4982
# Epoch 23/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6981 - probe_loss: 0.6981 - probe_accuracy: 0.3750
# Epoch 24/30
#  - ETA: 0s - loss: 0.6961 - probe_loss: 0.6961 - probe_accuracy: 0.4857
# Epoch 25/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6908 - probe_loss: 0.6908 - probe_accuracy: 0.5652
# Epoch 26/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6929 - probe_loss: 0.6929 - probe_accuracy: 0.5131
# Restoring model weights from the end of the best epoch.
# Epoch 00026: early stopping
# 11. CNN: accuracy = 52.38095238095239%, precision = 0.5, recall = 0.5, f1 = 0.5
# Confusion matrix:
# [[12 10]
#  [10 10]]
# Build finished in 0:00:00
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# 11. CNN (SNN conversion): accuracy = 54.761904761904766%, precision = 0.5263157894736842, recall = 0.5, f1 = 0.5128205128205129
# Confusion matrix:
# [[13  9]
#  [10 10]]
# Running ANN and SNN for file: dataset_result\P12.npz
# X (train) shape: (126, 1, 5040) Y (train) shape: (126, 1, 2)
# X (test) shape: (42, 1, 5040) Y (test) shape: (42, 1, 2)
# Build finished in 0:00:00
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Epoch 1/30
#  - ETA: 0s - loss: 0.6942 - probe_loss: 0.6942 - probe_accuracy: 0.5066
# Epoch 2/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6995 - probe_loss: 0.6995 - probe_accuracy: 0.4029
# Epoch 3/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6938 - probe_loss: 0.6938 - probe_accuracy: 0.5374
# Epoch 4/30
#  - ETA: 0s - loss: 0.7295 - probe_loss: 0.7295 - probe_accuracy: 0.1336
# Epoch 5/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6959 - probe_loss: 0.6959 - probe_accuracy: 0.5196
# Epoch 6/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6928 - probe_loss: 0.6928 - probe_accuracy: 0.5325
# Epoch 7/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6951 - probe_loss: 0.6951 - probe_accuracy: 0.4830
# Epoch 8/30
#  - ETA: 0s - loss: 0.6768 - probe_loss: 0.6768 - probe_accuracy: 0.6268
# Epoch 9/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6907 - probe_loss: 0.6907 - probe_accuracy: 0.5677
# Epoch 10/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6868 - probe_loss: 0.6868 - probe_accuracy: 0.6179
# Epoch 11/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6944 - probe_loss: 0.6944 - probe_accuracy: 0.5272
# Epoch 12/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6927 - probe_loss: 0.6927 - probe_accuracy: 0.4956
# Epoch 13/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6933 - probe_loss: 0.6933 - probe_accuracy: 0.5198
# Epoch 14/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.7007 - probe_loss: 0.7007 - probe_accuracy: 0.4491
# Epoch 15/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6936 - probe_loss: 0.6936 - probe_accuracy: 0.5646
# Epoch 16/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6920 - probe_loss: 0.6920 - probe_accuracy: 0.5535
# Epoch 17/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6995 - probe_loss: 0.6995 - probe_accuracy: 0.4143
# Restoring model weights from the end of the best epoch.
# Epoch 00017: early stopping
# 12. CNN: accuracy = 45.23809523809524%, precision = 0.46153846153846156, recall = 0.2727272727272727, f1 = 0.3428571428571428
# Confusion matrix:
# [[13  7]
#  [16  6]]
# Build finished in 0:00:00
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# 12. CNN (SNN conversion): accuracy = 42.857142857142854%, precision = 0.4166666666666667, recall = 0.22727272727272727, f1 = 0.29411764705882354
# Confusion matrix:
# [[13  7]
#  [17  5]]
# Running ANN and SNN for file: dataset_result\P13.npz
# X (train) shape: (126, 1, 5040) Y (train) shape: (126, 1, 2)
# X (test) shape: (42, 1, 5040) Y (test) shape: (42, 1, 2)
# Build finished in 0:00:00
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Epoch 1/30
# 126/126 [==============================] - 4s 8ms/step - loss: 0.6960 - probe_loss: 0.6960 - probe_accuracy: 0.3712
# Epoch 2/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6935 - probe_loss: 0.6935 - probe_accuracy: 0.5160
# Epoch 3/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6958 - probe_loss: 0.6958 - probe_accuracy: 0.5089
# Epoch 4/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6918 - probe_loss: 0.6918 - probe_accuracy: 0.5632
# Epoch 5/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6899 - probe_loss: 0.6899 - probe_accuracy: 0.5765
# Epoch 6/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6925 - probe_loss: 0.6925 - probe_accuracy: 0.5182
# Epoch 7/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6992 - probe_loss: 0.6992 - probe_accuracy: 0.4270
# Epoch 8/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6873 - probe_loss: 0.6873 - probe_accuracy: 0.6064
# Epoch 9/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6978 - probe_loss: 0.6978 - probe_accuracy: 0.4822
# Epoch 10/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6957 - probe_loss: 0.6957 - probe_accuracy: 0.5363
# Epoch 11/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6883 - probe_loss: 0.6883 - probe_accuracy: 0.6132
# Epoch 12/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6944 - probe_loss: 0.6944 - probe_accuracy: 0.5204
# Epoch 13/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6932 - probe_loss: 0.6932 - probe_accuracy: 0.5820
# Epoch 14/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6969 - probe_loss: 0.6969 - probe_accuracy: 0.4180
# Epoch 15/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6954 - probe_loss: 0.6954 - probe_accuracy: 0.4617
# Epoch 16/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6910 - probe_loss: 0.6910 - probe_accuracy: 0.5191
# Epoch 17/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6960 - probe_loss: 0.6960 - probe_accuracy: 0.4785
# Epoch 18/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6903 - probe_loss: 0.6903 - probe_accuracy: 0.5103
# Epoch 19/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6923 - probe_loss: 0.6923 - probe_accuracy: 0.4439
# Epoch 20/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6890 - probe_loss: 0.6890 - probe_accuracy: 0.5330
# Epoch 21/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6957 - probe_loss: 0.6957 - probe_accuracy: 0.4783
# Epoch 22/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6883 - probe_loss: 0.6883 - probe_accuracy: 0.5366
# Epoch 23/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6905 - probe_loss: 0.6905 - probe_accuracy: 0.5825
# Epoch 24/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6977 - probe_loss: 0.6977 - probe_accuracy: 0.4711
# Epoch 25/30
# 126/126 [==============================] - 1s 9ms/step - loss: 0.6888 - probe_loss: 0.6888 - probe_accuracy: 0.5056
# Epoch 26/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6893 - probe_loss: 0.6893 - probe_accuracy: 0.5325
# Epoch 27/30
# 126/126 [==============================] - 1s 9ms/step - loss: 0.6955 - probe_loss: 0.6955 - probe_accuracy: 0.4809
# Epoch 28/30
# 126/126 [==============================] - 1s 9ms/step - loss: 0.6894 - probe_loss: 0.6894 - probe_accuracy: 0.5531
# Epoch 29/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6929 - probe_loss: 0.6929 - probe_accuracy: 0.4691
# Epoch 30/30
# 126/126 [==============================] - 1s 9ms/step - loss: 0.6896 - probe_loss: 0.6896 - probe_accuracy: 0.5372
# Restoring model weights from the end of the best epoch.
# Epoch 00030: early stopping
# 13. CNN: accuracy = 42.857142857142854%, precision = 0.38095238095238093, recall = 0.42105263157894735, f1 = 0.4
# Confusion matrix:
# [[10 13]
#  [11  8]]
# Build finished in 0:00:00
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# 13. CNN (SNN conversion): accuracy = 54.761904761904766%, precision = 0.5, recall = 0.5263157894736842, f1 = 0.5128205128205129
# Confusion matrix:
# [[13 10]
#  [ 9 10]]
# Running ANN and SNN for file: dataset_result\P14.npz
# X (train) shape: (126, 1, 5040) Y (train) shape: (126, 1, 2)
# X (test) shape: (42, 1, 5040) Y (test) shape: (42, 1, 2)
# Build finished in 0:00:00
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Epoch 1/30
# 126/126 [==============================] - 4s 8ms/step - loss: 0.6943 - probe_loss: 0.6943 - probe_accuracy: 0.4804
# Epoch 2/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6945 - probe_loss: 0.6945 - probe_accuracy: 0.4859
# Epoch 3/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6980 - probe_loss: 0.6980 - probe_accuracy: 0.5295
# Epoch 4/30
# 126/126 [==============================] - 1s 9ms/step - loss: 0.6955 - probe_loss: 0.6955 - probe_accuracy: 0.5065
# Epoch 5/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6924 - probe_loss: 0.6924 - probe_accuracy: 0.4782
# Epoch 6/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.7044 - probe_loss: 0.7044 - probe_accuracy: 0.4660
# Epoch 7/30
# 126/126 [==============================] - 1s 9ms/step - loss: 0.7006 - probe_loss: 0.7006 - probe_accuracy: 0.4804
# Epoch 8/30
# 126/126 [==============================] - 1s 9ms/step - loss: 0.6979 - probe_loss: 0.6979 - probe_accuracy: 0.5160
# Epoch 9/30
# 126/126 [==============================] - 2s 14ms/step - loss: 0.6940 - probe_loss: 0.6940 - probe_accuracy: 0.5088
# Epoch 10/30
# 126/126 [==============================] - 1s 10ms/step - loss: 0.6919 - probe_loss: 0.6919 - probe_accuracy: 0.5184
# Epoch 11/30
# 126/126 [==============================] - 1s 10ms/step - loss: 0.6938 - probe_loss: 0.6938 - probe_accuracy: 0.4886
# Epoch 12/30
# 126/126 [==============================] - 1s 11ms/step - loss: 0.6976 - probe_loss: 0.6976 - probe_accuracy: 0.4949
# Epoch 13/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6912 - probe_loss: 0.6912 - probe_accuracy: 0.5685
# Restoring model weights from the end of the best epoch.
# Epoch 00013: early stopping
# 14. CNN: accuracy = 45.23809523809524%, precision = 0.47058823529411764, recall = 0.36363636363636365, f1 = 0.41025641025641024
# Confusion matrix:
# [[11  9]
#  [14  8]]
# Build finished in 0:00:00
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# 14. CNN (SNN conversion): accuracy = 61.904761904761905%, precision = 0.65, recall = 0.5909090909090909, f1 = 0.6190476190476191
# Confusion matrix:
# [[13  7]
#  [ 9 13]]
# Running ANN and SNN for file: dataset_result\P15.npz
# X (train) shape: (126, 1, 5040) Y (train) shape: (126, 1, 2)
# X (test) shape: (42, 1, 5040) Y (test) shape: (42, 1, 2)
# Build finished in 0:00:00
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Epoch 1/30
# 126/126 [==============================] - 4s 8ms/step - loss: 0.6942 - probe_loss: 0.6942 - probe_accuracy: 0.5031
# Epoch 2/30
#  - ETA: 0s - loss: 0.6936 - probe_loss: 0.6936 - probe_accuracy: 0.5586
# Epoch 3/30
# 126/126 [==============================] - 1s 9ms/step - loss: 0.6952 - probe_loss: 0.6952 - probe_accuracy: 0.4532
# Epoch 4/30
# 126/126 [==============================] - 1s 9ms/step - loss: 0.6895 - probe_loss: 0.6895 - probe_accuracy: 0.5997
# Epoch 5/30
# 126/126 [==============================] - 1s 11ms/step - loss: 0.6926 - probe_loss: 0.6926 - probe_accuracy: 0.5250
# Epoch 6/30
# 126/126 [==============================] - 1s 8ms/step - loss: 0.6972 - probe_loss: 0.6972 - probe_accuracy: 0.4662
# Epoch 7/30
# 126/126 [==============================] - 1s 9ms/step - loss: 0.6965 - probe_loss: 0.6965 - probe_accuracy: 0.4505
# Epoch 8/30
# ...
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:588: UserWarning: Activation type <function softmax_v2 at 0x000001A757CC1A60> does not have a native Nengo equivalent; falling back to a TensorNode
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\simulator.py:1765: UserWarning: Number of elements (1) in ['ndarray'] does not match number of Nodes (3); consider using an explicit input dictionary in this case, so that the assignment of data to objects is unambiguous.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: Layer type Dropout does not have a registered converter. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: average_pooling2d.padding has value same != valid, which is not supported. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: Cannot convert BatchNormalization layer to native Nengo objects unless inference_only=True or layer.trainable=False. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:588: UserWarning: Activation type <function softmax_v2 at 0x000001A757CC1A60> does not have a native Nengo equivalent; falling back to a TensorNode
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\simulator.py:1765: UserWarning: Number of elements (1) in ['ndarray'] does not match number of Nodes (3); consider using an explicit input dictionary in this case, so that the assignment of data to objects is unambiguous.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: Layer type Dropout does not have a registered converter. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: average_pooling2d.padding has value same != valid, which is not supported. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: Cannot convert BatchNormalization layer to native Nengo objects unless inference_only=True or layer.trainable=False. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:588: UserWarning: Activation type <function softmax_v2 at 0x000001A757CC1A60> does not have a native Nengo equivalent; falling back to a TensorNode
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\simulator.py:1765: UserWarning: Number of elements (1) in ['ndarray'] does not match number of Nodes (3); consider using an explicit input dictionary in this case, so that the assignment of data to objects is unambiguous.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: Layer type Dropout does not have a registered converter. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: average_pooling2d.padding has value same != valid, which is not supported. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: Cannot convert BatchNormalization layer to native Nengo objects unless inference_only=True or layer.trainable=False. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:588: UserWarning: Activation type <function softmax_v2 at 0x000001A757CC1A60> does not have a native Nengo equivalent; falling back to a TensorNode
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\simulator.py:1765: UserWarning: Number of elements (1) in ['ndarray'] does not match number of Nodes (3); consider using an explicit input dictionary in this case, so that the assignment of data to objects is unambiguous.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: Layer type Dropout does not have a registered converter. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: average_pooling2d.padding has value same != valid, which is not supported. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: Cannot convert BatchNormalization layer to native Nengo objects unless inference_only=True or layer.trainable=False. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:588: UserWarning: Activation type <function softmax_v2 at 0x000001A757CC1A60> does not have a native Nengo equivalent; falling back to a TensorNode
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\simulator.py:1765: UserWarning: Number of elements (1) in ['ndarray'] does not match number of Nodes (3); consider using an explicit input dictionary in this case, so that the assignment of data to objects is unambiguous.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: Layer type Dropout does not have a registered converter. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: average_pooling2d.padding has value same != valid, which is not supported. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: Cannot convert BatchNormalization layer to native Nengo objects unless inference_only=True or layer.trainable=False. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:588: UserWarning: Activation type <function softmax_v2 at 0x000001A757CC1A60> does not have a native Nengo equivalent; falling back to a TensorNode
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\simulator.py:1765: UserWarning: Number of elements (1) in ['ndarray'] does not match number of Nodes (3); consider using an explicit input dictionary in this case, so that the assignment of data to objects is unambiguous.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: Layer type Dropout does not have a registered converter. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: average_pooling2d.padding has value same != valid, which is not supported. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: Cannot convert BatchNormalization layer to native Nengo objects unless inference_only=True or layer.trainable=False. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:588: UserWarning: Activation type <function softmax_v2 at 0x000001A757CC1A60> does not have a native Nengo equivalent; falling back to a TensorNode
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\simulator.py:1765: UserWarning: Number of elements (1) in ['ndarray'] does not match number of Nodes (3); consider using an explicit input dictionary in this case, so that the assignment of data to objects is unambiguous.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: Layer type Dropout does not have a registered converter. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: average_pooling2d.padding has value same != valid, which is not supported. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: Cannot convert BatchNormalization layer to native Nengo objects unless inference_only=True or layer.trainable=False. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:588: UserWarning: Activation type <function softmax_v2 at 0x000001A757CC1A60> does not have a native Nengo equivalent; falling back to a TensorNode
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\simulator.py:1765: UserWarning: Number of elements (1) in ['ndarray'] does not match number of Nodes (3); consider using an explicit input dictionary in this case, so that the assignment of data to objects is unambiguous.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: Layer type Dropout does not have a registered converter. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: average_pooling2d.padding has value same != valid, which is not supported. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: Cannot convert BatchNormalization layer to native Nengo objects unless inference_only=True or layer.trainable=False. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:588: UserWarning: Activation type <function softmax_v2 at 0x000001A757CC1A60> does not have a native Nengo equivalent; falling back to a TensorNode
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\simulator.py:1765: UserWarning: Number of elements (1) in ['ndarray'] does not match number of Nodes (3); consider using an explicit input dictionary in this case, so that the assignment of data to objects is unambiguous.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: Layer type Dropout does not have a registered converter. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: average_pooling2d.padding has value same != valid, which is not supported. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: Cannot convert BatchNormalization layer to native Nengo objects unless inference_only=True or layer.trainable=False. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:588: UserWarning: Activation type <function softmax_v2 at 0x000001A757CC1A60> does not have a native Nengo equivalent; falling back to a TensorNode
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\simulator.py:1765: UserWarning: Number of elements (1) in ['ndarray'] does not match number of Nodes (3); consider using an explicit input dictionary in this case, so that the assignment of data to objects is unambiguous.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: Layer type Dropout does not have a registered converter. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: average_pooling2d.padding has value same != valid, which is not supported. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: Cannot convert BatchNormalization layer to native Nengo objects unless inference_only=True or layer.trainable=False. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:588: UserWarning: Activation type <function softmax_v2 at 0x000001A757CC1A60> does not have a native Nengo equivalent; falling back to a TensorNode
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\simulator.py:1765: UserWarning: Number of elements (1) in ['ndarray'] does not match number of Nodes (3); consider using an explicit input dictionary in this case, so that the assignment of data to objects is unambiguous.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: Layer type Dropout does not have a registered converter. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: average_pooling2d.padding has value same != valid, which is not supported. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: Cannot convert BatchNormalization layer to native Nengo objects unless inference_only=True or layer.trainable=False. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:588: UserWarning: Activation type <function softmax_v2 at 0x000001A757CC1A60> does not have a native Nengo equivalent; falling back to a TensorNode
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\simulator.py:1765: UserWarning: Number of elements (1) in ['ndarray'] does not match number of Nodes (3); consider using an explicit input dictionary in this case, so that the assignment of data to objects is unambiguous.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: Layer type Dropout does not have a registered converter. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: average_pooling2d.padding has value same != valid, which is not supported. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: Cannot convert BatchNormalization layer to native Nengo objects unless inference_only=True or layer.trainable=False. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:588: UserWarning: Activation type <function softmax_v2 at 0x000001A757CC1A60> does not have a native Nengo equivalent; falling back to a TensorNode
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\simulator.py:1765: UserWarning: Number of elements (1) in ['ndarray'] does not match number of Nodes (3); consider using an explicit input dictionary in this case, so that the assignment of data to objects is unambiguous.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: Layer type Dropout does not have a registered converter. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: average_pooling2d.padding has value same != valid, which is not supported. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: Cannot convert BatchNormalization layer to native Nengo objects unless inference_only=True or layer.trainable=False. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:588: UserWarning: Activation type <function softmax_v2 at 0x000001A757CC1A60> does not have a native Nengo equivalent; falling back to a TensorNode
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\simulator.py:1765: UserWarning: Number of elements (1) in ['ndarray'] does not match number of Nodes (3); consider using an explicit input dictionary in this case, so that the assignment of data to objects is unambiguous.
#   warnings.warn(

# %%
df = utils.create_data_df(ann, snn, num_participants)

# Rename iterations to participants
df = df.rename(columns={'iterations': 'participant'})

df
# Out:
#     participant  ann_accuracy  ann_precision  ann_recall    ann_f1  \
# 0             1      0.400000       0.500000    0.166667  0.250000
# 1             2      0.404762       0.368421    0.350000  0.358974
# 2             3      0.476190       0.476190    0.476190  0.476190
# 3             4      0.476190       0.428571    0.300000  0.352941
# 4             5      0.571429       0.555556    0.500000  0.526316
# 5             6      0.547619       0.600000    0.521739  0.558140
# 6             7      0.523810       0.533333    0.380952  0.444444
# 7             8      0.380952       0.363636    0.400000  0.380952
# 8             9      0.428571       0.363636    0.190476  0.250000
# 9            10      0.357143       0.363636    0.380952  0.372093
# 10           11      0.523810       0.500000    0.500000  0.500000
# 11           12      0.452381       0.461538    0.272727  0.342857
# 12           13      0.428571       0.380952    0.421053  0.400000
# 13           14      0.452381       0.470588    0.363636  0.410256
# 14           15      0.523810       0.523810    0.523810  0.523810
# 15           16      0.452381       0.500000    0.434783  0.465116
# 16           17      0.452381       0.458333    0.523810  0.488889
# 17           18      0.428571       0.352941    0.315789  0.333333
#
#     snn_accuracy  snn_precision  snn_recall    snn_f1
# 0       0.400000       0.500000    0.222222  0.307692
# 1       0.333333       0.250000    0.200000  0.222222
# 2       0.380952       0.368421    0.333333  0.350000
# 3       0.500000       0.461538    0.300000  0.363636
# 4       0.523810       0.500000    0.450000  0.473684
# 5       0.547619       0.611111    0.478261  0.536585
# 6       0.523810       0.533333    0.380952  0.444444
# 7       0.428571       0.409091    0.450000  0.428571
# 8       0.404762       0.333333    0.190476  0.242424
# 9       0.404762       0.400000    0.380952  0.390244
# 10      0.547619       0.526316    0.500000  0.512821
# 11      0.428571       0.416667    0.227273  0.294118
# 12      0.547619       0.500000    0.526316  0.512821
# 13      0.619048       0.650000    0.590909  0.619048
# 14      0.476190       0.480000    0.571429  0.521739
# 15      0.476190       0.526316    0.434783  0.476190
# 16      0.523810       0.521739    0.571429  0.545455
# 17      0.452381       0.375000    0.315789  0.342857

# %%
os.makedirs(data_output_folder, exist_ok=True)
df.to_excel(os.path.join(data_output_folder, iteration_data_file_name))

'Statistics for iterations successfully saved.'
# Out:
# 'Statistics for iterations successfully saved.'

# %%
df_stats = utils.create_stats_df(df)
df_stats
# Out:
#   models  average_accuracy  max_accuracy  accuracy_std  average_precision  \
# 0    ann          0.460053      0.571429      0.059164           0.455619
# 1    snn          0.473280      0.619048      0.074170           0.464604
#
#    max_precision  average_recall  max_recall  average_f1    max_f1
# 0           0.60        0.390144    0.523810    0.413017  0.558140
# 1           0.65        0.395785    0.590909    0.421364  0.619048

# %%
# Save the statistics
df_stats.to_excel(os.path.join(data_output_folder, iteration_stats_file_name))

'File with statistics successfully saved.'
# Out:
# 'File with statistics successfully saved.'

# %%
# Print confusion matrices
utils.print_confusion_matrices(ann, snn)
# Out:
# Confusion matrices for the ANN:
# [[ 9  3]
#  [15  3]]
#
# [[10 12]
#  [13  7]]
#
# [[10 11]
#  [11 10]]
#
# [[14  8]
#  [14  6]]
#
# [[14  8]
#  [10 10]]
#
# [[11  8]
#  [11 12]]
#
# [[14  7]
#  [13  8]]
#
# [[ 8 14]
#  [12  8]]
#
# [[14  7]
#  [17  4]]
#
# [[ 7 14]
#  [13  8]]
#
# [[12 10]
#  [10 10]]
#
# [[13  7]
#  [16  6]]
#
# [[10 13]
#  [11  8]]
#
# [[11  9]
#  [14  8]]
#
# [[11 10]
#  [10 11]]
#
# [[ 9 10]
#  [13 10]]
#
# [[ 8 13]
#  [10 11]]
#
# [[12 11]
#  [13  6]]
#
# Confusion matrices for the SNN
# [[ 8  4]
#  [14  4]]
#
# [[10 12]
#  [16  4]]
#
# [[ 9 12]
#  [14  7]]
#
# [[15  7]
#  [14  6]]
#
# [[13  9]
#  [11  9]]
#
# [[12  7]
#  [12 11]]
#
# [[14  7]
#  [13  8]]
#
# [[ 9 13]
#  [11  9]]
#
# [[13  8]
#  [17  4]]
#
# [[ 9 12]
#  [13  8]]
#
# [[13  9]
#  [10 10]]
#
# [[13  7]
#  [17  5]]
#
# [[13 10]
#  [ 9 10]]
#
# [[13  7]
#  [ 9 13]]
#
# [[ 8 13]
#  [ 9 12]]
#
# [[10  9]
#  [13 10]]
#
# [[10 11]
#  [ 9 12]]
#
# [[13 10]
#  [13  6]]
