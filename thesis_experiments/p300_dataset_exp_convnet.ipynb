# %%
# Necessary imports

import os
import statistics
import nengo
import keras
import pandas as pd
from sklearn import metrics
import tensorflow as tf
import json
import nengo_dl
import numpy as np
from scipy.io import loadmat
from sklearn.model_selection import train_test_split, ShuffleSplit
from tensorflow.python.keras import Input, Model
from tensorflow.python.keras.callbacks import EarlyStopping
from tensorflow.python.keras.layers import Conv2D, BatchNormalization, Dropout, AveragePooling2D, Flatten, Dense
from keras import backend as K

# %%
# First load the dataset and set seeds for consistency
# The dataset should be by default saved in ../datasets/VarekaGTNEpochs.mat
# The file can be downloaded here https://dataverse.harvard.edu/dataset.xhtml?persistentId=doi:10.7910/DVN/G9RRLN
dataset_path = os.path.join('..', 'datasets', 'VarekaGTNEpochs.mat')

params_folder_path = 'nengo_network_params' # path to saved parameters
os.makedirs('nengo_network_params', exist_ok=True)

seed = 0 # constant seed
np.random.seed(seed)
tf.random.set_seed(seed)

# %%
mat = loadmat(dataset_path)
target_data, non_target_data = mat['allTargetData'], mat['allNonTargetData'] # get target and non-target data
features = np.concatenate((target_data, non_target_data))

# target labels are represented as (1, 0) vector, non target labels are represented as (0, 1) vector
target_labels = np.tile(np.array([1, 0]), (target_data.shape[0], 1)) # set 'target' as (1, 0) vector
non_target_labels = np.tile(np.array([0, 1]), (non_target_data.shape[0], 1)) # set 'non target' as (0, 1) vector
labels = np.vstack((target_labels, non_target_labels)) # concatenate target and non target labels

# filter noise above 100 uV
threshold = 100.0
x_result, y_result = [], []
for i in range(features.shape[0]):
    if not np.max(np.abs(features[i])) > threshold:
        x_result.append(features[i])
        y_result.append(labels[i])

# Save data to numpy array
features, labels = np.array(x_result), np.array(y_result)
features = features.reshape((features.shape[0], 1, -1))
labels = labels.reshape((labels.shape[0], 1, -1))

# Print shapes
f'Features shape: {features.shape}, Labels shape: {labels.shape}'
# Out:
# 'Features shape: (8036, 1, 3600), Labels shape: (8036, 1, 2)'

# %%
# Define function to create the CNN model
# Slightly modified version from https://www.sciencedirect.com/science/article/pii/S1746809419304185
def create_model():
    """
    Function to create tensorflow model
    """
    inp = Input(shape=(3, 1200, 1), name='input_layer')
    conv2d = Conv2D(filters=6, kernel_size=(3, 3), activation=tf.nn.relu)(inp)
    dropout1 = Dropout(0.5, seed=seed)(conv2d)
    avg_pooling = AveragePooling2D(pool_size=(1, 8), padding='same')(dropout1)
    flatten = Flatten()(avg_pooling)
    dense1 = Dense(100, activation=tf.nn.relu)(flatten)
    batch_norm = BatchNormalization()(dense1)
    dropout2 = Dropout(0.5, seed=seed)(batch_norm)
    output = Dense(2, activation=tf.nn.softmax, name='output_layer')(dropout2)

    return Model(inputs=inp, outputs=output)

# %%
def get_metrics(simulator, output_layer, x_test, y_test, minibatch_size, network_name):
    """
    Function for calculating metrics
    :param simulator: simulator instance
    :param input_layer: input layer reference
    :param output_layer: output layer reference
    :param x_test: features of the testing subset
    :param y_test: labels of the testing subset
    :param network_name: name of the network
    :return: accuracy, recall and precision metrics
    """

    # Truncate the remaining number of samples since the predict function does use minibatch
    samples = (x_test.shape[0] // minibatch_size ) * minibatch_size
    x_test, y_test = x_test[:samples], y_test[:samples]

    predictions = simulator.predict(x_test)[output_layer] # get result from output layer when predicting on x_test
    predictions = predictions[:,-1,:] # get the last timestep
    predictions_argm = np.argmax(predictions, axis=-1) # get predicted label

    y_test = np.squeeze(y_test, axis=1) # remove time dimension
    y_test_argm = np.argmax(y_test, axis=-1) # get labels

    precision = metrics.precision_score(y_true=y_test_argm, y_pred=predictions_argm, average='binary') # get precision score
    recall = metrics.recall_score(y_true=y_test_argm, y_pred=predictions_argm, average='binary') # get recall
    f1 = metrics.f1_score(y_true=y_test_argm, y_pred=predictions_argm, average='binary')
    accuracy = metrics.accuracy_score(y_true=y_test_argm, y_pred=predictions_argm) # get accuracy
    confusion_matrix = metrics.confusion_matrix(y_true=y_test_argm, y_pred=predictions_argm)

    # Log the statistics
    print(f'{network_name}: accuracy = {accuracy * 100}%, precision = {precision}, '
          f'recall = {recall}, f1 = {f1}')
    print('Confusion matrix:')
    print(confusion_matrix)

    return accuracy, precision, recall, f1, confusion_matrix

# Define functions to run the analog and spiking networks

def run_ann(model, train, valid, test, params_save_path, iteration, shuffle_training=True):
    """
    Run ann via Nengo simulator. This fits the given model with the training data (train) and validates it using validation
    data (valid). Then accuracy is calculated using the test data (test) and weights are saved to params_save_path
    :param shuffle_training: whether to shuffle data (default true)
    :param model: tensorflow model created from create_model() function
    :param train: pair of features and labels from training data
    :param valid: pair of features and labels from validation data
    :param test: pair of features and labels from test data
    :param params_save_path: output path to save weights of the network for SNN testing
    :return accuracy on test data
    """

    # unwrap into training and testing data for each subset
    x_train, y_train = train[0], train[1]
    x_valid, y_valid = valid[0], valid[1]
    x_test, y_test = test[0], test[1]

    converter = nengo_dl.Converter(model)
    with nengo_dl.Simulator(converter.net, minibatch_size=64) as simulator:
        # Compile the model with binary cross-entropy and Adam optimizer
        simulator.compile(
            optimizer=keras.optimizers.Adam(),
            loss=keras.losses.BinaryCrossentropy(),
            metrics=['accuracy']
        )

        input_layer = converter.inputs[model.get_layer('input_layer')] # get nengo input layer
        output_layer = converter.outputs[model.get_layer('output_layer')] # get nengo output layer

        simulator.fit(
            x={ input_layer: x_train }, y={ output_layer: y_train },
            validation_data=({ input_layer: x_valid }, { output_layer: y_valid }),
            epochs=30,
            shuffle=shuffle_training,
            callbacks=[EarlyStopping(patience=5, verbose=1, restore_best_weights=True)] # early stop to avoid overfitting
        ) # train model

        simulator.save_params(params_save_path) # save params for SNN

        accuracy, precision, recall, f1, confusion_matrix = get_metrics(simulator, output_layer, x_test, y_test,
                                                  minibatch_size=simulator.minibatch_size,
                                                  network_name=f'{iteration}. ANN')

        return {
            'accuracy': accuracy,
            'precision': precision,
            'recall': recall,
            'f1': f1,
            'confusion_matrix': confusion_matrix
        }


def run_snn(model, test, params_load_path, timesteps, scale_firing_rates, synapse, iteration):
    """
    Runs SNN on test data. Loads pre-trained weights from params_load path and uses timesteps, scale_firing_rates and synapse
    parameters for simulator.
    :param model: reference to the tensorflow model
    :param test: reference to the test features and labels
    :param params_load_path: path to the saved weights of the ANN
    :param timesteps: number of timesteps - i.e. how long is the input streamed to the network
    :param scale_firing_rates: firing rate scaling - amplifies spikes
    :param synapse: synaptic smoothing
    :param iteration: iteration to print the result
    :return: accuracy calculated from predicted data
    """

    # Conversion of the TensorFlow model to a spiking Nengo model
    converter = nengo_dl.Converter(
        model=model,
        swap_activations={ tf.nn.relu: nengo.SpikingRectifiedLinear() },
        scale_firing_rates=scale_firing_rates,
        synapse=synapse
    )

    x_test, y_test = test[0], test[1]

    with converter.net:
        nengo_dl.configure_settings(stateful=False)

    output_layer = converter.outputs[model.get_layer('output_layer')] # output layer for simulator
    x_test_time_tiled = np.tile(x_test, (1, timesteps, 1)) # tile x_test to match desired timesteps for simulator

    with nengo_dl.Simulator(converter.net, minibatch_size=41, progress_bar=False) as simulator:
        simulator.load_params(params_load_path)

        name = f'{iteration}. SNN [timesteps={timesteps}, scale_firing_rates={scale_firing_rates}, synapse={synapse}]'
        accuracy, precision, recall, f1, confusion_matrix = get_metrics(simulator, output_layer, x_test_time_tiled, y_test,
                                                  minibatch_size=simulator.minibatch_size,
                                                  network_name=name)

        return {
            'accuracy': accuracy,
            'precision': precision,
            'recall': recall,
            'f1': f1,
            'confusion_matrix': confusion_matrix
        }

# %%
# Split the dataset into training and testing data
x_train, x_test, y_train, y_test = train_test_split(features, labels, test_size=0.25, random_state=seed, shuffle=True)

print(f'Train features shape: {x_train.shape}, train labels shape: {y_train.shape}')
print(f'Test features shape: {x_test.shape}, test labels shape: {y_test.shape}')

# Arrays to store results from the ANN and the SNN
ann, snn = [], {}

# Configuration for the spiking network with format: timesteps, scale_firing_rates, synapse
snn_config = [
    [50, 1000, 0.01], # best performing parameters for simulator
    [50, 1000, None], # synaptic smoothing turned off
    [50, 1, 0.01], # spike scaling turned off
    [50, 1, None] # everything turned off, only RELU is swapped for spiking RELU
]

variants = []
for variant in snn_config:
        # name of the configuration
        name = f'snn [timesteps={variant[0]}, scaling={variant[1]}, synapse=None]' if variant[2] is None \
            else 'snn [timesteps={}, scaling={}, synapse={:3f}]'.format(variant[0], int(variant[1]), variant[2])
        variants.append(name)
        snn[name] = []
# Out:
# Train features shape: (6027, 1, 3600), train labels shape: (6027, 1, 2)
# Test features shape: (2009, 1, 3600), test labels shape: (2009, 1, 2)

# %%
num_iterations = 30 # 30 iterations of CV
iteration = 1 # number of the current iteration
val_size = 0.25 # 25% of the data is used as validation data
for train_idx, val_idx in ShuffleSplit(n_splits=num_iterations, test_size=val_size, random_state=seed).split(x_train):
    print(f'Iteration: {iteration}')

    # Split all training data into current training data and validation data
    x_train_curr, y_train_curr = x_train[train_idx], y_train[train_idx]
    x_val_curr, y_val_curr = x_train[val_idx], y_train[val_idx]

    # Set params path
    params_path = os.path.join(params_folder_path, f'params_iter_{iteration}')

    # Create an untrained model
    model = create_model()

    # Run the analog network - train and evaluate
     # run ann
    ann_result = run_ann(model=model,
                         train=(x_train_curr, y_train_curr),
                         valid=(x_val_curr, y_val_curr),
                         test=(x_test, y_test),
                         params_save_path=params_path,
                         iteration=iteration
                         )
    K.clear_session() # clear session
    ann.append(ann_result) # append the result to the ANN array

    # Create an array where results for each configuration of the spiking network will be stored
    snn_config_results = []
    for i, variant_conf in enumerate(snn_config):
        snn_result = run_snn(model=model,
                          test=(x_test, y_test),
                          params_load_path=params_path,
                          timesteps=variant_conf[0],
                          scale_firing_rates=variant_conf[1],
                          synapse=variant_conf[2],
                          iteration=iteration
                          )
        K.clear_session() # clear session
        snn[variants[i]].append(snn_result) # save results

    del model # delete the model (if this is not called it "may" create a memory leak - depends on the simulation machine)
    iteration += 1
# Out:
# Iteration: 1
# Build finished in 0:00:00
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Epoch 1/30
# 70/70 [==============================] - 6s 23ms/step - loss: 1.1642 - probe_loss: 1.1642 - probe_accuracy: 0.5388 - val_loss: 0.9014 - val_probe_loss: 0.9014 - val_probe_accuracy: 0.5761
# Epoch 2/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.8336 - probe_loss: 0.8336 - probe_accuracy: 0.5830 - val_loss: 0.6994 - val_probe_loss: 0.6994 - val_probe_accuracy: 0.6209
# Epoch 3/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.7378 - probe_loss: 0.7378 - probe_accuracy: 0.6067 - val_loss: 0.6862 - val_probe_loss: 0.6862 - val_probe_accuracy: 0.6073
# Epoch 4/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6990 - probe_loss: 0.6990 - probe_accuracy: 0.6089 - val_loss: 0.6743 - val_probe_loss: 0.6743 - val_probe_accuracy: 0.6209
# Epoch 5/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6712 - probe_loss: 0.6712 - probe_accuracy: 0.6314 - val_loss: 0.6609 - val_probe_loss: 0.6609 - val_probe_accuracy: 0.6230
# Epoch 6/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6550 - probe_loss: 0.6550 - probe_accuracy: 0.6332 - val_loss: 0.6579 - val_probe_loss: 0.6579 - val_probe_accuracy: 0.6352
# Epoch 7/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6205 - probe_loss: 0.6205 - probe_accuracy: 0.6566 - val_loss: 0.6585 - val_probe_loss: 0.6585 - val_probe_accuracy: 0.6202
# Epoch 8/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6413 - probe_loss: 0.6413 - probe_accuracy: 0.6462 - val_loss: 0.6589 - val_probe_loss: 0.6589 - val_probe_accuracy: 0.6202
# Epoch 9/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6243 - probe_loss: 0.6243 - probe_accuracy: 0.6551 - val_loss: 0.6560 - val_probe_loss: 0.6560 - val_probe_accuracy: 0.6250
# Epoch 10/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6117 - probe_loss: 0.6117 - probe_accuracy: 0.6722 - val_loss: 0.6566 - val_probe_loss: 0.6566 - val_probe_accuracy: 0.6264
# Epoch 11/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6194 - probe_loss: 0.6194 - probe_accuracy: 0.6672 - val_loss: 0.6573 - val_probe_loss: 0.6573 - val_probe_accuracy: 0.6189
# Epoch 12/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6121 - probe_loss: 0.6121 - probe_accuracy: 0.6610 - val_loss: 0.6582 - val_probe_loss: 0.6582 - val_probe_accuracy: 0.6114
# Epoch 13/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6066 - probe_loss: 0.6066 - probe_accuracy: 0.6763 - val_loss: 0.6621 - val_probe_loss: 0.6621 - val_probe_accuracy: 0.6087
# Epoch 14/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6060 - probe_loss: 0.6060 - probe_accuracy: 0.6658 - val_loss: 0.6731 - val_probe_loss: 0.6731 - val_probe_accuracy: 0.6223
# Restoring model weights from the end of the best epoch.
# Epoch 00014: early stopping
# 1. ANN: accuracy = 63.40725806451613%, precision = 0.6228150873965042, recall = 0.6817724068479355, f1 = 0.6509615384615384
# Confusion matrix:
# [[581 410]
#  [316 677]]
# 1. SNN [timesteps=50, scale_firing_rates=1000, synapse=0.01]: accuracy = 63.41463414634146%, precision = 0.6229508196721312, recall = 0.6805970149253732, f1 = 0.6504992867332382
# Confusion matrix:
# [[590 414]
#  [321 684]]
# 1. SNN [timesteps=50, scale_firing_rates=1000, synapse=None]: accuracy = 63.76306620209059%, precision = 0.6264840182648402, recall = 0.6825870646766169, f1 = 0.6533333333333333
# Confusion matrix:
# [[595 409]
#  [319 686]]
# 1. SNN [timesteps=50, scale_firing_rates=1, synapse=0.01]: accuracy = 52.11548033847685%, precision = 0.5155684286748733, recall = 0.708457711442786, f1 = 0.5968147527242246
# Confusion matrix:
# [[335 669]
#  [293 712]]
# 1. SNN [timesteps=50, scale_firing_rates=1, synapse=None]: accuracy = 52.663016426082635%, precision = 0.518646408839779, recall = 0.7472636815920398, f1 = 0.6123114553607827
# Confusion matrix:
# [[307 697]
#  [254 751]]
# Iteration: 2
# Build finished in 0:00:00
# Optimization finished in 0:00:00
# Construction finished in 0:00:01
# Epoch 1/30
# 70/70 [==============================] - 6s 23ms/step - loss: 1.0740 - probe_loss: 1.0740 - probe_accuracy: 0.5356 - val_loss: 0.8232 - val_probe_loss: 0.8232 - val_probe_accuracy: 0.5999
# Epoch 2/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.8144 - probe_loss: 0.8144 - probe_accuracy: 0.5876 - val_loss: 0.7917 - val_probe_loss: 0.7917 - val_probe_accuracy: 0.5917
# Epoch 3/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.7414 - probe_loss: 0.7414 - probe_accuracy: 0.5976 - val_loss: 0.6702 - val_probe_loss: 0.6702 - val_probe_accuracy: 0.6162
# Epoch 4/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6991 - probe_loss: 0.6991 - probe_accuracy: 0.6107 - val_loss: 0.6580 - val_probe_loss: 0.6580 - val_probe_accuracy: 0.6162
# Epoch 5/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6793 - probe_loss: 0.6793 - probe_accuracy: 0.6175 - val_loss: 0.6562 - val_probe_loss: 0.6562 - val_probe_accuracy: 0.6230
# Epoch 6/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6617 - probe_loss: 0.6617 - probe_accuracy: 0.6215 - val_loss: 0.6582 - val_probe_loss: 0.6582 - val_probe_accuracy: 0.6128
# Epoch 7/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6362 - probe_loss: 0.6362 - probe_accuracy: 0.6420 - val_loss: 0.6438 - val_probe_loss: 0.6438 - val_probe_accuracy: 0.6311
# Epoch 8/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6329 - probe_loss: 0.6329 - probe_accuracy: 0.6440 - val_loss: 0.6506 - val_probe_loss: 0.6506 - val_probe_accuracy: 0.6257
# Epoch 9/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6500 - probe_loss: 0.6500 - probe_accuracy: 0.6239 - val_loss: 0.6572 - val_probe_loss: 0.6572 - val_probe_accuracy: 0.6243
# Epoch 10/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6162 - probe_loss: 0.6162 - probe_accuracy: 0.6551 - val_loss: 0.6510 - val_probe_loss: 0.6510 - val_probe_accuracy: 0.6168
# Epoch 11/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6175 - probe_loss: 0.6175 - probe_accuracy: 0.6622 - val_loss: 0.6609 - val_probe_loss: 0.6609 - val_probe_accuracy: 0.6060
# Epoch 12/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6150 - probe_loss: 0.6150 - probe_accuracy: 0.6706 - val_loss: 0.6536 - val_probe_loss: 0.6536 - val_probe_accuracy: 0.6257
# Restoring model weights from the end of the best epoch.
# Epoch 00012: early stopping
# 2. ANN: accuracy = 64.11290322580645%, precision = 0.6146938775510205, recall = 0.7583081570996979, f1 = 0.678990081154193
# Confusion matrix:
# [[519 472]
#  [240 753]]
# 2. SNN [timesteps=50, scale_firing_rates=1000, synapse=0.01]: accuracy = 64.36037829766053%, precision = 0.6166263115415658, recall = 0.7601990049751244, f1 = 0.6809269162210339
# Confusion matrix:
# [[529 475]
#  [241 764]]
# 2. SNN [timesteps=50, scale_firing_rates=1000, synapse=None]: accuracy = 64.21105027376804%, precision = 0.6155088852988692, recall = 0.7582089552238805, f1 = 0.6794471689701294
# Confusion matrix:
# [[528 476]
#  [243 762]]
# 2. SNN [timesteps=50, scale_firing_rates=1, synapse=0.01]: accuracy = 52.91189646590343%, precision = 0.5241605241605242, recall = 0.6368159203980099, f1 = 0.5750224618149146
# Confusion matrix:
# [[423 581]
#  [365 640]]
# 2. SNN [timesteps=50, scale_firing_rates=1, synapse=None]: accuracy = 52.16525634644101%, precision = 0.5166163141993958, recall = 0.6805970149253732, f1 = 0.5873765564620009
# Confusion matrix:
# [[364 640]
#  [321 684]]
# Iteration: 3
# Build finished in 0:00:00
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Epoch 1/30
# 70/70 [==============================] - 6s 23ms/step - loss: 1.1101 - probe_loss: 1.1101 - probe_accuracy: 0.5234 - val_loss: 0.8257 - val_probe_loss: 0.8257 - val_probe_accuracy: 0.6080
# Epoch 2/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.8034 - probe_loss: 0.8034 - probe_accuracy: 0.5828 - val_loss: 0.7124 - val_probe_loss: 0.7124 - val_probe_accuracy: 0.5904
# Epoch 3/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.7742 - probe_loss: 0.7742 - probe_accuracy: 0.5866 - val_loss: 0.6862 - val_probe_loss: 0.6862 - val_probe_accuracy: 0.6033
# Epoch 4/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6994 - probe_loss: 0.6994 - probe_accuracy: 0.6223 - val_loss: 0.6543 - val_probe_loss: 0.6543 - val_probe_accuracy: 0.6202
# Epoch 5/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6730 - probe_loss: 0.6730 - probe_accuracy: 0.6067 - val_loss: 0.6598 - val_probe_loss: 0.6598 - val_probe_accuracy: 0.6080
# Epoch 6/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6687 - probe_loss: 0.6687 - probe_accuracy: 0.6286 - val_loss: 0.6569 - val_probe_loss: 0.6569 - val_probe_accuracy: 0.6128
# Epoch 7/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6395 - probe_loss: 0.6395 - probe_accuracy: 0.6461 - val_loss: 0.6555 - val_probe_loss: 0.6555 - val_probe_accuracy: 0.6223
# Epoch 8/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6267 - probe_loss: 0.6267 - probe_accuracy: 0.6466 - val_loss: 0.6464 - val_probe_loss: 0.6464 - val_probe_accuracy: 0.6284
# Epoch 9/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6282 - probe_loss: 0.6282 - probe_accuracy: 0.6617 - val_loss: 0.6530 - val_probe_loss: 0.6530 - val_probe_accuracy: 0.6209
# Epoch 10/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6127 - probe_loss: 0.6127 - probe_accuracy: 0.6679 - val_loss: 0.6488 - val_probe_loss: 0.6488 - val_probe_accuracy: 0.6393
# Epoch 11/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6103 - probe_loss: 0.6103 - probe_accuracy: 0.6797 - val_loss: 0.6543 - val_probe_loss: 0.6543 - val_probe_accuracy: 0.6277
# Epoch 12/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6166 - probe_loss: 0.6166 - probe_accuracy: 0.6628 - val_loss: 0.6536 - val_probe_loss: 0.6536 - val_probe_accuracy: 0.6196
# Epoch 13/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6123 - probe_loss: 0.6123 - probe_accuracy: 0.6636 - val_loss: 0.6545 - val_probe_loss: 0.6545 - val_probe_accuracy: 0.6291
# Restoring model weights from the end of the best epoch.
# Epoch 00013: early stopping
# 3. ANN: accuracy = 63.659274193548384%, precision = 0.6162393162393163, recall = 0.7260825780463243, f1 = 0.6666666666666666
# Confusion matrix:
# [[542 449]
#  [272 721]]
# 3. SNN [timesteps=50, scale_firing_rates=1000, synapse=0.01]: accuracy = 64.0119462419114%, precision = 0.6192893401015228, recall = 0.7283582089552239, f1 = 0.6694101508916324
# Confusion matrix:
# [[554 450]
#  [273 732]]
# 3. SNN [timesteps=50, scale_firing_rates=1000, synapse=None]: accuracy = 64.0119462419114%, precision = 0.6186868686868687, recall = 0.7313432835820896, f1 = 0.6703146374829002
# Confusion matrix:
# [[551 453]
#  [270 735]]
# 3. SNN [timesteps=50, scale_firing_rates=1, synapse=0.01]: accuracy = 52.264808362369344%, precision = 0.5189456342668863, recall = 0.6268656716417911, f1 = 0.5678233438485805
# Confusion matrix:
# [[420 584]
#  [375 630]]
# 3. SNN [timesteps=50, scale_firing_rates=1, synapse=None]: accuracy = 54.00696864111498%, precision = 0.534468085106383, recall = 0.6248756218905472, f1 = 0.5761467889908257
# Confusion matrix:
# [[457 547]
#  [377 628]]
# Iteration: 4
# Build finished in 0:00:00
# Optimization finished in 0:00:00
# Construction finished in 0:00:01
# Epoch 1/30
# 70/70 [==============================] - 6s 24ms/step - loss: 1.0493 - probe_loss: 1.0493 - probe_accuracy: 0.5348 - val_loss: 0.8037 - val_probe_loss: 0.8037 - val_probe_accuracy: 0.5740
# Epoch 2/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.8140 - probe_loss: 0.8140 - probe_accuracy: 0.5735 - val_loss: 0.7133 - val_probe_loss: 0.7133 - val_probe_accuracy: 0.6073
# Epoch 3/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.7268 - probe_loss: 0.7268 - probe_accuracy: 0.5952 - val_loss: 0.6804 - val_probe_loss: 0.6804 - val_probe_accuracy: 0.6141
# Epoch 4/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6713 - probe_loss: 0.6713 - probe_accuracy: 0.6277 - val_loss: 0.6744 - val_probe_loss: 0.6744 - val_probe_accuracy: 0.6060
# Epoch 5/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6669 - probe_loss: 0.6669 - probe_accuracy: 0.6127 - val_loss: 0.6714 - val_probe_loss: 0.6714 - val_probe_accuracy: 0.6121
# Epoch 6/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6532 - probe_loss: 0.6532 - probe_accuracy: 0.6443 - val_loss: 0.6561 - val_probe_loss: 0.6561 - val_probe_accuracy: 0.6094
# Epoch 7/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6275 - probe_loss: 0.6275 - probe_accuracy: 0.6542 - val_loss: 0.6571 - val_probe_loss: 0.6571 - val_probe_accuracy: 0.6087
# Epoch 8/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6372 - probe_loss: 0.6372 - probe_accuracy: 0.6371 - val_loss: 0.6564 - val_probe_loss: 0.6564 - val_probe_accuracy: 0.6087
# Epoch 9/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6423 - probe_loss: 0.6423 - probe_accuracy: 0.6354 - val_loss: 0.6588 - val_probe_loss: 0.6588 - val_probe_accuracy: 0.6175
# Epoch 10/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6271 - probe_loss: 0.6271 - probe_accuracy: 0.6548 - val_loss: 0.6603 - val_probe_loss: 0.6603 - val_probe_accuracy: 0.6175
# Epoch 11/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6169 - probe_loss: 0.6169 - probe_accuracy: 0.6643 - val_loss: 0.6712 - val_probe_loss: 0.6712 - val_probe_accuracy: 0.6019
# Restoring model weights from the end of the best epoch.
# Epoch 00011: early stopping
# 4. ANN: accuracy = 63.40725806451613%, precision = 0.653272101033295, recall = 0.5730110775427996, f1 = 0.6105150214592274
# Confusion matrix:
# [[689 302]
#  [424 569]]
# 4. SNN [timesteps=50, scale_firing_rates=1000, synapse=0.01]: accuracy = 63.01642608262817%, precision = 0.6478555304740407, recall = 0.5711442786069652, f1 = 0.6070861977789529
# Confusion matrix:
# [[692 312]
#  [431 574]]
# 4. SNN [timesteps=50, scale_firing_rates=1000, synapse=None]: accuracy = 63.21553011448482%, precision = 0.6497747747747747, recall = 0.5741293532338309, f1 = 0.6096143687268885
# Confusion matrix:
# [[693 311]
#  [428 577]]
# 4. SNN [timesteps=50, scale_firing_rates=1, synapse=0.01]: accuracy = 52.36436037829766%, precision = 0.518957345971564, recall = 0.6537313432835821, f1 = 0.5785997357992073
# Confusion matrix:
# [[395 609]
#  [348 657]]
# 4. SNN [timesteps=50, scale_firing_rates=1, synapse=None]: accuracy = 52.961672473867594%, precision = 0.5225563909774437, recall = 0.6915422885572139, f1 = 0.5952890792291221
# Confusion matrix:
# [[369 635]
#  [310 695]]
# Iteration: 5
# Build finished in 0:00:00
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Epoch 1/30
# 70/70 [==============================] - 6s 23ms/step - loss: 1.0224 - probe_loss: 1.0224 - probe_accuracy: 0.5564 - val_loss: 0.7832 - val_probe_loss: 0.7832 - val_probe_accuracy: 0.5978
# Epoch 2/30
# 70/70 [==============================] - 1s 10ms/step - loss: 0.8111 - probe_loss: 0.8111 - probe_accuracy: 0.5729 - val_loss: 0.7110 - val_probe_loss: 0.7110 - val_probe_accuracy: 0.6033
# Epoch 3/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.7548 - probe_loss: 0.7548 - probe_accuracy: 0.5806 - val_loss: 0.6694 - val_probe_loss: 0.6694 - val_probe_accuracy: 0.6067
# Epoch 4/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6708 - probe_loss: 0.6708 - probe_accuracy: 0.6365 - val_loss: 0.6713 - val_probe_loss: 0.6713 - val_probe_accuracy: 0.6080
# Epoch 5/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6611 - probe_loss: 0.6611 - probe_accuracy: 0.6223 - val_loss: 0.6569 - val_probe_loss: 0.6569 - val_probe_accuracy: 0.6162
# Epoch 6/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6568 - probe_loss: 0.6568 - probe_accuracy: 0.6295 - val_loss: 0.6597 - val_probe_loss: 0.6597 - val_probe_accuracy: 0.6087
# Epoch 7/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6288 - probe_loss: 0.6288 - probe_accuracy: 0.6414 - val_loss: 0.6707 - val_probe_loss: 0.6707 - val_probe_accuracy: 0.5944
# Epoch 8/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6239 - probe_loss: 0.6239 - probe_accuracy: 0.6446 - val_loss: 0.6656 - val_probe_loss: 0.6656 - val_probe_accuracy: 0.6107
# Epoch 9/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6345 - probe_loss: 0.6345 - probe_accuracy: 0.6569 - val_loss: 0.6611 - val_probe_loss: 0.6611 - val_probe_accuracy: 0.5992
# Epoch 10/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6145 - probe_loss: 0.6145 - probe_accuracy: 0.6644 - val_loss: 0.6663 - val_probe_loss: 0.6663 - val_probe_accuracy: 0.6073
# Restoring model weights from the end of the best epoch.
# Epoch 00010: early stopping
# 5. ANN: accuracy = 62.298387096774185%, precision = 0.5985518905872889, recall = 0.7492447129909365, f1 = 0.6654740608228981
# Confusion matrix:
# [[492 499]
#  [249 744]]
# 5. SNN [timesteps=50, scale_firing_rates=1000, synapse=0.01]: accuracy = 62.61821801891488%, precision = 0.6006339144215531, recall = 0.7542288557213931, f1 = 0.6687251874724306
# Confusion matrix:
# [[500 504]
#  [247 758]]
# 5. SNN [timesteps=50, scale_firing_rates=1000, synapse=None]: accuracy = 62.518666002986556%, precision = 0.6001589825119237, recall = 0.7512437810945274, f1 = 0.6672558550596553
# Confusion matrix:
# [[501 503]
#  [250 755]]
# 5. SNN [timesteps=50, scale_firing_rates=1, synapse=0.01]: accuracy = 53.111000497760074%, precision = 0.5275590551181102, recall = 0.6, f1 = 0.5614525139664804
# Confusion matrix:
# [[464 540]
#  [402 603]]
# 5. SNN [timesteps=50, scale_firing_rates=1, synapse=None]: accuracy = 51.71727227476356%, precision = 0.5144270403957131, recall = 0.6208955223880597, f1 = 0.562669071235347
# Confusion matrix:
# [[415 589]
#  [381 624]]
# Iteration: 6
# Build finished in 0:00:00
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Epoch 1/30
# 70/70 [==============================] - 7s 23ms/step - loss: 1.0755 - probe_loss: 1.0755 - probe_accuracy: 0.5415 - val_loss: 0.8598 - val_probe_loss: 0.8598 - val_probe_accuracy: 0.5883
# Epoch 2/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.8143 - probe_loss: 0.8143 - probe_accuracy: 0.5906 - val_loss: 0.7157 - val_probe_loss: 0.7157 - val_probe_accuracy: 0.5999
# Epoch 3/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.7407 - probe_loss: 0.7407 - probe_accuracy: 0.5908 - val_loss: 0.6833 - val_probe_loss: 0.6833 - val_probe_accuracy: 0.5938
# Epoch 4/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6888 - probe_loss: 0.6888 - probe_accuracy: 0.6181 - val_loss: 0.6634 - val_probe_loss: 0.6634 - val_probe_accuracy: 0.6107
# Epoch 5/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6694 - probe_loss: 0.6694 - probe_accuracy: 0.6211 - val_loss: 0.6753 - val_probe_loss: 0.6753 - val_probe_accuracy: 0.5971
# Epoch 6/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6571 - probe_loss: 0.6571 - probe_accuracy: 0.6460 - val_loss: 0.6644 - val_probe_loss: 0.6644 - val_probe_accuracy: 0.6114
# Epoch 7/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6336 - probe_loss: 0.6336 - probe_accuracy: 0.6515 - val_loss: 0.6565 - val_probe_loss: 0.6565 - val_probe_accuracy: 0.6107
# Epoch 8/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6391 - probe_loss: 0.6391 - probe_accuracy: 0.6406 - val_loss: 0.6596 - val_probe_loss: 0.6596 - val_probe_accuracy: 0.6121
# Epoch 9/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6298 - probe_loss: 0.6298 - probe_accuracy: 0.6506 - val_loss: 0.6579 - val_probe_loss: 0.6579 - val_probe_accuracy: 0.6114
# Epoch 10/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6282 - probe_loss: 0.6282 - probe_accuracy: 0.6417 - val_loss: 0.6549 - val_probe_loss: 0.6549 - val_probe_accuracy: 0.6107
# Epoch 11/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6207 - probe_loss: 0.6207 - probe_accuracy: 0.6499 - val_loss: 0.6581 - val_probe_loss: 0.6581 - val_probe_accuracy: 0.6209
# Epoch 12/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6142 - probe_loss: 0.6142 - probe_accuracy: 0.6678 - val_loss: 0.6591 - val_probe_loss: 0.6591 - val_probe_accuracy: 0.6080
# Epoch 13/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6081 - probe_loss: 0.6081 - probe_accuracy: 0.6841 - val_loss: 0.6685 - val_probe_loss: 0.6685 - val_probe_accuracy: 0.6005
# Epoch 14/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6066 - probe_loss: 0.6066 - probe_accuracy: 0.6629 - val_loss: 0.6796 - val_probe_loss: 0.6796 - val_probe_accuracy: 0.6060
# Epoch 15/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6027 - probe_loss: 0.6027 - probe_accuracy: 0.6755 - val_loss: 0.6641 - val_probe_loss: 0.6641 - val_probe_accuracy: 0.6094
# Restoring model weights from the end of the best epoch.
# Epoch 00015: early stopping
# 6. ANN: accuracy = 63.81048387096774%, precision = 0.6230975828111012, recall = 0.7009063444108762, f1 = 0.6597156398104267
# Confusion matrix:
# [[570 421]
#  [297 696]]
# 6. SNN [timesteps=50, scale_firing_rates=1000, synapse=0.01]: accuracy = 63.962170233947234%, precision = 0.6244464127546502, recall = 0.7014925373134329, f1 = 0.6607310215557638
# Confusion matrix:
# [[580 424]
#  [300 705]]
# 6. SNN [timesteps=50, scale_firing_rates=1000, synapse=None]: accuracy = 64.16127426580388%, precision = 0.6262178919397697, recall = 0.7034825870646766, f1 = 0.6626054358013121
# Confusion matrix:
# [[582 422]
#  [298 707]]
# 6. SNN [timesteps=50, scale_firing_rates=1, synapse=0.01]: accuracy = 51.667496266799404%, precision = 0.5132398753894081, recall = 0.6557213930348259, f1 = 0.5757972913936217
# Confusion matrix:
# [[379 625]
#  [346 659]]
# 6. SNN [timesteps=50, scale_firing_rates=1, synapse=None]: accuracy = 53.95719263315082%, precision = 0.531496062992126, recall = 0.6716417910447762, f1 = 0.5934065934065935
# Confusion matrix:
# [[409 595]
#  [330 675]]
# Iteration: 7
# Build finished in 0:00:00
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Epoch 1/30
# 70/70 [==============================] - 7s 24ms/step - loss: 1.0126 - probe_loss: 1.0126 - probe_accuracy: 0.5567 - val_loss: 0.7440 - val_probe_loss: 0.7440 - val_probe_accuracy: 0.6141
# Epoch 2/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.8197 - probe_loss: 0.8197 - probe_accuracy: 0.5700 - val_loss: 0.7141 - val_probe_loss: 0.7141 - val_probe_accuracy: 0.6033
# Epoch 3/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.7187 - probe_loss: 0.7187 - probe_accuracy: 0.5943 - val_loss: 0.6905 - val_probe_loss: 0.6905 - val_probe_accuracy: 0.5904
# Epoch 4/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6939 - probe_loss: 0.6939 - probe_accuracy: 0.6135 - val_loss: 0.6672 - val_probe_loss: 0.6672 - val_probe_accuracy: 0.6277
# Epoch 5/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6622 - probe_loss: 0.6622 - probe_accuracy: 0.6173 - val_loss: 0.6629 - val_probe_loss: 0.6629 - val_probe_accuracy: 0.6141
# Epoch 6/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6478 - probe_loss: 0.6478 - probe_accuracy: 0.6319 - val_loss: 0.6575 - val_probe_loss: 0.6575 - val_probe_accuracy: 0.6216
# Epoch 7/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6325 - probe_loss: 0.6325 - probe_accuracy: 0.6498 - val_loss: 0.6588 - val_probe_loss: 0.6588 - val_probe_accuracy: 0.6135
# Epoch 8/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6244 - probe_loss: 0.6244 - probe_accuracy: 0.6546 - val_loss: 0.6606 - val_probe_loss: 0.6606 - val_probe_accuracy: 0.6141
# Epoch 9/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6327 - probe_loss: 0.6327 - probe_accuracy: 0.6385 - val_loss: 0.6555 - val_probe_loss: 0.6555 - val_probe_accuracy: 0.6189
# Epoch 10/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6191 - probe_loss: 0.6191 - probe_accuracy: 0.6688 - val_loss: 0.6632 - val_probe_loss: 0.6632 - val_probe_accuracy: 0.6121
# Epoch 11/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6141 - probe_loss: 0.6141 - probe_accuracy: 0.6661 - val_loss: 0.6616 - val_probe_loss: 0.6616 - val_probe_accuracy: 0.6128
# Epoch 12/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6142 - probe_loss: 0.6142 - probe_accuracy: 0.6800 - val_loss: 0.6614 - val_probe_loss: 0.6614 - val_probe_accuracy: 0.6209
# Epoch 13/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6063 - probe_loss: 0.6063 - probe_accuracy: 0.6740 - val_loss: 0.6591 - val_probe_loss: 0.6591 - val_probe_accuracy: 0.6182
# Epoch 14/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.5925 - probe_loss: 0.5925 - probe_accuracy: 0.6844 - val_loss: 0.6670 - val_probe_loss: 0.6670 - val_probe_accuracy: 0.6114
# Restoring model weights from the end of the best epoch.
# Epoch 00014: early stopping
# 7. ANN: accuracy = 63.81048387096774%, precision = 0.6190476190476191, recall = 0.7200402819738168, f1 = 0.6657355679702048
# Confusion matrix:
# [[551 440]
#  [278 715]]
# 7. SNN [timesteps=50, scale_firing_rates=1000, synapse=0.01]: accuracy = 63.91239422598307%, precision = 0.6194539249146758, recall = 0.7223880597014926, f1 = 0.6669728984841525
# Confusion matrix:
# [[558 446]
#  [279 726]]
# 7. SNN [timesteps=50, scale_firing_rates=1000, synapse=None]: accuracy = 63.862618218018916%, precision = 0.6191289496157131, recall = 0.7213930348258707, f1 = 0.6663602941176472
# Confusion matrix:
# [[558 446]
#  [280 725]]
# 7. SNN [timesteps=50, scale_firing_rates=1, synapse=0.01]: accuracy = 51.91637630662021%, precision = 0.5146286571642911, recall = 0.6825870646766169, f1 = 0.5868263473053893
# Confusion matrix:
# [[357 647]
#  [319 686]]
# 7. SNN [timesteps=50, scale_firing_rates=1, synapse=None]: accuracy = 52.51368840219014%, precision = 0.5190156599552572, recall = 0.6925373134328359, f1 = 0.5933503836317137
# Confusion matrix:
# [[359 645]
#  [309 696]]
# Iteration: 8
# Build finished in 0:00:00
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Epoch 1/30
# 70/70 [==============================] - 7s 24ms/step - loss: 1.1150 - probe_loss: 1.1150 - probe_accuracy: 0.5448 - val_loss: 0.8492 - val_probe_loss: 0.8492 - val_probe_accuracy: 0.5924
# Epoch 2/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.8176 - probe_loss: 0.8176 - probe_accuracy: 0.5976 - val_loss: 0.7168 - val_probe_loss: 0.7168 - val_probe_accuracy: 0.5802
# Epoch 3/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.7438 - probe_loss: 0.7438 - probe_accuracy: 0.6142 - val_loss: 0.6994 - val_probe_loss: 0.6994 - val_probe_accuracy: 0.5999
# Epoch 4/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.7191 - probe_loss: 0.7191 - probe_accuracy: 0.5983 - val_loss: 0.6755 - val_probe_loss: 0.6755 - val_probe_accuracy: 0.5904
# Epoch 5/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6721 - probe_loss: 0.6721 - probe_accuracy: 0.6225 - val_loss: 0.6711 - val_probe_loss: 0.6711 - val_probe_accuracy: 0.6107
# Epoch 6/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6511 - probe_loss: 0.6511 - probe_accuracy: 0.6242 - val_loss: 0.6647 - val_probe_loss: 0.6647 - val_probe_accuracy: 0.6033
# Epoch 7/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6354 - probe_loss: 0.6354 - probe_accuracy: 0.6466 - val_loss: 0.6646 - val_probe_loss: 0.6646 - val_probe_accuracy: 0.6202
# Epoch 8/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6284 - probe_loss: 0.6284 - probe_accuracy: 0.6571 - val_loss: 0.6603 - val_probe_loss: 0.6603 - val_probe_accuracy: 0.6121
# Epoch 9/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6139 - probe_loss: 0.6139 - probe_accuracy: 0.6608 - val_loss: 0.6761 - val_probe_loss: 0.6761 - val_probe_accuracy: 0.6094
# Epoch 10/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6245 - probe_loss: 0.6245 - probe_accuracy: 0.6637 - val_loss: 0.6635 - val_probe_loss: 0.6635 - val_probe_accuracy: 0.6135
# Epoch 11/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6128 - probe_loss: 0.6128 - probe_accuracy: 0.6729 - val_loss: 0.6671 - val_probe_loss: 0.6671 - val_probe_accuracy: 0.6121
# Epoch 12/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6043 - probe_loss: 0.6043 - probe_accuracy: 0.6759 - val_loss: 0.6690 - val_probe_loss: 0.6690 - val_probe_accuracy: 0.6053
# Epoch 13/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6038 - probe_loss: 0.6038 - probe_accuracy: 0.6902 - val_loss: 0.6644 - val_probe_loss: 0.6644 - val_probe_accuracy: 0.6189
# Restoring model weights from the end of the best epoch.
# Epoch 00013: early stopping
# 8. ANN: accuracy = 63.81048387096774%, precision = 0.6448893572181243, recall = 0.6163141993957704, f1 = 0.6302780638516993
# Confusion matrix:
# [[654 337]
#  [381 612]]
# 8. SNN [timesteps=50, scale_firing_rates=1000, synapse=0.01]: accuracy = 63.962170233947234%, precision = 0.6455958549222798, recall = 0.6199004975124378, f1 = 0.63248730964467
# Confusion matrix:
# [[662 342]
#  [382 623]]
# 8. SNN [timesteps=50, scale_firing_rates=1000, synapse=None]: accuracy = 63.91239422598307%, precision = 0.6443298969072165, recall = 0.6218905472636815, f1 = 0.6329113924050633
# Confusion matrix:
# [[659 345]
#  [380 625]]
# 8. SNN [timesteps=50, scale_firing_rates=1, synapse=0.01]: accuracy = 51.81682429069189%, precision = 0.5124077800134138, recall = 0.7601990049751244, f1 = 0.6121794871794871
# Confusion matrix:
# [[277 727]
#  [241 764]]
# 8. SNN [timesteps=50, scale_firing_rates=1, synapse=None]: accuracy = 51.96615231458437%, precision = 0.5137931034482759, recall = 0.7412935323383084, f1 = 0.6069246435845215
# Confusion matrix:
# [[299 705]
#  [260 745]]
# Iteration: 9
# Build finished in 0:00:00
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Epoch 1/30
# 70/70 [==============================] - 6s 23ms/step - loss: 1.0385 - probe_loss: 1.0385 - probe_accuracy: 0.5589 - val_loss: 0.7974 - val_probe_loss: 0.7974 - val_probe_accuracy: 0.6202
# Epoch 2/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.8108 - probe_loss: 0.8108 - probe_accuracy: 0.5833 - val_loss: 0.7017 - val_probe_loss: 0.7017 - val_probe_accuracy: 0.6230
# Epoch 3/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.7376 - probe_loss: 0.7376 - probe_accuracy: 0.5898 - val_loss: 0.6780 - val_probe_loss: 0.6780 - val_probe_accuracy: 0.6264
# Epoch 4/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.7008 - probe_loss: 0.7008 - probe_accuracy: 0.6218 - val_loss: 0.6739 - val_probe_loss: 0.6739 - val_probe_accuracy: 0.6243
# Epoch 5/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6787 - probe_loss: 0.6787 - probe_accuracy: 0.6263 - val_loss: 0.6686 - val_probe_loss: 0.6686 - val_probe_accuracy: 0.6175
# Epoch 6/30
# 70/70 [==============================] - 1s 12ms/step - loss: 0.6613 - probe_loss: 0.6613 - probe_accuracy: 0.6305 - val_loss: 0.6590 - val_probe_loss: 0.6590 - val_probe_accuracy: 0.6162
# Epoch 7/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6416 - probe_loss: 0.6416 - probe_accuracy: 0.6414 - val_loss: 0.6562 - val_probe_loss: 0.6562 - val_probe_accuracy: 0.6304
# Epoch 8/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6260 - probe_loss: 0.6260 - probe_accuracy: 0.6580 - val_loss: 0.6538 - val_probe_loss: 0.6538 - val_probe_accuracy: 0.6196
# Epoch 9/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6417 - probe_loss: 0.6417 - probe_accuracy: 0.6280 - val_loss: 0.6576 - val_probe_loss: 0.6576 - val_probe_accuracy: 0.6420
# Epoch 10/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6139 - probe_loss: 0.6139 - probe_accuracy: 0.6738 - val_loss: 0.6572 - val_probe_loss: 0.6572 - val_probe_accuracy: 0.6277
# Epoch 11/30
# 70/70 [==============================] - 1s 12ms/step - loss: 0.6224 - probe_loss: 0.6224 - probe_accuracy: 0.6540 - val_loss: 0.6568 - val_probe_loss: 0.6568 - val_probe_accuracy: 0.6325
# Epoch 12/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.5980 - probe_loss: 0.5980 - probe_accuracy: 0.6933 - val_loss: 0.6516 - val_probe_loss: 0.6516 - val_probe_accuracy: 0.6372
# Epoch 13/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6155 - probe_loss: 0.6155 - probe_accuracy: 0.6599 - val_loss: 0.6566 - val_probe_loss: 0.6566 - val_probe_accuracy: 0.6250
# Epoch 14/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6077 - probe_loss: 0.6077 - probe_accuracy: 0.6786 - val_loss: 0.6537 - val_probe_loss: 0.6537 - val_probe_accuracy: 0.6135
# Epoch 15/30
# 70/70 [==============================] - 1s 12ms/step - loss: 0.6140 - probe_loss: 0.6140 - probe_accuracy: 0.6624 - val_loss: 0.6591 - val_probe_loss: 0.6591 - val_probe_accuracy: 0.6270
# Epoch 16/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6092 - probe_loss: 0.6092 - probe_accuracy: 0.6650 - val_loss: 0.6569 - val_probe_loss: 0.6569 - val_probe_accuracy: 0.6141
# Epoch 17/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.5986 - probe_loss: 0.5986 - probe_accuracy: 0.6753 - val_loss: 0.6547 - val_probe_loss: 0.6547 - val_probe_accuracy: 0.6216
# Restoring model weights from the end of the best epoch.
# Epoch 00017: early stopping
# 9. ANN: accuracy = 62.298387096774185%, precision = 0.6170009551098377, recall = 0.6505538771399798, f1 = 0.6333333333333332
# Confusion matrix:
# [[590 401]
#  [347 646]]
# 9. SNN [timesteps=50, scale_firing_rates=1000, synapse=0.01]: accuracy = 62.76754604280737%, precision = 0.6215704824976348, recall = 0.6537313432835821, f1 = 0.6372453928225024
# Confusion matrix:
# [[604 400]
#  [348 657]]
# 9. SNN [timesteps=50, scale_firing_rates=1000, synapse=None]: accuracy = 62.17023394723743%, precision = 0.6158940397350994, recall = 0.6477611940298508, f1 = 0.6314258001939865
# Confusion matrix:
# [[598 406]
#  [354 651]]
# 9. SNN [timesteps=50, scale_firing_rates=1, synapse=0.01]: accuracy = 52.264808362369344%, precision = 0.5178018575851393, recall = 0.6656716417910448, f1 = 0.5824989116238571
# Confusion matrix:
# [[381 623]
#  [336 669]]
# 9. SNN [timesteps=50, scale_firing_rates=1, synapse=None]: accuracy = 50.970632155301146%, precision = 0.5075528700906344, recall = 0.6686567164179105, f1 = 0.5770717045942465
# Confusion matrix:
# [[352 652]
#  [333 672]]
# Iteration: 10
# Build finished in 0:00:00
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Epoch 1/30
# 70/70 [==============================] - 7s 28ms/step - loss: 1.1365 - probe_loss: 1.1365 - probe_accuracy: 0.5623 - val_loss: 0.8627 - val_probe_loss: 0.8627 - val_probe_accuracy: 0.5938
# Epoch 2/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.8361 - probe_loss: 0.8361 - probe_accuracy: 0.5801 - val_loss: 0.7413 - val_probe_loss: 0.7413 - val_probe_accuracy: 0.6094
# Epoch 3/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.7558 - probe_loss: 0.7558 - probe_accuracy: 0.6068 - val_loss: 0.7009 - val_probe_loss: 0.7009 - val_probe_accuracy: 0.6175
# Epoch 4/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.7328 - probe_loss: 0.7328 - probe_accuracy: 0.5978 - val_loss: 0.6754 - val_probe_loss: 0.6754 - val_probe_accuracy: 0.6107
# Epoch 5/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6713 - probe_loss: 0.6713 - probe_accuracy: 0.6271 - val_loss: 0.6578 - val_probe_loss: 0.6578 - val_probe_accuracy: 0.6196
# Epoch 6/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6476 - probe_loss: 0.6476 - probe_accuracy: 0.6490 - val_loss: 0.6602 - val_probe_loss: 0.6602 - val_probe_accuracy: 0.6094
# Epoch 7/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6442 - probe_loss: 0.6442 - probe_accuracy: 0.6460 - val_loss: 0.6644 - val_probe_loss: 0.6644 - val_probe_accuracy: 0.6046
# Epoch 8/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6396 - probe_loss: 0.6396 - probe_accuracy: 0.6399 - val_loss: 0.6538 - val_probe_loss: 0.6538 - val_probe_accuracy: 0.6175
# Epoch 9/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6282 - probe_loss: 0.6282 - probe_accuracy: 0.6562 - val_loss: 0.6561 - val_probe_loss: 0.6561 - val_probe_accuracy: 0.6209
# Epoch 10/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6172 - probe_loss: 0.6172 - probe_accuracy: 0.6609 - val_loss: 0.6515 - val_probe_loss: 0.6515 - val_probe_accuracy: 0.6270
# Epoch 11/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6043 - probe_loss: 0.6043 - probe_accuracy: 0.6662 - val_loss: 0.6624 - val_probe_loss: 0.6624 - val_probe_accuracy: 0.6135
# Epoch 12/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6242 - probe_loss: 0.6242 - probe_accuracy: 0.6452 - val_loss: 0.6517 - val_probe_loss: 0.6517 - val_probe_accuracy: 0.6168
# Epoch 13/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6213 - probe_loss: 0.6213 - probe_accuracy: 0.6655 - val_loss: 0.6556 - val_probe_loss: 0.6556 - val_probe_accuracy: 0.6236
# Epoch 14/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6167 - probe_loss: 0.6167 - probe_accuracy: 0.6638 - val_loss: 0.6573 - val_probe_loss: 0.6573 - val_probe_accuracy: 0.6243
# Epoch 15/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6024 - probe_loss: 0.6024 - probe_accuracy: 0.6802 - val_loss: 0.6529 - val_probe_loss: 0.6529 - val_probe_accuracy: 0.6175
# Restoring model weights from the end of the best epoch.
# Epoch 00015: early stopping
# 10. ANN: accuracy = 62.903225806451616%, precision = 0.6215704824976348, recall = 0.6616314199395771, f1 = 0.6409756097560976
# Confusion matrix:
# [[591 400]
#  [336 657]]
# 10. SNN [timesteps=50, scale_firing_rates=1000, synapse=0.01]: accuracy = 62.81732205077153%, precision = 0.6201117318435754, recall = 0.6626865671641791, f1 = 0.6406926406926406
# Confusion matrix:
# [[596 408]
#  [339 666]]
# 10. SNN [timesteps=50, scale_firing_rates=1000, synapse=None]: accuracy = 63.06620209059234%, precision = 0.6230121608980356, recall = 0.6626865671641791, f1 = 0.6422372227579557
# Confusion matrix:
# [[601 403]
#  [339 666]]
# 10. SNN [timesteps=50, scale_firing_rates=1, synapse=0.01]: accuracy = 53.40965654554505%, precision = 0.5262757044935262, recall = 0.6875621890547263, f1 = 0.5962036238136325
# Confusion matrix:
# [[382 622]
#  [314 691]]
# 10. SNN [timesteps=50, scale_firing_rates=1, synapse=None]: accuracy = 52.762568442010945%, precision = 0.5224358974358975, recall = 0.6487562189054726, f1 = 0.5787838437638704
# Confusion matrix:
# [[408 596]
#  [353 652]]
# Iteration: 11
# Build finished in 0:00:00
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Epoch 1/30
# 70/70 [==============================] - 6s 23ms/step - loss: 1.0201 - probe_loss: 1.0201 - probe_accuracy: 0.5624 - val_loss: 0.8036 - val_probe_loss: 0.8036 - val_probe_accuracy: 0.6114
# Epoch 2/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.8165 - probe_loss: 0.8165 - probe_accuracy: 0.6002 - val_loss: 0.7097 - val_probe_loss: 0.7097 - val_probe_accuracy: 0.6073
# Epoch 3/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.7432 - probe_loss: 0.7432 - probe_accuracy: 0.5940 - val_loss: 0.6665 - val_probe_loss: 0.6665 - val_probe_accuracy: 0.6243
# Epoch 4/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6816 - probe_loss: 0.6816 - probe_accuracy: 0.6293 - val_loss: 0.6575 - val_probe_loss: 0.6575 - val_probe_accuracy: 0.6304
# Epoch 5/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6772 - probe_loss: 0.6772 - probe_accuracy: 0.6166 - val_loss: 0.6520 - val_probe_loss: 0.6520 - val_probe_accuracy: 0.6277
# Epoch 6/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6493 - probe_loss: 0.6493 - probe_accuracy: 0.6311 - val_loss: 0.6493 - val_probe_loss: 0.6493 - val_probe_accuracy: 0.6284
# Epoch 7/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6310 - probe_loss: 0.6310 - probe_accuracy: 0.6577 - val_loss: 0.6526 - val_probe_loss: 0.6526 - val_probe_accuracy: 0.6270
# Epoch 8/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6307 - probe_loss: 0.6307 - probe_accuracy: 0.6438 - val_loss: 0.6549 - val_probe_loss: 0.6549 - val_probe_accuracy: 0.6304
# Epoch 9/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6196 - probe_loss: 0.6196 - probe_accuracy: 0.6602 - val_loss: 0.6461 - val_probe_loss: 0.6461 - val_probe_accuracy: 0.6291
# Epoch 10/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6195 - probe_loss: 0.6195 - probe_accuracy: 0.6586 - val_loss: 0.6502 - val_probe_loss: 0.6502 - val_probe_accuracy: 0.6420
# Epoch 11/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6140 - probe_loss: 0.6140 - probe_accuracy: 0.6604 - val_loss: 0.6496 - val_probe_loss: 0.6496 - val_probe_accuracy: 0.6345
# Epoch 12/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6107 - probe_loss: 0.6107 - probe_accuracy: 0.6673 - val_loss: 0.6581 - val_probe_loss: 0.6581 - val_probe_accuracy: 0.6270
# Epoch 13/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6102 - probe_loss: 0.6102 - probe_accuracy: 0.6697 - val_loss: 0.6544 - val_probe_loss: 0.6544 - val_probe_accuracy: 0.6175
# Epoch 14/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6082 - probe_loss: 0.6082 - probe_accuracy: 0.6626 - val_loss: 0.6484 - val_probe_loss: 0.6484 - val_probe_accuracy: 0.6223
# Restoring model weights from the end of the best epoch.
# Epoch 00014: early stopping
# 11. ANN: accuracy = 63.40725806451613%, precision = 0.6403785488958991, recall = 0.6132930513595166, f1 = 0.6265432098765431
# Confusion matrix:
# [[649 342]
#  [384 609]]
# 11. SNN [timesteps=50, scale_firing_rates=1000, synapse=0.01]: accuracy = 63.31508213041314%, precision = 0.6392931392931392, recall = 0.6119402985074627, f1 = 0.625317742755465
# Confusion matrix:
# [[657 347]
#  [390 615]]
# 11. SNN [timesteps=50, scale_firing_rates=1000, synapse=None]: accuracy = 63.11597809855649%, precision = 0.6375, recall = 0.608955223880597, f1 = 0.6229007633587786
# Confusion matrix:
# [[656 348]
#  [393 612]]
# 11. SNN [timesteps=50, scale_firing_rates=1, synapse=0.01]: accuracy = 53.210552513688405%, precision = 0.5258964143426295, recall = 0.6567164179104478, f1 = 0.5840707964601769
# Confusion matrix:
# [[409 595]
#  [345 660]]
# 11. SNN [timesteps=50, scale_firing_rates=1, synapse=None]: accuracy = 53.160776505724236%, precision = 0.5256410256410257, recall = 0.6527363184079602, f1 = 0.5823346648912561
# Confusion matrix:
# [[412 592]
#  [349 656]]
# Iteration: 12
# Build finished in 0:00:00
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Epoch 1/30
# 70/70 [==============================] - 6s 24ms/step - loss: 1.1085 - probe_loss: 1.1085 - probe_accuracy: 0.5427 - val_loss: 0.8159 - val_probe_loss: 0.8159 - val_probe_accuracy: 0.6019
# Epoch 2/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.8825 - probe_loss: 0.8825 - probe_accuracy: 0.5657 - val_loss: 0.7585 - val_probe_loss: 0.7585 - val_probe_accuracy: 0.5910
# Epoch 3/30
# 70/70 [==============================] - 1s 12ms/step - loss: 0.7528 - probe_loss: 0.7528 - probe_accuracy: 0.6136 - val_loss: 0.6727 - val_probe_loss: 0.6727 - val_probe_accuracy: 0.6155
# Epoch 4/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.7176 - probe_loss: 0.7176 - probe_accuracy: 0.6118 - val_loss: 0.6626 - val_probe_loss: 0.6626 - val_probe_accuracy: 0.6107
# Epoch 5/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6928 - probe_loss: 0.6928 - probe_accuracy: 0.6026 - val_loss: 0.6658 - val_probe_loss: 0.6658 - val_probe_accuracy: 0.6107
# Epoch 6/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6628 - probe_loss: 0.6628 - probe_accuracy: 0.6157 - val_loss: 0.6541 - val_probe_loss: 0.6541 - val_probe_accuracy: 0.6168
# Epoch 7/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6464 - probe_loss: 0.6464 - probe_accuracy: 0.6366 - val_loss: 0.6514 - val_probe_loss: 0.6514 - val_probe_accuracy: 0.6162
# Epoch 8/30
# 70/70 [==============================] - 1s 12ms/step - loss: 0.6329 - probe_loss: 0.6329 - probe_accuracy: 0.6431 - val_loss: 0.6509 - val_probe_loss: 0.6509 - val_probe_accuracy: 0.6298
# Epoch 9/30
# 70/70 [==============================] - 1s 12ms/step - loss: 0.6271 - probe_loss: 0.6271 - probe_accuracy: 0.6476 - val_loss: 0.6583 - val_probe_loss: 0.6583 - val_probe_accuracy: 0.6250
# Epoch 10/30
# 70/70 [==============================] - 1s 13ms/step - loss: 0.6193 - probe_loss: 0.6193 - probe_accuracy: 0.6495 - val_loss: 0.6559 - val_probe_loss: 0.6559 - val_probe_accuracy: 0.6162
# Epoch 11/30
# 70/70 [==============================] - 1s 12ms/step - loss: 0.6191 - probe_loss: 0.6191 - probe_accuracy: 0.6523 - val_loss: 0.6702 - val_probe_loss: 0.6702 - val_probe_accuracy: 0.6128
# Epoch 12/30
# 70/70 [==============================] - 1s 12ms/step - loss: 0.6087 - probe_loss: 0.6087 - probe_accuracy: 0.6639 - val_loss: 0.6514 - val_probe_loss: 0.6514 - val_probe_accuracy: 0.6352
# Epoch 13/30
# 70/70 [==============================] - 1s 12ms/step - loss: 0.6138 - probe_loss: 0.6138 - probe_accuracy: 0.6624 - val_loss: 0.6686 - val_probe_loss: 0.6686 - val_probe_accuracy: 0.6067
# Restoring model weights from the end of the best epoch.
# Epoch 00013: early stopping
# 12. ANN: accuracy = 63.55846774193549%, precision = 0.6313229571984436, recall = 0.6535750251762337, f1 = 0.6422563087580406
# Confusion matrix:
# [[612 379]
#  [344 649]]
# 12. SNN [timesteps=50, scale_firing_rates=1000, synapse=0.01]: accuracy = 63.51418616226978%, precision = 0.629277566539924, recall = 0.6587064676616915, f1 = 0.6436558094312104
# Confusion matrix:
# [[614 390]
#  [343 662]]
# ...
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: Cannot convert BatchNormalization layer to native Nengo objects unless inference_only=True or layer.trainable=False. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:588: UserWarning: Activation type <function softmax_v2 at 0x0000028D19F77D30> does not have a native Nengo equivalent; falling back to a TensorNode
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\simulator.py:1765: UserWarning: Number of elements (1) in ['ndarray'] does not match number of Nodes (3); consider using an explicit input dictionary in this case, so that the assignment of data to objects is unambiguous.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: Layer type Dropout does not have a registered converter. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: average_pooling2d.padding has value same != valid, which is not supported. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: Cannot convert BatchNormalization layer to native Nengo objects unless inference_only=True or layer.trainable=False. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:588: UserWarning: Activation type <function softmax_v2 at 0x0000028D19F77D30> does not have a native Nengo equivalent; falling back to a TensorNode
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\simulator.py:1765: UserWarning: Number of elements (1) in ['ndarray'] does not match number of Nodes (3); consider using an explicit input dictionary in this case, so that the assignment of data to objects is unambiguous.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: Layer type Dropout does not have a registered converter. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: average_pooling2d.padding has value same != valid, which is not supported. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: Cannot convert BatchNormalization layer to native Nengo objects unless inference_only=True or layer.trainable=False. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:588: UserWarning: Activation type <function softmax_v2 at 0x0000028D19F77D30> does not have a native Nengo equivalent; falling back to a TensorNode
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\simulator.py:1765: UserWarning: Number of elements (1) in ['ndarray'] does not match number of Nodes (3); consider using an explicit input dictionary in this case, so that the assignment of data to objects is unambiguous.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: Layer type Dropout does not have a registered converter. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: average_pooling2d.padding has value same != valid, which is not supported. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: Cannot convert BatchNormalization layer to native Nengo objects unless inference_only=True or layer.trainable=False. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:588: UserWarning: Activation type <function softmax_v2 at 0x0000028D19F77D30> does not have a native Nengo equivalent; falling back to a TensorNode
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\simulator.py:1921: UserWarning: Number of elements in input data (1507) is not evenly divisible by Simulator.minibatch_size (64); input data will be truncated.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\simulator.py:1921: UserWarning: Number of elements in input data (4520) is not evenly divisible by Simulator.minibatch_size (64); input data will be truncated.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\simulator.py:1765: UserWarning: Number of elements (1) in ['ndarray'] does not match number of Nodes (3); consider using an explicit input dictionary in this case, so that the assignment of data to objects is unambiguous.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: Layer type Dropout does not have a registered converter. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: average_pooling2d.padding has value same != valid, which is not supported. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: Cannot convert BatchNormalization layer to native Nengo objects unless inference_only=True or layer.trainable=False. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:588: UserWarning: Activation type <function softmax_v2 at 0x0000028D19F77D30> does not have a native Nengo equivalent; falling back to a TensorNode
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\simulator.py:1765: UserWarning: Number of elements (1) in ['ndarray'] does not match number of Nodes (3); consider using an explicit input dictionary in this case, so that the assignment of data to objects is unambiguous.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: Layer type Dropout does not have a registered converter. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: average_pooling2d.padding has value same != valid, which is not supported. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: Cannot convert BatchNormalization layer to native Nengo objects unless inference_only=True or layer.trainable=False. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:588: UserWarning: Activation type <function softmax_v2 at 0x0000028D19F77D30> does not have a native Nengo equivalent; falling back to a TensorNode
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\simulator.py:1765: UserWarning: Number of elements (1) in ['ndarray'] does not match number of Nodes (3); consider using an explicit input dictionary in this case, so that the assignment of data to objects is unambiguous.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: Layer type Dropout does not have a registered converter. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: average_pooling2d.padding has value same != valid, which is not supported. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: Cannot convert BatchNormalization layer to native Nengo objects unless inference_only=True or layer.trainable=False. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:588: UserWarning: Activation type <function softmax_v2 at 0x0000028D19F77D30> does not have a native Nengo equivalent; falling back to a TensorNode
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\simulator.py:1765: UserWarning: Number of elements (1) in ['ndarray'] does not match number of Nodes (3); consider using an explicit input dictionary in this case, so that the assignment of data to objects is unambiguous.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: Layer type Dropout does not have a registered converter. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: average_pooling2d.padding has value same != valid, which is not supported. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: Cannot convert BatchNormalization layer to native Nengo objects unless inference_only=True or layer.trainable=False. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:588: UserWarning: Activation type <function softmax_v2 at 0x0000028D19F77D30> does not have a native Nengo equivalent; falling back to a TensorNode
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\simulator.py:1765: UserWarning: Number of elements (1) in ['ndarray'] does not match number of Nodes (3); consider using an explicit input dictionary in this case, so that the assignment of data to objects is unambiguous.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: Layer type Dropout does not have a registered converter. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: average_pooling2d.padding has value same != valid, which is not supported. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: Cannot convert BatchNormalization layer to native Nengo objects unless inference_only=True or layer.trainable=False. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:588: UserWarning: Activation type <function softmax_v2 at 0x0000028D19F77D30> does not have a native Nengo equivalent; falling back to a TensorNode
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\simulator.py:1921: UserWarning: Number of elements in input data (1507) is not evenly divisible by Simulator.minibatch_size (64); input data will be truncated.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\simulator.py:1921: UserWarning: Number of elements in input data (4520) is not evenly divisible by Simulator.minibatch_size (64); input data will be truncated.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\simulator.py:1765: UserWarning: Number of elements (1) in ['ndarray'] does not match number of Nodes (3); consider using an explicit input dictionary in this case, so that the assignment of data to objects is unambiguous.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: Layer type Dropout does not have a registered converter. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: average_pooling2d.padding has value same != valid, which is not supported. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: Cannot convert BatchNormalization layer to native Nengo objects unless inference_only=True or layer.trainable=False. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:588: UserWarning: Activation type <function softmax_v2 at 0x0000028D19F77D30> does not have a native Nengo equivalent; falling back to a TensorNode
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\simulator.py:1765: UserWarning: Number of elements (1) in ['ndarray'] does not match number of Nodes (3); consider using an explicit input dictionary in this case, so that the assignment of data to objects is unambiguous.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: Layer type Dropout does not have a registered converter. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: average_pooling2d.padding has value same != valid, which is not supported. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: Cannot convert BatchNormalization layer to native Nengo objects unless inference_only=True or layer.trainable=False. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:588: UserWarning: Activation type <function softmax_v2 at 0x0000028D19F77D30> does not have a native Nengo equivalent; falling back to a TensorNode
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\simulator.py:1765: UserWarning: Number of elements (1) in ['ndarray'] does not match number of Nodes (3); consider using an explicit input dictionary in this case, so that the assignment of data to objects is unambiguous.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: Layer type Dropout does not have a registered converter. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: average_pooling2d.padding has value same != valid, which is not supported. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: Cannot convert BatchNormalization layer to native Nengo objects unless inference_only=True or layer.trainable=False. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:588: UserWarning: Activation type <function softmax_v2 at 0x0000028D19F77D30> does not have a native Nengo equivalent; falling back to a TensorNode
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\simulator.py:1765: UserWarning: Number of elements (1) in ['ndarray'] does not match number of Nodes (3); consider using an explicit input dictionary in this case, so that the assignment of data to objects is unambiguous.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: Layer type Dropout does not have a registered converter. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: average_pooling2d.padding has value same != valid, which is not supported. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: Cannot convert BatchNormalization layer to native Nengo objects unless inference_only=True or layer.trainable=False. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:588: UserWarning: Activation type <function softmax_v2 at 0x0000028D19F77D30> does not have a native Nengo equivalent; falling back to a TensorNode
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\simulator.py:1765: UserWarning: Number of elements (1) in ['ndarray'] does not match number of Nodes (3); consider using an explicit input dictionary in this case, so that the assignment of data to objects is unambiguous.
#   warnings.warn(

# %%
data = {
    'iterations': [x for x in range(1, num_iterations + 1)],
    'ann_accuracy': [x['accuracy'] for x in ann],
    'ann_precision': [x['precision'] for x in ann],
    'ann_recall': [x['recall'] for x in ann],
    'ann_f1': [x['f1'] for x in ann]
}

for variant_name in variants:
    data[f'{variant_name}_accuracy'] = [x['accuracy'] for x in snn[variant_name]]
    data[f'{variant_name}_precision'] = [x['precision'] for x in snn[variant_name]]
    data[f'{variant_name}_recall'] = [x['recall'] for x in snn[variant_name]]
    data[f'{variant_name}_f1'] = [x['f1'] for x in snn[variant_name]]

# %%
# Create pandas dataframe and save it to xlsx
output_folder_path = 'p300_exp_output'
os.makedirs(output_folder_path, exist_ok=True)

df = pd.DataFrame(data)
df.to_excel(os.path.join(output_folder_path, 'data_iterations.xlsx'))
print('File with iteration data successfully saved.')
# Out:
# File with iteration data successfully saved.

# %%
network_names = ['ann'] + variants # names of each network in the pandas data frame
data_stats = {
    'models': network_names,
    'average_acc': [],
    'max_acc': [],
    'std_acc': [],
    'average_precision': [],
    'max_precision': [],
    'average_recall': [],
    'max_recall': [],
    'average_f1': [],
    'max_f1': []
} # statistics from the experiment

average_acc, max_acc, std_acc = [], [], []
average_precision, max_precision = [], []
average_recall, max_recall = [], []
for network_name in network_names:
    data_stats['average_acc'].append(df[f'{network_name}_accuracy'].mean())
    data_stats['max_acc'].append(df[f'{network_name}_accuracy'].max())
    data_stats['std_acc'].append(df[f'{network_name}_accuracy'].std())

    data_stats['average_precision'].append(df[f'{network_name}_precision'].mean())
    data_stats['max_precision'].append(df[f'{network_name}_precision'].max())

    data_stats['average_recall'].append(df[f'{network_name}_recall'].mean())
    data_stats['max_recall'].append(df[f'{network_name}_recall'].max())

    data_stats['average_f1'].append(df[f'{network_name}_f1'].mean())
    data_stats['max_f1'].append(df[f'{network_name}_f1'].max())

data_stats
# Out:
# {'models': ['ann',
#   'snn [timesteps=50, scaling=1000, synapse=0.010000]',
#   'snn [timesteps=50, scaling=1000, synapse=None]',
#   'snn [timesteps=50, scaling=1, synapse=0.010000]',
#   'snn [timesteps=50, scaling=1, synapse=None]'],
#  'average_acc': [0.6338037634408603,
#   0.6346606935457111,
#   0.6342624854819976,
#   0.5227974116475859,
#   0.5217521154803385],
#  'max_acc': [0.6431451612903226,
#   0.6441015430562469,
#   0.6436037829766053,
#   0.5435540069686411,
#   0.5400696864111498],
#  'std_acc': [0.005313992352052009,
#   0.005525041526861927,
#   0.005871682520816084,
#   0.011863820015739044,
#   0.01081601290332919],
#  'average_precision': [0.6261031129726431,
#   0.6265150380045471,
#   0.6260811062287179,
#   0.5182836447733139,
#   0.5173996827496619],
#  'max_precision': [0.6611374407582938,
#   0.6631823461091754,
#   0.6592765460910152,
#   0.5355535553555355,
#   0.534468085106383],
#  'average_recall': [0.6715676401477005,
#   0.6729353233830847,
#   0.6726036484245441,
#   0.6614925373134326,
#   0.6645107794361527],
#  'max_recall': [0.7583081570996979,
#   0.7601990049751244,
#   0.7582089552238805,
#   0.7601990049751244,
#   0.7472636815920398],
#  'average_f1': [0.6464647397256298,
#   0.6473472683621824,
#   0.6469701739317336,
#   0.580566286843646,
#   0.5811522173741432],
#  'max_f1': [0.678990081154193,
#   0.6809269162210339,
#   0.6794471689701294,
#   0.6121794871794871,
#   0.6123114553607827]}

# %%
df_stats = pd.DataFrame(data_stats)
df_stats.to_excel(os.path.join(output_folder_path, 'statistics.xlsx'))
print('File with statistics successfully saved.')
# Out:
# File with statistics successfully saved.
