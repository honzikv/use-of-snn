# %%
# Necessary imports

import os
import nengo
import keras
import pandas as pd
from sklearn import metrics
import tensorflow as tf
import nengo_dl
import numpy as np
from scipy.io import loadmat
from sklearn.model_selection import train_test_split, ShuffleSplit
from tensorflow.python.keras import Input, Model
from tensorflow.python.keras.callbacks import EarlyStopping
from tensorflow.python.keras.layers import Conv2D, BatchNormalization, Dropout, AveragePooling2D, Flatten, Dense
from keras import backend as K

# %%
# First load the dataset and set seeds for consistency
# The dataset should be by default saved in ../datasets/VarekaGTNEpochs.mat
# The file can be downloaded here https://dataverse.harvard.edu/dataset.xhtml?persistentId=doi:10.7910/DVN/G9RRLN
dataset_path = os.path.join('dataset', 'VarekaGTNEpochs.mat')

params_folder_path = 'nengo_network_params' # path to saved parameters
os.makedirs('nengo_network_params', exist_ok=True)

seed = 0 # constant seed
np.random.seed(seed)
tf.random.set_seed(seed)

# %%
mat = loadmat(dataset_path)
target_data, non_target_data = mat['allTargetData'], mat['allNonTargetData'] # get target and non-target data
features = np.concatenate((target_data, non_target_data))

# Target labels are represented as (1, 0) vector, non target labels are represented as (0, 1) vector
target_labels = np.tile(np.array([1, 0]), (target_data.shape[0], 1)) # set 'target' as (1, 0) vector
non_target_labels = np.tile(np.array([0, 1]), (non_target_data.shape[0], 1)) # set 'non target' as (0, 1) vector
labels = np.vstack((target_labels, non_target_labels)) # concatenate target and non target labels

# Filter noise above 100 uV
threshold = 100.0
x_result, y_result = [], []
for i in range(features.shape[0]):
    if not np.max(np.abs(features[i])) > threshold:
        x_result.append(features[i])
        y_result.append(labels[i])

# Save data to numpy array
features, labels = np.array(x_result), np.array(y_result)
features = features.reshape((features.shape[0], 1, -1))
labels = labels.reshape((labels.shape[0], 1, -1))

# Print shapes
f'Features shape: {features.shape}, Labels shape: {labels.shape}'
# Out:
# 'Features shape: (8036, 1, 3600), Labels shape: (8036, 1, 2)'

# %%
# Define function to create the CNN model
# Slightly modified version from https://www.sciencedirect.com/science/article/pii/S1746809419304185
def create_model():
    """
    Function to create tensorflow model
    """
    inp = Input(shape=(3, 1200, 1), name='input_layer')
    conv2d = Conv2D(filters=6, kernel_size=(3, 3), activation=tf.nn.relu)(inp)
    dropout1 = Dropout(0.5, seed=seed)(conv2d)
    avg_pooling = AveragePooling2D(pool_size=(1, 8), padding='same')(dropout1)
    flatten = Flatten()(avg_pooling)
    dense1 = Dense(100, activation=tf.nn.relu)(flatten)
    batch_norm = BatchNormalization()(dense1)
    dropout2 = Dropout(0.5, seed=seed)(batch_norm)
    output = Dense(2, activation=tf.nn.softmax, name='output_layer')(dropout2)

    return Model(inputs=inp, outputs=output)

# %%
# Since we used [1,0] as true (target) we also need to reference the correct index during metrics evaluation.
# In sklearn this means that we set the pos_label to 0 instead of 1
true_ref_idx = np.argmax(np.array([1, 0]))

def get_metrics(simulator, output_layer, x_test, y_test, minibatch_size, network_name):
    """
    Function for calculating metrics
    :param simulator: simulator instance
    :param input_layer: input layer reference
    :param output_layer: output layer reference
    :param x_test: features of the testing subset
    :param y_test: labels of the testing subset
    :param network_name: name of the network
    :return: accuracy, recall and precision metrics
    """

    # Truncate the remaining number of samples since the predict function uses minibatch_size as well (i.e.
    samples = (x_test.shape[0] // minibatch_size ) * minibatch_size
    x_test, y_test = x_test[:samples], y_test[:samples]

    predictions = simulator.predict(x_test)[output_layer] # get result from output layer when predicting on x_test
    predictions = predictions[:,-1,:] # get the last timestep
    predictions_argm = np.argmax(predictions, axis=-1) # get predicted label

    y_test = np.squeeze(y_test, axis=1) # remove time dimension
    y_test_argm = np.argmax(y_test, axis=-1) # get labels, due to one-hot encoding 0 = target, 1 = non-target

    precision = metrics.precision_score(y_true=y_test_argm, y_pred=predictions_argm, pos_label=true_ref_idx) # get precision score
    recall = metrics.recall_score(y_true=y_test_argm, y_pred=predictions_argm, pos_label=true_ref_idx) # get recall
    f1 = metrics.f1_score(y_true=y_test_argm, y_pred=predictions_argm, pos_label=true_ref_idx)
    accuracy = metrics.accuracy_score(y_true=y_test_argm, y_pred=predictions_argm) # get accuracy

    # First column - "0" = target samples, second column "1" = non-target samples
    confusion_matrix = metrics.confusion_matrix(y_true=y_test_argm, y_pred=predictions_argm)

    # Log the statistics
    print(f'{network_name}: accuracy = {accuracy * 100}%, precision = {precision}, '
          f'recall = {recall}, f1 = {f1}')
    print('Confusion matrix:')
    print(confusion_matrix)

    return accuracy, precision, recall, f1, confusion_matrix

# Define functions to run the analog and spiking networks

def run_ann(model, train, valid, test, params_save_path, iteration, shuffle_training=True):
    """
    Run ann via Nengo simulator. This fits the given model with the training data (train) and validates it using validation
    data (valid). Then accuracy is calculated using the test data (test) and weights are saved to params_save_path
    :param shuffle_training: whether to shuffle data (default true)
    :param model: tensorflow model created from create_model() function
    :param train: pair of features and labels from training data
    :param valid: pair of features and labels from validation data
    :param test: pair of features and labels from test data
    :param params_save_path: output path to save weights of the network for SNN testing
    :return accuracy, precision, recall, f1 and confusion matrix from the testing data
    """

    # unwrap into training and testing data for each subset
    x_train, y_train = train[0], train[1]
    x_valid, y_valid = valid[0], valid[1]
    x_test, y_test = test[0], test[1]

    converter = nengo_dl.Converter(model)
    with nengo_dl.Simulator(converter.net, minibatch_size=64) as simulator:
        # Compile the model with binary cross-entropy and Adam optimizer
        simulator.compile(
            optimizer=keras.optimizers.Adam(),
            loss=keras.losses.BinaryCrossentropy(),
            metrics=['accuracy']
        )

        input_layer = converter.inputs[model.get_layer('input_layer')] # get nengo input layer
        output_layer = converter.outputs[model.get_layer('output_layer')] # get nengo output layer

        simulator.fit(
            x={ input_layer: x_train }, y={ output_layer: y_train },
            validation_data=({ input_layer: x_valid }, { output_layer: y_valid }),
            epochs=30,
            shuffle=shuffle_training,
            callbacks=[EarlyStopping(patience=5, verbose=1, restore_best_weights=True)] # early stop to avoid overfitting
        ) # train model

        simulator.save_params(params_save_path) # save params for SNN

        accuracy, precision, recall, f1, confusion_matrix = get_metrics(simulator, output_layer, x_test, y_test,
                                                  minibatch_size=simulator.minibatch_size,
                                                  network_name=f'{iteration}. ANN')

        return {
            'accuracy': accuracy,
            'precision': precision,
            'recall': recall,
            'f1': f1,
            'confusion_matrix': confusion_matrix
        }


def run_snn(model, test, params_load_path, timesteps, scale_firing_rates, synapse, iteration):
    """
    Runs SNN on test data. Loads pre-trained weights from params_load path and uses timesteps, scale_firing_rates and synapse
    parameters for simulator.
    :param model: reference to the tensorflow model
    :param test: reference to the test features and labels
    :param params_load_path: path to the saved weights of the ANN
    :param timesteps: number of timesteps - i.e. how long is the input streamed to the network
    :param scale_firing_rates: firing rate scaling - amplifies spikes
    :param synapse: synaptic smoothing
    :param iteration: iteration to print the result
    :return: accuracy, precision, recall, f1 and confusion matrix from the testing data
    """

    # Conversion of the TensorFlow model to a spiking Nengo model
    converter = nengo_dl.Converter(
        model=model,
        swap_activations={ tf.nn.relu: nengo.SpikingRectifiedLinear() },
        scale_firing_rates=scale_firing_rates,
        synapse=synapse
    )

    x_test, y_test = test[0], test[1] # get test features and labels

    with converter.net:
        nengo_dl.configure_settings(stateful=False)

    output_layer = converter.outputs[model.get_layer('output_layer')] # output layer for simulator
    x_test_time_tiled = np.tile(x_test, (1, timesteps, 1)) # tile x_test to match desired timesteps for simulator

    with nengo_dl.Simulator(converter.net, minibatch_size=41, progress_bar=False) as simulator:
        simulator.load_params(params_load_path)

        # Name of the network for print in get_metrics function
        name = f'{iteration}. SNN [timesteps={timesteps}, scale_firing_rates={scale_firing_rates}, synapse={synapse}]'
        accuracy, precision, recall, f1, confusion_matrix = get_metrics(simulator, output_layer, x_test_time_tiled, y_test,
                                                  minibatch_size=simulator.minibatch_size,
                                                  network_name=name)

        return {
            'accuracy': accuracy,
            'precision': precision,
            'recall': recall,
            'f1': f1,
            'confusion_matrix': confusion_matrix
        }

# %%
# Split the dataset into training and testing data
x_train, x_test, y_train, y_test = train_test_split(features, labels, test_size=0.25, random_state=seed, shuffle=True)

print(f'Train features shape: {x_train.shape}, train labels shape: {y_train.shape}')
print(f'Test features shape: {x_test.shape}, test labels shape: {y_test.shape}')

# Arrays to store results from the ANN and the SNN
ann, snn = [], {}

# Configuration for the spiking network with format: timesteps, scale_firing_rates, synapse
snn_config = [
    [50, 1000, 0.01], # best performing parameters for simulator
    [50, 1000, None], # synaptic smoothing turned off
    [50, 1, 0.01], # spike scaling turned off
    [50, 1, None] # everything turned off, only RELU is swapped for spiking RELU
]

variants = []
for variant in snn_config:
        # name of the configuration
        name = f'snn [timesteps={variant[0]}, scaling={variant[1]}, synapse=None]' if variant[2] is None \
            else 'snn [timesteps={}, scaling={}, synapse={:3f}]'.format(variant[0], int(variant[1]), variant[2])
        variants.append(name)
        snn[name] = []
# Out:
# Train features shape: (6027, 1, 3600), train labels shape: (6027, 1, 2)
# Test features shape: (2009, 1, 3600), test labels shape: (2009, 1, 2)

# %%
num_iterations = 30 # 30 iterations of CV
iteration = 1 # number of the current iteration
val_size = 0.25 # 25% of the data is used as validation data
for train_idx, val_idx in ShuffleSplit(n_splits=num_iterations, test_size=val_size, random_state=seed).split(x_train):
    print(f'Iteration: {iteration}')

    # Split all training data into current training data and validation data
    x_train_curr, y_train_curr = x_train[train_idx], y_train[train_idx]
    x_val_curr, y_val_curr = x_train[val_idx], y_train[val_idx]

    # Set params path
    params_path = os.path.join(params_folder_path, f'params_iter_{iteration}')

    # Create an untrained model
    model = create_model()

    # Run the analog network - train and evaluate
     # run ann
    ann_result = run_ann(model=model,
                         train=(x_train_curr, y_train_curr),
                         valid=(x_val_curr, y_val_curr),
                         test=(x_test, y_test),
                         params_save_path=params_path,
                         iteration=iteration
                         )
    K.clear_session() # clear session
    ann.append(ann_result) # append the result to the ANN array

    # Create an array where results for each configuration of the spiking network will be stored
    snn_config_results = []
    for i, variant_conf in enumerate(snn_config):
        snn_result = run_snn(model=model,
                          test=(x_test, y_test),
                          params_load_path=params_path,
                          timesteps=variant_conf[0],
                          scale_firing_rates=variant_conf[1],
                          synapse=variant_conf[2],
                          iteration=iteration
                          )
        K.clear_session() # clear session
        snn[variants[i]].append(snn_result) # save results

    del model # delete the model (if this is not called it "may" create a memory leak - depends on the simulation machine)
    iteration += 1
# Out:
# Iteration: 1
# Build finished in 0:00:00
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Epoch 1/30
# 70/70 [==============================] - 7s 24ms/step - loss: 1.1069 - probe_loss: 1.1069 - probe_accuracy: 0.5313 - val_loss: 0.8531 - val_probe_loss: 0.8531 - val_probe_accuracy: 0.6060
# Epoch 2/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.8421 - probe_loss: 0.8421 - probe_accuracy: 0.5736 - val_loss: 0.7205 - val_probe_loss: 0.7205 - val_probe_accuracy: 0.5985
# Epoch 3/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.7546 - probe_loss: 0.7546 - probe_accuracy: 0.6014 - val_loss: 0.6714 - val_probe_loss: 0.6714 - val_probe_accuracy: 0.6209
# Epoch 4/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.7072 - probe_loss: 0.7072 - probe_accuracy: 0.6126 - val_loss: 0.6650 - val_probe_loss: 0.6650 - val_probe_accuracy: 0.6216
# Epoch 5/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.6727 - probe_loss: 0.6727 - probe_accuracy: 0.6250 - val_loss: 0.6598 - val_probe_loss: 0.6598 - val_probe_accuracy: 0.6202
# Epoch 6/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.6689 - probe_loss: 0.6689 - probe_accuracy: 0.6321 - val_loss: 0.6595 - val_probe_loss: 0.6595 - val_probe_accuracy: 0.6189
# Epoch 7/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.6374 - probe_loss: 0.6374 - probe_accuracy: 0.6434 - val_loss: 0.6575 - val_probe_loss: 0.6575 - val_probe_accuracy: 0.6243
# Epoch 8/30
# 70/70 [==============================] - 1s 10ms/step - loss: 0.6393 - probe_loss: 0.6393 - probe_accuracy: 0.6384 - val_loss: 0.6566 - val_probe_loss: 0.6566 - val_probe_accuracy: 0.6270
# Epoch 9/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.6387 - probe_loss: 0.6387 - probe_accuracy: 0.6331 - val_loss: 0.6609 - val_probe_loss: 0.6609 - val_probe_accuracy: 0.6155
# Epoch 10/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.6367 - probe_loss: 0.6367 - probe_accuracy: 0.6458 - val_loss: 0.6614 - val_probe_loss: 0.6614 - val_probe_accuracy: 0.6114
# Epoch 11/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.6194 - probe_loss: 0.6194 - probe_accuracy: 0.6596 - val_loss: 0.6612 - val_probe_loss: 0.6612 - val_probe_accuracy: 0.6182
# Epoch 12/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.6172 - probe_loss: 0.6172 - probe_accuracy: 0.6616 - val_loss: 0.6621 - val_probe_loss: 0.6621 - val_probe_accuracy: 0.6189
# Epoch 13/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.6196 - probe_loss: 0.6196 - probe_accuracy: 0.6536 - val_loss: 0.6674 - val_probe_loss: 0.6674 - val_probe_accuracy: 0.6175
# Restoring model weights from the end of the best epoch.
# Epoch 00013: early stopping
# 1. ANN: accuracy = 63.91129032258065%, precision = 0.6464323748668797, recall = 0.6125126135216953, f1 = 0.6290155440414507
# Confusion matrix:
# [[607 384]
#  [332 661]]
# 1. SNN [timesteps=50, scale_firing_rates=1000, synapse=0.01]: accuracy = 64.06172224987556%, precision = 0.6487341772151899, recall = 0.6125498007968128, f1 = 0.6301229508196722
# Confusion matrix:
# [[615 389]
#  [333 672]]
# 1. SNN [timesteps=50, scale_firing_rates=1000, synapse=None]: accuracy = 63.663514186162274%, precision = 0.6439075630252101, recall = 0.6105577689243028, f1 = 0.6267893660531697
# Confusion matrix:
# [[613 391]
#  [339 666]]
# 1. SNN [timesteps=50, scale_firing_rates=1, synapse=0.01]: accuracy = 52.01592832254853%, precision = 0.5275482093663911, recall = 0.38147410358565736, f1 = 0.44277456647398844
# Confusion matrix:
# [[383 621]
#  [343 662]]
# 1. SNN [timesteps=50, scale_firing_rates=1, synapse=None]: accuracy = 52.51368840219014%, precision = 0.5315656565656566, recall = 0.41932270916334663, f1 = 0.4688195991091314
# Confusion matrix:
# [[421 583]
#  [371 634]]
# Iteration: 2
# Build finished in 0:00:00
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Epoch 1/30
# 70/70 [==============================] - 4s 15ms/step - loss: 1.1670 - probe_loss: 1.1670 - probe_accuracy: 0.5506 - val_loss: 0.8699 - val_probe_loss: 0.8699 - val_probe_accuracy: 0.5985
# Epoch 2/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.8749 - probe_loss: 0.8749 - probe_accuracy: 0.5788 - val_loss: 0.6993 - val_probe_loss: 0.6993 - val_probe_accuracy: 0.6148
# Epoch 3/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.7774 - probe_loss: 0.7774 - probe_accuracy: 0.5930 - val_loss: 0.6786 - val_probe_loss: 0.6786 - val_probe_accuracy: 0.6148
# Epoch 4/30
#  - 1s 9ms/step - loss: 0.7255 - probe_loss: 0.7255 - probe_accuracy: 0.5989 - val_loss: 0.6619 - val_probe_loss: 0.6619 - val_probe_accuracy: 0.6223
# Epoch 5/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.6766 - probe_loss: 0.6766 - probe_accuracy: 0.6226 - val_loss: 0.6529 - val_probe_loss: 0.6529 - val_probe_accuracy: 0.6365
# Epoch 6/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.6647 - probe_loss: 0.6647 - probe_accuracy: 0.6236 - val_loss: 0.6569 - val_probe_loss: 0.6569 - val_probe_accuracy: 0.6284
# Epoch 7/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.6424 - probe_loss: 0.6424 - probe_accuracy: 0.6404 - val_loss: 0.6506 - val_probe_loss: 0.6506 - val_probe_accuracy: 0.6345
# Epoch 8/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.6544 - probe_loss: 0.6544 - probe_accuracy: 0.6393 - val_loss: 0.6569 - val_probe_loss: 0.6569 - val_probe_accuracy: 0.6216
# Epoch 9/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.6275 - probe_loss: 0.6275 - probe_accuracy: 0.6597 - val_loss: 0.6523 - val_probe_loss: 0.6523 - val_probe_accuracy: 0.6304
# Epoch 10/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.6279 - probe_loss: 0.6279 - probe_accuracy: 0.6590 - val_loss: 0.6555 - val_probe_loss: 0.6555 - val_probe_accuracy: 0.6264
# Epoch 11/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.6202 - probe_loss: 0.6202 - probe_accuracy: 0.6566 - val_loss: 0.6561 - val_probe_loss: 0.6561 - val_probe_accuracy: 0.6243
# Epoch 12/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.6069 - probe_loss: 0.6069 - probe_accuracy: 0.6666 - val_loss: 0.6598 - val_probe_loss: 0.6598 - val_probe_accuracy: 0.6250
# Restoring model weights from the end of the best epoch.
# Epoch 00012: early stopping
# 2. ANN: accuracy = 63.608870967741936%, precision = 0.6558516801853997, recall = 0.5711402623612513, f1 = 0.6105717367853291
# Confusion matrix:
# [[566 425]
#  [297 696]]
# 2. SNN [timesteps=50, scale_firing_rates=1000, synapse=0.01]: accuracy = 63.464410154305625%, precision = 0.6537585421412301, recall = 0.5717131474103586, f1 = 0.6099893730074389
# Confusion matrix:
# [[574 430]
#  [304 701]]
# 2. SNN [timesteps=50, scale_firing_rates=1000, synapse=None]: accuracy = 63.464410154305625%, precision = 0.6551724137931034, recall = 0.5677290836653387, f1 = 0.6083244397011739
# Confusion matrix:
# [[570 434]
#  [300 705]]
# 2. SNN [timesteps=50, scale_firing_rates=1, synapse=0.01]: accuracy = 52.812344449975114%, precision = 0.5368421052631579, recall = 0.4063745019920319, f1 = 0.46258503401360546
# Confusion matrix:
# [[408 596]
#  [352 653]]
# 2. SNN [timesteps=50, scale_firing_rates=1, synapse=None]: accuracy = 51.21951219512195%, precision = 0.5149625935162094, recall = 0.4113545816733068, f1 = 0.45736434108527124
# Confusion matrix:
# [[413 591]
#  [389 616]]
# Iteration: 3
# Build finished in 0:00:00
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Epoch 1/30
# 70/70 [==============================] - 4s 17ms/step - loss: 1.0989 - probe_loss: 1.0989 - probe_accuracy: 0.5428 - val_loss: 0.9356 - val_probe_loss: 0.9356 - val_probe_accuracy: 0.5815
# Epoch 2/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.8421 - probe_loss: 0.8421 - probe_accuracy: 0.5825 - val_loss: 0.7366 - val_probe_loss: 0.7366 - val_probe_accuracy: 0.5992
# Epoch 3/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.7542 - probe_loss: 0.7542 - probe_accuracy: 0.5978 - val_loss: 0.6902 - val_probe_loss: 0.6902 - val_probe_accuracy: 0.6107
# Epoch 4/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.6931 - probe_loss: 0.6931 - probe_accuracy: 0.6111 - val_loss: 0.6702 - val_probe_loss: 0.6702 - val_probe_accuracy: 0.6182
# Epoch 5/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.6606 - probe_loss: 0.6606 - probe_accuracy: 0.6408 - val_loss: 0.6638 - val_probe_loss: 0.6638 - val_probe_accuracy: 0.6202
# Epoch 6/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.6407 - probe_loss: 0.6407 - probe_accuracy: 0.6368 - val_loss: 0.6671 - val_probe_loss: 0.6671 - val_probe_accuracy: 0.6162
# Epoch 7/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.6386 - probe_loss: 0.6386 - probe_accuracy: 0.6475 - val_loss: 0.6578 - val_probe_loss: 0.6578 - val_probe_accuracy: 0.6202
# Epoch 8/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.6387 - probe_loss: 0.6387 - probe_accuracy: 0.6423 - val_loss: 0.6566 - val_probe_loss: 0.6566 - val_probe_accuracy: 0.6270
# Epoch 9/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.6228 - probe_loss: 0.6228 - probe_accuracy: 0.6631 - val_loss: 0.6644 - val_probe_loss: 0.6644 - val_probe_accuracy: 0.6264
# Epoch 10/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.6265 - probe_loss: 0.6265 - probe_accuracy: 0.6598 - val_loss: 0.6570 - val_probe_loss: 0.6570 - val_probe_accuracy: 0.6284
# Epoch 11/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.6102 - probe_loss: 0.6102 - probe_accuracy: 0.6779 - val_loss: 0.6660 - val_probe_loss: 0.6660 - val_probe_accuracy: 0.6026
# Epoch 12/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.6131 - probe_loss: 0.6131 - probe_accuracy: 0.6551 - val_loss: 0.6603 - val_probe_loss: 0.6603 - val_probe_accuracy: 0.6168
# Epoch 13/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.5917 - probe_loss: 0.5917 - probe_accuracy: 0.6836 - val_loss: 0.6651 - val_probe_loss: 0.6651 - val_probe_accuracy: 0.6223
# Restoring model weights from the end of the best epoch.
# Epoch 00013: early stopping
# 3. ANN: accuracy = 63.10483870967742%, precision = 0.6263414634146341, recall = 0.6478304742684158, f1 = 0.636904761904762
# Confusion matrix:
# [[642 349]
#  [383 610]]
# 3. SNN [timesteps=50, scale_firing_rates=1000, synapse=0.01]: accuracy = 63.61373817819811%, precision = 0.6318840579710145, recall = 0.651394422310757, f1 = 0.6414909269249633
# Confusion matrix:
# [[654 350]
#  [381 624]]
# 3. SNN [timesteps=50, scale_firing_rates=1000, synapse=None]: accuracy = 63.06620209059234%, precision = 0.627431906614786, recall = 0.6424302788844621, f1 = 0.6348425196850392
# Confusion matrix:
# [[645 359]
#  [383 622]]
# 3. SNN [timesteps=50, scale_firing_rates=1, synapse=0.01]: accuracy = 53.907416625186656%, precision = 0.5566860465116279, recall = 0.38147410358565736, f1 = 0.45271867612293143
# Confusion matrix:
# [[383 621]
#  [305 700]]
# 3. SNN [timesteps=50, scale_firing_rates=1, synapse=None]: accuracy = 50.07466401194625%, precision = 0.5007153075822603, recall = 0.34860557768924305, f1 = 0.41103934233705225
# Confusion matrix:
# [[350 654]
#  [349 656]]
# Iteration: 4
# Build finished in 0:00:00
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Epoch 1/30
# 70/70 [==============================] - 4s 15ms/step - loss: 1.0861 - probe_loss: 1.0861 - probe_accuracy: 0.5580 - val_loss: 0.9588 - val_probe_loss: 0.9588 - val_probe_accuracy: 0.5754
# Epoch 2/30
#  - ETA: 0s - loss: 0.8352 - probe_loss: 0.8352 - probe_accuracy: 0.5915
# Epoch 3/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.7597 - probe_loss: 0.7597 - probe_accuracy: 0.5970 - val_loss: 0.6769 - val_probe_loss: 0.6769 - val_probe_accuracy: 0.6236
# Epoch 4/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.7188 - probe_loss: 0.7188 - probe_accuracy: 0.6107 - val_loss: 0.6719 - val_probe_loss: 0.6719 - val_probe_accuracy: 0.6135
# Epoch 5/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.6587 - probe_loss: 0.6587 - probe_accuracy: 0.6309 - val_loss: 0.6662 - val_probe_loss: 0.6662 - val_probe_accuracy: 0.6209
# Epoch 6/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.6602 - probe_loss: 0.6602 - probe_accuracy: 0.6198 - val_loss: 0.6535 - val_probe_loss: 0.6535 - val_probe_accuracy: 0.6332
# Epoch 7/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.6500 - probe_loss: 0.6500 - probe_accuracy: 0.6373 - val_loss: 0.6835 - val_probe_loss: 0.6835 - val_probe_accuracy: 0.6264
# Epoch 8/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.6523 - probe_loss: 0.6523 - probe_accuracy: 0.6334 - val_loss: 0.6497 - val_probe_loss: 0.6497 - val_probe_accuracy: 0.6291
# Epoch 9/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.6267 - probe_loss: 0.6267 - probe_accuracy: 0.6609 - val_loss: 0.6470 - val_probe_loss: 0.6470 - val_probe_accuracy: 0.6386
# Epoch 10/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.6222 - probe_loss: 0.6222 - probe_accuracy: 0.6657 - val_loss: 0.6611 - val_probe_loss: 0.6611 - val_probe_accuracy: 0.6243
# Epoch 11/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.6304 - probe_loss: 0.6304 - probe_accuracy: 0.6525 - val_loss: 0.6477 - val_probe_loss: 0.6477 - val_probe_accuracy: 0.6427
# Epoch 12/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.6268 - probe_loss: 0.6268 - probe_accuracy: 0.6548 - val_loss: 0.6553 - val_probe_loss: 0.6553 - val_probe_accuracy: 0.6379
# Epoch 13/30
# 70/70 [==============================] - 1s 10ms/step - loss: 0.6172 - probe_loss: 0.6172 - probe_accuracy: 0.6671 - val_loss: 0.6484 - val_probe_loss: 0.6484 - val_probe_accuracy: 0.6447
# Epoch 14/30
#  - ETA: 0s - loss: 0.6244 - probe_loss: 0.6244 - probe_accuracy: 0.6850
# Restoring model weights from the end of the best epoch.
# Epoch 00014: early stopping
# 4. ANN: accuracy = 63.76008064516129%, precision = 0.6497797356828194, recall = 0.5953582240161454, f1 = 0.6213796735123749
# Confusion matrix:
# [[590 401]
#  [318 675]]
# 4. SNN [timesteps=50, scale_firing_rates=1000, synapse=0.01]: accuracy = 63.61373817819811%, precision = 0.6491803278688525, recall = 0.5916334661354582, f1 = 0.6190724335591454
# Confusion matrix:
# [[594 410]
#  [321 684]]
# 4. SNN [timesteps=50, scale_firing_rates=1000, synapse=None]: accuracy = 63.71329019412643%, precision = 0.6496191512513602, recall = 0.5946215139442231, f1 = 0.6209048361934478
# Confusion matrix:
# [[597 407]
#  [322 683]]
# 4. SNN [timesteps=50, scale_firing_rates=1, synapse=0.01]: accuracy = 52.71279243404678%, precision = 0.536, recall = 0.40039840637450197, f1 = 0.4583808437856328
# Confusion matrix:
# [[402 602]
#  [348 657]]
# 4. SNN [timesteps=50, scale_firing_rates=1, synapse=None]: accuracy = 53.26032852165257%, precision = 0.5427069645203679, recall = 0.4113545816733068, f1 = 0.4679886685552408
# Confusion matrix:
# [[413 591]
#  [348 657]]
# Iteration: 5
# Build finished in 0:00:00
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Epoch 1/30
# 70/70 [==============================] - 4s 16ms/step - loss: 1.1513 - probe_loss: 1.1513 - probe_accuracy: 0.5396 - val_loss: 0.8875 - val_probe_loss: 0.8875 - val_probe_accuracy: 0.5774
# Epoch 2/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.8208 - probe_loss: 0.8208 - probe_accuracy: 0.5927 - val_loss: 0.7104 - val_probe_loss: 0.7104 - val_probe_accuracy: 0.6026
# Epoch 3/30
# 70/70 [==============================] - 1s 12ms/step - loss: 0.7607 - probe_loss: 0.7607 - probe_accuracy: 0.6069 - val_loss: 0.6764 - val_probe_loss: 0.6764 - val_probe_accuracy: 0.6175
# Epoch 4/30
# 70/70 [==============================] - 1s 14ms/step - loss: 0.7144 - probe_loss: 0.7144 - probe_accuracy: 0.6064 - val_loss: 0.6792 - val_probe_loss: 0.6792 - val_probe_accuracy: 0.6060
# Epoch 5/30
# 70/70 [==============================] - 1s 15ms/step - loss: 0.6736 - probe_loss: 0.6736 - probe_accuracy: 0.6314 - val_loss: 0.6574 - val_probe_loss: 0.6574 - val_probe_accuracy: 0.6148
# Epoch 6/30
# 70/70 [==============================] - 1s 15ms/step - loss: 0.6572 - probe_loss: 0.6572 - probe_accuracy: 0.6269 - val_loss: 0.6529 - val_probe_loss: 0.6529 - val_probe_accuracy: 0.6060
# Epoch 7/30
# 70/70 [==============================] - 1s 12ms/step - loss: 0.6437 - probe_loss: 0.6437 - probe_accuracy: 0.6283 - val_loss: 0.6571 - val_probe_loss: 0.6571 - val_probe_accuracy: 0.6026
# Epoch 8/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.6402 - probe_loss: 0.6402 - probe_accuracy: 0.6443 - val_loss: 0.6642 - val_probe_loss: 0.6642 - val_probe_accuracy: 0.6005
# Epoch 9/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.6345 - probe_loss: 0.6345 - probe_accuracy: 0.6525 - val_loss: 0.6680 - val_probe_loss: 0.6680 - val_probe_accuracy: 0.6060
# Epoch 10/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.6326 - probe_loss: 0.6326 - probe_accuracy: 0.6467 - val_loss: 0.6775 - val_probe_loss: 0.6775 - val_probe_accuracy: 0.6033
# Epoch 11/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.6171 - probe_loss: 0.6171 - probe_accuracy: 0.6711 - val_loss: 0.6669 - val_probe_loss: 0.6669 - val_probe_accuracy: 0.6019
# Restoring model weights from the end of the best epoch.
# Epoch 00011: early stopping
# 5. ANN: accuracy = 62.701612903225815%, precision = 0.6180620884289746, recall = 0.6629667003027245, f1 = 0.6397273612463487
# Confusion matrix:
# [[657 334]
#  [406 587]]
# 5. SNN [timesteps=50, scale_firing_rates=1000, synapse=0.01]: accuracy = 62.7177700348432%, precision = 0.6188257222739981, recall = 0.6613545816733067, f1 = 0.6393837265286471
# Confusion matrix:
# [[664 340]
#  [409 596]]
# 5. SNN [timesteps=50, scale_firing_rates=1000, synapse=None]: accuracy = 62.41911398705824%, precision = 0.6155988857938719, recall = 0.6603585657370518, f1 = 0.6371936568957232
# Confusion matrix:
# [[663 341]
#  [414 591]]
# 5. SNN [timesteps=50, scale_firing_rates=1, synapse=0.01]: accuracy = 50.42309606769537%, precision = 0.5054794520547945, recall = 0.36752988047808766, f1 = 0.42560553633217996
# Confusion matrix:
# [[369 635]
#  [361 644]]
# 5. SNN [timesteps=50, scale_firing_rates=1, synapse=None]: accuracy = 52.663016426082635%, precision = 0.5386861313868613, recall = 0.36752988047808766, f1 = 0.4369449378330373
# Confusion matrix:
# [[369 635]
#  [316 689]]
# Iteration: 6
# Build finished in 0:00:00
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Epoch 1/30
# 70/70 [==============================] - 4s 16ms/step - loss: 1.0419 - probe_loss: 1.0419 - probe_accuracy: 0.5551 - val_loss: 1.0443 - val_probe_loss: 1.0443 - val_probe_accuracy: 0.5686
# Epoch 2/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.8344 - probe_loss: 0.8344 - probe_accuracy: 0.5936 - val_loss: 0.7203 - val_probe_loss: 0.7203 - val_probe_accuracy: 0.5992
# Epoch 3/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.7402 - probe_loss: 0.7402 - probe_accuracy: 0.6082 - val_loss: 0.6815 - val_probe_loss: 0.6815 - val_probe_accuracy: 0.6182
# Epoch 4/30
#  - ETA: 0s - loss: 0.6912 - probe_loss: 0.6912 - probe_accuracy: 0.6026
# Epoch 5/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.6629 - probe_loss: 0.6629 - probe_accuracy: 0.6374 - val_loss: 0.6759 - val_probe_loss: 0.6759 - val_probe_accuracy: 0.6053
# Epoch 6/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.6472 - probe_loss: 0.6472 - probe_accuracy: 0.6389 - val_loss: 0.6606 - val_probe_loss: 0.6606 - val_probe_accuracy: 0.6053
# Epoch 7/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.6400 - probe_loss: 0.6400 - probe_accuracy: 0.6456 - val_loss: 0.6674 - val_probe_loss: 0.6674 - val_probe_accuracy: 0.6019
# Epoch 8/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.6297 - probe_loss: 0.6297 - probe_accuracy: 0.6580 - val_loss: 0.6648 - val_probe_loss: 0.6648 - val_probe_accuracy: 0.5999
# Epoch 9/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.6040 - probe_loss: 0.6040 - probe_accuracy: 0.6854 - val_loss: 0.6653 - val_probe_loss: 0.6653 - val_probe_accuracy: 0.6005
# Epoch 10/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.6126 - probe_loss: 0.6126 - probe_accuracy: 0.6803 - val_loss: 0.6667 - val_probe_loss: 0.6667 - val_probe_accuracy: 0.5938
# Epoch 11/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.6096 - probe_loss: 0.6096 - probe_accuracy: 0.6671 - val_loss: 0.6628 - val_probe_loss: 0.6628 - val_probe_accuracy: 0.6094
# Restoring model weights from the end of the best epoch.
# Epoch 00011: early stopping
# 6. ANN: accuracy = 63.40725806451613%, precision = 0.644808743169399, recall = 0.5953582240161454, f1 = 0.6190975865687303
# Confusion matrix:
# [[590 401]
#  [325 668]]
# 6. SNN [timesteps=50, scale_firing_rates=1000, synapse=0.01]: accuracy = 63.41463414634146%, precision = 0.6460369163952225, recall = 0.5926294820717132, f1 = 0.6181818181818182
# Confusion matrix:
# [[595 409]
#  [326 679]]
# 6. SNN [timesteps=50, scale_firing_rates=1000, synapse=None]: accuracy = 63.663514186162274%, precision = 0.6489130434782608, recall = 0.5946215139442231, f1 = 0.6205821205821205
# Confusion matrix:
# [[597 407]
#  [323 682]]
# 6. SNN [timesteps=50, scale_firing_rates=1, synapse=0.01]: accuracy = 52.613240418118465%, precision = 0.5411392405063291, recall = 0.34063745019920316, f1 = 0.4180929095354523
# Confusion matrix:
# [[342 662]
#  [290 715]]
# 6. SNN [timesteps=50, scale_firing_rates=1, synapse=None]: accuracy = 52.11548033847685%, precision = 0.5290055248618785, recall = 0.38147410358565736, f1 = 0.443287037037037
# Confusion matrix:
# [[383 621]
#  [341 664]]
# Iteration: 7
# Build finished in 0:00:00
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Epoch 1/30
# 70/70 [==============================] - 3s 16ms/step - loss: 1.1314 - probe_loss: 1.1314 - probe_accuracy: 0.5566 - val_loss: 0.8296 - val_probe_loss: 0.8296 - val_probe_accuracy: 0.6202
# Epoch 2/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.8461 - probe_loss: 0.8461 - probe_accuracy: 0.5882 - val_loss: 0.7819 - val_probe_loss: 0.7819 - val_probe_accuracy: 0.6148
# Epoch 3/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.7666 - probe_loss: 0.7666 - probe_accuracy: 0.5970 - val_loss: 0.6824 - val_probe_loss: 0.6824 - val_probe_accuracy: 0.6216
# Epoch 4/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.7111 - probe_loss: 0.7111 - probe_accuracy: 0.6171 - val_loss: 0.6685 - val_probe_loss: 0.6685 - val_probe_accuracy: 0.6291
# Epoch 5/30
#  - ETA: 0s - loss: 0.6768 - probe_loss: 0.6768 - probe_accuracy: 0.6082
# Epoch 6/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.6588 - probe_loss: 0.6588 - probe_accuracy: 0.6354 - val_loss: 0.6574 - val_probe_loss: 0.6574 - val_probe_accuracy: 0.6277
# Epoch 7/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.6473 - probe_loss: 0.6473 - probe_accuracy: 0.6356 - val_loss: 0.6611 - val_probe_loss: 0.6611 - val_probe_accuracy: 0.6148
# Epoch 8/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.6541 - probe_loss: 0.6541 - probe_accuracy: 0.6314 - val_loss: 0.6547 - val_probe_loss: 0.6547 - val_probe_accuracy: 0.6311
# Epoch 9/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.6325 - probe_loss: 0.6325 - probe_accuracy: 0.6472 - val_loss: 0.6548 - val_probe_loss: 0.6548 - val_probe_accuracy: 0.6196
# Epoch 10/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.6249 - probe_loss: 0.6249 - probe_accuracy: 0.6553 - val_loss: 0.6498 - val_probe_loss: 0.6498 - val_probe_accuracy: 0.6236
# Epoch 11/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.6327 - probe_loss: 0.6327 - probe_accuracy: 0.6492 - val_loss: 0.6513 - val_probe_loss: 0.6513 - val_probe_accuracy: 0.6284
# Epoch 12/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.6202 - probe_loss: 0.6202 - probe_accuracy: 0.6553 - val_loss: 0.6601 - val_probe_loss: 0.6601 - val_probe_accuracy: 0.6291
# Epoch 13/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.6151 - probe_loss: 0.6151 - probe_accuracy: 0.6663 - val_loss: 0.6525 - val_probe_loss: 0.6525 - val_probe_accuracy: 0.6202
# Epoch 14/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.6135 - probe_loss: 0.6135 - probe_accuracy: 0.6766 - val_loss: 0.6551 - val_probe_loss: 0.6551 - val_probe_accuracy: 0.6345
# Epoch 15/30
#  - ETA: 0s - loss: 0.6090 - probe_loss: 0.6090 - probe_accuracy: 0.6693
# Restoring model weights from the end of the best epoch.
# Epoch 00015: early stopping
# 7. ANN: accuracy = 64.01209677419355%, precision = 0.6720496894409937, recall = 0.5459132189707366, f1 = 0.6024498886414255
# Confusion matrix:
# [[541 450]
#  [264 729]]
# 7. SNN [timesteps=50, scale_firing_rates=1000, synapse=0.01]: accuracy = 64.0119462419114%, precision = 0.6732429099876696, recall = 0.5438247011952191, f1 = 0.6016528925619835
# Confusion matrix:
# [[546 458]
#  [265 740]]
# 7. SNN [timesteps=50, scale_firing_rates=1000, synapse=None]: accuracy = 64.11149825783971%, precision = 0.6740467404674046, recall = 0.545816733067729, f1 = 0.6031920748486516
# Confusion matrix:
# [[548 456]
#  [265 740]]
# 7. SNN [timesteps=50, scale_firing_rates=1, synapse=0.01]: accuracy = 52.762568442010945%, precision = 0.5323910482921084, recall = 0.450199203187251, f1 = 0.48785752833243384
# Confusion matrix:
# [[452 552]
#  [397 608]]
# 7. SNN [timesteps=50, scale_firing_rates=1, synapse=None]: accuracy = 54.30562468889995%, precision = 0.5536159600997507, recall = 0.44223107569721115, f1 = 0.4916943521594685
# Confusion matrix:
# [[444 560]
#  [358 647]]
# Iteration: 8
# Build finished in 0:00:00
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Epoch 1/30
# 70/70 [==============================] - 4s 17ms/step - loss: 1.1306 - probe_loss: 1.1306 - probe_accuracy: 0.5388 - val_loss: 0.7911 - val_probe_loss: 0.7911 - val_probe_accuracy: 0.6039
# Epoch 2/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.8269 - probe_loss: 0.8269 - probe_accuracy: 0.5927 - val_loss: 0.7283 - val_probe_loss: 0.7283 - val_probe_accuracy: 0.6005
# Epoch 3/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.7622 - probe_loss: 0.7622 - probe_accuracy: 0.6184 - val_loss: 0.6879 - val_probe_loss: 0.6879 - val_probe_accuracy: 0.6141
# Epoch 4/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.7165 - probe_loss: 0.7165 - probe_accuracy: 0.6189 - val_loss: 0.6633 - val_probe_loss: 0.6633 - val_probe_accuracy: 0.6107
# Epoch 5/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.6898 - probe_loss: 0.6898 - probe_accuracy: 0.6236 - val_loss: 0.6716 - val_probe_loss: 0.6716 - val_probe_accuracy: 0.6155
# Epoch 6/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.6538 - probe_loss: 0.6538 - probe_accuracy: 0.6329 - val_loss: 0.6560 - val_probe_loss: 0.6560 - val_probe_accuracy: 0.6284
# Epoch 7/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.6261 - probe_loss: 0.6261 - probe_accuracy: 0.6442 - val_loss: 0.6590 - val_probe_loss: 0.6590 - val_probe_accuracy: 0.6189
# Epoch 8/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.6246 - probe_loss: 0.6246 - probe_accuracy: 0.6491 - val_loss: 0.6582 - val_probe_loss: 0.6582 - val_probe_accuracy: 0.6209
# Epoch 9/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.6235 - probe_loss: 0.6235 - probe_accuracy: 0.6484 - val_loss: 0.6549 - val_probe_loss: 0.6549 - val_probe_accuracy: 0.6284
# Epoch 10/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.6013 - probe_loss: 0.6013 - probe_accuracy: 0.6894 - val_loss: 0.6595 - val_probe_loss: 0.6595 - val_probe_accuracy: 0.6257
# Epoch 11/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.6142 - probe_loss: 0.6142 - probe_accuracy: 0.6643 - val_loss: 0.6582 - val_probe_loss: 0.6582 - val_probe_accuracy: 0.6257
# Epoch 12/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.5985 - probe_loss: 0.5985 - probe_accuracy: 0.6731 - val_loss: 0.6610 - val_probe_loss: 0.6610 - val_probe_accuracy: 0.6141
# Epoch 13/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.5892 - probe_loss: 0.5892 - probe_accuracy: 0.6962 - val_loss: 0.6621 - val_probe_loss: 0.6621 - val_probe_accuracy: 0.6236
# Epoch 14/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.5969 - probe_loss: 0.5969 - probe_accuracy: 0.6883 - val_loss: 0.6684 - val_probe_loss: 0.6684 - val_probe_accuracy: 0.5985
# Restoring model weights from the end of the best epoch.
# Epoch 00014: early stopping
# 8. ANN: accuracy = 63.306451612903224%, precision = 0.6437158469945355, recall = 0.5943491422805247, f1 = 0.6180482686253935
# Confusion matrix:
# [[589 402]
#  [326 667]]
# 8. SNN [timesteps=50, scale_firing_rates=1000, synapse=0.01]: accuracy = 63.61373817819811%, precision = 0.648854961832061, recall = 0.5926294820717132, f1 = 0.6194690265486726
# Confusion matrix:
# [[595 409]
#  [322 683]]
# 8. SNN [timesteps=50, scale_firing_rates=1000, synapse=None]: accuracy = 63.91239422598307%, precision = 0.6524590163934426, recall = 0.5946215139442231, f1 = 0.6221990620114642
# Confusion matrix:
# [[597 407]
#  [318 687]]
# 8. SNN [timesteps=50, scale_firing_rates=1, synapse=0.01]: accuracy = 52.762568442010945%, precision = 0.5374149659863946, recall = 0.3934262948207171, f1 = 0.45428407130534787
# Confusion matrix:
# [[395 609]
#  [340 665]]
# 8. SNN [timesteps=50, scale_firing_rates=1, synapse=None]: accuracy = 52.41413638626182%, precision = 0.5351906158357771, recall = 0.36354581673306774, f1 = 0.43297746144721233
# Confusion matrix:
# [[365 639]
#  [317 688]]
# Iteration: 9
# Build finished in 0:00:00
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Epoch 1/30
# 70/70 [==============================] - 4s 16ms/step - loss: 1.1423 - probe_loss: 1.1423 - probe_accuracy: 0.5403 - val_loss: 0.9080 - val_probe_loss: 0.9080 - val_probe_accuracy: 0.6026
# Epoch 2/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.8627 - probe_loss: 0.8627 - probe_accuracy: 0.5719 - val_loss: 0.7033 - val_probe_loss: 0.7033 - val_probe_accuracy: 0.6230
# Epoch 3/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.7830 - probe_loss: 0.7830 - probe_accuracy: 0.5939 - val_loss: 0.6840 - val_probe_loss: 0.6840 - val_probe_accuracy: 0.6128
# Epoch 4/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.7010 - probe_loss: 0.7010 - probe_accuracy: 0.6164 - val_loss: 0.6684 - val_probe_loss: 0.6684 - val_probe_accuracy: 0.6250
# Epoch 5/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.7004 - probe_loss: 0.7004 - probe_accuracy: 0.6082 - val_loss: 0.6478 - val_probe_loss: 0.6478 - val_probe_accuracy: 0.6304
# Epoch 6/30
# 70/70 [==============================] - 1s 10ms/step - loss: 0.6760 - probe_loss: 0.6760 - probe_accuracy: 0.6147 - val_loss: 0.6559 - val_probe_loss: 0.6559 - val_probe_accuracy: 0.6196
# Epoch 7/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.6440 - probe_loss: 0.6440 - probe_accuracy: 0.6385 - val_loss: 0.6456 - val_probe_loss: 0.6456 - val_probe_accuracy: 0.6277
# Epoch 8/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.6379 - probe_loss: 0.6379 - probe_accuracy: 0.6475 - val_loss: 0.6513 - val_probe_loss: 0.6513 - val_probe_accuracy: 0.6209
# Epoch 9/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.6274 - probe_loss: 0.6274 - probe_accuracy: 0.6582 - val_loss: 0.6474 - val_probe_loss: 0.6474 - val_probe_accuracy: 0.6304
# Epoch 10/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.6269 - probe_loss: 0.6269 - probe_accuracy: 0.6566 - val_loss: 0.6577 - val_probe_loss: 0.6577 - val_probe_accuracy: 0.6135
# Epoch 11/30
# 70/70 [==============================] - 1s 10ms/step - loss: 0.6297 - probe_loss: 0.6297 - probe_accuracy: 0.6540 - val_loss: 0.6508 - val_probe_loss: 0.6508 - val_probe_accuracy: 0.6148
# Epoch 12/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.6251 - probe_loss: 0.6251 - probe_accuracy: 0.6581 - val_loss: 0.6503 - val_probe_loss: 0.6503 - val_probe_accuracy: 0.6202
# Restoring model weights from the end of the best epoch.
# Epoch 00012: early stopping
# 9. ANN: accuracy = 64.1633064516129%, precision = 0.6440329218106996, recall = 0.6316851664984864, f1 = 0.6377992868059094
# Confusion matrix:
# [[626 365]
#  [346 647]]
# 9. SNN [timesteps=50, scale_firing_rates=1000, synapse=0.01]: accuracy = 64.45993031358886%, precision = 0.6479591836734694, recall = 0.6324701195219123, f1 = 0.6401209677419355
# Confusion matrix:
# [[635 369]
#  [345 660]]
# 9. SNN [timesteps=50, scale_firing_rates=1000, synapse=None]: accuracy = 64.06172224987556%, precision = 0.6441717791411042, recall = 0.6274900398406374, f1 = 0.6357214934409687
# Confusion matrix:
# [[630 374]
#  [348 657]]
# 9. SNN [timesteps=50, scale_firing_rates=1, synapse=0.01]: accuracy = 53.06122448979592%, precision = 0.5394566623544631, recall = 0.4153386454183267, f1 = 0.4693303320202589
# Confusion matrix:
# [[417 587]
#  [356 649]]
# 9. SNN [timesteps=50, scale_firing_rates=1, synapse=None]: accuracy = 53.26032852165257%, precision = 0.5450762829403606, recall = 0.39143426294820716, f1 = 0.45565217391304347
# Confusion matrix:
# [[393 611]
#  [328 677]]
# Iteration: 10
# Build finished in 0:00:00
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Epoch 1/30
# 70/70 [==============================] - 3s 16ms/step - loss: 1.0905 - probe_loss: 1.0905 - probe_accuracy: 0.5341 - val_loss: 0.9271 - val_probe_loss: 0.9271 - val_probe_accuracy: 0.5808
# Epoch 2/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.8412 - probe_loss: 0.8412 - probe_accuracy: 0.5675 - val_loss: 0.7344 - val_probe_loss: 0.7344 - val_probe_accuracy: 0.5883
# Epoch 3/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.7380 - probe_loss: 0.7380 - probe_accuracy: 0.5931 - val_loss: 0.6670 - val_probe_loss: 0.6670 - val_probe_accuracy: 0.6046
# Epoch 4/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.7225 - probe_loss: 0.7225 - probe_accuracy: 0.5879 - val_loss: 0.6725 - val_probe_loss: 0.6725 - val_probe_accuracy: 0.6039
# Epoch 5/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.6841 - probe_loss: 0.6841 - probe_accuracy: 0.6132 - val_loss: 0.6570 - val_probe_loss: 0.6570 - val_probe_accuracy: 0.6148
# Epoch 6/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.6660 - probe_loss: 0.6660 - probe_accuracy: 0.6184 - val_loss: 0.6572 - val_probe_loss: 0.6572 - val_probe_accuracy: 0.6175
# Epoch 7/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.6514 - probe_loss: 0.6514 - probe_accuracy: 0.6249 - val_loss: 0.6537 - val_probe_loss: 0.6537 - val_probe_accuracy: 0.6101
# Epoch 8/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.6460 - probe_loss: 0.6460 - probe_accuracy: 0.6367 - val_loss: 0.6538 - val_probe_loss: 0.6538 - val_probe_accuracy: 0.6073
# Epoch 9/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.6286 - probe_loss: 0.6286 - probe_accuracy: 0.6547 - val_loss: 0.6550 - val_probe_loss: 0.6550 - val_probe_accuracy: 0.6012
# Epoch 10/30
# 70/70 [==============================] - 1s 10ms/step - loss: 0.6258 - probe_loss: 0.6258 - probe_accuracy: 0.6465 - val_loss: 0.6522 - val_probe_loss: 0.6522 - val_probe_accuracy: 0.6182
# Epoch 11/30
# 70/70 [==============================] - 1s 10ms/step - loss: 0.6326 - probe_loss: 0.6326 - probe_accuracy: 0.6423 - val_loss: 0.6631 - val_probe_loss: 0.6631 - val_probe_accuracy: 0.6107
# Epoch 12/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.6231 - probe_loss: 0.6231 - probe_accuracy: 0.6459 - val_loss: 0.6536 - val_probe_loss: 0.6536 - val_probe_accuracy: 0.6175
# Epoch 13/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.6139 - probe_loss: 0.6139 - probe_accuracy: 0.6671 - val_loss: 0.6536 - val_probe_loss: 0.6536 - val_probe_accuracy: 0.6162
# Epoch 14/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.6099 - probe_loss: 0.6099 - probe_accuracy: 0.6652 - val_loss: 0.6543 - val_probe_loss: 0.6543 - val_probe_accuracy: 0.6148
# Epoch 15/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.6196 - probe_loss: 0.6196 - probe_accuracy: 0.6559 - val_loss: 0.6584 - val_probe_loss: 0.6584 - val_probe_accuracy: 0.6060
# Restoring model weights from the end of the best epoch.
# Epoch 00015: early stopping
# 10. ANN: accuracy = 64.01209677419355%, precision = 0.6487647690655209, recall = 0.6094853683148335, f1 = 0.6285119667013527
# Confusion matrix:
# [[604 387]
#  [327 666]]
# 10. SNN [timesteps=50, scale_firing_rates=1000, synapse=0.01]: accuracy = 64.21105027376804%, precision = 0.6511134676564156, recall = 0.6115537848605578, f1 = 0.630713918849512
# Confusion matrix:
# [[614 390]
#  [329 676]]
# 10. SNN [timesteps=50, scale_firing_rates=1000, synapse=None]: accuracy = 63.962170233947234%, precision = 0.648619957537155, recall = 0.6085657370517928, f1 = 0.6279547790339156
# Confusion matrix:
# [[611 393]
#  [331 674]]
# 10. SNN [timesteps=50, scale_firing_rates=1, synapse=0.01]: accuracy = 51.46839223494276%, precision = 0.5180572851805728, recall = 0.41434262948207173, f1 = 0.460431654676259
# Confusion matrix:
# [[416 588]
#  [387 618]]
# 10. SNN [timesteps=50, scale_firing_rates=1, synapse=None]: accuracy = 52.36436037829766%, precision = 0.5297845373891001, recall = 0.4163346613545817, f1 = 0.4662576687116564
# Confusion matrix:
# [[418 586]
#  [371 634]]
# Iteration: 11
# Build finished in 0:00:00
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Epoch 1/30
# 70/70 [==============================] - 4s 19ms/step - loss: 1.1286 - probe_loss: 1.1286 - probe_accuracy: 0.5520 - val_loss: 0.7922 - val_probe_loss: 0.7922 - val_probe_accuracy: 0.6175
# Epoch 2/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.8295 - probe_loss: 0.8295 - probe_accuracy: 0.5873 - val_loss: 0.6881 - val_probe_loss: 0.6881 - val_probe_accuracy: 0.6141
# Epoch 3/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.7528 - probe_loss: 0.7528 - probe_accuracy: 0.5954 - val_loss: 0.6594 - val_probe_loss: 0.6594 - val_probe_accuracy: 0.6365
# Epoch 4/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.7201 - probe_loss: 0.7201 - probe_accuracy: 0.5966 - val_loss: 0.6650 - val_probe_loss: 0.6650 - val_probe_accuracy: 0.6264
# Epoch 5/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.6918 - probe_loss: 0.6918 - probe_accuracy: 0.6034 - val_loss: 0.6483 - val_probe_loss: 0.6483 - val_probe_accuracy: 0.6481
# Epoch 6/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.6535 - probe_loss: 0.6535 - probe_accuracy: 0.6260 - val_loss: 0.6560 - val_probe_loss: 0.6560 - val_probe_accuracy: 0.6447
# Epoch 7/30
# 70/70 [==============================] - 1s 10ms/step - loss: 0.6345 - probe_loss: 0.6345 - probe_accuracy: 0.6462 - val_loss: 0.6504 - val_probe_loss: 0.6504 - val_probe_accuracy: 0.6406
# Epoch 8/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.6327 - probe_loss: 0.6327 - probe_accuracy: 0.6552 - val_loss: 0.6478 - val_probe_loss: 0.6478 - val_probe_accuracy: 0.6399
# Epoch 9/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.6328 - probe_loss: 0.6328 - probe_accuracy: 0.6501 - val_loss: 0.6528 - val_probe_loss: 0.6528 - val_probe_accuracy: 0.6420
# Epoch 10/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.6276 - probe_loss: 0.6276 - probe_accuracy: 0.6492 - val_loss: 0.6497 - val_probe_loss: 0.6497 - val_probe_accuracy: 0.6318
# Epoch 11/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.6221 - probe_loss: 0.6221 - probe_accuracy: 0.6584 - val_loss: 0.6532 - val_probe_loss: 0.6532 - val_probe_accuracy: 0.6365
# Epoch 12/30
# 70/70 [==============================] - 1s 10ms/step - loss: 0.6219 - probe_loss: 0.6219 - probe_accuracy: 0.6527 - val_loss: 0.6508 - val_probe_loss: 0.6508 - val_probe_accuracy: 0.6359
# Epoch 13/30
# 70/70 [==============================] - 1s 10ms/step - loss: 0.6099 - probe_loss: 0.6099 - probe_accuracy: 0.6685 - val_loss: 0.6510 - val_probe_loss: 0.6510 - val_probe_accuracy: 0.6304
# Restoring model weights from the end of the best epoch.
# Epoch 00013: early stopping
# 11. ANN: accuracy = 64.26411290322581%, precision = 0.647489539748954, recall = 0.6246215943491423, f1 = 0.6358500256805341
# Confusion matrix:
# [[619 372]
#  [337 656]]
# 11. SNN [timesteps=50, scale_firing_rates=1000, synapse=0.01]: accuracy = 64.11149825783971%, precision = 0.645426515930113, recall = 0.6254980079681275, f1 = 0.635306019221042
# Confusion matrix:
# [[628 376]
#  [345 660]]
# 11. SNN [timesteps=50, scale_firing_rates=1000, synapse=None]: accuracy = 64.36037829766053%, precision = 0.6487603305785123, recall = 0.6254980079681275, f1 = 0.6369168356997972
# Confusion matrix:
# [[628 376]
#  [340 665]]
# 11. SNN [timesteps=50, scale_firing_rates=1, synapse=0.01]: accuracy = 54.30562468889995%, precision = 0.5529556650246306, recall = 0.44721115537848605, f1 = 0.49449339207048454
# Confusion matrix:
# [[449 555]
#  [363 642]]
# 11. SNN [timesteps=50, scale_firing_rates=1, synapse=None]: accuracy = 52.5634644101543%, precision = 0.5330739299610895, recall = 0.40936254980079684, f1 = 0.46309859154929583
# Confusion matrix:
# [[411 593]
#  [360 645]]
# Iteration: 12
# Build finished in 0:00:00
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Epoch 1/30
# 70/70 [==============================] - 4s 17ms/step - loss: 1.1093 - probe_loss: 1.1093 - probe_accuracy: 0.5429 - val_loss: 0.7878 - val_probe_loss: 0.7878 - val_probe_accuracy: 0.5924
# Epoch 2/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.8319 - probe_loss: 0.8319 - probe_accuracy: 0.5782 - val_loss: 0.7465 - val_probe_loss: 0.7465 - val_probe_accuracy: 0.5883
# Epoch 3/30
# 70/70 [==============================] - 1s 10ms/step - loss: 0.7434 - probe_loss: 0.7434 - probe_accuracy: 0.5946 - val_loss: 0.6622 - val_probe_loss: 0.6622 - val_probe_accuracy: 0.6060
# Epoch 4/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.7230 - probe_loss: 0.7230 - probe_accuracy: 0.5886 - val_loss: 0.6788 - val_probe_loss: 0.6788 - val_probe_accuracy: 0.6128
# Epoch 5/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.6882 - probe_loss: 0.6882 - probe_accuracy: 0.6098 - val_loss: 0.6540 - val_probe_loss: 0.6540 - val_probe_accuracy: 0.6094
# Epoch 6/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.6583 - probe_loss: 0.6583 - probe_accuracy: 0.6286 - val_loss: 0.6514 - val_probe_loss: 0.6514 - val_probe_accuracy: 0.6250
# Epoch 7/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.6445 - probe_loss: 0.6445 - probe_accuracy: 0.6311 - val_loss: 0.6528 - val_probe_loss: 0.6528 - val_probe_accuracy: 0.6209
# Epoch 8/30
# 70/70 [==============================] - 1s 10ms/step - loss: 0.6449 - probe_loss: 0.6449 - probe_accuracy: 0.6389 - val_loss: 0.6618 - val_probe_loss: 0.6618 - val_probe_accuracy: 0.5999
# Epoch 9/30
#  - ETA: 0s - loss: 0.6218 - probe_loss: 0.6218 - probe_accuracy: 0.6523
# Epoch 10/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.6284 - probe_loss: 0.6284 - probe_accuracy: 0.6630 - val_loss: 0.6563 - val_probe_loss: 0.6563 - val_probe_accuracy: 0.6189
# Epoch 11/30
# 70/70 [==============================] - 1s 10ms/step - loss: 0.6319 - probe_loss: 0.6319 - probe_accuracy: 0.6551 - val_loss: 0.6536 - val_probe_loss: 0.6536 - val_probe_accuracy: 0.6128
# Restoring model weights from the end of the best epoch.
# Epoch 00011: early stopping
# 12. ANN: accuracy = 63.76008064516129%, precision = 0.6497797356828194, recall = 0.5953582240161454, f1 = 0.6213796735123749
# Confusion matrix:
# [[590 401]
#  [318 675]]
# 12. SNN [timesteps=50, scale_firing_rates=1000, synapse=0.01]: accuracy = 63.91239422598307%, precision = 0.6517954298150164, recall = 0.5966135458167331, f1 = 0.6229849193967758
# Confusion matrix:
# [[599 405]
#  [320 685]]
# 12. SNN [timesteps=50, scale_firing_rates=1000, synapse=None]: accuracy = 64.06172224987556%, precision = 0.652267818574514, recall = 0.601593625498008, f1 = 0.6259067357512953
# Confusion matrix:
# [[604 400]
#  [322 683]]
# 12. SNN [timesteps=50, scale_firing_rates=1, synapse=0.01]: accuracy = 49.67645594823295%, precision = 0.4957678355501814, recall = 0.40836653386454186, f1 = 0.4478427089022392
# Confusion matrix:
# [[410 594]
#  [417 588]]
# 12. SNN [timesteps=50, scale_firing_rates=1, synapse=None]: accuracy = 51.51816824290692%, precision = 0.5184729064039408, recall = 0.41932270916334663, f1 = 0.4636563876651982
# Confusion matrix:
# [[421 583]
#  [391 614]]
# Iteration: 13
# Build finished in 0:00:00
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Epoch 1/30
# 70/70 [==============================] - 4s 16ms/step - loss: 1.1308 - probe_loss: 1.1308 - probe_accuracy: 0.5562 - val_loss: 0.8280 - val_probe_loss: 0.8280 - val_probe_accuracy: 0.6121
# Epoch 2/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.8335 - probe_loss: 0.8335 - probe_accuracy: 0.5837 - val_loss: 0.6930 - val_probe_loss: 0.6930 - val_probe_accuracy: 0.6209
# Epoch 3/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.7969 - probe_loss: 0.7969 - probe_accuracy: 0.5799 - val_loss: 0.6876 - val_probe_loss: 0.6876 - val_probe_accuracy: 0.5917
# Epoch 4/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.7423 - probe_loss: 0.7423 - probe_accuracy: 0.5881 - val_loss: 0.6857 - val_probe_loss: 0.6857 - val_probe_accuracy: 0.6033
# Epoch 5/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.7030 - probe_loss: 0.7030 - probe_accuracy: 0.5900 - val_loss: 0.6564 - val_probe_loss: 0.6564 - val_probe_accuracy: 0.6236
# Epoch 6/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.6800 - probe_loss: 0.6800 - probe_accuracy: 0.6205 - val_loss: 0.6567 - val_probe_loss: 0.6567 - val_probe_accuracy: 0.6209
# Epoch 7/30
# 70/70 [==============================] - 1s 9ms/step - loss: 0.6568 - probe_loss: 0.6568 - probe_accuracy: 0.6269 - val_loss: 0.6627 - val_probe_loss: 0.6627 - val_probe_accuracy: 0.6046
# Epoch 8/30
# ...
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: Cannot convert BatchNormalization layer to native Nengo objects unless inference_only=True or layer.trainable=False. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:588: UserWarning: Activation type <function softmax_v2 at 0x00000157777D8DC0> does not have a native Nengo equivalent; falling back to a TensorNode
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\simulator.py:1765: UserWarning: Number of elements (1) in ['ndarray'] does not match number of Nodes (3); consider using an explicit input dictionary in this case, so that the assignment of data to objects is unambiguous.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: Layer type Dropout does not have a registered converter. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: average_pooling2d.padding has value same != valid, which is not supported. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: Cannot convert BatchNormalization layer to native Nengo objects unless inference_only=True or layer.trainable=False. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:588: UserWarning: Activation type <function softmax_v2 at 0x00000157777D8DC0> does not have a native Nengo equivalent; falling back to a TensorNode
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\simulator.py:1765: UserWarning: Number of elements (1) in ['ndarray'] does not match number of Nodes (3); consider using an explicit input dictionary in this case, so that the assignment of data to objects is unambiguous.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: Layer type Dropout does not have a registered converter. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: average_pooling2d.padding has value same != valid, which is not supported. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: Cannot convert BatchNormalization layer to native Nengo objects unless inference_only=True or layer.trainable=False. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:588: UserWarning: Activation type <function softmax_v2 at 0x00000157777D8DC0> does not have a native Nengo equivalent; falling back to a TensorNode
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\simulator.py:1765: UserWarning: Number of elements (1) in ['ndarray'] does not match number of Nodes (3); consider using an explicit input dictionary in this case, so that the assignment of data to objects is unambiguous.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: Layer type Dropout does not have a registered converter. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: average_pooling2d.padding has value same != valid, which is not supported. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: Cannot convert BatchNormalization layer to native Nengo objects unless inference_only=True or layer.trainable=False. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:588: UserWarning: Activation type <function softmax_v2 at 0x00000157777D8DC0> does not have a native Nengo equivalent; falling back to a TensorNode
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\simulator.py:1921: UserWarning: Number of elements in input data (1507) is not evenly divisible by Simulator.minibatch_size (64); input data will be truncated.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\simulator.py:1921: UserWarning: Number of elements in input data (4520) is not evenly divisible by Simulator.minibatch_size (64); input data will be truncated.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\simulator.py:1765: UserWarning: Number of elements (1) in ['ndarray'] does not match number of Nodes (3); consider using an explicit input dictionary in this case, so that the assignment of data to objects is unambiguous.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: Layer type Dropout does not have a registered converter. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: average_pooling2d.padding has value same != valid, which is not supported. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: Cannot convert BatchNormalization layer to native Nengo objects unless inference_only=True or layer.trainable=False. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:588: UserWarning: Activation type <function softmax_v2 at 0x00000157777D8DC0> does not have a native Nengo equivalent; falling back to a TensorNode
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\simulator.py:1765: UserWarning: Number of elements (1) in ['ndarray'] does not match number of Nodes (3); consider using an explicit input dictionary in this case, so that the assignment of data to objects is unambiguous.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: Layer type Dropout does not have a registered converter. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: average_pooling2d.padding has value same != valid, which is not supported. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: Cannot convert BatchNormalization layer to native Nengo objects unless inference_only=True or layer.trainable=False. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:588: UserWarning: Activation type <function softmax_v2 at 0x00000157777D8DC0> does not have a native Nengo equivalent; falling back to a TensorNode
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\simulator.py:1765: UserWarning: Number of elements (1) in ['ndarray'] does not match number of Nodes (3); consider using an explicit input dictionary in this case, so that the assignment of data to objects is unambiguous.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: Layer type Dropout does not have a registered converter. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: average_pooling2d.padding has value same != valid, which is not supported. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: Cannot convert BatchNormalization layer to native Nengo objects unless inference_only=True or layer.trainable=False. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:588: UserWarning: Activation type <function softmax_v2 at 0x00000157777D8DC0> does not have a native Nengo equivalent; falling back to a TensorNode
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\simulator.py:1765: UserWarning: Number of elements (1) in ['ndarray'] does not match number of Nodes (3); consider using an explicit input dictionary in this case, so that the assignment of data to objects is unambiguous.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: Layer type Dropout does not have a registered converter. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: average_pooling2d.padding has value same != valid, which is not supported. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: Cannot convert BatchNormalization layer to native Nengo objects unless inference_only=True or layer.trainable=False. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:588: UserWarning: Activation type <function softmax_v2 at 0x00000157777D8DC0> does not have a native Nengo equivalent; falling back to a TensorNode
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\simulator.py:1765: UserWarning: Number of elements (1) in ['ndarray'] does not match number of Nodes (3); consider using an explicit input dictionary in this case, so that the assignment of data to objects is unambiguous.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: Layer type Dropout does not have a registered converter. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: average_pooling2d.padding has value same != valid, which is not supported. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: Cannot convert BatchNormalization layer to native Nengo objects unless inference_only=True or layer.trainable=False. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:588: UserWarning: Activation type <function softmax_v2 at 0x00000157777D8DC0> does not have a native Nengo equivalent; falling back to a TensorNode
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\simulator.py:1921: UserWarning: Number of elements in input data (1507) is not evenly divisible by Simulator.minibatch_size (64); input data will be truncated.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\simulator.py:1921: UserWarning: Number of elements in input data (4520) is not evenly divisible by Simulator.minibatch_size (64); input data will be truncated.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\simulator.py:1765: UserWarning: Number of elements (1) in ['ndarray'] does not match number of Nodes (3); consider using an explicit input dictionary in this case, so that the assignment of data to objects is unambiguous.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: Layer type Dropout does not have a registered converter. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: average_pooling2d.padding has value same != valid, which is not supported. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: Cannot convert BatchNormalization layer to native Nengo objects unless inference_only=True or layer.trainable=False. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:588: UserWarning: Activation type <function softmax_v2 at 0x00000157777D8DC0> does not have a native Nengo equivalent; falling back to a TensorNode
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\simulator.py:1765: UserWarning: Number of elements (1) in ['ndarray'] does not match number of Nodes (3); consider using an explicit input dictionary in this case, so that the assignment of data to objects is unambiguous.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: Layer type Dropout does not have a registered converter. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: average_pooling2d.padding has value same != valid, which is not supported. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: Cannot convert BatchNormalization layer to native Nengo objects unless inference_only=True or layer.trainable=False. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:588: UserWarning: Activation type <function softmax_v2 at 0x00000157777D8DC0> does not have a native Nengo equivalent; falling back to a TensorNode
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\simulator.py:1765: UserWarning: Number of elements (1) in ['ndarray'] does not match number of Nodes (3); consider using an explicit input dictionary in this case, so that the assignment of data to objects is unambiguous.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: Layer type Dropout does not have a registered converter. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: average_pooling2d.padding has value same != valid, which is not supported. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: Cannot convert BatchNormalization layer to native Nengo objects unless inference_only=True or layer.trainable=False. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:588: UserWarning: Activation type <function softmax_v2 at 0x00000157777D8DC0> does not have a native Nengo equivalent; falling back to a TensorNode
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\simulator.py:1765: UserWarning: Number of elements (1) in ['ndarray'] does not match number of Nodes (3); consider using an explicit input dictionary in this case, so that the assignment of data to objects is unambiguous.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: Layer type Dropout does not have a registered converter. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: average_pooling2d.padding has value same != valid, which is not supported. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: Cannot convert BatchNormalization layer to native Nengo objects unless inference_only=True or layer.trainable=False. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:588: UserWarning: Activation type <function softmax_v2 at 0x00000157777D8DC0> does not have a native Nengo equivalent; falling back to a TensorNode
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\simulator.py:1765: UserWarning: Number of elements (1) in ['ndarray'] does not match number of Nodes (3); consider using an explicit input dictionary in this case, so that the assignment of data to objects is unambiguous.
#   warnings.warn(

# %%
# Create dictionary with the data for pandas dataframe
data = {
    'iterations': [x for x in range(1, num_iterations + 1)],
    'ann_accuracy': [x['accuracy'] for x in ann],
    'ann_precision': [x['precision'] for x in ann],
    'ann_recall': [x['recall'] for x in ann],
    'ann_f1': [x['f1'] for x in ann]
}

for variant_name in variants:
    data[f'{variant_name}_accuracy'] = [x['accuracy'] for x in snn[variant_name]]
    data[f'{variant_name}_precision'] = [x['precision'] for x in snn[variant_name]]
    data[f'{variant_name}_recall'] = [x['recall'] for x in snn[variant_name]]
    data[f'{variant_name}_f1'] = [x['f1'] for x in snn[variant_name]]

# %%
# Create pandas dataframe and save it to xlsx file
output_folder_path = 'p300_exp_output'
os.makedirs(output_folder_path, exist_ok=True)

df = pd.DataFrame(data)
df
# Out:
#     iterations  ann_accuracy  ann_precision  ann_recall    ann_f1  \
# 0            1      0.639113       0.646432    0.612513  0.629016
# 1            2      0.636089       0.655852    0.571140  0.610572
# 2            3      0.631048       0.626341    0.647830  0.636905
# 3            4      0.637601       0.649780    0.595358  0.621380
# 4            5      0.627016       0.618062    0.662967  0.639727
# 5            6      0.634073       0.644809    0.595358  0.619098
# 6            7      0.640121       0.672050    0.545913  0.602450
# 7            8      0.633065       0.643716    0.594349  0.618048
# 8            9      0.641633       0.644033    0.631685  0.637799
# 9           10      0.640121       0.648765    0.609485  0.628512
# 10          11      0.642641       0.647490    0.624622  0.635850
# 11          12      0.637601       0.649780    0.595358  0.621380
# 12          13      0.637601       0.662291    0.560040  0.606889
# 13          14      0.642137       0.654565    0.600404  0.626316
# 14          15      0.632056       0.647458    0.578204  0.610874
# 15          16      0.592742       0.591226    0.598385  0.594784
# 16          17      0.614415       0.614372    0.612513  0.613441
# 17          18      0.636593       0.640333    0.621594  0.630824
# 18          19      0.642137       0.670303    0.558022  0.609031
# 19          20      0.633569       0.633065    0.633703  0.633384
# 20          21      0.633569       0.624060    0.670030  0.646229
# 21          22      0.647177       0.654295    0.622603  0.638056
# 22          23      0.629032       0.659176    0.532795  0.589286
# 23          24      0.622984       0.628844    0.598385  0.613237
# 24          25      0.645665       0.657895    0.605449  0.630583
# 25          26      0.643145       0.664726    0.576186  0.617297
# 26          27      0.632560       0.648190    0.578204  0.611200
# 27          28      0.621472       0.625523    0.603431  0.614278
# 28          29      0.630040       0.639220    0.595358  0.616510
# 29          30      0.625504       0.637168    0.581231  0.607916
#
#     snn [timesteps=50, scaling=1000, synapse=0.010000]_accuracy  \
# 0                                            0.640617
# 1                                            0.634644
# 2                                            0.636137
# 3                                            0.636137
# 4                                            0.627178
# 5                                            0.634146
# 6                                            0.640119
# 7                                            0.636137
# 8                                            0.644599
# 9                                            0.642111
# 10                                           0.641115
# 11                                           0.639124
# 12                                           0.639622
# 13                                           0.640617
# 14                                           0.633151
# 15                                           0.592334
# 16                                           0.617222
# 17                                           0.641613
# 18                                           0.641613
# 19                                           0.633151
# 20                                           0.631658
# 21                                           0.644102
# 22                                           0.635142
# 23                                           0.624689
# 24                                           0.648581
# 25                                           0.642111
# 26                                           0.630662
# 27                                           0.624191
# 28                                           0.629169
# 29                                           0.627178
#
#     snn [timesteps=50, scaling=1000, synapse=0.010000]_precision  \
# 0                                            0.648734
# 1                                            0.653759
# 2                                            0.631884
# 3                                            0.649180
# 4                                            0.618826
# 5                                            0.646037
# 6                                            0.673243
# 7                                            0.648855
# 8                                            0.647959
# 9                                            0.651113
# 10                                           0.645427
# 11                                           0.651795
# 12                                           0.665877
# 13                                           0.652597
# 14                                           0.650169
# 15                                           0.591313
# 16                                           0.616915
# 17                                           0.645492
# 18                                           0.669856
# 19                                           0.632047
# 20                                           0.622449
# 21                                           0.652266
# 22                                           0.666667
# 23                                           0.631303
# 24                                           0.662309
# 25                                           0.663230
# 26                                           0.646861
# 27                                           0.628749
# 28                                           0.637620
# 29                                           0.639040
#
#     snn [timesteps=50, scaling=1000, synapse=0.010000]_recall  \
# 0                                            0.612550
# 1                                            0.571713
# 2                                            0.651394
# 3                                            0.591633
# 4                                            0.661355
# 5                                            0.592629
# 6                                            0.543825
# 7                                            0.592629
# 8                                            0.632470
# 9                                            0.611554
# 10                                           0.625498
# 11                                           0.596614
# 12                                           0.559761
# 13                                           0.600598
# 14                                           0.575697
# 15                                           0.596614
# 16                                           0.617530
# 17                                           0.627490
# 18                                           0.557769
# 19                                           0.636454
# 20                                           0.668327
# 21                                           0.616534
# 22                                           0.539841
# 23                                           0.598606
# 24                                           0.605578
# 25                                           0.576693
# 26                                           0.574701
# 27                                           0.605578
# 28                                           0.597610
# 29                                           0.583665
#
#     snn [timesteps=50, scaling=1000, synapse=0.010000]_f1  \
# 0                                            0.630123
# 1                                            0.609989
# 2                                            0.641491
# 3                                            0.619072
# 4                                            0.639384
# 5                                            0.618182
# 6                                            0.601653
# 7                                            0.619469
# 8                                            0.640121
# 9                                            0.630714
# 10                                           0.635306
# 11                                           0.622985
# 12                                           0.608225
# 13                                           0.625519
# 14                                           0.610671
# 15                                           0.593951
# 16                                           0.617222
# 17                                           0.636364
# 18                                           0.608696
# 19                                           0.634243
# 20                                           0.644573
# 21                                           0.633897
# 22                                           0.596588
# 23                                           0.614519
# 24                                           0.632674
# 25                                           0.616942
# 26                                           0.608650
# 27                                           0.616946
# 28                                           0.616967
# 29                                           0.610099
#
#     snn [timesteps=50, scaling=1000, synapse=None]_accuracy  ...  \
# 0                                            0.636635        ...
# 1                                            0.634644        ...
# 2                                            0.630662        ...
# 3                                            0.637133        ...
# 4                                            0.624191        ...
# 5                                            0.636635        ...
# 6                                            0.641115        ...
# 7                                            0.639124        ...
# 8                                            0.640617        ...
# 9                                            0.639622        ...
# 10                                           0.643604        ...
# 11                                           0.640617        ...
# 12                                           0.639124        ...
# 13                                           0.637631        ...
# 14                                           0.631160        ...
# 15                                           0.594326        ...
# 16                                           0.612245        ...
# 17                                           0.637133        ...
# 18                                           0.642111        ...
# 19                                           0.629169        ...
# 20                                           0.632653        ...
# 21                                           0.644102        ...
# 22                                           0.628671        ...
# 23                                           0.628173        ...
# 24                                           0.649577        ...
# 25                                           0.644599        ...
# 26                                           0.632155        ...
# 27                                           0.623693        ...
# 28                                           0.630662        ...
# 29                                           0.624689        ...
#
#     snn [timesteps=50, scaling=1000, synapse=None]_recall  \
# 0                                            0.610558
# 1                                            0.567729
# 2                                            0.642430
# 3                                            0.594622
# 4                                            0.660359
# 5                                            0.594622
# 6                                            0.545817
# 7                                            0.594622
# 8                                            0.627490
# 9                                            0.608566
# 10                                           0.625498
# 11                                           0.601594
# 12                                           0.559761
# 13                                           0.599602
# 14                                           0.576693
# 15                                           0.597610
# 16                                           0.612550
# 17                                           0.624502
# 18                                           0.558765
# 19                                           0.632470
# 20                                           0.667331
# 21                                           0.617530
# 22                                           0.532869
# 23                                           0.599602
# 24                                           0.608566
# 25                                           0.577689
# 26                                           0.575697
# 27                                           0.603586
# 28                                           0.592629
# 29                                           0.575697
#
#     snn [timesteps=50, scaling=1000, synapse=None]_f1  \
# 0                                            0.626789
# 1                                            0.608324
# 2                                            0.634843
# 3                                            0.620905
# 4                                            0.637194
# 5                                            0.620582
# 6                                            0.603192
# 7                                            0.622199
# 8                                            0.635721
# 9                                            0.627955
# 10                                           0.636917
# 11                                           0.625907
# 12                                           0.607896
# 13                                           0.623188
# 14                                           0.609795
# 15                                           0.595533
# 16                                           0.612245
# 17                                           0.632375
# 18                                           0.609451
# 19                                           0.630273
# 20                                           0.644851
# 21                                           0.634271
# 22                                           0.589207
# 23                                           0.617119
# 24                                           0.634476
# 25                                           0.618997
# 26                                           0.610026
# 27                                           0.615854
# 28                                           0.615942
# 29                                           0.605236
#
#     snn [timesteps=50, scaling=1, synapse=0.010000]_accuracy  \
# 0                                            0.520159
# 1                                            0.528123
# 2                                            0.539074
# 3                                            0.527128
# 4                                            0.504231
# 5                                            0.526132
# 6                                            0.527626
# 7                                            0.527626
# 8                                            0.530612
# 9                                            0.514684
# 10                                           0.543056
# 11                                           0.496765
# 12                                           0.537581
# 13                                           0.528621
# 14                                           0.510702
# 15                                           0.510702
# 16                                           0.498756
# 17                                           0.522648
# 18                                           0.531608
# 19                                           0.503733
# 20                                           0.493280
# 21                                           0.511200
# 22                                           0.528621
# 23                                           0.535590
# 24                                           0.501742
# 25                                           0.531608
# 26                                           0.511697
# 27                                           0.507715
# 28                                           0.513191
# 29                                           0.527128
#
#     snn [timesteps=50, scaling=1, synapse=0.010000]_precision  \
# 0                                            0.527548
# 1                                            0.536842
# 2                                            0.556686
# 3                                            0.536000
# 4                                            0.505479
# 5                                            0.541139
# 6                                            0.532391
# 7                                            0.537415
# 8                                            0.539457
# 9                                            0.518057
# 10                                           0.552956
# 11                                           0.495768
# 12                                           0.542182
# 13                                           0.536213
# 14                                           0.513241
# 15                                           0.519924
# 16                                           0.498008
# 17                                           0.531735
# 18                                           0.540025
# 19                                           0.504122
# 20                                           0.491071
# 21                                           0.518771
# 22                                           0.541126
# 23                                           0.543452
# 24                                           0.502063
# 25                                           0.542282
# 26                                           0.515646
# 27                                           0.509202
# 28                                           0.519231
# 29                                           0.540179
#
#     snn [timesteps=50, scaling=1, synapse=0.010000]_recall  \
# 0                                            0.381474
# 1                                            0.406375
# 2                                            0.381474
# 3                                            0.400398
# 4                                            0.367530
# 5                                            0.340637
# 6                                            0.450199
# 7                                            0.393426
# 8                                            0.415339
# 9                                            0.414343
# 10                                           0.447211
# 11                                           0.408367
# 12                                           0.480080
# 13                                           0.420319
# 14                                           0.405378
# 15                                           0.272908
# 16                                           0.373506
# 17                                           0.375498
# 18                                           0.423307
# 19                                           0.426295
# 20                                           0.383466
# 21                                           0.302789
# 22                                           0.373506
# 23                                           0.442231
# 24                                           0.363546
# 25                                           0.402390
# 26                                           0.377490
# 27                                           0.413347
# 28                                           0.349602
# 29                                           0.361554
#
#     snn [timesteps=50, scaling=1, synapse=0.010000]_f1  \
# 0                                            0.442775
# 1                                            0.462585
# 2                                            0.452719
# 3                                            0.458381
# 4                                            0.425606
# 5                                            0.418093
# 6                                            0.487858
# 7                                            0.454284
# 8                                            0.469330
# 9                                            0.460432
# 10                                           0.494493
# 11                                           0.447843
# 12                                           0.509245
# 13                                           0.471245
# 14                                           0.452977
# 15                                           0.357936
# 16                                           0.426864
# 17                                           0.440163
# 18                                           0.474595
# 19                                           0.461954
# 20                                           0.430649
# 21                                           0.382390
# 22                                           0.441956
# 23                                           0.487644
# 24                                           0.421722
# 25                                           0.461978
# 26                                           0.435883
# 27                                           0.456295
# 28                                           0.417857
# 29                                           0.433174
#
#     snn [timesteps=50, scaling=1, synapse=None]_accuracy  \
# 0                                            0.525137
# 1                                            0.512195
# 2                                            0.500747
# 3                                            0.532603
# 4                                            0.526630
# 5                                            0.521155
# 6                                            0.543056
# 7                                            0.524141
# 8                                            0.532603
# 9                                            0.523644
# 10                                           0.525635
# 11                                           0.515182
# 12                                           0.524639
# 13                                           0.522150
# 14                                           0.537581
# 15                                           0.506720
# 16                                           0.511697
# 17                                           0.516675
# 18                                           0.545047
# 19                                           0.500747
# 20                                           0.530114
# 21                                           0.494276
# 22                                           0.513191
# 23                                           0.528123
# 24                                           0.518666
# 25                                           0.517173
# 26                                           0.515182
# 27                                           0.529119
# 28                                           0.545545
# 29                                           0.517173
#
#     snn [timesteps=50, scaling=1, synapse=None]_precision  \
# 0                                            0.531566
# 1                                            0.514963
# 2                                            0.500715
# 3                                            0.542707
# 4                                            0.538686
# 5                                            0.529006
# 6                                            0.553616
# 7                                            0.535191
# 8                                            0.545076
# 9                                            0.529785
# 10                                           0.533074
# 11                                           0.518473
# 12                                           0.527559
# 13                                           0.529650
# 14                                           0.544803
# 15                                           0.510888
# 16                                           0.515646
# 17                                           0.523471
# 18                                           0.560811
# 19                                           0.500627
# 20                                           0.538560
# 21                                           0.489831
# 22                                           0.519878
# 23                                           0.535264
# 24                                           0.525802
# 25                                           0.525000
# 26                                           0.522455
# 27                                           0.537662
# 28                                           0.558559
# 29                                           0.523810
#
#     snn [timesteps=50, scaling=1, synapse=None]_recall  \
# 0                                            0.419323
# 1                                            0.411355
# 2                                            0.348606
# 3                                            0.411355
# 4                                            0.367530
# 5                                            0.381474
# 6                                            0.442231
# 7                                            0.363546
# 8                                            0.391434
# 9                                            0.416335
# 10                                           0.409363
# 11                                           0.419323
# 12                                           0.467131
# 13                                           0.391434
# 14                                           0.454183
# 15                                           0.303785
# 16                                           0.377490
# 17                                           0.366534
# 18                                           0.413347
# 19                                           0.397410
# 20                                           0.417331
# 21                                           0.287849
# 22                                           0.338645
# 23                                           0.423307
# 24                                           0.375498
# 25                                           0.355578
# 26                                           0.347610
# 27                                           0.412351
# 28                                           0.432271
# 29                                           0.372510
#
#     snn [timesteps=50, scaling=1, synapse=None]_f1
# 0                                         0.468820
# 1                                         0.457364
# 2                                         0.411039
# 3                                         0.467989
# 4                                         0.436945
# 5                                         0.443287
# 6                                         0.491694
# 7                                         0.432977
# 8                                         0.455652
# 9                                         0.466258
# 10                                        0.463099
# 11                                        0.463656
# 12                                        0.495510
# 13                                        0.450172
# 14                                        0.495383
# 15                                        0.381012
# 16                                        0.435883
# 17                                        0.431166
# 18                                        0.475917
# 19                                        0.443087
# 20                                        0.470258
# 21                                        0.362610
# 22                                        0.410133
# 23                                        0.472747
# 24                                        0.438117
# 25                                        0.423990
# 26                                        0.417464
# 27                                        0.466742
# 28                                        0.487367
# 29                                        0.435390
#
# [30 rows x 21 columns]

# %%
df.to_excel(os.path.join(output_folder_path, 'data_iterations.xlsx'))

'File with iteration data successfully saved.'
# Out:
# 'File with iteration data successfully saved.'

# %%
network_names = ['ann'] + variants # names of each network in the pandas data frame
data_stats = {
    'models': network_names,
    'average_acc': [],
    'max_acc': [],
    'std_acc': [],
    'average_precision': [],
    'max_precision': [],
    'average_recall': [],
    'max_recall': [],
    'average_f1': [],
    'max_f1': []
} # statistics from the experiment

average_acc, max_acc, std_acc = [], [], []
average_precision, max_precision = [], []
average_recall, max_recall = [], []
for network_name in network_names:
    data_stats['average_acc'].append(df[f'{network_name}_accuracy'].mean())
    data_stats['max_acc'].append(df[f'{network_name}_accuracy'].max())
    data_stats['std_acc'].append(df[f'{network_name}_accuracy'].std())

    data_stats['average_precision'].append(df[f'{network_name}_precision'].mean())
    data_stats['max_precision'].append(df[f'{network_name}_precision'].max())

    data_stats['average_recall'].append(df[f'{network_name}_recall'].mean())
    data_stats['max_recall'].append(df[f'{network_name}_recall'].max())

    data_stats['average_f1'].append(df[f'{network_name}_f1'].mean())
    data_stats['max_f1'].append(df[f'{network_name}_f1'].max())

# %%
df_stats = pd.DataFrame(data_stats)

df_stats
# Out:
#                                               models  average_acc   max_acc  \
# 0                                                ann     0.633417  0.647177
# 1  snn [timesteps=50, scaling=1000, synapse=0.010...     0.634296  0.648581
# 2     snn [timesteps=50, scaling=1000, synapse=None]     0.633549  0.649577
# 3    snn [timesteps=50, scaling=1, synapse=0.010000]     0.519711  0.543056
# 4        snn [timesteps=50, scaling=1, synapse=None]     0.521885  0.545545
#
#     std_acc  average_precision  max_precision  average_recall  max_recall  \
# 0  0.010733           0.643327       0.672050        0.600437    0.670030
# 1  0.010596           0.644719       0.673243        0.600764    0.668327
# 2  0.010726           0.644069       0.674047        0.599568    0.667331
# 3  0.013647           0.526274       0.556686        0.391799    0.480080
# 4  0.012559           0.528771       0.560811        0.390538    0.467131
#
#    average_f1    max_f1
# 0    0.620362  0.646229
# 1    0.621174  0.644573
# 2    0.620242  0.644851
# 3    0.447964  0.509245
# 4    0.448391  0.495510

# %%
df_stats.to_excel(os.path.join(output_folder_path, 'statistics.xlsx'))

'File with statistics successfully saved.'
# Out:
# 'File with statistics successfully saved.'
