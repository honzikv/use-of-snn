# %%
# Necessary imports

import os
import statistics
import nengo
import keras
import pandas as pd
from sklearn import metrics
import tensorflow as tf
import json
import nengo_dl
import numpy as np
from scipy.io import loadmat
from sklearn.model_selection import train_test_split, ShuffleSplit
from tensorflow.python.keras import Input, Model
from tensorflow.python.keras.callbacks import EarlyStopping
from tensorflow.python.keras.layers import Conv2D, BatchNormalization, Dropout, AveragePooling2D, Flatten, Dense
from keras import backend as K

# %%
# First load the dataset and set seeds for consistency
# The dataset should be by default saved in ../datasets/VarekaGTNEpochs.mat
# The file can be downloaded here https://dataverse.harvard.edu/dataset.xhtml?persistentId=doi:10.7910/DVN/G9RRLN
dataset_path = os.path.join('dataset', 'VarekaGTNEpochs.mat')

params_folder_path = 'nengo_network_params' # path to saved parameters
os.makedirs('nengo_network_params', exist_ok=True)

seed = 0 # constant seed
np.random.seed(seed)
tf.random.set_seed(seed)

# %%
mat = loadmat(dataset_path)
target_data, non_target_data = mat['allTargetData'], mat['allNonTargetData'] # get target and non-target data
features = np.concatenate((target_data, non_target_data))

# target labels are represented as (1, 0) vector, non target labels are represented as (0, 1) vector
target_labels = np.tile(np.array([1, 0]), (target_data.shape[0], 1)) # set 'target' as (1, 0) vector
non_target_labels = np.tile(np.array([0, 1]), (non_target_data.shape[0], 1)) # set 'non target' as (0, 1) vector
labels = np.vstack((target_labels, non_target_labels)) # concatenate target and non target labels

# filter noise above 100 uV
threshold = 100.0
x_result, y_result = [], []
for i in range(features.shape[0]):
    if not np.max(np.abs(features[i])) > threshold:
        x_result.append(features[i])
        y_result.append(labels[i])

# Save data to numpy array
features, labels = np.array(x_result), np.array(y_result)
features = features.reshape((features.shape[0], 1, -1))
labels = labels.reshape((labels.shape[0], 1, -1))

# Print shapes
f'Features shape: {features.shape}, Labels shape: {labels.shape}'
# Out:
# 'Features shape: (8036, 1, 3600), Labels shape: (8036, 1, 2)'

# %%
# Define function to create the CNN model
# Slightly modified version from https://www.sciencedirect.com/science/article/pii/S1746809419304185
def create_model():
    """
    Function to create tensorflow model
    """
    inp = Input(shape=(3, 1200, 1), name='input_layer')
    conv2d = Conv2D(filters=6, kernel_size=(3, 3), activation=tf.nn.relu)(inp)
    dropout1 = Dropout(0.5, seed=seed)(conv2d)
    avg_pooling = AveragePooling2D(pool_size=(1, 8), padding='same')(dropout1)
    flatten = Flatten()(avg_pooling)
    dense1 = Dense(100, activation=tf.nn.relu)(flatten)
    batch_norm = BatchNormalization()(dense1)
    dropout2 = Dropout(0.5, seed=seed)(batch_norm)
    output = Dense(2, activation=tf.nn.softmax, name='output_layer')(dropout2)

    return Model(inputs=inp, outputs=output)

# %%
def get_metrics(simulator, output_layer, x_test, y_test, minibatch_size, network_name):
    """
    Function for calculating metrics
    :param simulator: simulator instance
    :param input_layer: input layer reference
    :param output_layer: output layer reference
    :param x_test: features of the testing subset
    :param y_test: labels of the testing subset
    :param network_name: name of the network
    :return: accuracy, recall and precision metrics
    """

    # Truncate the remaining number of samples since the predict function uses minibatch_size as well (i.e.
    samples = (x_test.shape[0] // minibatch_size ) * minibatch_size
    x_test, y_test = x_test[:samples], y_test[:samples]

    predictions = simulator.predict(x_test)[output_layer] # get result from output layer when predicting on x_test
    predictions = predictions[:,-1,:] # get the last timestep
    predictions_argm = np.argmax(predictions, axis=-1) # get predicted label

    y_test = np.squeeze(y_test, axis=1) # remove time dimension
    y_test_argm = np.argmax(y_test, axis=-1) # get labels

    precision = metrics.precision_score(y_true=y_test_argm, y_pred=predictions_argm, average='binary') # get precision score
    recall = metrics.recall_score(y_true=y_test_argm, y_pred=predictions_argm, average='binary') # get recall
    f1 = metrics.f1_score(y_true=y_test_argm, y_pred=predictions_argm, average='binary')
    accuracy = metrics.accuracy_score(y_true=y_test_argm, y_pred=predictions_argm) # get accuracy
    confusion_matrix = metrics.confusion_matrix(y_true=y_test_argm, y_pred=predictions_argm)

    # Log the statistics
    print(f'{network_name}: accuracy = {accuracy * 100}%, precision = {precision}, '
          f'recall = {recall}, f1 = {f1}')
    print('Confusion matrix:')
    print(confusion_matrix)

    return accuracy, precision, recall, f1, confusion_matrix

# Define functions to run the analog and spiking networks

def run_ann(model, train, valid, test, params_save_path, iteration, shuffle_training=True):
    """
    Run ann via Nengo simulator. This fits the given model with the training data (train) and validates it using validation
    data (valid). Then accuracy is calculated using the test data (test) and weights are saved to params_save_path
    :param shuffle_training: whether to shuffle data (default true)
    :param model: tensorflow model created from create_model() function
    :param train: pair of features and labels from training data
    :param valid: pair of features and labels from validation data
    :param test: pair of features and labels from test data
    :param params_save_path: output path to save weights of the network for SNN testing
    :return accuracy, precision, recall, f1 and confusion matrix from the testing data
    """

    # unwrap into training and testing data for each subset
    x_train, y_train = train[0], train[1]
    x_valid, y_valid = valid[0], valid[1]
    x_test, y_test = test[0], test[1]

    converter = nengo_dl.Converter(model)
    with nengo_dl.Simulator(converter.net, minibatch_size=64) as simulator:
        # Compile the model with binary cross-entropy and Adam optimizer
        simulator.compile(
            optimizer=keras.optimizers.Adam(),
            loss=keras.losses.BinaryCrossentropy(),
            metrics=['accuracy']
        )

        input_layer = converter.inputs[model.get_layer('input_layer')] # get nengo input layer
        output_layer = converter.outputs[model.get_layer('output_layer')] # get nengo output layer

        simulator.fit(
            x={ input_layer: x_train }, y={ output_layer: y_train },
            validation_data=({ input_layer: x_valid }, { output_layer: y_valid }),
            epochs=30,
            shuffle=shuffle_training,
            callbacks=[EarlyStopping(patience=5, verbose=1, restore_best_weights=True)] # early stop to avoid overfitting
        ) # train model

        simulator.save_params(params_save_path) # save params for SNN

        accuracy, precision, recall, f1, confusion_matrix = get_metrics(simulator, output_layer, x_test, y_test,
                                                  minibatch_size=simulator.minibatch_size,
                                                  network_name=f'{iteration}. ANN')

        return {
            'accuracy': accuracy,
            'precision': precision,
            'recall': recall,
            'f1': f1,
            'confusion_matrix': confusion_matrix
        }


def run_snn(model, test, params_load_path, timesteps, scale_firing_rates, synapse, iteration):
    """
    Runs SNN on test data. Loads pre-trained weights from params_load path and uses timesteps, scale_firing_rates and synapse
    parameters for simulator.
    :param model: reference to the tensorflow model
    :param test: reference to the test features and labels
    :param params_load_path: path to the saved weights of the ANN
    :param timesteps: number of timesteps - i.e. how long is the input streamed to the network
    :param scale_firing_rates: firing rate scaling - amplifies spikes
    :param synapse: synaptic smoothing
    :param iteration: iteration to print the result
    :return: accuracy, precision, recall, f1 and confusion matrix from the testing data
    """

    # Conversion of the TensorFlow model to a spiking Nengo model
    converter = nengo_dl.Converter(
        model=model,
        swap_activations={ tf.nn.relu: nengo.SpikingRectifiedLinear() },
        scale_firing_rates=scale_firing_rates,
        synapse=synapse
    )

    x_test, y_test = test[0], test[1] # get test features and labels

    with converter.net:
        nengo_dl.configure_settings(stateful=False)

    output_layer = converter.outputs[model.get_layer('output_layer')] # output layer for simulator
    x_test_time_tiled = np.tile(x_test, (1, timesteps, 1)) # tile x_test to match desired timesteps for simulator

    with nengo_dl.Simulator(converter.net, minibatch_size=41, progress_bar=False) as simulator:
        simulator.load_params(params_load_path)

        # Name of the network for print in get_metrics function
        name = f'{iteration}. SNN [timesteps={timesteps}, scale_firing_rates={scale_firing_rates}, synapse={synapse}]'
        accuracy, precision, recall, f1, confusion_matrix = get_metrics(simulator, output_layer, x_test_time_tiled, y_test,
                                                  minibatch_size=simulator.minibatch_size,
                                                  network_name=name)

        return {
            'accuracy': accuracy,
            'precision': precision,
            'recall': recall,
            'f1': f1,
            'confusion_matrix': confusion_matrix
        }

# %%
# Split the dataset into training and testing data
x_train, x_test, y_train, y_test = train_test_split(features, labels, test_size=0.25, random_state=seed, shuffle=True)

print(f'Train features shape: {x_train.shape}, train labels shape: {y_train.shape}')
print(f'Test features shape: {x_test.shape}, test labels shape: {y_test.shape}')

# Arrays to store results from the ANN and the SNN
ann, snn = [], {}

# Configuration for the spiking network with format: timesteps, scale_firing_rates, synapse
snn_config = [
    [50, 1000, 0.01], # best performing parameters for simulator
    [50, 1000, None], # synaptic smoothing turned off
    [50, 1, 0.01], # spike scaling turned off
    [50, 1, None] # everything turned off, only RELU is swapped for spiking RELU
]

variants = []
for variant in snn_config:
        # name of the configuration
        name = f'snn [timesteps={variant[0]}, scaling={variant[1]}, synapse=None]' if variant[2] is None \
            else 'snn [timesteps={}, scaling={}, synapse={:3f}]'.format(variant[0], int(variant[1]), variant[2])
        variants.append(name)
        snn[name] = []
# Out:
# Train features shape: (6027, 1, 3600), train labels shape: (6027, 1, 2)
# Test features shape: (2009, 1, 3600), test labels shape: (2009, 1, 2)

# %%
num_iterations = 30 # 30 iterations of CV
iteration = 1 # number of the current iteration
val_size = 0.25 # 25% of the data is used as validation data
for train_idx, val_idx in ShuffleSplit(n_splits=num_iterations, test_size=val_size, random_state=seed).split(x_train):
    print(f'Iteration: {iteration}')

    # Split all training data into current training data and validation data
    x_train_curr, y_train_curr = x_train[train_idx], y_train[train_idx]
    x_val_curr, y_val_curr = x_train[val_idx], y_train[val_idx]

    # Set params path
    params_path = os.path.join(params_folder_path, f'params_iter_{iteration}')

    # Create an untrained model
    model = create_model()

    # Run the analog network - train and evaluate
     # run ann
    ann_result = run_ann(model=model,
                         train=(x_train_curr, y_train_curr),
                         valid=(x_val_curr, y_val_curr),
                         test=(x_test, y_test),
                         params_save_path=params_path,
                         iteration=iteration
                         )
    K.clear_session() # clear session
    ann.append(ann_result) # append the result to the ANN array

    # Create an array where results for each configuration of the spiking network will be stored
    snn_config_results = []
    for i, variant_conf in enumerate(snn_config):
        snn_result = run_snn(model=model,
                          test=(x_test, y_test),
                          params_load_path=params_path,
                          timesteps=variant_conf[0],
                          scale_firing_rates=variant_conf[1],
                          synapse=variant_conf[2],
                          iteration=iteration
                          )
        K.clear_session() # clear session
        snn[variants[i]].append(snn_result) # save results

    del model # delete the model (if this is not called it "may" create a memory leak - depends on the simulation machine)
    iteration += 1
# Out:
# Iteration: 1
# Build finished in 0:00:00
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Epoch 1/30
# 70/70 [==============================] - 7s 30ms/step - loss: 1.1069 - probe_loss: 1.1069 - probe_accuracy: 0.5313 - val_loss: 0.8525 - val_probe_loss: 0.8525 - val_probe_accuracy: 0.6060
# Epoch 2/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.8417 - probe_loss: 0.8417 - probe_accuracy: 0.5741 - val_loss: 0.7130 - val_probe_loss: 0.7130 - val_probe_accuracy: 0.6026
# Epoch 3/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.7561 - probe_loss: 0.7561 - probe_accuracy: 0.5946 - val_loss: 0.6711 - val_probe_loss: 0.6711 - val_probe_accuracy: 0.6291
# Epoch 4/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.7055 - probe_loss: 0.7055 - probe_accuracy: 0.6172 - val_loss: 0.6666 - val_probe_loss: 0.6666 - val_probe_accuracy: 0.6236
# Epoch 5/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6740 - probe_loss: 0.6740 - probe_accuracy: 0.6224 - val_loss: 0.6571 - val_probe_loss: 0.6571 - val_probe_accuracy: 0.6298
# Epoch 6/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6642 - probe_loss: 0.6642 - probe_accuracy: 0.6298 - val_loss: 0.6566 - val_probe_loss: 0.6566 - val_probe_accuracy: 0.6257
# Epoch 7/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6399 - probe_loss: 0.6399 - probe_accuracy: 0.6426 - val_loss: 0.6559 - val_probe_loss: 0.6559 - val_probe_accuracy: 0.6270
# Epoch 8/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6407 - probe_loss: 0.6407 - probe_accuracy: 0.6386 - val_loss: 0.6586 - val_probe_loss: 0.6586 - val_probe_accuracy: 0.6162
# Epoch 9/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6355 - probe_loss: 0.6355 - probe_accuracy: 0.6305 - val_loss: 0.6796 - val_probe_loss: 0.6796 - val_probe_accuracy: 0.6114
# Epoch 10/30
#  - ETA: 0s - loss: 0.6598 - probe_loss: 0.6598 - probe_accuracy: 0.6351
# Epoch 11/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6187 - probe_loss: 0.6187 - probe_accuracy: 0.6540 - val_loss: 0.6605 - val_probe_loss: 0.6605 - val_probe_accuracy: 0.6209
# Epoch 12/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6165 - probe_loss: 0.6165 - probe_accuracy: 0.6727 - val_loss: 0.6589 - val_probe_loss: 0.6589 - val_probe_accuracy: 0.6182
# Restoring model weights from the end of the best epoch.
# Epoch 00012: early stopping
# 1. ANN: accuracy = 64.56653225806451%, precision = 0.6510416666666666, recall = 0.6294058408862034, f1 = 0.6400409626216078
# Confusion matrix:
# [[656 335]
#  [368 625]]
# 1. SNN [timesteps=50, scale_firing_rates=1000, synapse=0.01]: accuracy = 64.70881035340965%, precision = 0.6510204081632653, recall = 0.6348258706467662, f1 = 0.6428211586901763
# Confusion matrix:
# [[662 342]
#  [367 638]]
# 1. SNN [timesteps=50, scale_firing_rates=1000, synapse=None]: accuracy = 64.6590343454455%, precision = 0.6515930113052415, recall = 0.6308457711442786, f1 = 0.641051567239636
# Confusion matrix:
# [[665 339]
#  [371 634]]
# 1. SNN [timesteps=50, scale_firing_rates=1, synapse=0.01]: accuracy = 51.96615231458437%, precision = 0.5155520995334371, recall = 0.6597014925373135, f1 = 0.5787865560890442
# Confusion matrix:
# [[381 623]
#  [342 663]]
# 1. SNN [timesteps=50, scale_firing_rates=1, synapse=None]: accuracy = 51.96615231458437%, precision = 0.5158730158730159, recall = 0.6467661691542289, f1 = 0.5739514348785872
# Confusion matrix:
# [[394 610]
#  [355 650]]
# Iteration: 2
# Build finished in 0:00:00
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Epoch 1/30
# 70/70 [==============================] - 4s 19ms/step - loss: 1.1670 - probe_loss: 1.1670 - probe_accuracy: 0.5506 - val_loss: 0.8699 - val_probe_loss: 0.8699 - val_probe_accuracy: 0.5985
# Epoch 2/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.8749 - probe_loss: 0.8749 - probe_accuracy: 0.5788 - val_loss: 0.7001 - val_probe_loss: 0.7001 - val_probe_accuracy: 0.6114
# Epoch 3/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.7782 - probe_loss: 0.7782 - probe_accuracy: 0.5980 - val_loss: 0.6807 - val_probe_loss: 0.6807 - val_probe_accuracy: 0.6202
# Epoch 4/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.7274 - probe_loss: 0.7274 - probe_accuracy: 0.5970 - val_loss: 0.6627 - val_probe_loss: 0.6627 - val_probe_accuracy: 0.6270
# Epoch 5/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6730 - probe_loss: 0.6730 - probe_accuracy: 0.6204 - val_loss: 0.6548 - val_probe_loss: 0.6548 - val_probe_accuracy: 0.6345
# Epoch 6/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6641 - probe_loss: 0.6641 - probe_accuracy: 0.6191 - val_loss: 0.6593 - val_probe_loss: 0.6593 - val_probe_accuracy: 0.6223
# Epoch 7/30
# 70/70 [==============================] - 1s 10ms/step - loss: 0.6447 - probe_loss: 0.6447 - probe_accuracy: 0.6353 - val_loss: 0.6542 - val_probe_loss: 0.6542 - val_probe_accuracy: 0.6352
# Epoch 8/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6533 - probe_loss: 0.6533 - probe_accuracy: 0.6378 - val_loss: 0.6597 - val_probe_loss: 0.6597 - val_probe_accuracy: 0.6148
# Epoch 9/30
# 70/70 [==============================] - 1s 10ms/step - loss: 0.6261 - probe_loss: 0.6261 - probe_accuracy: 0.6583 - val_loss: 0.6520 - val_probe_loss: 0.6520 - val_probe_accuracy: 0.6379
# Epoch 10/30
# 70/70 [==============================] - 1s 10ms/step - loss: 0.6283 - probe_loss: 0.6283 - probe_accuracy: 0.6581 - val_loss: 0.6596 - val_probe_loss: 0.6596 - val_probe_accuracy: 0.6196
# Epoch 11/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6230 - probe_loss: 0.6230 - probe_accuracy: 0.6442 - val_loss: 0.6570 - val_probe_loss: 0.6570 - val_probe_accuracy: 0.6148
# Epoch 12/30
#  - ETA: 0s - loss: 0.5954 - probe_loss: 0.5954 - probe_accuracy: 0.6826
# Epoch 13/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6112 - probe_loss: 0.6112 - probe_accuracy: 0.6734 - val_loss: 0.6586 - val_probe_loss: 0.6586 - val_probe_accuracy: 0.6250
# Epoch 14/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6170 - probe_loss: 0.6170 - probe_accuracy: 0.6554 - val_loss: 0.6594 - val_probe_loss: 0.6594 - val_probe_accuracy: 0.6338
# Restoring model weights from the end of the best epoch.
# Epoch 00014: early stopping
# 2. ANN: accuracy = 63.659274193548384%, precision = 0.6343873517786561, recall = 0.6465256797583081, f1 = 0.6403990024937656
# Confusion matrix:
# [[621 370]
#  [351 642]]
# 2. SNN [timesteps=50, scale_firing_rates=1000, synapse=0.01]: accuracy = 63.663514186162274%, precision = 0.633107454017425, recall = 0.6507462686567164, f1 = 0.6418056918547596
# Confusion matrix:
# [[625 379]
#  [351 654]]
# 2. SNN [timesteps=50, scale_firing_rates=1000, synapse=None]: accuracy = 63.71329019412643%, precision = 0.6337209302325582, recall = 0.6507462686567164, f1 = 0.642120765832106
# Confusion matrix:
# [[626 378]
#  [351 654]]
# 2. SNN [timesteps=50, scale_firing_rates=1, synapse=0.01]: accuracy = 50.970632155301146%, precision = 0.5079872204472844, recall = 0.6328358208955224, f1 = 0.563579973416039
# Confusion matrix:
# [[388 616]
#  [369 636]]
# 2. SNN [timesteps=50, scale_firing_rates=1, synapse=None]: accuracy = 52.41413638626182%, precision = 0.5194290245836638, recall = 0.6517412935323383, f1 = 0.5781112091791705
# Confusion matrix:
# [[398 606]
#  [350 655]]
# Iteration: 3
# Build finished in 0:00:00
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Epoch 1/30
# 70/70 [==============================] - 5s 20ms/step - loss: 1.0989 - probe_loss: 1.0989 - probe_accuracy: 0.5428 - val_loss: 0.9355 - val_probe_loss: 0.9355 - val_probe_accuracy: 0.5815
# Epoch 2/30
# 70/70 [==============================] - 1s 12ms/step - loss: 0.8417 - probe_loss: 0.8417 - probe_accuracy: 0.5823 - val_loss: 0.7312 - val_probe_loss: 0.7312 - val_probe_accuracy: 0.6026
# Epoch 3/30
# 70/70 [==============================] - 1s 12ms/step - loss: 0.7531 - probe_loss: 0.7531 - probe_accuracy: 0.5967 - val_loss: 0.6862 - val_probe_loss: 0.6862 - val_probe_accuracy: 0.6073
# Epoch 4/30
# 70/70 [==============================] - 1s 13ms/step - loss: 0.6885 - probe_loss: 0.6885 - probe_accuracy: 0.6133 - val_loss: 0.6671 - val_probe_loss: 0.6671 - val_probe_accuracy: 0.6196
# Epoch 5/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6610 - probe_loss: 0.6610 - probe_accuracy: 0.6300 - val_loss: 0.6600 - val_probe_loss: 0.6600 - val_probe_accuracy: 0.6182
# Epoch 6/30
# 70/70 [==============================] - 1s 10ms/step - loss: 0.6427 - probe_loss: 0.6427 - probe_accuracy: 0.6345 - val_loss: 0.6651 - val_probe_loss: 0.6651 - val_probe_accuracy: 0.6141
# Epoch 7/30
# 70/70 [==============================] - 1s 10ms/step - loss: 0.6422 - probe_loss: 0.6422 - probe_accuracy: 0.6407 - val_loss: 0.6566 - val_probe_loss: 0.6566 - val_probe_accuracy: 0.6202
# Epoch 8/30
# 70/70 [==============================] - 1s 10ms/step - loss: 0.6405 - probe_loss: 0.6405 - probe_accuracy: 0.6400 - val_loss: 0.6590 - val_probe_loss: 0.6590 - val_probe_accuracy: 0.6243
# Epoch 9/30
# 70/70 [==============================] - 1s 10ms/step - loss: 0.6254 - probe_loss: 0.6254 - probe_accuracy: 0.6530 - val_loss: 0.6589 - val_probe_loss: 0.6589 - val_probe_accuracy: 0.6318
# Epoch 10/30
# 70/70 [==============================] - 1s 10ms/step - loss: 0.6251 - probe_loss: 0.6251 - probe_accuracy: 0.6595 - val_loss: 0.6561 - val_probe_loss: 0.6561 - val_probe_accuracy: 0.6359
# Epoch 11/30
# 70/70 [==============================] - 1s 10ms/step - loss: 0.6153 - probe_loss: 0.6153 - probe_accuracy: 0.6742 - val_loss: 0.6587 - val_probe_loss: 0.6587 - val_probe_accuracy: 0.6250
# Epoch 12/30
# 70/70 [==============================] - 1s 10ms/step - loss: 0.6148 - probe_loss: 0.6148 - probe_accuracy: 0.6667 - val_loss: 0.6568 - val_probe_loss: 0.6568 - val_probe_accuracy: 0.6243
# Epoch 13/30
# 70/70 [==============================] - 1s 10ms/step - loss: 0.6017 - probe_loss: 0.6017 - probe_accuracy: 0.6836 - val_loss: 0.6583 - val_probe_loss: 0.6583 - val_probe_accuracy: 0.6298
# Epoch 14/30
# 70/70 [==============================] - 1s 10ms/step - loss: 0.6068 - probe_loss: 0.6068 - probe_accuracy: 0.6763 - val_loss: 0.6919 - val_probe_loss: 0.6919 - val_probe_accuracy: 0.6005
# Epoch 15/30
# 70/70 [==============================] - 1s 10ms/step - loss: 0.6047 - probe_loss: 0.6047 - probe_accuracy: 0.6755 - val_loss: 0.6651 - val_probe_loss: 0.6651 - val_probe_accuracy: 0.6067
# Restoring model weights from the end of the best epoch.
# Epoch 00015: early stopping
# 3. ANN: accuracy = 63.05443548387096%, precision = 0.6359832635983264, recall = 0.6122860020140987, f1 = 0.6239096972806567
# Confusion matrix:
# [[643 348]
#  [385 608]]
# 3. SNN [timesteps=50, scale_firing_rates=1000, synapse=0.01]: accuracy = 62.81732205077153%, precision = 0.6338174273858921, recall = 0.6079601990049751, f1 = 0.6206196038598274
# Confusion matrix:
# [[651 353]
#  [394 611]]
# 3. SNN [timesteps=50, scale_firing_rates=1000, synapse=None]: accuracy = 62.96665007466401%, precision = 0.6349534643226473, recall = 0.6109452736318408, f1 = 0.6227180527383367
# Confusion matrix:
# [[651 353]
#  [391 614]]
# 3. SNN [timesteps=50, scale_firing_rates=1, synapse=0.01]: accuracy = 51.51816824290692%, precision = 0.5121951219512195, recall = 0.6477611940298508, f1 = 0.5720562390158171
# Confusion matrix:
# [[384 620]
#  [354 651]]
# 3. SNN [timesteps=50, scale_firing_rates=1, synapse=None]: accuracy = 53.40965654554505%, precision = 0.5265998457979953, recall = 0.6796019900497512, f1 = 0.5933970460469157
# Confusion matrix:
# [[390 614]
#  [322 683]]
# Iteration: 4
# Build finished in 0:00:00
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Epoch 1/30
# 70/70 [==============================] - 4s 18ms/step - loss: 1.0861 - probe_loss: 1.0861 - probe_accuracy: 0.5580 - val_loss: 0.9588 - val_probe_loss: 0.9588 - val_probe_accuracy: 0.5754
# Epoch 2/30
# 70/70 [==============================] - 1s 10ms/step - loss: 0.8344 - probe_loss: 0.8344 - probe_accuracy: 0.5912 - val_loss: 0.7490 - val_probe_loss: 0.7490 - val_probe_accuracy: 0.5883
# Epoch 3/30
# 70/70 [==============================] - 1s 10ms/step - loss: 0.7598 - probe_loss: 0.7598 - probe_accuracy: 0.5961 - val_loss: 0.6794 - val_probe_loss: 0.6794 - val_probe_accuracy: 0.6162
# Epoch 4/30
# 70/70 [==============================] - 1s 10ms/step - loss: 0.7191 - probe_loss: 0.7191 - probe_accuracy: 0.6057 - val_loss: 0.6802 - val_probe_loss: 0.6802 - val_probe_accuracy: 0.6148
# Epoch 5/30
# 70/70 [==============================] - 1s 10ms/step - loss: 0.6625 - probe_loss: 0.6625 - probe_accuracy: 0.6298 - val_loss: 0.6670 - val_probe_loss: 0.6670 - val_probe_accuracy: 0.6209
# Epoch 6/30
# 70/70 [==============================] - 1s 10ms/step - loss: 0.6597 - probe_loss: 0.6597 - probe_accuracy: 0.6222 - val_loss: 0.6574 - val_probe_loss: 0.6574 - val_probe_accuracy: 0.6277
# Epoch 7/30
# 70/70 [==============================] - 1s 10ms/step - loss: 0.6487 - probe_loss: 0.6487 - probe_accuracy: 0.6436 - val_loss: 0.6526 - val_probe_loss: 0.6526 - val_probe_accuracy: 0.6277
# Epoch 8/30
# 70/70 [==============================] - 1s 10ms/step - loss: 0.6476 - probe_loss: 0.6476 - probe_accuracy: 0.6320 - val_loss: 0.6494 - val_probe_loss: 0.6494 - val_probe_accuracy: 0.6277
# Epoch 9/30
# 70/70 [==============================] - 1s 10ms/step - loss: 0.6320 - probe_loss: 0.6320 - probe_accuracy: 0.6588 - val_loss: 0.6513 - val_probe_loss: 0.6513 - val_probe_accuracy: 0.6359
# Epoch 10/30
# 70/70 [==============================] - 1s 10ms/step - loss: 0.6214 - probe_loss: 0.6214 - probe_accuracy: 0.6607 - val_loss: 0.6534 - val_probe_loss: 0.6534 - val_probe_accuracy: 0.6277
# Epoch 11/30
# 70/70 [==============================] - 1s 10ms/step - loss: 0.6257 - probe_loss: 0.6257 - probe_accuracy: 0.6527 - val_loss: 0.6497 - val_probe_loss: 0.6497 - val_probe_accuracy: 0.6189
# Epoch 12/30
# 70/70 [==============================] - 1s 10ms/step - loss: 0.6240 - probe_loss: 0.6240 - probe_accuracy: 0.6525 - val_loss: 0.6526 - val_probe_loss: 0.6526 - val_probe_accuracy: 0.6277
# Epoch 13/30
# 70/70 [==============================] - 1s 10ms/step - loss: 0.6124 - probe_loss: 0.6124 - probe_accuracy: 0.6699 - val_loss: 0.6493 - val_probe_loss: 0.6493 - val_probe_accuracy: 0.6345
# Epoch 14/30
# 70/70 [==============================] - 1s 10ms/step - loss: 0.6113 - probe_loss: 0.6113 - probe_accuracy: 0.6788 - val_loss: 0.6511 - val_probe_loss: 0.6511 - val_probe_accuracy: 0.6264
# Epoch 15/30
# 70/70 [==============================] - 1s 10ms/step - loss: 0.6150 - probe_loss: 0.6150 - probe_accuracy: 0.6677 - val_loss: 0.6564 - val_probe_loss: 0.6564 - val_probe_accuracy: 0.6264
# Epoch 16/30
# 70/70 [==============================] - 1s 10ms/step - loss: 0.5885 - probe_loss: 0.5885 - probe_accuracy: 0.6976 - val_loss: 0.6552 - val_probe_loss: 0.6552 - val_probe_accuracy: 0.6257
# Epoch 17/30
# 70/70 [==============================] - 1s 10ms/step - loss: 0.5967 - probe_loss: 0.5967 - probe_accuracy: 0.6814 - val_loss: 0.6585 - val_probe_loss: 0.6585 - val_probe_accuracy: 0.6141
# Epoch 18/30
# 70/70 [==============================] - 1s 10ms/step - loss: 0.5943 - probe_loss: 0.5943 - probe_accuracy: 0.6917 - val_loss: 0.6676 - val_probe_loss: 0.6676 - val_probe_accuracy: 0.6189
# Restoring model weights from the end of the best epoch.
# Epoch 00018: early stopping
# 4. ANN: accuracy = 63.659274193548384%, precision = 0.6346534653465347, recall = 0.6455186304128903, f1 = 0.6400399400898652
# Confusion matrix:
# [[622 369]
#  [352 641]]
# 4. SNN [timesteps=50, scale_firing_rates=1000, synapse=0.01]: accuracy = 63.464410154305625%, precision = 0.6327130264446621, recall = 0.6427860696517413, f1 = 0.6377097729516289
# Confusion matrix:
# [[629 375]
#  [359 646]]
# 4. SNN [timesteps=50, scale_firing_rates=1000, synapse=None]: accuracy = 63.76306620209059%, precision = 0.6340755082284608, recall = 0.6517412935323383, f1 = 0.6427870461236507
# Confusion matrix:
# [[626 378]
#  [350 655]]
# 4. SNN [timesteps=50, scale_firing_rates=1, synapse=0.01]: accuracy = 50.174216027874564%, precision = 0.5014184397163121, recall = 0.7034825870646766, f1 = 0.5855072463768116
# Confusion matrix:
# [[301 703]
#  [298 707]]
# 4. SNN [timesteps=50, scale_firing_rates=1, synapse=None]: accuracy = 51.61772025883524%, precision = 0.5125666412795126, recall = 0.6696517412935323, f1 = 0.5806729939603106
# Confusion matrix:
# [[364 640]
#  [332 673]]
# Iteration: 5
# Build finished in 0:00:00
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Epoch 1/30
# 70/70 [==============================] - 4s 18ms/step - loss: 1.1513 - probe_loss: 1.1513 - probe_accuracy: 0.5396 - val_loss: 0.8875 - val_probe_loss: 0.8875 - val_probe_accuracy: 0.5774
# Epoch 2/30
# 70/70 [==============================] - 1s 10ms/step - loss: 0.8219 - probe_loss: 0.8219 - probe_accuracy: 0.5933 - val_loss: 0.7148 - val_probe_loss: 0.7148 - val_probe_accuracy: 0.5999
# Epoch 3/30
# 70/70 [==============================] - 1s 10ms/step - loss: 0.7567 - probe_loss: 0.7567 - probe_accuracy: 0.6116 - val_loss: 0.6731 - val_probe_loss: 0.6731 - val_probe_accuracy: 0.6060
# Epoch 4/30
# 70/70 [==============================] - 1s 10ms/step - loss: 0.7090 - probe_loss: 0.7090 - probe_accuracy: 0.6001 - val_loss: 0.6650 - val_probe_loss: 0.6650 - val_probe_accuracy: 0.6101
# Epoch 5/30
# 70/70 [==============================] - 1s 10ms/step - loss: 0.6726 - probe_loss: 0.6726 - probe_accuracy: 0.6216 - val_loss: 0.6586 - val_probe_loss: 0.6586 - val_probe_accuracy: 0.6202
# Epoch 6/30
# 70/70 [==============================] - 1s 10ms/step - loss: 0.6522 - probe_loss: 0.6522 - probe_accuracy: 0.6336 - val_loss: 0.6538 - val_probe_loss: 0.6538 - val_probe_accuracy: 0.6162
# Epoch 7/30
# 70/70 [==============================] - 1s 10ms/step - loss: 0.6467 - probe_loss: 0.6467 - probe_accuracy: 0.6280 - val_loss: 0.6547 - val_probe_loss: 0.6547 - val_probe_accuracy: 0.6128
# Epoch 8/30
# 70/70 [==============================] - 1s 10ms/step - loss: 0.6360 - probe_loss: 0.6360 - probe_accuracy: 0.6476 - val_loss: 0.6595 - val_probe_loss: 0.6595 - val_probe_accuracy: 0.6087
# Epoch 9/30
# 70/70 [==============================] - 1s 10ms/step - loss: 0.6364 - probe_loss: 0.6364 - probe_accuracy: 0.6528 - val_loss: 0.6594 - val_probe_loss: 0.6594 - val_probe_accuracy: 0.6019
# Epoch 10/30
# 70/70 [==============================] - 1s 10ms/step - loss: 0.6357 - probe_loss: 0.6357 - probe_accuracy: 0.6496 - val_loss: 0.6597 - val_probe_loss: 0.6597 - val_probe_accuracy: 0.6155
# Epoch 11/30
# 70/70 [==============================] - 1s 10ms/step - loss: 0.6139 - probe_loss: 0.6139 - probe_accuracy: 0.6702 - val_loss: 0.6677 - val_probe_loss: 0.6677 - val_probe_accuracy: 0.5931
# Restoring model weights from the end of the best epoch.
# Epoch 00011: early stopping
# 5. ANN: accuracy = 63.45766129032258%, precision = 0.636734693877551, recall = 0.6283987915407855, f1 = 0.6325392802838317
# Confusion matrix:
# [[635 356]
#  [369 624]]
# 5. SNN [timesteps=50, scale_firing_rates=1000, synapse=0.01]: accuracy = 63.31508213041314%, precision = 0.6350806451612904, recall = 0.6268656716417911, f1 = 0.6309464196294442
# Confusion matrix:
# [[642 362]
#  [375 630]]
# 5. SNN [timesteps=50, scale_firing_rates=1000, synapse=None]: accuracy = 63.3648581383773%, precision = 0.6357214934409687, recall = 0.6268656716417911, f1 = 0.6312625250501002
# Confusion matrix:
# [[643 361]
#  [375 630]]
# 5. SNN [timesteps=50, scale_firing_rates=1, synapse=0.01]: accuracy = 53.06122448979592%, precision = 0.5245641838351822, recall = 0.6587064676616915, f1 = 0.5840317600352889
# Confusion matrix:
# [[404 600]
#  [343 662]]
# 5. SNN [timesteps=50, scale_firing_rates=1, synapse=None]: accuracy = 51.81682429069189%, precision = 0.5137546468401487, recall = 0.6875621890547263, f1 = 0.5880851063829788
# Confusion matrix:
# [[350 654]
#  [314 691]]
# Iteration: 6
# Build finished in 0:00:00
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Epoch 1/30
# 70/70 [==============================] - 4s 18ms/step - loss: 1.0419 - probe_loss: 1.0419 - probe_accuracy: 0.5551 - val_loss: 1.0443 - val_probe_loss: 1.0443 - val_probe_accuracy: 0.5686
# Epoch 2/30
# 70/70 [==============================] - 1s 10ms/step - loss: 0.8344 - probe_loss: 0.8344 - probe_accuracy: 0.5936 - val_loss: 0.7203 - val_probe_loss: 0.7203 - val_probe_accuracy: 0.5992
# Epoch 3/30
# 70/70 [==============================] - 1s 10ms/step - loss: 0.7400 - probe_loss: 0.7400 - probe_accuracy: 0.6076 - val_loss: 0.6853 - val_probe_loss: 0.6853 - val_probe_accuracy: 0.6094
# Epoch 4/30
# 70/70 [==============================] - 1s 10ms/step - loss: 0.7021 - probe_loss: 0.7021 - probe_accuracy: 0.6138 - val_loss: 0.6803 - val_probe_loss: 0.6803 - val_probe_accuracy: 0.6101
# Epoch 5/30
# 70/70 [==============================] - 1s 10ms/step - loss: 0.6638 - probe_loss: 0.6638 - probe_accuracy: 0.6292 - val_loss: 0.6747 - val_probe_loss: 0.6747 - val_probe_accuracy: 0.6080
# Epoch 6/30
# 70/70 [==============================] - 1s 10ms/step - loss: 0.6489 - probe_loss: 0.6489 - probe_accuracy: 0.6433 - val_loss: 0.6624 - val_probe_loss: 0.6624 - val_probe_accuracy: 0.6039
# Epoch 7/30
# 70/70 [==============================] - 1s 10ms/step - loss: 0.6418 - probe_loss: 0.6418 - probe_accuracy: 0.6433 - val_loss: 0.6701 - val_probe_loss: 0.6701 - val_probe_accuracy: 0.6080
# Epoch 8/30
# 70/70 [==============================] - 1s 10ms/step - loss: 0.6383 - probe_loss: 0.6383 - probe_accuracy: 0.6386 - val_loss: 0.6663 - val_probe_loss: 0.6663 - val_probe_accuracy: 0.6019
# Epoch 9/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6072 - probe_loss: 0.6072 - probe_accuracy: 0.6832 - val_loss: 0.6715 - val_probe_loss: 0.6715 - val_probe_accuracy: 0.6012
# Epoch 10/30
# 70/70 [==============================] - 1s 10ms/step - loss: 0.6094 - probe_loss: 0.6094 - probe_accuracy: 0.6672 - val_loss: 0.6659 - val_probe_loss: 0.6659 - val_probe_accuracy: 0.6101
# Epoch 11/30
# 70/70 [==============================] - 1s 10ms/step - loss: 0.6044 - probe_loss: 0.6044 - probe_accuracy: 0.6871 - val_loss: 0.6714 - val_probe_loss: 0.6714 - val_probe_accuracy: 0.6114
# Restoring model weights from the end of the best epoch.
# Epoch 00011: early stopping
# 6. ANN: accuracy = 63.76008064516129%, precision = 0.6335282651072125, recall = 0.6545820745216515, f1 = 0.6438831104507181
# Confusion matrix:
# [[615 376]
#  [343 650]]
# 6. SNN [timesteps=50, scale_firing_rates=1000, synapse=0.01]: accuracy = 63.3648581383773%, precision = 0.6282173498570067, recall = 0.6557213930348259, f1 = 0.6416747809152873
# Confusion matrix:
# [[614 390]
#  [346 659]]
# 6. SNN [timesteps=50, scale_firing_rates=1000, synapse=None]: accuracy = 63.663514186162274%, precision = 0.6318312559923298, recall = 0.6557213930348259, f1 = 0.6435546875
# Confusion matrix:
# [[620 384]
#  [346 659]]
# 6. SNN [timesteps=50, scale_firing_rates=1, synapse=0.01]: accuracy = 52.86212045793928%, precision = 0.5216095380029806, recall = 0.6965174129353234, f1 = 0.5965061780997019
# Confusion matrix:
# [[362 642]
#  [305 700]]
# 6. SNN [timesteps=50, scale_firing_rates=1, synapse=None]: accuracy = 51.36884021901443%, precision = 0.5103244837758112, recall = 0.6885572139303483, f1 = 0.5861922914019483
# Confusion matrix:
# [[340 664]
#  [313 692]]
# Iteration: 7
# Build finished in 0:00:00
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Epoch 1/30
# 70/70 [==============================] - 5s 19ms/step - loss: 1.1314 - probe_loss: 1.1314 - probe_accuracy: 0.5566 - val_loss: 0.8296 - val_probe_loss: 0.8296 - val_probe_accuracy: 0.6202
# Epoch 2/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.8461 - probe_loss: 0.8461 - probe_accuracy: 0.5882 - val_loss: 0.7774 - val_probe_loss: 0.7774 - val_probe_accuracy: 0.6128
# Epoch 3/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.7657 - probe_loss: 0.7657 - probe_accuracy: 0.5973 - val_loss: 0.6954 - val_probe_loss: 0.6954 - val_probe_accuracy: 0.6209
# Epoch 4/30
# 70/70 [==============================] - 1s 10ms/step - loss: 0.7110 - probe_loss: 0.7110 - probe_accuracy: 0.6158 - val_loss: 0.6716 - val_probe_loss: 0.6716 - val_probe_accuracy: 0.6304
# Epoch 5/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6906 - probe_loss: 0.6906 - probe_accuracy: 0.6120 - val_loss: 0.6647 - val_probe_loss: 0.6647 - val_probe_accuracy: 0.6277
# Epoch 6/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6611 - probe_loss: 0.6611 - probe_accuracy: 0.6249 - val_loss: 0.6605 - val_probe_loss: 0.6605 - val_probe_accuracy: 0.6223
# Epoch 7/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6495 - probe_loss: 0.6495 - probe_accuracy: 0.6382 - val_loss: 0.6601 - val_probe_loss: 0.6601 - val_probe_accuracy: 0.6080
# Epoch 8/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6531 - probe_loss: 0.6531 - probe_accuracy: 0.6270 - val_loss: 0.6534 - val_probe_loss: 0.6534 - val_probe_accuracy: 0.6223
# Epoch 9/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6358 - probe_loss: 0.6358 - probe_accuracy: 0.6419 - val_loss: 0.6572 - val_probe_loss: 0.6572 - val_probe_accuracy: 0.6257
# Epoch 10/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6273 - probe_loss: 0.6273 - probe_accuracy: 0.6497 - val_loss: 0.6539 - val_probe_loss: 0.6539 - val_probe_accuracy: 0.6230
# Epoch 11/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6309 - probe_loss: 0.6309 - probe_accuracy: 0.6492 - val_loss: 0.6575 - val_probe_loss: 0.6575 - val_probe_accuracy: 0.6304
# Epoch 12/30
# 70/70 [==============================] - 1s 10ms/step - loss: 0.6184 - probe_loss: 0.6184 - probe_accuracy: 0.6615 - val_loss: 0.6566 - val_probe_loss: 0.6566 - val_probe_accuracy: 0.6325
# Epoch 13/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6151 - probe_loss: 0.6151 - probe_accuracy: 0.6618 - val_loss: 0.6547 - val_probe_loss: 0.6547 - val_probe_accuracy: 0.6202
# Restoring model weights from the end of the best epoch.
# Epoch 00013: early stopping
# 7. ANN: accuracy = 63.81048387096774%, precision = 0.611879576891782, recall = 0.75730110775428, f1 = 0.6768676867686769
# Confusion matrix:
# [[514 477]
#  [241 752]]
# 7. SNN [timesteps=50, scale_firing_rates=1000, synapse=0.01]: accuracy = 64.21105027376804%, precision = 0.6144, recall = 0.764179104477612, f1 = 0.6811529933481153
# Confusion matrix:
# [[522 482]
#  [237 768]]
# 7. SNN [timesteps=50, scale_firing_rates=1000, synapse=None]: accuracy = 64.26082628173221%, precision = 0.6152610441767068, recall = 0.7621890547263681, f1 = 0.6808888888888889
# Confusion matrix:
# [[525 479]
#  [239 766]]
# 7. SNN [timesteps=50, scale_firing_rates=1, synapse=0.01]: accuracy = 52.663016426082635%, precision = 0.5242805755395683, recall = 0.5800995024875621, f1 = 0.5507794048181388
# Confusion matrix:
# [[475 529]
#  [422 583]]
# 7. SNN [timesteps=50, scale_firing_rates=1, synapse=None]: accuracy = 54.30562468889995%, precision = 0.5375323554788611, recall = 0.6199004975124378, f1 = 0.5757855822550831
# Confusion matrix:
# [[468 536]
#  [382 623]]
# Iteration: 8
# Build finished in 0:00:00
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Epoch 1/30
# 70/70 [==============================] - 4s 18ms/step - loss: 1.1306 - probe_loss: 1.1306 - probe_accuracy: 0.5388 - val_loss: 0.7912 - val_probe_loss: 0.7912 - val_probe_accuracy: 0.6039
# Epoch 2/30
# 70/70 [==============================] - 1s 10ms/step - loss: 0.8273 - probe_loss: 0.8273 - probe_accuracy: 0.5919 - val_loss: 0.7249 - val_probe_loss: 0.7249 - val_probe_accuracy: 0.6005
# Epoch 3/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.7625 - probe_loss: 0.7625 - probe_accuracy: 0.6211 - val_loss: 0.6933 - val_probe_loss: 0.6933 - val_probe_accuracy: 0.6033
# Epoch 4/30
# 70/70 [==============================] - 1s 10ms/step - loss: 0.7128 - probe_loss: 0.7128 - probe_accuracy: 0.6173 - val_loss: 0.6621 - val_probe_loss: 0.6621 - val_probe_accuracy: 0.6209
# Epoch 5/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6906 - probe_loss: 0.6906 - probe_accuracy: 0.6240 - val_loss: 0.6643 - val_probe_loss: 0.6643 - val_probe_accuracy: 0.6182
# Epoch 6/30
# 70/70 [==============================] - 1s 10ms/step - loss: 0.6563 - probe_loss: 0.6563 - probe_accuracy: 0.6338 - val_loss: 0.6562 - val_probe_loss: 0.6562 - val_probe_accuracy: 0.6202
# Epoch 7/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6274 - probe_loss: 0.6274 - probe_accuracy: 0.6480 - val_loss: 0.6595 - val_probe_loss: 0.6595 - val_probe_accuracy: 0.6114
# Epoch 8/30
#  - 1s 11ms/step - loss: 0.6278 - probe_loss: 0.6278 - probe_accuracy: 0.6507 - val_loss: 0.6573 - val_probe_loss: 0.6573 - val_probe_accuracy: 0.6236
# Epoch 9/30
# 70/70 [==============================] - 1s 15ms/step - loss: 0.6233 - probe_loss: 0.6233 - probe_accuracy: 0.6576 - val_loss: 0.6571 - val_probe_loss: 0.6571 - val_probe_accuracy: 0.6264
# Epoch 10/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6039 - probe_loss: 0.6039 - probe_accuracy: 0.6825 - val_loss: 0.6613 - val_probe_loss: 0.6613 - val_probe_accuracy: 0.6128
# Epoch 11/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6137 - probe_loss: 0.6137 - probe_accuracy: 0.6676 - val_loss: 0.6602 - val_probe_loss: 0.6602 - val_probe_accuracy: 0.6182
# Restoring model weights from the end of the best epoch.
# Epoch 00011: early stopping
# 8. ANN: accuracy = 64.71774193548387%, precision = 0.6367880485527544, recall = 0.6868076535750252, f1 = 0.6608527131782945
# Confusion matrix:
# [[602 389]
#  [311 682]]
# 8. SNN [timesteps=50, scale_firing_rates=1000, synapse=0.01]: accuracy = 64.70881035340965%, precision = 0.6365313653136532, recall = 0.6865671641791045, f1 = 0.6606031594064147
# Confusion matrix:
# [[610 394]
#  [315 690]]
# 8. SNN [timesteps=50, scale_firing_rates=1000, synapse=None]: accuracy = 64.50970632155301%, precision = 0.6334552102376599, recall = 0.6895522388059702, f1 = 0.6603144354454502
# Confusion matrix:
# [[603 401]
#  [312 693]]
# 8. SNN [timesteps=50, scale_firing_rates=1, synapse=0.01]: accuracy = 51.51816824290692%, precision = 0.5124099279423538, recall = 0.6368159203980099, f1 = 0.5678793256433008
# Confusion matrix:
# [[395 609]
#  [365 640]]
# 8. SNN [timesteps=50, scale_firing_rates=1, synapse=None]: accuracy = 51.31906421105027%, precision = 0.5105716523101018, recall = 0.6487562189054726, f1 = 0.5714285714285714
# Confusion matrix:
# [[379 625]
#  [353 652]]
# Iteration: 9
# Build finished in 0:00:00
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Epoch 1/30
# 70/70 [==============================] - 5s 20ms/step - loss: 1.1423 - probe_loss: 1.1423 - probe_accuracy: 0.5403 - val_loss: 0.9071 - val_probe_loss: 0.9071 - val_probe_accuracy: 0.6033
# Epoch 2/30
# 70/70 [==============================] - 1s 10ms/step - loss: 0.8593 - probe_loss: 0.8593 - probe_accuracy: 0.5713 - val_loss: 0.7021 - val_probe_loss: 0.7021 - val_probe_accuracy: 0.6182
# Epoch 3/30
# 70/70 [==============================] - 1s 10ms/step - loss: 0.7796 - probe_loss: 0.7796 - probe_accuracy: 0.5914 - val_loss: 0.6852 - val_probe_loss: 0.6852 - val_probe_accuracy: 0.6209
# Epoch 4/30
# 70/70 [==============================] - 1s 10ms/step - loss: 0.6999 - probe_loss: 0.6999 - probe_accuracy: 0.6251 - val_loss: 0.6609 - val_probe_loss: 0.6609 - val_probe_accuracy: 0.6223
# Epoch 5/30
# 70/70 [==============================] - 1s 10ms/step - loss: 0.6977 - probe_loss: 0.6977 - probe_accuracy: 0.6031 - val_loss: 0.6461 - val_probe_loss: 0.6461 - val_probe_accuracy: 0.6284
# Epoch 6/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6705 - probe_loss: 0.6705 - probe_accuracy: 0.6148 - val_loss: 0.6553 - val_probe_loss: 0.6553 - val_probe_accuracy: 0.6298
# Epoch 7/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6441 - probe_loss: 0.6441 - probe_accuracy: 0.6340 - val_loss: 0.6545 - val_probe_loss: 0.6545 - val_probe_accuracy: 0.6202
# Epoch 8/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6478 - probe_loss: 0.6478 - probe_accuracy: 0.6322 - val_loss: 0.6488 - val_probe_loss: 0.6488 - val_probe_accuracy: 0.6298
# Epoch 9/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6230 - probe_loss: 0.6230 - probe_accuracy: 0.6554 - val_loss: 0.6544 - val_probe_loss: 0.6544 - val_probe_accuracy: 0.6325
# Epoch 10/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6254 - probe_loss: 0.6254 - probe_accuracy: 0.6513 - val_loss: 0.6559 - val_probe_loss: 0.6559 - val_probe_accuracy: 0.6277
# Restoring model weights from the end of the best epoch.
# Epoch 00010: early stopping
# 9. ANN: accuracy = 63.55846774193549%, precision = 0.6409185803757829, recall = 0.6183282980866063, f1 = 0.629420809841107
# Confusion matrix:
# [[647 344]
#  [379 614]]
# 9. SNN [timesteps=50, scale_firing_rates=1000, synapse=0.01]: accuracy = 63.663514186162274%, precision = 0.6436781609195402, recall = 0.6129353233830845, f1 = 0.6279306829765544
# Confusion matrix:
# [[663 341]
#  [389 616]]
# 9. SNN [timesteps=50, scale_firing_rates=1000, synapse=None]: accuracy = 63.51418616226978%, precision = 0.6402061855670103, recall = 0.6179104477611941, f1 = 0.6288607594936708
# Confusion matrix:
# [[655 349]
#  [384 621]]
# 9. SNN [timesteps=50, scale_firing_rates=1, synapse=0.01]: accuracy = 49.77600796416127%, precision = 0.49834437086092714, recall = 0.5990049751243781, f1 = 0.5440578400361501
# Confusion matrix:
# [[398 606]
#  [403 602]]
# 9. SNN [timesteps=50, scale_firing_rates=1, synapse=None]: accuracy = 52.215032354405174%, precision = 0.5179282868525896, recall = 0.6467661691542289, f1 = 0.5752212389380532
# Confusion matrix:
# [[399 605]
#  [355 650]]
# Iteration: 10
# Build finished in 0:00:00
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Epoch 1/30
# 70/70 [==============================] - 4s 18ms/step - loss: 1.0905 - probe_loss: 1.0905 - probe_accuracy: 0.5341 - val_loss: 0.9234 - val_probe_loss: 0.9234 - val_probe_accuracy: 0.5795
# Epoch 2/30
# 70/70 [==============================] - 1s 12ms/step - loss: 0.8398 - probe_loss: 0.8398 - probe_accuracy: 0.5638 - val_loss: 0.7165 - val_probe_loss: 0.7165 - val_probe_accuracy: 0.5965
# Epoch 3/30
# 70/70 [==============================] - 1s 10ms/step - loss: 0.7387 - probe_loss: 0.7387 - probe_accuracy: 0.5905 - val_loss: 0.6662 - val_probe_loss: 0.6662 - val_probe_accuracy: 0.6128
# Epoch 4/30
# 70/70 [==============================] - 1s 10ms/step - loss: 0.7217 - probe_loss: 0.7217 - probe_accuracy: 0.5972 - val_loss: 0.6717 - val_probe_loss: 0.6717 - val_probe_accuracy: 0.6053
# Epoch 5/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6879 - probe_loss: 0.6879 - probe_accuracy: 0.6112 - val_loss: 0.6594 - val_probe_loss: 0.6594 - val_probe_accuracy: 0.6114
# Epoch 6/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6674 - probe_loss: 0.6674 - probe_accuracy: 0.6202 - val_loss: 0.6579 - val_probe_loss: 0.6579 - val_probe_accuracy: 0.6107
# Epoch 7/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6473 - probe_loss: 0.6473 - probe_accuracy: 0.6344 - val_loss: 0.6549 - val_probe_loss: 0.6549 - val_probe_accuracy: 0.6026
# Epoch 8/30
# 70/70 [==============================] - 1s 15ms/step - loss: 0.6407 - probe_loss: 0.6407 - probe_accuracy: 0.6418 - val_loss: 0.6539 - val_probe_loss: 0.6539 - val_probe_accuracy: 0.6107
# Epoch 9/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6247 - probe_loss: 0.6247 - probe_accuracy: 0.6560 - val_loss: 0.6569 - val_probe_loss: 0.6569 - val_probe_accuracy: 0.6039
# Epoch 10/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6266 - probe_loss: 0.6266 - probe_accuracy: 0.6505 - val_loss: 0.6491 - val_probe_loss: 0.6491 - val_probe_accuracy: 0.6148
# Epoch 11/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6271 - probe_loss: 0.6271 - probe_accuracy: 0.6556 - val_loss: 0.6604 - val_probe_loss: 0.6604 - val_probe_accuracy: 0.5938
# Epoch 12/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6231 - probe_loss: 0.6231 - probe_accuracy: 0.6615 - val_loss: 0.6768 - val_probe_loss: 0.6768 - val_probe_accuracy: 0.5999
# Epoch 13/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6175 - probe_loss: 0.6175 - probe_accuracy: 0.6513 - val_loss: 0.6570 - val_probe_loss: 0.6570 - val_probe_accuracy: 0.6094
# Epoch 14/30
# 70/70 [==============================] - 1s 10ms/step - loss: 0.6132 - probe_loss: 0.6132 - probe_accuracy: 0.6615 - val_loss: 0.6633 - val_probe_loss: 0.6633 - val_probe_accuracy: 0.5971
# Epoch 15/30
# 70/70 [==============================] - 1s 10ms/step - loss: 0.6201 - probe_loss: 0.6201 - probe_accuracy: 0.6561 - val_loss: 0.6711 - val_probe_loss: 0.6711 - val_probe_accuracy: 0.6087
# Restoring model weights from the end of the best epoch.
# Epoch 00015: early stopping
# 10. ANN: accuracy = 64.31451612903226%, precision = 0.6306141154903758, recall = 0.6928499496475328, f1 = 0.6602687140115163
# Confusion matrix:
# [[588 403]
#  [305 688]]
# 10. SNN [timesteps=50, scale_firing_rates=1000, synapse=0.01]: accuracy = 64.31060228969636%, precision = 0.6304347826086957, recall = 0.6925373134328359, f1 = 0.6600284495021337
# Confusion matrix:
# [[596 408]
#  [309 696]]
# 10. SNN [timesteps=50, scale_firing_rates=1000, synapse=None]: accuracy = 64.31060228969636%, precision = 0.6309090909090909, recall = 0.690547263681592, f1 = 0.6593824228028503
# Confusion matrix:
# [[598 406]
#  [311 694]]
# 10. SNN [timesteps=50, scale_firing_rates=1, synapse=0.01]: accuracy = 51.71727227476356%, precision = 0.5139888089528377, recall = 0.6398009950248756, f1 = 0.5700354609929078
# Confusion matrix:
# [[396 608]
#  [362 643]]
# 10. SNN [timesteps=50, scale_firing_rates=1, synapse=None]: accuracy = 52.463912394225986%, precision = 0.520764119601329, recall = 0.6238805970149254, f1 = 0.5676776822091445
# Confusion matrix:
# [[427 577]
#  [378 627]]
# Iteration: 11
# Build finished in 0:00:00
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Epoch 1/30
# 70/70 [==============================] - 4s 21ms/step - loss: 1.1286 - probe_loss: 1.1286 - probe_accuracy: 0.5520 - val_loss: 0.7922 - val_probe_loss: 0.7922 - val_probe_accuracy: 0.6175
# Epoch 2/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.8318 - probe_loss: 0.8318 - probe_accuracy: 0.5870 - val_loss: 0.7331 - val_probe_loss: 0.7331 - val_probe_accuracy: 0.6033
# Epoch 3/30
# 70/70 [==============================] - 1s 10ms/step - loss: 0.7596 - probe_loss: 0.7596 - probe_accuracy: 0.5853 - val_loss: 0.6681 - val_probe_loss: 0.6681 - val_probe_accuracy: 0.6386
# Epoch 4/30
# 70/70 [==============================] - 1s 10ms/step - loss: 0.7288 - probe_loss: 0.7288 - probe_accuracy: 0.5988 - val_loss: 0.6719 - val_probe_loss: 0.6719 - val_probe_accuracy: 0.6284
# Epoch 5/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6950 - probe_loss: 0.6950 - probe_accuracy: 0.6069 - val_loss: 0.6531 - val_probe_loss: 0.6531 - val_probe_accuracy: 0.6386
# Epoch 6/30
# 70/70 [==============================] - 1s 10ms/step - loss: 0.6599 - probe_loss: 0.6599 - probe_accuracy: 0.6309 - val_loss: 0.6644 - val_probe_loss: 0.6644 - val_probe_accuracy: 0.6284
# Epoch 7/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6384 - probe_loss: 0.6384 - probe_accuracy: 0.6409 - val_loss: 0.6526 - val_probe_loss: 0.6526 - val_probe_accuracy: 0.6427
# Epoch 8/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6327 - probe_loss: 0.6327 - probe_accuracy: 0.6510 - val_loss: 0.6490 - val_probe_loss: 0.6490 - val_probe_accuracy: 0.6311
# Epoch 9/30
#  - ETA: 0s - loss: 0.6346 - probe_loss: 0.6346 - probe_accuracy: 0.6470
# Epoch 10/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6251 - probe_loss: 0.6251 - probe_accuracy: 0.6503 - val_loss: 0.6498 - val_probe_loss: 0.6498 - val_probe_accuracy: 0.6365
# Epoch 11/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6180 - probe_loss: 0.6180 - probe_accuracy: 0.6543 - val_loss: 0.6541 - val_probe_loss: 0.6541 - val_probe_accuracy: 0.6291
# Epoch 12/30
# 70/70 [==============================] - 1s 10ms/step - loss: 0.6204 - probe_loss: 0.6204 - probe_accuracy: 0.6536 - val_loss: 0.6526 - val_probe_loss: 0.6526 - val_probe_accuracy: 0.6393
# Epoch 13/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6134 - probe_loss: 0.6134 - probe_accuracy: 0.6622 - val_loss: 0.6547 - val_probe_loss: 0.6547 - val_probe_accuracy: 0.6243
# Restoring model weights from the end of the best epoch.
# Epoch 00013: early stopping
# 11. ANN: accuracy = 64.1633064516129%, precision = 0.650319829424307, recall = 0.6143001007049346, f1 = 0.6317969963749352
# Confusion matrix:
# [[663 328]
#  [383 610]]
# 11. SNN [timesteps=50, scale_firing_rates=1000, synapse=0.01]: accuracy = 63.962170233947234%, precision = 0.648363252375924, recall = 0.6109452736318408, f1 = 0.6290983606557378
# Confusion matrix:
# [[671 333]
#  [391 614]]
# 11. SNN [timesteps=50, scale_firing_rates=1000, synapse=None]: accuracy = 64.16127426580388%, precision = 0.6492146596858639, recall = 0.6169154228855721, f1 = 0.6326530612244898
# Confusion matrix:
# [[669 335]
#  [385 620]]
# 11. SNN [timesteps=50, scale_firing_rates=1, synapse=0.01]: accuracy = 55.00248880039821%, precision = 0.5398579321231255, recall = 0.6805970149253732, f1 = 0.602112676056338
# Confusion matrix:
# [[421 583]
#  [321 684]]
# 11. SNN [timesteps=50, scale_firing_rates=1, synapse=None]: accuracy = 53.011448481831756%, precision = 0.5251028806584362, recall = 0.6348258706467662, f1 = 0.5747747747747748
# Confusion matrix:
# [[427 577]
#  [367 638]]
# Iteration: 12
# Build finished in 0:00:00
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Epoch 1/30
# 70/70 [==============================] - 5s 23ms/step - loss: 1.1093 - probe_loss: 1.1093 - probe_accuracy: 0.5429 - val_loss: 0.7878 - val_probe_loss: 0.7878 - val_probe_accuracy: 0.5924
# Epoch 2/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.8319 - probe_loss: 0.8319 - probe_accuracy: 0.5772 - val_loss: 0.7489 - val_probe_loss: 0.7489 - val_probe_accuracy: 0.5856
# Epoch 3/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.7439 - probe_loss: 0.7439 - probe_accuracy: 0.5921 - val_loss: 0.6532 - val_probe_loss: 0.6532 - val_probe_accuracy: 0.6107
# Epoch 4/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.7226 - probe_loss: 0.7226 - probe_accuracy: 0.5892 - val_loss: 0.6555 - val_probe_loss: 0.6555 - val_probe_accuracy: 0.6114
# Epoch 5/30
# 70/70 [==============================] - 1s 10ms/step - loss: 0.6843 - probe_loss: 0.6843 - probe_accuracy: 0.6146 - val_loss: 0.6495 - val_probe_loss: 0.6495 - val_probe_accuracy: 0.6168
# Epoch 6/30
# 70/70 [==============================] - 1s 10ms/step - loss: 0.6592 - probe_loss: 0.6592 - probe_accuracy: 0.6262 - val_loss: 0.6470 - val_probe_loss: 0.6470 - val_probe_accuracy: 0.6230
# Epoch 7/30
# 70/70 [==============================] - 1s 10ms/step - loss: 0.6431 - probe_loss: 0.6431 - probe_accuracy: 0.6448 - val_loss: 0.6552 - val_probe_loss: 0.6552 - val_probe_accuracy: 0.6196
# Epoch 8/30
# 70/70 [==============================] - 1s 10ms/step - loss: 0.6471 - probe_loss: 0.6471 - probe_accuracy: 0.6374 - val_loss: 0.6572 - val_probe_loss: 0.6572 - val_probe_accuracy: 0.5944
# Epoch 9/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6246 - probe_loss: 0.6246 - probe_accuracy: 0.6616 - val_loss: 0.6575 - val_probe_loss: 0.6575 - val_probe_accuracy: 0.6060
# Epoch 10/30
# 70/70 [==============================] - 1s 12ms/step - loss: 0.6247 - probe_loss: 0.6247 - probe_accuracy: 0.6612 - val_loss: 0.6576 - val_probe_loss: 0.6576 - val_probe_accuracy: 0.6230
# Epoch 11/30
# 70/70 [==============================] - 1s 13ms/step - loss: 0.6324 - probe_loss: 0.6324 - probe_accuracy: 0.6529 - val_loss: 0.6518 - val_probe_loss: 0.6518 - val_probe_accuracy: 0.6168
# Restoring model weights from the end of the best epoch.
# Epoch 00011: early stopping
# 12. ANN: accuracy = 63.15524193548387%, precision = 0.609715242881072, recall = 0.7331319234642497, f1 = 0.6657521719250113
# Confusion matrix:
# [[525 466]
#  [265 728]]
# 12. SNN [timesteps=50, scale_firing_rates=1000, synapse=0.01]: accuracy = 63.11597809855649%, precision = 0.6096345514950167, recall = 0.7303482587064677, f1 = 0.6645540968764146
# Confusion matrix:
# [[534 470]
#  [271 734]]
# 12. SNN [timesteps=50, scale_firing_rates=1000, synapse=None]: accuracy = 62.96665007466401%, precision = 0.6077621800165153, recall = 0.7323383084577114, f1 = 0.6642599277978339
# Confusion matrix:
# [[529 475]
#  [269 736]]
# 12. SNN [timesteps=50, scale_firing_rates=1, synapse=0.01]: accuracy = 50.174216027874564%, precision = 0.5016863406408094, recall = 0.5920398009950248, f1 = 0.5431309904153353
# Confusion matrix:
# [[413 591]
#  [410 595]]
# 12. SNN [timesteps=50, scale_firing_rates=1, synapse=None]: accuracy = 51.46839223494276%, precision = 0.5120967741935484, recall = 0.6318407960199005, f1 = 0.5657015590200445
# Confusion matrix:
# [[399 605]
#  [370 635]]
# Iteration: 13
# Build finished in 0:00:00
# Optimization finished in 0:00:00
# Construction finished in 0:00:00
# Epoch 1/30
# 70/70 [==============================] - 4s 19ms/step - loss: 1.1308 - probe_loss: 1.1308 - probe_accuracy: 0.5562 - val_loss: 0.8280 - val_probe_loss: 0.8280 - val_probe_accuracy: 0.6121
# Epoch 2/30
#  - ETA: 0s - loss: 0.8185 - probe_loss: 0.8185 - probe_accuracy: 0.5988
# Epoch 3/30
# 70/70 [==============================] - 1s 16ms/step - loss: 0.7912 - probe_loss: 0.7912 - probe_accuracy: 0.5807 - val_loss: 0.6831 - val_probe_loss: 0.6831 - val_probe_accuracy: 0.6067
# Epoch 4/30
# 70/70 [==============================] - 1s 12ms/step - loss: 0.7394 - probe_loss: 0.7394 - probe_accuracy: 0.5921 - val_loss: 0.6809 - val_probe_loss: 0.6809 - val_probe_accuracy: 0.6209
# Epoch 5/30
# 70/70 [==============================] - 1s 11ms/step - loss: 0.6993 - probe_loss: 0.6993 - probe_accuracy: 0.6047 - val_loss: 0.6530 - val_probe_loss: 0.6530 - val_probe_accuracy: 0.6209
# Epoch 6/30
# ...
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: Cannot convert BatchNormalization layer to native Nengo objects unless inference_only=True or layer.trainable=False. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:588: UserWarning: Activation type <function softmax_v2 at 0x00000252D7F06DC0> does not have a native Nengo equivalent; falling back to a TensorNode
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\simulator.py:1765: UserWarning: Number of elements (1) in ['ndarray'] does not match number of Nodes (3); consider using an explicit input dictionary in this case, so that the assignment of data to objects is unambiguous.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: Layer type Dropout does not have a registered converter. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: average_pooling2d.padding has value same != valid, which is not supported. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: Cannot convert BatchNormalization layer to native Nengo objects unless inference_only=True or layer.trainable=False. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:588: UserWarning: Activation type <function softmax_v2 at 0x00000252D7F06DC0> does not have a native Nengo equivalent; falling back to a TensorNode
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\simulator.py:1765: UserWarning: Number of elements (1) in ['ndarray'] does not match number of Nodes (3); consider using an explicit input dictionary in this case, so that the assignment of data to objects is unambiguous.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: Layer type Dropout does not have a registered converter. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: average_pooling2d.padding has value same != valid, which is not supported. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: Cannot convert BatchNormalization layer to native Nengo objects unless inference_only=True or layer.trainable=False. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:588: UserWarning: Activation type <function softmax_v2 at 0x00000252D7F06DC0> does not have a native Nengo equivalent; falling back to a TensorNode
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\simulator.py:1765: UserWarning: Number of elements (1) in ['ndarray'] does not match number of Nodes (3); consider using an explicit input dictionary in this case, so that the assignment of data to objects is unambiguous.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: Layer type Dropout does not have a registered converter. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: average_pooling2d.padding has value same != valid, which is not supported. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: Cannot convert BatchNormalization layer to native Nengo objects unless inference_only=True or layer.trainable=False. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:588: UserWarning: Activation type <function softmax_v2 at 0x00000252D7F06DC0> does not have a native Nengo equivalent; falling back to a TensorNode
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\simulator.py:1921: UserWarning: Number of elements in input data (1507) is not evenly divisible by Simulator.minibatch_size (64); input data will be truncated.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\simulator.py:1921: UserWarning: Number of elements in input data (4520) is not evenly divisible by Simulator.minibatch_size (64); input data will be truncated.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\simulator.py:1765: UserWarning: Number of elements (1) in ['ndarray'] does not match number of Nodes (3); consider using an explicit input dictionary in this case, so that the assignment of data to objects is unambiguous.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: Layer type Dropout does not have a registered converter. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: average_pooling2d.padding has value same != valid, which is not supported. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: Cannot convert BatchNormalization layer to native Nengo objects unless inference_only=True or layer.trainable=False. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:588: UserWarning: Activation type <function softmax_v2 at 0x00000252D7F06DC0> does not have a native Nengo equivalent; falling back to a TensorNode
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\simulator.py:1765: UserWarning: Number of elements (1) in ['ndarray'] does not match number of Nodes (3); consider using an explicit input dictionary in this case, so that the assignment of data to objects is unambiguous.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: Layer type Dropout does not have a registered converter. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: average_pooling2d.padding has value same != valid, which is not supported. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: Cannot convert BatchNormalization layer to native Nengo objects unless inference_only=True or layer.trainable=False. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:588: UserWarning: Activation type <function softmax_v2 at 0x00000252D7F06DC0> does not have a native Nengo equivalent; falling back to a TensorNode
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\simulator.py:1765: UserWarning: Number of elements (1) in ['ndarray'] does not match number of Nodes (3); consider using an explicit input dictionary in this case, so that the assignment of data to objects is unambiguous.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: Layer type Dropout does not have a registered converter. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: average_pooling2d.padding has value same != valid, which is not supported. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: Cannot convert BatchNormalization layer to native Nengo objects unless inference_only=True or layer.trainable=False. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:588: UserWarning: Activation type <function softmax_v2 at 0x00000252D7F06DC0> does not have a native Nengo equivalent; falling back to a TensorNode
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\simulator.py:1765: UserWarning: Number of elements (1) in ['ndarray'] does not match number of Nodes (3); consider using an explicit input dictionary in this case, so that the assignment of data to objects is unambiguous.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: Layer type Dropout does not have a registered converter. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: average_pooling2d.padding has value same != valid, which is not supported. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: Cannot convert BatchNormalization layer to native Nengo objects unless inference_only=True or layer.trainable=False. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:588: UserWarning: Activation type <function softmax_v2 at 0x00000252D7F06DC0> does not have a native Nengo equivalent; falling back to a TensorNode
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\simulator.py:1765: UserWarning: Number of elements (1) in ['ndarray'] does not match number of Nodes (3); consider using an explicit input dictionary in this case, so that the assignment of data to objects is unambiguous.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: Layer type Dropout does not have a registered converter. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: average_pooling2d.padding has value same != valid, which is not supported. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: Cannot convert BatchNormalization layer to native Nengo objects unless inference_only=True or layer.trainable=False. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:588: UserWarning: Activation type <function softmax_v2 at 0x00000252D7F06DC0> does not have a native Nengo equivalent; falling back to a TensorNode
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\simulator.py:1921: UserWarning: Number of elements in input data (1507) is not evenly divisible by Simulator.minibatch_size (64); input data will be truncated.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\simulator.py:1921: UserWarning: Number of elements in input data (4520) is not evenly divisible by Simulator.minibatch_size (64); input data will be truncated.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\simulator.py:1765: UserWarning: Number of elements (1) in ['ndarray'] does not match number of Nodes (3); consider using an explicit input dictionary in this case, so that the assignment of data to objects is unambiguous.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: Layer type Dropout does not have a registered converter. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: average_pooling2d.padding has value same != valid, which is not supported. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: Cannot convert BatchNormalization layer to native Nengo objects unless inference_only=True or layer.trainable=False. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:588: UserWarning: Activation type <function softmax_v2 at 0x00000252D7F06DC0> does not have a native Nengo equivalent; falling back to a TensorNode
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\simulator.py:1765: UserWarning: Number of elements (1) in ['ndarray'] does not match number of Nodes (3); consider using an explicit input dictionary in this case, so that the assignment of data to objects is unambiguous.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: Layer type Dropout does not have a registered converter. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: average_pooling2d.padding has value same != valid, which is not supported. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: Cannot convert BatchNormalization layer to native Nengo objects unless inference_only=True or layer.trainable=False. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:588: UserWarning: Activation type <function softmax_v2 at 0x00000252D7F06DC0> does not have a native Nengo equivalent; falling back to a TensorNode
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\simulator.py:1765: UserWarning: Number of elements (1) in ['ndarray'] does not match number of Nodes (3); consider using an explicit input dictionary in this case, so that the assignment of data to objects is unambiguous.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: Layer type Dropout does not have a registered converter. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: average_pooling2d.padding has value same != valid, which is not supported. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: Cannot convert BatchNormalization layer to native Nengo objects unless inference_only=True or layer.trainable=False. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:588: UserWarning: Activation type <function softmax_v2 at 0x00000252D7F06DC0> does not have a native Nengo equivalent; falling back to a TensorNode
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\simulator.py:1765: UserWarning: Number of elements (1) in ['ndarray'] does not match number of Nodes (3); consider using an explicit input dictionary in this case, so that the assignment of data to objects is unambiguous.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: Layer type Dropout does not have a registered converter. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: average_pooling2d.padding has value same != valid, which is not supported. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:326: UserWarning: Cannot convert BatchNormalization layer to native Nengo objects unless inference_only=True or layer.trainable=False. Falling back to TensorNode.
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\converter.py:588: UserWarning: Activation type <function softmax_v2 at 0x00000252D7F06DC0> does not have a native Nengo equivalent; falling back to a TensorNode
#   warnings.warn(
# c:\dev\anaconda\envs\spiking-nn\lib\site-packages\nengo_dl\simulator.py:1765: UserWarning: Number of elements (1) in ['ndarray'] does not match number of Nodes (3); consider using an explicit input dictionary in this case, so that the assignment of data to objects is unambiguous.
#   warnings.warn(

# %%
# Create dictionary with the data for pandas dataframe
data = {
    'iterations': [x for x in range(1, num_iterations + 1)],
    'ann_accuracy': [x['accuracy'] for x in ann],
    'ann_precision': [x['precision'] for x in ann],
    'ann_recall': [x['recall'] for x in ann],
    'ann_f1': [x['f1'] for x in ann]
}

for variant_name in variants:
    data[f'{variant_name}_accuracy'] = [x['accuracy'] for x in snn[variant_name]]
    data[f'{variant_name}_precision'] = [x['precision'] for x in snn[variant_name]]
    data[f'{variant_name}_recall'] = [x['recall'] for x in snn[variant_name]]
    data[f'{variant_name}_f1'] = [x['f1'] for x in snn[variant_name]]

# %%
# Create pandas dataframe and save it to xlsx file
output_folder_path = 'p300_exp_output'
os.makedirs(output_folder_path, exist_ok=True)

df = pd.DataFrame(data)
df.to_excel(os.path.join(output_folder_path, 'data_iterations.xlsx'))

'File with iteration data successfully saved.'
# Out:
# 'File with iteration data successfully saved.'

# %%
network_names = ['ann'] + variants # names of each network in the pandas data frame
data_stats = {
    'models': network_names,
    'average_acc': [],
    'max_acc': [],
    'std_acc': [],
    'average_precision': [],
    'max_precision': [],
    'average_recall': [],
    'max_recall': [],
    'average_f1': [],
    'max_f1': []
} # statistics from the experiment

average_acc, max_acc, std_acc = [], [], []
average_precision, max_precision = [], []
average_recall, max_recall = [], []
for network_name in network_names:
    data_stats['average_acc'].append(df[f'{network_name}_accuracy'].mean())
    data_stats['max_acc'].append(df[f'{network_name}_accuracy'].max())
    data_stats['std_acc'].append(df[f'{network_name}_accuracy'].std())

    data_stats['average_precision'].append(df[f'{network_name}_precision'].mean())
    data_stats['max_precision'].append(df[f'{network_name}_precision'].max())

    data_stats['average_recall'].append(df[f'{network_name}_recall'].mean())
    data_stats['max_recall'].append(df[f'{network_name}_recall'].max())

    data_stats['average_f1'].append(df[f'{network_name}_f1'].mean())
    data_stats['max_f1'].append(df[f'{network_name}_f1'].max())

data_stats
# Out:
# {'models': ['ann',
#   'snn [timesteps=50, scaling=1000, synapse=0.010000]',
#   'snn [timesteps=50, scaling=1000, synapse=None]',
#   'snn [timesteps=50, scaling=1, synapse=0.010000]',
#   'snn [timesteps=50, scaling=1, synapse=None]'],
#  'average_acc': [0.6323756720430108,
#   0.6333001493280239,
#   0.6334660693545711,
#   0.5182512029201924,
#   0.5195785631325701],
#  'max_acc': [0.6471774193548387,
#   0.6470881035340965,
#   0.646590343454455,
#   0.5500248880039821,
#   0.5450472872075659],
#  'std_acc': [0.010929149670875896,
#   0.010188601231666695,
#   0.0099039922610446,
#   0.01369118457865331,
#   0.011928408885575293],
#  'average_precision': [0.6264068541694552,
#   0.6269430369742859,
#   0.627068634435105,
#   0.5151235161164964,
#   0.5164234675251682],
#  'max_precision': [0.6510416666666666,
#   0.6510204081632653,
#   0.6515930113052415,
#   0.541978387364921,
#   0.5391903531438416],
#  'average_recall': [0.6607586438402148,
#   0.6619237147595356,
#   0.6622553897180763,
#   0.6318739635157546,
#   0.6379767827529024],
#  'max_recall': [0.75730110775428,
#   0.764179104477612,
#   0.7621890547263681,
#   0.709452736318408,
#   0.718407960199005],
#  'average_f1': [0.6421694628376341,
#   0.6429921611214074,
#   0.6432497920582735,
#   0.5656111790087789,
#   0.5688214071718872],
#  'max_f1': [0.6778432260987767,
#   0.6811529933481153,
#   0.6808888888888889,
#   0.602112676056338,
#   0.5955441302485005]}

# %%
df_stats = pd.DataFrame(data_stats)
df_stats.to_excel(os.path.join(output_folder_path, 'statistics.xlsx'))

'File with statistics successfully saved.'
# Out:
# 'File with statistics successfully saved.'
