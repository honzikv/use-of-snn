# %%
import os
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.python.keras import  Sequential
from tensorflow.python.keras.callbacks import EarlyStopping
from tensorflow.python.keras.layers import Dropout, Dense, BatchNormalization, LSTM
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split, KFold
from keras import backend as K
import bnci_utils as utils

# %%
num_participants = 18
dataset_path = os.path.join('dataset_result')
files = [os.path.join(dataset_path, 'P{:02d}.npz'.format(i+1))
         for i in range(num_participants)] # P01 - P18 files


# Set seed to produce consistent result
seed = 2
np.random.seed(seed)
tf.random.set_seed(seed)

# %%
# Function to transform the dataset to be usable for the neural network - i.e one hot encode and reshape the dataset
def transform_dataset(features, labels):
    labels = labels.reshape((-1, 1)) # reshape so one hot encoding can be used
    labels = OneHotEncoder().fit_transform(labels).toarray() # apply one hot encoding
    features = features.reshape((features.shape[0], 14, -1))

    return features, labels

# %%
# Definition of the lstm model
def lstm_model():
    model = Sequential([
        LSTM(124, input_shape=(14, 360), activation=tf.nn.relu, return_sequences=True),
        Dropout(0.4),
        BatchNormalization(),
        LSTM(124, activation=tf.nn.relu),
        Dropout(0.3),
        BatchNormalization(),
        Dense(64, activation=tf.nn.relu),
        Dropout(0.2),
        Dense(2, activation=tf.nn.softmax, name='output_layer')
    ])

    return model

# %%
# Function to run the network with training data and testing data
def run_network(model, x_train, y_train, x_test, y_test, iteration, epochs=30):

    model.compile(
        optimizer=tf.keras.optimizers.Adam(),
        loss=tf.losses.BinaryCrossentropy(),
        metrics=['accuracy'],

    )
    # Train the model
    model.fit(x_train, y_train, epochs=epochs, callbacks=[
        EarlyStopping(patience=8, verbose=1, restore_best_weights=True, monitor='loss')
    ])

    # Get the results
    accuracy, precision, recall, f1, confusion_matrix = utils.get_metrics_keras(model, x_test, y_test,
                                                                                f'{iteration}. LSTM')
    # Return the results as a dictionary
    return {
        'accuracy': accuracy,
        'precision': precision,
        'recall': recall,
        'f1': f1,
        'confusion_matrix': confusion_matrix
    }

# %%
def run_individual(file, particip_num, model, test_size=0.25, epochs=30):
    print('Running ANN for file:', file)
    dataset = np.load(file) # load numpy file containing the preprocessed data for specific participant
    features, labels = dataset['features'], dataset['labels'] # get features and labels from the numpy file

    # transform numpy arrays
    features, labels = transform_dataset(features, labels)
    # split to training and testing data
    x_train, x_test, y_train, y_test = train_test_split(features, labels, test_size=test_size, random_state=seed,
                                                        shuffle=True)
    print('X (train) shape:', x_train.shape, 'Y (train) shape:', y_train.shape)
    print('X (test) shape:', x_test.shape, 'Y (test) shape:', y_test.shape)

    return run_network(model, x_train, y_train, x_test, y_test, particip_num, epochs)

# %%
i = 1
results = []
for file in files:
    results.append(run_individual(file=file, particip_num=i, model=lstm_model()))
    i += 1
    K.clear_session()
# Out:
# Running ANN for file: dataset_result\P01.npz
# X (train) shape: (90, 14, 360) Y (train) shape: (90, 2)
# X (test) shape: (30, 14, 360) Y (test) shape: (30, 2)
# Epoch 1/30
# 3/3 [==============================] - 6s 113ms/step - loss: 0.9746 - accuracy: 0.5062
# Epoch 2/30
# 3/3 [==============================] - 0s 113ms/step - loss: 0.6656 - accuracy: 0.6314
# Epoch 3/30
# 3/3 [==============================] - 0s 111ms/step - loss: 0.6794 - accuracy: 0.6308
# Epoch 4/30
# 3/3 [==============================] - 0s 130ms/step - loss: 0.5626 - accuracy: 0.7472
# Epoch 5/30
# 3/3 [==============================] - 0s 115ms/step - loss: 0.5443 - accuracy: 0.7511
# Epoch 6/30
# 3/3 [==============================] - 0s 109ms/step - loss: 0.6047 - accuracy: 0.7857
# Epoch 7/30
# 3/3 [==============================] - 0s 108ms/step - loss: 0.4797 - accuracy: 0.8336
# Epoch 8/30
# 3/3 [==============================] - 0s 106ms/step - loss: 0.4612 - accuracy: 0.8023
# Epoch 9/30
# 3/3 [==============================] - 0s 108ms/step - loss: 0.4139 - accuracy: 0.8336
# Epoch 10/30
# 3/3 [==============================] - 0s 110ms/step - loss: 0.4276 - accuracy: 0.8213
# Epoch 11/30
# 3/3 [==============================] - 0s 126ms/step - loss: 0.3398 - accuracy: 0.8887
# Epoch 12/30
# 3/3 [==============================] - 0s 127ms/step - loss: 0.2291 - accuracy: 0.9410
# Epoch 13/30
# 3/3 [==============================] - 0s 110ms/step - loss: 0.2401 - accuracy: 0.9338
# Epoch 14/30
# 3/3 [==============================] - 0s 108ms/step - loss: 0.2439 - accuracy: 0.9031
# Epoch 15/30
# 3/3 [==============================] - 0s 109ms/step - loss: 0.2063 - accuracy: 0.9159
# Epoch 16/30
# 3/3 [==============================] - 0s 107ms/step - loss: 0.1531 - accuracy: 0.9477
# Epoch 17/30
# 3/3 [==============================] - 0s 107ms/step - loss: 0.2587 - accuracy: 0.9387
# Epoch 18/30
# 3/3 [==============================] - 0s 111ms/step - loss: 0.1614 - accuracy: 0.9449
# Epoch 19/30
# 3/3 [==============================] - 0s 106ms/step - loss: 0.0875 - accuracy: 0.9811
# Epoch 20/30
# 3/3 [==============================] - 0s 124ms/step - loss: 0.0992 - accuracy: 0.9850
# Epoch 21/30
# 3/3 [==============================] - 0s 111ms/step - loss: 0.1341 - accuracy: 0.9426
# Epoch 22/30
# 3/3 [==============================] - 0s 111ms/step - loss: 0.0922 - accuracy: 0.9944
# Epoch 23/30
# 3/3 [==============================] - 0s 111ms/step - loss: 0.0563 - accuracy: 0.9944
# Epoch 24/30
# 3/3 [==============================] - 0s 110ms/step - loss: 0.0648 - accuracy: 0.9827
# Epoch 25/30
# 3/3 [==============================] - 0s 115ms/step - loss: 0.0551 - accuracy: 0.9905
# Epoch 26/30
# 3/3 [==============================] - 0s 109ms/step - loss: 0.0642 - accuracy: 0.9827
# Epoch 27/30
# 3/3 [==============================] - 0s 109ms/step - loss: 0.0578 - accuracy: 0.9755
# Epoch 28/30
# 3/3 [==============================] - 0s 123ms/step - loss: 0.0502 - accuracy: 0.9944
# Epoch 29/30
# 3/3 [==============================] - 0s 135ms/step - loss: 0.0635 - accuracy: 0.9772
# Epoch 30/30
# 3/3 [==============================] - 0s 140ms/step - loss: 0.0522 - accuracy: 0.9850
# 1. LSTM: accuracy = 63.33333333333333%, precision = 0.6842105263157895, recall = 0.7222222222222222, f1 = 0.7027027027027027
# Confusion matrix:
# [[ 6  6]
#  [ 5 13]]
# Running ANN for file: dataset_result\P02.npz
# X (train) shape: (126, 14, 360) Y (train) shape: (126, 2)
# X (test) shape: (42, 14, 360) Y (test) shape: (42, 2)
# Epoch 1/30
# 4/4 [==============================] - 5s 111ms/step - loss: 0.9141 - accuracy: 0.4771
# Epoch 2/30
# 4/4 [==============================] - 0s 111ms/step - loss: 1.0151 - accuracy: 0.4570
# Epoch 3/30
# 4/4 [==============================] - 0s 117ms/step - loss: 0.6923 - accuracy: 0.5902
# Epoch 4/30
# 4/4 [==============================] - 0s 118ms/step - loss: 0.7136 - accuracy: 0.6916
# Epoch 5/30
# 4/4 [==============================] - 0s 112ms/step - loss: 0.6846 - accuracy: 0.6467
# Epoch 6/30
# 4/4 [==============================] - 0s 108ms/step - loss: 0.6672 - accuracy: 0.6592
# Epoch 7/30
# 4/4 [==============================] - 0s 120ms/step - loss: 0.6264 - accuracy: 0.6458
# Epoch 8/30
# 4/4 [==============================] - 1s 124ms/step - loss: 0.6512 - accuracy: 0.6354
# Epoch 9/30
# 4/4 [==============================] - 0s 111ms/step - loss: 0.7246 - accuracy: 0.6352
# Epoch 10/30
# 4/4 [==============================] - 0s 110ms/step - loss: 0.6616 - accuracy: 0.6384
# Epoch 11/30
# 4/4 [==============================] - 0s 114ms/step - loss: 0.8265 - accuracy: 0.5872
# Epoch 12/30
# 4/4 [==============================] - 0s 109ms/step - loss: 0.7171 - accuracy: 0.5432
# Epoch 13/30
# 4/4 [==============================] - 0s 113ms/step - loss: 0.6316 - accuracy: 0.7169
# Epoch 14/30
# 4/4 [==============================] - 1s 133ms/step - loss: 0.6640 - accuracy: 0.6834
# Epoch 15/30
# 4/4 [==============================] - 0s 109ms/step - loss: 0.6832 - accuracy: 0.6080
# Epoch 16/30
# 4/4 [==============================] - 0s 108ms/step - loss: 0.6672 - accuracy: 0.6868
# Epoch 17/30
# 4/4 [==============================] - 0s 120ms/step - loss: 0.6190 - accuracy: 0.6520
# Epoch 18/30
# 4/4 [==============================] - 0s 113ms/step - loss: 0.5540 - accuracy: 0.6856
# Epoch 19/30
# 4/4 [==============================] - 0s 117ms/step - loss: 0.5716 - accuracy: 0.7559
# Epoch 20/30
# 4/4 [==============================] - 0s 109ms/step - loss: 0.5572 - accuracy: 0.7128
# Epoch 21/30
# 4/4 [==============================] - 0s 125ms/step - loss: 0.5623 - accuracy: 0.7212
# Epoch 22/30
# 4/4 [==============================] - 0s 111ms/step - loss: 0.5019 - accuracy: 0.7433
# Epoch 23/30
# 4/4 [==============================] - 0s 110ms/step - loss: 0.4607 - accuracy: 0.7861
# Epoch 24/30
# 4/4 [==============================] - 0s 118ms/step - loss: 0.4823 - accuracy: 0.7693
# Epoch 25/30
# 4/4 [==============================] - 0s 111ms/step - loss: 0.4388 - accuracy: 0.7809
# Epoch 26/30
# 4/4 [==============================] - 0s 114ms/step - loss: 0.3830 - accuracy: 0.8249
# Epoch 27/30
# 4/4 [==============================] - 0s 113ms/step - loss: 0.4314 - accuracy: 0.7526
# Epoch 28/30
# 4/4 [==============================] - 0s 121ms/step - loss: 0.4236 - accuracy: 0.7832
# Epoch 29/30
# 4/4 [==============================] - 0s 113ms/step - loss: 0.4413 - accuracy: 0.8041
# Epoch 30/30
# 4/4 [==============================] - 0s 111ms/step - loss: 0.3507 - accuracy: 0.7902
# 2. LSTM: accuracy = 45.23809523809524%, precision = 0.45454545454545453, recall = 0.75, f1 = 0.5660377358490566
# Confusion matrix:
# [[ 4 18]
#  [ 5 15]]
# Running ANN for file: dataset_result\P03.npz
# X (train) shape: (126, 14, 360) Y (train) shape: (126, 2)
# X (test) shape: (42, 14, 360) Y (test) shape: (42, 2)
# Epoch 1/30
# 4/4 [==============================] - 5s 113ms/step - loss: 0.7945 - accuracy: 0.5681
# Epoch 2/30
# 4/4 [==============================] - 1s 138ms/step - loss: 0.7931 - accuracy: 0.5924
# Epoch 3/30
# 4/4 [==============================] - 1s 119ms/step - loss: 0.7175 - accuracy: 0.5712
# Epoch 4/30
# 4/4 [==============================] - 0s 122ms/step - loss: 0.6071 - accuracy: 0.6929
# Epoch 5/30
# 4/4 [==============================] - 0s 116ms/step - loss: 0.7102 - accuracy: 0.6404
# Epoch 6/30
# 4/4 [==============================] - 0s 115ms/step - loss: 0.6141 - accuracy: 0.6800
# Epoch 7/30
# 4/4 [==============================] - 0s 127ms/step - loss: 0.5733 - accuracy: 0.7879
# Epoch 8/30
# 4/4 [==============================] - 0s 112ms/step - loss: 0.6124 - accuracy: 0.6813
# Epoch 9/30
# 4/4 [==============================] - 1s 120ms/step - loss: 0.5196 - accuracy: 0.7262
# Epoch 10/30
# 4/4 [==============================] - 0s 110ms/step - loss: 0.6500 - accuracy: 0.5872
# Epoch 11/30
# 4/4 [==============================] - 0s 124ms/step - loss: 0.5076 - accuracy: 0.7095
# Epoch 12/30
# 4/4 [==============================] - 0s 112ms/step - loss: 0.5398 - accuracy: 0.7297
# Epoch 13/30
# 4/4 [==============================] - 0s 109ms/step - loss: 0.4667 - accuracy: 0.7966
# Epoch 14/30
# 4/4 [==============================] - 0s 110ms/step - loss: 0.4539 - accuracy: 0.7476
# Epoch 15/30
# 4/4 [==============================] - 0s 113ms/step - loss: 0.4631 - accuracy: 0.7577
# Epoch 16/30
# 4/4 [==============================] - 0s 108ms/step - loss: 0.4309 - accuracy: 0.8071
# Epoch 17/30
# 4/4 [==============================] - 0s 114ms/step - loss: 0.4039 - accuracy: 0.7788
# Epoch 18/30
# 4/4 [==============================] - 0s 109ms/step - loss: 0.3592 - accuracy: 0.8784
# Epoch 19/30
# 4/4 [==============================] - 0s 110ms/step - loss: 0.3070 - accuracy: 0.8565
# Epoch 20/30
# 4/4 [==============================] - 0s 109ms/step - loss: 0.2852 - accuracy: 0.8847
# Epoch 21/30
# 4/4 [==============================] - 0s 123ms/step - loss: 0.2656 - accuracy: 0.9130
# Epoch 22/30
# 4/4 [==============================] - 0s 117ms/step - loss: 0.2619 - accuracy: 0.8964
# Epoch 23/30
# 4/4 [==============================] - 0s 114ms/step - loss: 0.1747 - accuracy: 0.9433
# Epoch 24/30
# 4/4 [==============================] - 0s 111ms/step - loss: 0.2144 - accuracy: 0.9193
# Epoch 25/30
# 4/4 [==============================] - 0s 111ms/step - loss: 0.1648 - accuracy: 0.9622
# Epoch 26/30
# 4/4 [==============================] - 0s 124ms/step - loss: 0.1561 - accuracy: 0.9151
# Epoch 27/30
# 4/4 [==============================] - 0s 112ms/step - loss: 0.1807 - accuracy: 0.8974
# Epoch 28/30
# 4/4 [==============================] - 0s 120ms/step - loss: 0.1768 - accuracy: 0.9236
# Epoch 29/30
# 4/4 [==============================] - 0s 113ms/step - loss: 0.1251 - accuracy: 0.9632
# Epoch 30/30
# 4/4 [==============================] - 0s 111ms/step - loss: 0.1321 - accuracy: 0.9611
# 3. LSTM: accuracy = 59.523809523809526%, precision = 0.6666666666666666, recall = 0.38095238095238093, f1 = 0.4848484848484849
# Confusion matrix:
# [[17  4]
#  [13  8]]
# Running ANN for file: dataset_result\P04.npz
# X (train) shape: (126, 14, 360) Y (train) shape: (126, 2)
# X (test) shape: (42, 14, 360) Y (test) shape: (42, 2)
# Epoch 1/30
# 4/4 [==============================] - 5s 113ms/step - loss: 0.9215 - accuracy: 0.4769
# Epoch 2/30
# 4/4 [==============================] - 0s 110ms/step - loss: 0.7307 - accuracy: 0.6299
# Epoch 3/30
# 4/4 [==============================] - 1s 136ms/step - loss: 0.7172 - accuracy: 0.6572
# Epoch 4/30
# 4/4 [==============================] - 1s 142ms/step - loss: 0.6232 - accuracy: 0.6531
# Epoch 5/30
# 4/4 [==============================] - 0s 120ms/step - loss: 0.6216 - accuracy: 0.7199
# Epoch 6/30
# 4/4 [==============================] - 1s 140ms/step - loss: 0.6333 - accuracy: 0.6826
# Epoch 7/30
# 4/4 [==============================] - 1s 125ms/step - loss: 0.6194 - accuracy: 0.7359
# Epoch 8/30
# 4/4 [==============================] - 1s 141ms/step - loss: 0.5725 - accuracy: 0.7349
# Epoch 9/30
# 4/4 [==============================] - 1s 128ms/step - loss: 0.5085 - accuracy: 0.7285
# Epoch 10/30
# 4/4 [==============================] - 0s 115ms/step - loss: 0.4582 - accuracy: 0.7851
# Epoch 11/30
# 4/4 [==============================] - 0s 129ms/step - loss: 0.3577 - accuracy: 0.8448
# Epoch 12/30
# 4/4 [==============================] - 0s 110ms/step - loss: 0.3170 - accuracy: 0.8544
# Epoch 13/30
# 4/4 [==============================] - 0s 111ms/step - loss: 0.3284 - accuracy: 0.8417
# Epoch 14/30
# 4/4 [==============================] - 0s 120ms/step - loss: 0.3245 - accuracy: 0.8220
# Epoch 15/30
# 4/4 [==============================] - 0s 116ms/step - loss: 0.3138 - accuracy: 0.8709
# Epoch 16/30
# 4/4 [==============================] - 0s 111ms/step - loss: 0.3060 - accuracy: 0.8751
# Epoch 17/30
# 4/4 [==============================] - 0s 110ms/step - loss: 0.3457 - accuracy: 0.8974
# Epoch 18/30
# 4/4 [==============================] - 1s 132ms/step - loss: 0.2374 - accuracy: 0.9161
# Epoch 19/30
# 4/4 [==============================] - 0s 111ms/step - loss: 0.3241 - accuracy: 0.8637
# Epoch 20/30
# 4/4 [==============================] - 0s 111ms/step - loss: 0.1775 - accuracy: 0.9465
# Epoch 21/30
# 4/4 [==============================] - 0s 123ms/step - loss: 0.2273 - accuracy: 0.9109
# Epoch 22/30
# 4/4 [==============================] - 0s 112ms/step - loss: 0.2415 - accuracy: 0.9088
# Epoch 23/30
# 4/4 [==============================] - 1s 125ms/step - loss: 0.1750 - accuracy: 0.9528
# Epoch 24/30
# 4/4 [==============================] - 0s 114ms/step - loss: 0.2200 - accuracy: 0.8889
# Epoch 25/30
# 4/4 [==============================] - 0s 111ms/step - loss: 0.1879 - accuracy: 0.9057
# Epoch 26/30
# 4/4 [==============================] - 0s 111ms/step - loss: 0.1939 - accuracy: 0.9591
# Epoch 27/30
# 4/4 [==============================] - 0s 115ms/step - loss: 0.1177 - accuracy: 0.9591
# Epoch 28/30
# 4/4 [==============================] - 0s 111ms/step - loss: 0.1156 - accuracy: 0.9685
# Epoch 29/30
# 4/4 [==============================] - 0s 117ms/step - loss: 0.1441 - accuracy: 0.9443
# Epoch 30/30
# 4/4 [==============================] - 1s 132ms/step - loss: 0.1247 - accuracy: 0.9612
# 4. LSTM: accuracy = 40.476190476190474%, precision = 0.391304347826087, recall = 0.45, f1 = 0.4186046511627907
# Confusion matrix:
# [[ 8 14]
#  [11  9]]
# Running ANN for file: dataset_result\P05.npz
# X (train) shape: (126, 14, 360) Y (train) shape: (126, 2)
# X (test) shape: (42, 14, 360) Y (test) shape: (42, 2)
# Epoch 1/30
# 4/4 [==============================] - 5s 115ms/step - loss: 1.1184 - accuracy: 0.5230
# Epoch 2/30
# 4/4 [==============================] - 1s 135ms/step - loss: 1.0338 - accuracy: 0.5336
# Epoch 3/30
# 4/4 [==============================] - 0s 113ms/step - loss: 0.7553 - accuracy: 0.6613
# Epoch 4/30
# 4/4 [==============================] - 1s 134ms/step - loss: 0.9377 - accuracy: 0.5841
# Epoch 5/30
# 4/4 [==============================] - 1s 137ms/step - loss: 0.6508 - accuracy: 0.7119
# Epoch 6/30
# 4/4 [==============================] - 1s 145ms/step - loss: 0.5996 - accuracy: 0.6969
# Epoch 7/30
# 4/4 [==============================] - 1s 126ms/step - loss: 0.5452 - accuracy: 0.7251
# Epoch 8/30
# 4/4 [==============================] - 0s 112ms/step - loss: 0.6067 - accuracy: 0.6656
# Epoch 9/30
# 4/4 [==============================] - 0s 115ms/step - loss: 0.4379 - accuracy: 0.8017
# Epoch 10/30
# 4/4 [==============================] - 1s 134ms/step - loss: 0.4698 - accuracy: 0.7924
# Epoch 11/30
# 4/4 [==============================] - 0s 114ms/step - loss: 0.3964 - accuracy: 0.8604
# Epoch 12/30
# 4/4 [==============================] - 0s 125ms/step - loss: 0.4230 - accuracy: 0.8467
# Epoch 13/30
# 4/4 [==============================] - 1s 141ms/step - loss: 0.3745 - accuracy: 0.8365
# Epoch 14/30
# 4/4 [==============================] - 0s 110ms/step - loss: 0.3340 - accuracy: 0.8239
# Epoch 15/30
# 4/4 [==============================] - 1s 128ms/step - loss: 0.3729 - accuracy: 0.8406
# Epoch 16/30
# 4/4 [==============================] - 0s 118ms/step - loss: 0.2774 - accuracy: 0.8857
# Epoch 17/30
# 4/4 [==============================] - 0s 111ms/step - loss: 0.3991 - accuracy: 0.8732
# Epoch 18/30
# 4/4 [==============================] - 0s 118ms/step - loss: 0.3321 - accuracy: 0.8586
# Epoch 19/30
# 4/4 [==============================] - 0s 111ms/step - loss: 0.2787 - accuracy: 0.8702
# Epoch 20/30
# 4/4 [==============================] - 0s 113ms/step - loss: 0.2992 - accuracy: 0.8899
# Epoch 21/30
# 4/4 [==============================] - 0s 114ms/step - loss: 0.1793 - accuracy: 0.9214
# Epoch 22/30
# 4/4 [==============================] - 0s 111ms/step - loss: 0.1659 - accuracy: 0.9161
# Epoch 23/30
# 4/4 [==============================] - 0s 109ms/step - loss: 0.1652 - accuracy: 0.9318
# Epoch 24/30
# 4/4 [==============================] - 0s 111ms/step - loss: 0.2240 - accuracy: 0.9005
# Epoch 25/30
# 4/4 [==============================] - 0s 110ms/step - loss: 0.1996 - accuracy: 0.9182
# Epoch 26/30
# 4/4 [==============================] - 0s 113ms/step - loss: 0.2009 - accuracy: 0.9287
# Epoch 27/30
# 4/4 [==============================] - 0s 110ms/step - loss: 0.1580 - accuracy: 0.9089
# Epoch 28/30
# 4/4 [==============================] - 1s 143ms/step - loss: 0.1242 - accuracy: 0.9643
# Epoch 29/30
# 4/4 [==============================] - 0s 111ms/step - loss: 0.1571 - accuracy: 0.9413
# Epoch 30/30
# 4/4 [==============================] - 0s 114ms/step - loss: 0.1550 - accuracy: 0.9172
# WARNING:tensorflow:5 out of the last 8 calls to <function Model.make_predict_function.<locals>.predict_function at 0x00000255FD126310> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 5. LSTM: accuracy = 40.476190476190474%, precision = 0.3684210526315789, recall = 0.35, f1 = 0.358974358974359
# Confusion matrix:
# [[10 12]
#  [13  7]]
# Running ANN for file: dataset_result\P06.npz
# X (train) shape: (126, 14, 360) Y (train) shape: (126, 2)
# X (test) shape: (42, 14, 360) Y (test) shape: (42, 2)
# Epoch 1/30
# 4/4 [==============================] - 5s 113ms/step - loss: 1.2384 - accuracy: 0.4834
# Epoch 2/30
# 4/4 [==============================] - 0s 110ms/step - loss: 0.9680 - accuracy: 0.5430
# Epoch 3/30
# 4/4 [==============================] - 0s 113ms/step - loss: 0.8228 - accuracy: 0.6332
# Epoch 4/30
# 4/4 [==============================] - 0s 112ms/step - loss: 0.7920 - accuracy: 0.6490
# Epoch 5/30
# 4/4 [==============================] - 1s 122ms/step - loss: 0.7635 - accuracy: 0.6342
# Epoch 6/30
# 4/4 [==============================] - 0s 113ms/step - loss: 0.6832 - accuracy: 0.7138
# Epoch 7/30
# 4/4 [==============================] - 0s 129ms/step - loss: 0.5877 - accuracy: 0.6971
# Epoch 8/30
# 4/4 [==============================] - 0s 114ms/step - loss: 0.5819 - accuracy: 0.7160
# Epoch 9/30
# 4/4 [==============================] - 1s 137ms/step - loss: 0.5223 - accuracy: 0.7221
# Epoch 10/30
# 4/4 [==============================] - 1s 132ms/step - loss: 0.6469 - accuracy: 0.6993
# Epoch 11/30
# 4/4 [==============================] - 0s 115ms/step - loss: 0.4297 - accuracy: 0.8039
# Epoch 12/30
# 4/4 [==============================] - 0s 122ms/step - loss: 0.5418 - accuracy: 0.7179
# Epoch 13/30
# 4/4 [==============================] - 1s 122ms/step - loss: 0.5112 - accuracy: 0.7434
# Epoch 14/30
# 4/4 [==============================] - 0s 115ms/step - loss: 0.4251 - accuracy: 0.7892
# Epoch 15/30
# 4/4 [==============================] - 0s 116ms/step - loss: 0.4048 - accuracy: 0.8440
# Epoch 16/30
# 4/4 [==============================] - 0s 112ms/step - loss: 0.4437 - accuracy: 0.7790
# Epoch 17/30
# 4/4 [==============================] - 0s 123ms/step - loss: 0.4674 - accuracy: 0.8008
# Epoch 18/30
# 4/4 [==============================] - 0s 113ms/step - loss: 0.3813 - accuracy: 0.8123
# Epoch 19/30
# 4/4 [==============================] - 0s 115ms/step - loss: 0.4448 - accuracy: 0.7729
# Epoch 20/30
# 4/4 [==============================] - 0s 112ms/step - loss: 0.3510 - accuracy: 0.8482
# Epoch 21/30
# 4/4 [==============================] - 0s 113ms/step - loss: 0.2970 - accuracy: 0.8847
# Epoch 22/30
# 4/4 [==============================] - 0s 109ms/step - loss: 0.3379 - accuracy: 0.8544
# Epoch 23/30
# 4/4 [==============================] - 0s 117ms/step - loss: 0.3121 - accuracy: 0.8729
# Epoch 24/30
# 4/4 [==============================] - 1s 148ms/step - loss: 0.2351 - accuracy: 0.8784
# Epoch 25/30
# 4/4 [==============================] - 0s 111ms/step - loss: 0.2839 - accuracy: 0.8816
# Epoch 26/30
# 4/4 [==============================] - 0s 111ms/step - loss: 0.2359 - accuracy: 0.9401
# Epoch 27/30
# 4/4 [==============================] - 0s 109ms/step - loss: 0.2439 - accuracy: 0.8943
# Epoch 28/30
# 4/4 [==============================] - 0s 115ms/step - loss: 0.1613 - accuracy: 0.9339
# Epoch 29/30
# 4/4 [==============================] - 1s 144ms/step - loss: 0.2050 - accuracy: 0.9120
# Epoch 30/30
# 4/4 [==============================] - 1s 132ms/step - loss: 0.1690 - accuracy: 0.9151
# WARNING:tensorflow:6 out of the last 10 calls to <function Model.make_predict_function.<locals>.predict_function at 0x00000257017A30D0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 6. LSTM: accuracy = 52.38095238095239%, precision = 0.5652173913043478, recall = 0.5652173913043478, f1 = 0.5652173913043478
# Confusion matrix:
# [[ 9 10]
#  [10 13]]
# Running ANN for file: dataset_result\P07.npz
# X (train) shape: (126, 14, 360) Y (train) shape: (126, 2)
# X (test) shape: (42, 14, 360) Y (test) shape: (42, 2)
# Epoch 1/30
# 4/4 [==============================] - 5s 144ms/step - loss: 0.9942 - accuracy: 0.4989
# Epoch 2/30
# 4/4 [==============================] - 0s 111ms/step - loss: 0.7661 - accuracy: 0.5901
# Epoch 3/30
# 4/4 [==============================] - 0s 117ms/step - loss: 0.7945 - accuracy: 0.5471
# Epoch 4/30
# 4/4 [==============================] - 0s 116ms/step - loss: 0.7904 - accuracy: 0.5862
# Epoch 5/30
# 4/4 [==============================] - 0s 115ms/step - loss: 0.7094 - accuracy: 0.6372
# Epoch 6/30
# 4/4 [==============================] - 0s 120ms/step - loss: 0.4851 - accuracy: 0.7558
# Epoch 7/30
# 4/4 [==============================] - 0s 119ms/step - loss: 0.4983 - accuracy: 0.7429
# Epoch 8/30
# 4/4 [==============================] - 1s 136ms/step - loss: 0.4199 - accuracy: 0.8092
# Epoch 9/30
# 4/4 [==============================] - 0s 120ms/step - loss: 0.4731 - accuracy: 0.7935
# Epoch 10/30
# 4/4 [==============================] - 1s 145ms/step - loss: 0.5373 - accuracy: 0.7297
# Epoch 11/30
# 4/4 [==============================] - 0s 120ms/step - loss: 0.4243 - accuracy: 0.8165
# Epoch 12/30
# 4/4 [==============================] - 0s 117ms/step - loss: 0.3831 - accuracy: 0.7987
# Epoch 13/30
# 4/4 [==============================] - 0s 119ms/step - loss: 0.4071 - accuracy: 0.7788
# Epoch 14/30
# 4/4 [==============================] - 1s 132ms/step - loss: 0.3466 - accuracy: 0.8618
# Epoch 15/30
# 4/4 [==============================] - 1s 149ms/step - loss: 0.3450 - accuracy: 0.8366
# Epoch 16/30
# 4/4 [==============================] - 1s 133ms/step - loss: 0.3562 - accuracy: 0.8691
# Epoch 17/30
# 4/4 [==============================] - 1s 129ms/step - loss: 0.3432 - accuracy: 0.8668
# Epoch 18/30
# 4/4 [==============================] - 0s 114ms/step - loss: 0.1833 - accuracy: 0.9276
# Epoch 19/30
# 4/4 [==============================] - 0s 115ms/step - loss: 0.2738 - accuracy: 0.8942
# Epoch 20/30
# 4/4 [==============================] - 0s 128ms/step - loss: 0.2198 - accuracy: 0.9371
# Epoch 21/30
# 4/4 [==============================] - 0s 119ms/step - loss: 0.1775 - accuracy: 0.9203
# Epoch 22/30
# 4/4 [==============================] - 0s 123ms/step - loss: 0.2197 - accuracy: 0.9141
# Epoch 23/30
# 4/4 [==============================] - 1s 133ms/step - loss: 0.1971 - accuracy: 0.9256
# Epoch 24/30
# 4/4 [==============================] - 1s 133ms/step - loss: 0.1391 - accuracy: 0.9664
# Epoch 25/30
# 4/4 [==============================] - 1s 130ms/step - loss: 0.1212 - accuracy: 0.9686
# Epoch 26/30
# 4/4 [==============================] - 1s 120ms/step - loss: 0.1425 - accuracy: 0.9380
# Epoch 27/30
# 4/4 [==============================] - 0s 116ms/step - loss: 0.1479 - accuracy: 0.9455
# Epoch 28/30
# 4/4 [==============================] - 0s 114ms/step - loss: 0.1761 - accuracy: 0.9445
# Epoch 29/30
# 4/4 [==============================] - 1s 142ms/step - loss: 0.0728 - accuracy: 0.9821
# Epoch 30/30
# 4/4 [==============================] - 1s 134ms/step - loss: 0.1192 - accuracy: 0.9518
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x00000257012A7310> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 7. LSTM: accuracy = 47.61904761904761%, precision = 0.48, recall = 0.5714285714285714, f1 = 0.5217391304347826
# Confusion matrix:
# [[ 8 13]
#  [ 9 12]]
# Running ANN for file: dataset_result\P08.npz
# X (train) shape: (126, 14, 360) Y (train) shape: (126, 2)
# X (test) shape: (42, 14, 360) Y (test) shape: (42, 2)
# Epoch 1/30
# 4/4 [==============================] - 5s 139ms/step - loss: 1.2115 - accuracy: 0.5136
# Epoch 2/30
# 4/4 [==============================] - 0s 114ms/step - loss: 0.8759 - accuracy: 0.5788
# Epoch 3/30
# 4/4 [==============================] - 1s 139ms/step - loss: 0.8271 - accuracy: 0.6102
# Epoch 4/30
# 4/4 [==============================] - 1s 143ms/step - loss: 0.8385 - accuracy: 0.6017
# Epoch 5/30
# 4/4 [==============================] - 1s 137ms/step - loss: 0.6376 - accuracy: 0.6911
# Epoch 6/30
# 4/4 [==============================] - 1s 128ms/step - loss: 0.5182 - accuracy: 0.7538
# Epoch 7/30
# 4/4 [==============================] - 0s 113ms/step - loss: 0.5228 - accuracy: 0.7839
# Epoch 8/30
# 4/4 [==============================] - 0s 113ms/step - loss: 0.3992 - accuracy: 0.8291
# Epoch 9/30
# 4/4 [==============================] - 0s 118ms/step - loss: 0.4062 - accuracy: 0.8156
# Epoch 10/30
# 4/4 [==============================] - 0s 112ms/step - loss: 0.4740 - accuracy: 0.7957
# Epoch 11/30
# 4/4 [==============================] - 0s 115ms/step - loss: 0.3101 - accuracy: 0.8574
# Epoch 12/30
# 4/4 [==============================] - 0s 123ms/step - loss: 0.2720 - accuracy: 0.8826
# Epoch 13/30
# 4/4 [==============================] - 1s 126ms/step - loss: 0.2257 - accuracy: 0.9277
# Epoch 14/30
# 4/4 [==============================] - 0s 117ms/step - loss: 0.1841 - accuracy: 0.9391
# Epoch 15/30
# 4/4 [==============================] - 0s 117ms/step - loss: 0.1910 - accuracy: 0.9234
# Epoch 16/30
# 4/4 [==============================] - 0s 120ms/step - loss: 0.0941 - accuracy: 0.9665
# Epoch 17/30
# 4/4 [==============================] - 1s 127ms/step - loss: 0.1727 - accuracy: 0.9351
# Epoch 18/30
# 4/4 [==============================] - 0s 117ms/step - loss: 0.1607 - accuracy: 0.9362
# Epoch 19/30
# 4/4 [==============================] - 0s 118ms/step - loss: 0.0626 - accuracy: 0.9916
# Epoch 20/30
# 4/4 [==============================] - 0s 117ms/step - loss: 0.0971 - accuracy: 0.9811
# Epoch 21/30
# 4/4 [==============================] - 0s 113ms/step - loss: 0.0522 - accuracy: 0.9884
# Epoch 22/30
# 4/4 [==============================] - 0s 125ms/step - loss: 0.0415 - accuracy: 0.9884
# Epoch 23/30
# 4/4 [==============================] - 0s 129ms/step - loss: 0.0432 - accuracy: 0.9947
# Epoch 24/30
# 4/4 [==============================] - 1s 140ms/step - loss: 0.0677 - accuracy: 0.9738
# Epoch 25/30
# 4/4 [==============================] - 1s 139ms/step - loss: 0.0407 - accuracy: 0.9916
# Epoch 26/30
# 4/4 [==============================] - 1s 138ms/step - loss: 0.0458 - accuracy: 0.9884
# Epoch 27/30
# 4/4 [==============================] - 1s 142ms/step - loss: 0.0323 - accuracy: 0.9916
# Epoch 28/30
# 4/4 [==============================] - 0s 120ms/step - loss: 0.0371 - accuracy: 0.9968
# Epoch 29/30
# 4/4 [==============================] - 0s 125ms/step - loss: 0.0342 - accuracy: 0.9947
# Epoch 30/30
# 4/4 [==============================] - 0s 117ms/step - loss: 0.0187 - accuracy: 1.0000
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000025706675310> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 8. LSTM: accuracy = 54.761904761904766%, precision = 0.52, recall = 0.65, f1 = 0.5777777777777778
# Confusion matrix:
# [[10 12]
#  [ 7 13]]
# Running ANN for file: dataset_result\P09.npz
# X (train) shape: (126, 14, 360) Y (train) shape: (126, 2)
# X (test) shape: (42, 14, 360) Y (test) shape: (42, 2)
# Epoch 1/30
# 4/4 [==============================] - 5s 115ms/step - loss: 0.8858 - accuracy: 0.5524
# Epoch 2/30
# 4/4 [==============================] - 0s 112ms/step - loss: 0.7240 - accuracy: 0.7012
# Epoch 3/30
# 4/4 [==============================] - 1s 128ms/step - loss: 0.5090 - accuracy: 0.7597
# Epoch 4/30
# 4/4 [==============================] - 0s 113ms/step - loss: 0.6112 - accuracy: 0.7432
# Epoch 5/30
# 4/4 [==============================] - 0s 115ms/step - loss: 0.5631 - accuracy: 0.7390
# Epoch 6/30
# 4/4 [==============================] - 0s 114ms/step - loss: 0.3355 - accuracy: 0.8519
# Epoch 7/30
# 4/4 [==============================] - 0s 113ms/step - loss: 0.3762 - accuracy: 0.8469
# Epoch 8/30
# 4/4 [==============================] - 1s 142ms/step - loss: 0.3429 - accuracy: 0.8417
# Epoch 9/30
# 4/4 [==============================] - 0s 116ms/step - loss: 0.2104 - accuracy: 0.9633
# Epoch 10/30
# 4/4 [==============================] - 0s 114ms/step - loss: 0.2208 - accuracy: 0.9402
# Epoch 11/30
# 4/4 [==============================] - 0s 113ms/step - loss: 0.1565 - accuracy: 0.9686
# Epoch 12/30
# 4/4 [==============================] - 1s 140ms/step - loss: 0.1489 - accuracy: 0.9676
# Epoch 13/30
# 4/4 [==============================] - 0s 114ms/step - loss: 0.1059 - accuracy: 0.9822
# Epoch 14/30
# 4/4 [==============================] - 0s 115ms/step - loss: 0.0869 - accuracy: 0.9916
# Epoch 15/30
# 4/4 [==============================] - 0s 117ms/step - loss: 0.0840 - accuracy: 0.9686
# Epoch 16/30
# 4/4 [==============================] - 0s 116ms/step - loss: 0.0706 - accuracy: 1.0000
# Epoch 17/30
# 4/4 [==============================] - 1s 143ms/step - loss: 0.0528 - accuracy: 1.0000
# Epoch 18/30
# 4/4 [==============================] - 0s 114ms/step - loss: 0.0450 - accuracy: 0.9916
# Epoch 19/30
# 4/4 [==============================] - 0s 122ms/step - loss: 0.0488 - accuracy: 0.9832
# Epoch 20/30
# 4/4 [==============================] - 0s 115ms/step - loss: 0.0341 - accuracy: 1.0000
# Epoch 21/30
# 4/4 [==============================] - 1s 143ms/step - loss: 0.0449 - accuracy: 0.9854
# Epoch 22/30
# 4/4 [==============================] - 1s 144ms/step - loss: 0.0341 - accuracy: 0.9822
# Epoch 23/30
# 4/4 [==============================] - 1s 146ms/step - loss: 0.0568 - accuracy: 0.9801
# Epoch 24/30
# 4/4 [==============================] - 1s 123ms/step - loss: 0.0162 - accuracy: 1.0000
# Epoch 25/30
# 4/4 [==============================] - 0s 113ms/step - loss: 0.0185 - accuracy: 0.9947
# Epoch 26/30
# 4/4 [==============================] - 0s 114ms/step - loss: 0.0197 - accuracy: 1.0000
# Epoch 27/30
# 4/4 [==============================] - 0s 113ms/step - loss: 0.0156 - accuracy: 1.0000
# Epoch 28/30
# 4/4 [==============================] - 0s 116ms/step - loss: 0.0125 - accuracy: 1.0000
# Epoch 29/30
# 4/4 [==============================] - 0s 113ms/step - loss: 0.0475 - accuracy: 0.9811
# Epoch 30/30
# 4/4 [==============================] - 0s 121ms/step - loss: 0.0101 - accuracy: 1.0000
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x00000256FF9CF4C0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 9. LSTM: accuracy = 52.38095238095239%, precision = 0.5238095238095238, recall = 0.5238095238095238, f1 = 0.5238095238095238
# Confusion matrix:
# [[11 10]
#  [10 11]]
# Running ANN for file: dataset_result\P10.npz
# X (train) shape: (126, 14, 360) Y (train) shape: (126, 2)
# X (test) shape: (42, 14, 360) Y (test) shape: (42, 2)
# Epoch 1/30
# 4/4 [==============================] - 5s 115ms/step - loss: 0.8896 - accuracy: 0.5598
# Epoch 2/30
# 4/4 [==============================] - 0s 117ms/step - loss: 0.8167 - accuracy: 0.5639
# Epoch 3/30
# 4/4 [==============================] - 0s 116ms/step - loss: 0.5944 - accuracy: 0.6834
# Epoch 4/30
# 4/4 [==============================] - 0s 116ms/step - loss: 0.7070 - accuracy: 0.5683
# Epoch 5/30
# 4/4 [==============================] - 0s 115ms/step - loss: 0.7361 - accuracy: 0.5947
# Epoch 6/30
# 4/4 [==============================] - 0s 118ms/step - loss: 0.6177 - accuracy: 0.6825
# Epoch 7/30
# 4/4 [==============================] - 0s 113ms/step - loss: 0.5894 - accuracy: 0.7159
# Epoch 8/30
# 4/4 [==============================] - 0s 115ms/step - loss: 0.6051 - accuracy: 0.6992
# Epoch 9/30
# 4/4 [==============================] - 1s 132ms/step - loss: 0.5023 - accuracy: 0.7955
# Epoch 10/30
# 4/4 [==============================] - 0s 117ms/step - loss: 0.4853 - accuracy: 0.7705
# Epoch 11/30
# 4/4 [==============================] - 0s 116ms/step - loss: 0.5729 - accuracy: 0.7496
# Epoch 12/30
# 4/4 [==============================] - 0s 115ms/step - loss: 0.3856 - accuracy: 0.8343
# Epoch 13/30
# 4/4 [==============================] - 0s 113ms/step - loss: 0.3707 - accuracy: 0.8553
# Epoch 14/30
# 4/4 [==============================] - 0s 118ms/step - loss: 0.4214 - accuracy: 0.8301
# Epoch 15/30
# 4/4 [==============================] - 0s 117ms/step - loss: 0.3554 - accuracy: 0.8367
# Epoch 16/30
# 4/4 [==============================] - 0s 119ms/step - loss: 0.3038 - accuracy: 0.8607
# Epoch 17/30
# 4/4 [==============================] - 0s 117ms/step - loss: 0.2915 - accuracy: 0.8606
# Epoch 18/30
# 4/4 [==============================] - 1s 144ms/step - loss: 0.2748 - accuracy: 0.8941
# Epoch 19/30
# 4/4 [==============================] - 0s 116ms/step - loss: 0.3340 - accuracy: 0.8962
# Epoch 20/30
# 4/4 [==============================] - 0s 124ms/step - loss: 0.2670 - accuracy: 0.8659
# Epoch 21/30
# 4/4 [==============================] - 1s 127ms/step - loss: 0.2412 - accuracy: 0.9317
# Epoch 22/30
# 4/4 [==============================] - 0s 115ms/step - loss: 0.1791 - accuracy: 0.9308
# Epoch 23/30
# 4/4 [==============================] - 0s 118ms/step - loss: 0.1420 - accuracy: 0.9414
# Epoch 24/30
# 4/4 [==============================] - 0s 115ms/step - loss: 0.1440 - accuracy: 0.9476
# Epoch 25/30
# 4/4 [==============================] - 0s 118ms/step - loss: 0.2109 - accuracy: 0.9349
# Epoch 26/30
# 4/4 [==============================] - 1s 141ms/step - loss: 0.1429 - accuracy: 0.9372
# Epoch 27/30
# 4/4 [==============================] - 0s 116ms/step - loss: 0.1422 - accuracy: 0.9434
# Epoch 28/30
# 4/4 [==============================] - 1s 130ms/step - loss: 0.0991 - accuracy: 0.9686
# Epoch 29/30
# 4/4 [==============================] - 0s 118ms/step - loss: 0.1199 - accuracy: 0.9863
# Epoch 30/30
# 4/4 [==============================] - 1s 140ms/step - loss: 0.1310 - accuracy: 0.9434
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x00000255CF3E2670> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 10. LSTM: accuracy = 57.14285714285714%, precision = 0.5555555555555556, recall = 0.7142857142857143, f1 = 0.6250000000000001
# Confusion matrix:
# [[ 9 12]
#  [ 6 15]]
# Running ANN for file: dataset_result\P11.npz
# X (train) shape: (126, 14, 360) Y (train) shape: (126, 2)
# X (test) shape: (42, 14, 360) Y (test) shape: (42, 2)
# Epoch 1/30
# 4/4 [==============================] - 5s 123ms/step - loss: 1.4193 - accuracy: 0.4456
# Epoch 2/30
# 4/4 [==============================] - 1s 144ms/step - loss: 0.9101 - accuracy: 0.6318
# Epoch 3/30
# 4/4 [==============================] - 1s 149ms/step - loss: 0.9068 - accuracy: 0.5934
# Epoch 4/30
# 4/4 [==============================] - 1s 132ms/step - loss: 0.7944 - accuracy: 0.6394
# Epoch 5/30
# 4/4 [==============================] - 0s 122ms/step - loss: 0.6046 - accuracy: 0.7012
# Epoch 6/30
# 4/4 [==============================] - 0s 119ms/step - loss: 0.5789 - accuracy: 0.7557
# Epoch 7/30
# 4/4 [==============================] - 1s 127ms/step - loss: 0.5413 - accuracy: 0.7245
# Epoch 8/30
# 4/4 [==============================] - 1s 134ms/step - loss: 0.6200 - accuracy: 0.7129
# Epoch 9/30
# 4/4 [==============================] - 1s 145ms/step - loss: 0.4738 - accuracy: 0.8101
# Epoch 10/30
# 4/4 [==============================] - 1s 134ms/step - loss: 0.4520 - accuracy: 0.7977
# Epoch 11/30
# 4/4 [==============================] - 0s 120ms/step - loss: 0.4766 - accuracy: 0.8072
# Epoch 12/30
# 4/4 [==============================] - 0s 118ms/step - loss: 0.4742 - accuracy: 0.7946
# Epoch 13/30
# 4/4 [==============================] - 1s 149ms/step - loss: 0.3124 - accuracy: 0.8659
# Epoch 14/30
# 4/4 [==============================] - 0s 116ms/step - loss: 0.3356 - accuracy: 0.8544
# Epoch 15/30
# 4/4 [==============================] - 0s 118ms/step - loss: 0.3720 - accuracy: 0.8084
# Epoch 16/30
# 4/4 [==============================] - 1s 138ms/step - loss: 0.2092 - accuracy: 0.9223
# Epoch 17/30
# 4/4 [==============================] - 1s 148ms/step - loss: 0.3169 - accuracy: 0.8367
# Epoch 18/30
# 4/4 [==============================] - 1s 142ms/step - loss: 0.1293 - accuracy: 0.9685
# Epoch 19/30
# 4/4 [==============================] - 0s 122ms/step - loss: 0.1722 - accuracy: 0.9256
# Epoch 20/30
# 4/4 [==============================] - 0s 122ms/step - loss: 0.1230 - accuracy: 0.9496
# Epoch 21/30
# 4/4 [==============================] - 0s 116ms/step - loss: 0.1714 - accuracy: 0.9393
# Epoch 22/30
# 4/4 [==============================] - 0s 123ms/step - loss: 0.1276 - accuracy: 0.9392
# Epoch 23/30
# 4/4 [==============================] - 0s 122ms/step - loss: 0.0885 - accuracy: 0.9727
# Epoch 24/30
# 4/4 [==============================] - 0s 121ms/step - loss: 0.1129 - accuracy: 0.9392
# Epoch 25/30
# 4/4 [==============================] - 0s 121ms/step - loss: 0.0810 - accuracy: 0.9770
# Epoch 26/30
# 4/4 [==============================] - 1s 143ms/step - loss: 0.0708 - accuracy: 0.9916
# Epoch 27/30
# 4/4 [==============================] - 0s 122ms/step - loss: 0.0558 - accuracy: 0.9822
# Epoch 28/30
# 4/4 [==============================] - 0s 121ms/step - loss: 0.1138 - accuracy: 0.9738
# Epoch 29/30
# 4/4 [==============================] - 0s 123ms/step - loss: 0.0946 - accuracy: 0.9517
# Epoch 30/30
# 4/4 [==============================] - 0s 122ms/step - loss: 0.0532 - accuracy: 0.9738
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x00000255CF291670> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 11. LSTM: accuracy = 54.761904761904766%, precision = 0.5333333333333333, recall = 0.4, f1 = 0.4571428571428572
# Confusion matrix:
# [[15  7]
#  [12  8]]
# Running ANN for file: dataset_result\P12.npz
# X (train) shape: (126, 14, 360) Y (train) shape: (126, 2)
# X (test) shape: (42, 14, 360) Y (test) shape: (42, 2)
# Epoch 1/30
# 4/4 [==============================] - 5s 114ms/step - loss: 0.9364 - accuracy: 0.4352
# Epoch 2/30
# 4/4 [==============================] - 1s 121ms/step - loss: 0.8572 - accuracy: 0.5001
# Epoch 3/30
# 4/4 [==============================] - 0s 119ms/step - loss: 0.7550 - accuracy: 0.6174
# Epoch 4/30
# 4/4 [==============================] - 0s 122ms/step - loss: 0.5732 - accuracy: 0.7114
# Epoch 5/30
# 4/4 [==============================] - 0s 117ms/step - loss: 0.6563 - accuracy: 0.6216
# Epoch 6/30
# 4/4 [==============================] - 0s 119ms/step - loss: 0.5813 - accuracy: 0.6906
# Epoch 7/30
# 4/4 [==============================] - 0s 116ms/step - loss: 0.5010 - accuracy: 0.7399
# Epoch 8/30
# 4/4 [==============================] - 0s 116ms/step - loss: 0.5998 - accuracy: 0.7107
# Epoch 9/30
# 4/4 [==============================] - 0s 116ms/step - loss: 0.5887 - accuracy: 0.7223
# Epoch 10/30
# 4/4 [==============================] - 0s 119ms/step - loss: 0.5513 - accuracy: 0.7348
# Epoch 11/30
# 4/4 [==============================] - 0s 120ms/step - loss: 0.5878 - accuracy: 0.6648
# Epoch 12/30
# 4/4 [==============================] - 0s 119ms/step - loss: 0.5520 - accuracy: 0.7126
# Epoch 13/30
# 4/4 [==============================] - 0s 126ms/step - loss: 0.4407 - accuracy: 0.7506
# Epoch 14/30
# 4/4 [==============================] - 1s 119ms/step - loss: 0.5061 - accuracy: 0.7590
# Epoch 15/30
# 4/4 [==============================] - 1s 136ms/step - loss: 0.6013 - accuracy: 0.7705
# Epoch 16/30
# 4/4 [==============================] - 1s 142ms/step - loss: 0.4020 - accuracy: 0.8019
# Epoch 17/30
# 4/4 [==============================] - 1s 118ms/step - loss: 0.4324 - accuracy: 0.8019
# Epoch 18/30
# 4/4 [==============================] - 1s 135ms/step - loss: 0.3413 - accuracy: 0.8742
# Epoch 19/30
# 4/4 [==============================] - 1s 133ms/step - loss: 0.4904 - accuracy: 0.7581
# Epoch 20/30
# 4/4 [==============================] - 1s 136ms/step - loss: 0.3682 - accuracy: 0.8428
# Epoch 21/30
# 4/4 [==============================] - 0s 117ms/step - loss: 0.3685 - accuracy: 0.8143
# Epoch 22/30
# 4/4 [==============================] - 0s 122ms/step - loss: 0.4141 - accuracy: 0.8187
# Epoch 23/30
# 4/4 [==============================] - 0s 118ms/step - loss: 0.3792 - accuracy: 0.8312
# Epoch 24/30
# 4/4 [==============================] - 1s 127ms/step - loss: 0.3252 - accuracy: 0.8638
# Epoch 25/30
# 4/4 [==============================] - 1s 143ms/step - loss: 0.2868 - accuracy: 0.9098
# Epoch 26/30
# 4/4 [==============================] - 1s 146ms/step - loss: 0.1815 - accuracy: 0.9392
# Epoch 27/30
# 4/4 [==============================] - 0s 117ms/step - loss: 0.2575 - accuracy: 0.9024
# Epoch 28/30
# 4/4 [==============================] - 0s 114ms/step - loss: 0.2385 - accuracy: 0.8868
# Epoch 29/30
# 4/4 [==============================] - 1s 127ms/step - loss: 0.2630 - accuracy: 0.8827
# Epoch 30/30
# 4/4 [==============================] - 0s 121ms/step - loss: 0.2329 - accuracy: 0.9035
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000025592E329D0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 12. LSTM: accuracy = 57.14285714285714%, precision = 0.6428571428571429, recall = 0.4090909090909091, f1 = 0.5000000000000001
# Confusion matrix:
# [[15  5]
#  [13  9]]
# Running ANN for file: dataset_result\P13.npz
# X (train) shape: (126, 14, 360) Y (train) shape: (126, 2)
# X (test) shape: (42, 14, 360) Y (test) shape: (42, 2)
# Epoch 1/30
# 4/4 [==============================] - 5s 115ms/step - loss: 1.0288 - accuracy: 0.4945
# Epoch 2/30
# 4/4 [==============================] - 1s 129ms/step - loss: 0.8604 - accuracy: 0.4825
# Epoch 3/30
# 4/4 [==============================] - 0s 115ms/step - loss: 0.6871 - accuracy: 0.5954
# Epoch 4/30
# 4/4 [==============================] - 0s 114ms/step - loss: 0.6744 - accuracy: 0.6813
# Epoch 5/30
# 4/4 [==============================] - 1s 147ms/step - loss: 0.4972 - accuracy: 0.7443
# Epoch 6/30
# 4/4 [==============================] - 0s 117ms/step - loss: 0.5888 - accuracy: 0.7179
# Epoch 7/30
# 4/4 [==============================] - 0s 113ms/step - loss: 0.4594 - accuracy: 0.8405
# Epoch 8/30
# 4/4 [==============================] - 1s 138ms/step - loss: 0.4841 - accuracy: 0.7682
# Epoch 9/30
# 4/4 [==============================] - 1s 126ms/step - loss: 0.4655 - accuracy: 0.7651
# Epoch 10/30
# 4/4 [==============================] - 1s 122ms/step - loss: 0.3798 - accuracy: 0.8197
# Epoch 11/30
# 4/4 [==============================] - 0s 118ms/step - loss: 0.3660 - accuracy: 0.8543
# Epoch 12/30
# 4/4 [==============================] - 0s 114ms/step - loss: 0.3797 - accuracy: 0.8785
# Epoch 13/30
# 4/4 [==============================] - 0s 112ms/step - loss: 0.3779 - accuracy: 0.8041
# Epoch 14/30
# 4/4 [==============================] - 0s 115ms/step - loss: 0.3080 - accuracy: 0.8888
# Epoch 15/30
# 4/4 [==============================] - 1s 134ms/step - loss: 0.3192 - accuracy: 0.8565
# Epoch 16/30
# 4/4 [==============================] - 1s 145ms/step - loss: 0.2809 - accuracy: 0.8753
# Epoch 17/30
# 4/4 [==============================] - 1s 133ms/step - loss: 0.2737 - accuracy: 0.8953
# Epoch 18/30
# 4/4 [==============================] - 0s 120ms/step - loss: 0.1791 - accuracy: 0.9485
# Epoch 19/30
# 4/4 [==============================] - 0s 111ms/step - loss: 0.1898 - accuracy: 0.9308
# Epoch 20/30
# 4/4 [==============================] - 1s 135ms/step - loss: 0.1402 - accuracy: 0.9422
# Epoch 21/30
# 4/4 [==============================] - 1s 129ms/step - loss: 0.0925 - accuracy: 0.9800
# Epoch 22/30
# 4/4 [==============================] - 0s 114ms/step - loss: 0.0799 - accuracy: 0.9884
# Epoch 23/30
# 4/4 [==============================] - 0s 118ms/step - loss: 0.0892 - accuracy: 0.9602
# Epoch 24/30
# 4/4 [==============================] - 1s 125ms/step - loss: 0.0777 - accuracy: 0.9780
# Epoch 25/30
# 4/4 [==============================] - 0s 113ms/step - loss: 0.0772 - accuracy: 0.9770
# Epoch 26/30
# 4/4 [==============================] - 1s 137ms/step - loss: 0.0573 - accuracy: 0.9884
# Epoch 27/30
# ...
# X (test) shape: (42, 14, 360) Y (test) shape: (42, 2)
# Epoch 1/30
# 4/4 [==============================] - 5s 112ms/step - loss: 0.8691 - accuracy: 0.5357
# Epoch 2/30
# 4/4 [==============================] - 0s 121ms/step - loss: 0.8524 - accuracy: 0.5264
# Epoch 3/30
# 4/4 [==============================] - 1s 127ms/step - loss: 0.6920 - accuracy: 0.6402
# Epoch 4/30
# 4/4 [==============================] - 1s 137ms/step - loss: 0.6535 - accuracy: 0.6209
# Epoch 5/30
# 4/4 [==============================] - 0s 116ms/step - loss: 0.6301 - accuracy: 0.6646
# Epoch 6/30
# 4/4 [==============================] - 0s 127ms/step - loss: 0.5769 - accuracy: 0.6950
# Epoch 7/30
# 4/4 [==============================] - 0s 115ms/step - loss: 0.4189 - accuracy: 0.7798
# Epoch 8/30
# 4/4 [==============================] - 0s 119ms/step - loss: 0.4789 - accuracy: 0.8155
# Epoch 9/30
# 4/4 [==============================] - 0s 123ms/step - loss: 0.4518 - accuracy: 0.8009
# Epoch 10/30
# 4/4 [==============================] - 0s 119ms/step - loss: 0.3997 - accuracy: 0.7641
# Epoch 11/30
# 4/4 [==============================] - 1s 139ms/step - loss: 0.3579 - accuracy: 0.8384
# Epoch 12/30
# 4/4 [==============================] - 1s 124ms/step - loss: 0.3577 - accuracy: 0.8575
# Epoch 13/30
# 4/4 [==============================] - 0s 116ms/step - loss: 0.4433 - accuracy: 0.8071
# Epoch 14/30
# 4/4 [==============================] - 0s 118ms/step - loss: 0.3106 - accuracy: 0.8743
# Epoch 15/30
# 4/4 [==============================] - 1s 134ms/step - loss: 0.2762 - accuracy: 0.8921
# Epoch 16/30
# 4/4 [==============================] - 1s 128ms/step - loss: 0.2605 - accuracy: 0.8805
# Epoch 17/30
# 4/4 [==============================] - 0s 123ms/step - loss: 0.2592 - accuracy: 0.8617
# Epoch 18/30
# 4/4 [==============================] - 0s 117ms/step - loss: 0.2310 - accuracy: 0.8972
# Epoch 19/30
# 4/4 [==============================] - 0s 116ms/step - loss: 0.2298 - accuracy: 0.9016
# Epoch 20/30
# 4/4 [==============================] - 1s 135ms/step - loss: 0.1599 - accuracy: 0.9255
# Epoch 21/30
# 4/4 [==============================] - 0s 120ms/step - loss: 0.2104 - accuracy: 0.9141
# Epoch 22/30
# 4/4 [==============================] - 1s 128ms/step - loss: 0.1307 - accuracy: 0.9612
# Epoch 23/30
# 4/4 [==============================] - 1s 127ms/step - loss: 0.0927 - accuracy: 0.9916
# Epoch 24/30
# 4/4 [==============================] - 0s 119ms/step - loss: 0.0828 - accuracy: 0.9749
# Epoch 25/30
# 4/4 [==============================] - 0s 120ms/step - loss: 0.0621 - accuracy: 0.9916
# Epoch 26/30
# 4/4 [==============================] - 1s 144ms/step - loss: 0.0526 - accuracy: 0.9822
# Epoch 27/30
# 4/4 [==============================] - 0s 117ms/step - loss: 0.0943 - accuracy: 0.9654
# Epoch 28/30
# 4/4 [==============================] - 1s 131ms/step - loss: 0.0768 - accuracy: 0.9779
# Epoch 29/30
# 4/4 [==============================] - 0s 118ms/step - loss: 0.0545 - accuracy: 0.9863
# Epoch 30/30
# 4/4 [==============================] - 0s 117ms/step - loss: 0.0842 - accuracy: 0.9758
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000025702F76B80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 15. LSTM: accuracy = 47.61904761904761%, precision = 0.4782608695652174, recall = 0.5238095238095238, f1 = 0.5
# Confusion matrix:
# [[ 9 12]
#  [10 11]]
# Running ANN for file: dataset_result\P16.npz
# X (train) shape: (126, 14, 360) Y (train) shape: (126, 2)
# X (test) shape: (42, 14, 360) Y (test) shape: (42, 2)
# Epoch 1/30
# 4/4 [==============================] - 5s 119ms/step - loss: 1.0916 - accuracy: 0.4558
# Epoch 2/30
# 4/4 [==============================] - 0s 128ms/step - loss: 0.7222 - accuracy: 0.6164
# Epoch 3/30
# 4/4 [==============================] - 1s 128ms/step - loss: 0.6683 - accuracy: 0.6864
# Epoch 4/30
# 4/4 [==============================] - 1s 140ms/step - loss: 0.6265 - accuracy: 0.6993
# Epoch 5/30
# 4/4 [==============================] - 1s 129ms/step - loss: 0.6585 - accuracy: 0.6888
# Epoch 6/30
# 4/4 [==============================] - 1s 132ms/step - loss: 0.6049 - accuracy: 0.6823
# Epoch 7/30
# 4/4 [==============================] - 0s 126ms/step - loss: 0.6234 - accuracy: 0.7297
# Epoch 8/30
# 4/4 [==============================] - 1s 129ms/step - loss: 0.4355 - accuracy: 0.8071
# Epoch 9/30
# 4/4 [==============================] - 1s 126ms/step - loss: 0.4405 - accuracy: 0.7800
# Epoch 10/30
# 4/4 [==============================] - 0s 126ms/step - loss: 0.3843 - accuracy: 0.8365
# Epoch 11/30
# 4/4 [==============================] - 1s 135ms/step - loss: 0.3427 - accuracy: 0.8688
# Epoch 12/30
# 4/4 [==============================] - 0s 126ms/step - loss: 0.2848 - accuracy: 0.8888
# Epoch 13/30
# 4/4 [==============================] - 1s 131ms/step - loss: 0.3500 - accuracy: 0.8709
# Epoch 14/30
# 4/4 [==============================] - 1s 133ms/step - loss: 0.2808 - accuracy: 0.8984
# Epoch 15/30
# 4/4 [==============================] - 0s 127ms/step - loss: 0.2660 - accuracy: 0.9015
# Epoch 16/30
# 4/4 [==============================] - 0s 125ms/step - loss: 0.2945 - accuracy: 0.8617
# Epoch 17/30
# 4/4 [==============================] - 1s 135ms/step - loss: 0.2381 - accuracy: 0.8953
# Epoch 18/30
# 4/4 [==============================] - 1s 129ms/step - loss: 0.2278 - accuracy: 0.9172
# Epoch 19/30
# 4/4 [==============================] - 1s 140ms/step - loss: 0.2463 - accuracy: 0.9140
# Epoch 20/30
# 4/4 [==============================] - 1s 134ms/step - loss: 0.1728 - accuracy: 0.9193
# Epoch 21/30
# 4/4 [==============================] - 1s 147ms/step - loss: 0.1579 - accuracy: 0.9800
# Epoch 22/30
# 4/4 [==============================] - 1s 146ms/step - loss: 0.1529 - accuracy: 0.9256
# Epoch 23/30
# 4/4 [==============================] - 1s 149ms/step - loss: 0.1544 - accuracy: 0.9560
# Epoch 24/30
# 4/4 [==============================] - 1s 130ms/step - loss: 0.1301 - accuracy: 0.9675
# Epoch 25/30
# 4/4 [==============================] - 0s 120ms/step - loss: 0.1809 - accuracy: 0.9382
# Epoch 26/30
# 4/4 [==============================] - 0s 123ms/step - loss: 0.1482 - accuracy: 0.9456
# Epoch 27/30
# 4/4 [==============================] - 0s 123ms/step - loss: 0.1012 - accuracy: 0.9727
# Epoch 28/30
# 4/4 [==============================] - 0s 122ms/step - loss: 0.0557 - accuracy: 0.9895
# Epoch 29/30
# 4/4 [==============================] - 1s 129ms/step - loss: 0.0880 - accuracy: 0.9717
# Epoch 30/30
# 4/4 [==============================] - 1s 137ms/step - loss: 0.0458 - accuracy: 0.9831
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x00000255CFA2F5E0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 16. LSTM: accuracy = 45.23809523809524%, precision = 0.5, recall = 0.43478260869565216, f1 = 0.46511627906976744
# Confusion matrix:
# [[ 9 10]
#  [13 10]]
# Running ANN for file: dataset_result\P17.npz
# X (train) shape: (126, 14, 360) Y (train) shape: (126, 2)
# X (test) shape: (42, 14, 360) Y (test) shape: (42, 2)
# Epoch 1/30
# 4/4 [==============================] - 5s 147ms/step - loss: 1.0365 - accuracy: 0.5303
# Epoch 2/30
# 4/4 [==============================] - 1s 129ms/step - loss: 0.6375 - accuracy: 0.6824
# Epoch 3/30
# 4/4 [==============================] - 0s 121ms/step - loss: 0.5423 - accuracy: 0.7046
# Epoch 4/30
# 4/4 [==============================] - 0s 121ms/step - loss: 0.4945 - accuracy: 0.7653
# Epoch 5/30
# 4/4 [==============================] - 0s 123ms/step - loss: 0.5138 - accuracy: 0.7726
# Epoch 6/30
# 4/4 [==============================] - 1s 144ms/step - loss: 0.3855 - accuracy: 0.8228
# Epoch 7/30
# 4/4 [==============================] - 1s 134ms/step - loss: 0.2483 - accuracy: 0.9211
# Epoch 8/30
# 4/4 [==============================] - 0s 122ms/step - loss: 0.3487 - accuracy: 0.8187
# Epoch 9/30
# 4/4 [==============================] - 1s 145ms/step - loss: 0.2915 - accuracy: 0.8941
# Epoch 10/30
# 4/4 [==============================] - 1s 131ms/step - loss: 0.1876 - accuracy: 0.9319
# Epoch 11/30
# 4/4 [==============================] - 1s 145ms/step - loss: 0.1937 - accuracy: 0.9474
# Epoch 12/30
# 4/4 [==============================] - 0s 121ms/step - loss: 0.1313 - accuracy: 0.9518
# Epoch 13/30
# 4/4 [==============================] - 0s 121ms/step - loss: 0.1011 - accuracy: 0.9873
# Epoch 14/30
# 4/4 [==============================] - 1s 120ms/step - loss: 0.1482 - accuracy: 0.9559
# Epoch 15/30
# 4/4 [==============================] - 0s 124ms/step - loss: 0.1136 - accuracy: 0.9770
# Epoch 16/30
# 4/4 [==============================] - 0s 122ms/step - loss: 0.0889 - accuracy: 0.9770
# Epoch 17/30
# 4/4 [==============================] - 0s 126ms/step - loss: 0.0661 - accuracy: 0.9864
# Epoch 18/30
# 4/4 [==============================] - 1s 140ms/step - loss: 0.0446 - accuracy: 0.9854
# Epoch 19/30
# 4/4 [==============================] - 1s 122ms/step - loss: 0.0288 - accuracy: 1.0000
# Epoch 20/30
# 4/4 [==============================] - 0s 120ms/step - loss: 0.0476 - accuracy: 0.9916
# Epoch 21/30
# 4/4 [==============================] - 1s 131ms/step - loss: 0.0256 - accuracy: 1.0000
# Epoch 22/30
# 4/4 [==============================] - 1s 131ms/step - loss: 0.0185 - accuracy: 1.0000
# Epoch 23/30
# 4/4 [==============================] - 0s 123ms/step - loss: 0.0139 - accuracy: 0.9968
# Epoch 24/30
# 4/4 [==============================] - 0s 119ms/step - loss: 0.0199 - accuracy: 0.9947
# Epoch 25/30
# 4/4 [==============================] - 0s 122ms/step - loss: 0.0160 - accuracy: 1.0000
# Epoch 26/30
# 4/4 [==============================] - 0s 119ms/step - loss: 0.0166 - accuracy: 1.0000
# Epoch 27/30
# 4/4 [==============================] - 1s 136ms/step - loss: 0.0096 - accuracy: 1.0000
# Epoch 28/30
# 4/4 [==============================] - 1s 142ms/step - loss: 0.0068 - accuracy: 1.0000
# Epoch 29/30
# 4/4 [==============================] - 1s 133ms/step - loss: 0.0190 - accuracy: 1.0000
# Epoch 30/30
# 4/4 [==============================] - 1s 141ms/step - loss: 0.0152 - accuracy: 1.0000
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000025717DFC310> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 17. LSTM: accuracy = 38.095238095238095%, precision = 0.4, recall = 0.47619047619047616, f1 = 0.43478260869565216
# Confusion matrix:
# [[ 6 15]
#  [11 10]]
# Running ANN for file: dataset_result\P18.npz
# X (train) shape: (126, 14, 360) Y (train) shape: (126, 2)
# X (test) shape: (42, 14, 360) Y (test) shape: (42, 2)
# Epoch 1/30
# 4/4 [==============================] - 5s 110ms/step - loss: 0.9068 - accuracy: 0.5388
# Epoch 2/30
# 4/4 [==============================] - 1s 137ms/step - loss: 0.7789 - accuracy: 0.6018
# Epoch 3/30
# 4/4 [==============================] - 1s 130ms/step - loss: 0.7112 - accuracy: 0.6822
# Epoch 4/30
# 4/4 [==============================] - 0s 118ms/step - loss: 0.5822 - accuracy: 0.6959
# Epoch 5/30
# 4/4 [==============================] - 0s 116ms/step - loss: 0.6508 - accuracy: 0.6270
# Epoch 6/30
# 4/4 [==============================] - 0s 124ms/step - loss: 0.4880 - accuracy: 0.7818
# Epoch 7/30
# 4/4 [==============================] - 0s 116ms/step - loss: 0.5608 - accuracy: 0.7590
# Epoch 8/30
# 4/4 [==============================] - 0s 117ms/step - loss: 0.5035 - accuracy: 0.7786
# Epoch 9/30
# 4/4 [==============================] - 0s 116ms/step - loss: 0.4955 - accuracy: 0.7513
# Epoch 10/30
# 4/4 [==============================] - 0s 118ms/step - loss: 0.5405 - accuracy: 0.7486
# Epoch 11/30
# 4/4 [==============================] - 1s 126ms/step - loss: 0.4217 - accuracy: 0.7643
# Epoch 12/30
# 4/4 [==============================] - 1s 143ms/step - loss: 0.2978 - accuracy: 0.8772
# Epoch 13/30
# 4/4 [==============================] - 0s 118ms/step - loss: 0.3811 - accuracy: 0.8165
# Epoch 14/30
# 4/4 [==============================] - 0s 121ms/step - loss: 0.3059 - accuracy: 0.8711
# Epoch 15/30
# 4/4 [==============================] - 1s 137ms/step - loss: 0.3049 - accuracy: 0.8660
# Epoch 16/30
# 4/4 [==============================] - 1s 131ms/step - loss: 0.2248 - accuracy: 0.9099
# Epoch 17/30
# 4/4 [==============================] - 1s 131ms/step - loss: 0.2726 - accuracy: 0.8566
# Epoch 18/30
# 4/4 [==============================] - 0s 118ms/step - loss: 0.1541 - accuracy: 0.9506
# Epoch 19/30
# 4/4 [==============================] - 0s 118ms/step - loss: 0.1578 - accuracy: 0.9487
# Epoch 20/30
# 4/4 [==============================] - 0s 115ms/step - loss: 0.1140 - accuracy: 0.9864
# Epoch 21/30
# 4/4 [==============================] - 0s 119ms/step - loss: 0.1195 - accuracy: 0.9527
# Epoch 22/30
# 4/4 [==============================] - 1s 142ms/step - loss: 0.0817 - accuracy: 0.9832
# Epoch 23/30
# 4/4 [==============================] - 1s 142ms/step - loss: 0.0708 - accuracy: 0.9968
# Epoch 24/30
# 4/4 [==============================] - 0s 116ms/step - loss: 0.0594 - accuracy: 0.9864
# Epoch 25/30
# 4/4 [==============================] - 1s 143ms/step - loss: 0.0724 - accuracy: 0.9801
# Epoch 26/30
# 4/4 [==============================] - 1s 120ms/step - loss: 0.0767 - accuracy: 0.9779
# Epoch 27/30
# 4/4 [==============================] - 0s 124ms/step - loss: 0.0453 - accuracy: 0.9916
# Epoch 28/30
# 4/4 [==============================] - 1s 137ms/step - loss: 0.0433 - accuracy: 0.9947
# Epoch 29/30
# 4/4 [==============================] - 1s 137ms/step - loss: 0.1045 - accuracy: 0.9590
# Epoch 30/30
# 4/4 [==============================] - 0s 118ms/step - loss: 0.0887 - accuracy: 0.9622
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x00000255CFA2FA60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 18. LSTM: accuracy = 45.23809523809524%, precision = 0.4230769230769231, recall = 0.5789473684210527, f1 = 0.4888888888888889
# Confusion matrix:
# [[ 8 15]
#  [ 8 11]]

# %%
# Create pandas dataframe with stats from each iterations
df = pd.DataFrame({
    'participant': [x for x in range(1, num_participants + 1)],
    'accuracy': [x['accuracy'] for x in results],
    'precision': [x['precision'] for x in results],
    'recall': [x['recall'] for x in results],
    'f1': [x['f1'] for x in results],
})

df
# Out:
#     participant  accuracy  precision    recall        f1
# 0             1  0.633333   0.684211  0.722222  0.702703
# 1             2  0.452381   0.454545  0.750000  0.566038
# 2             3  0.595238   0.666667  0.380952  0.484848
# 3             4  0.404762   0.391304  0.450000  0.418605
# 4             5  0.404762   0.368421  0.350000  0.358974
# 5             6  0.523810   0.565217  0.565217  0.565217
# 6             7  0.476190   0.480000  0.571429  0.521739
# 7             8  0.547619   0.520000  0.650000  0.577778
# 8             9  0.523810   0.523810  0.523810  0.523810
# 9            10  0.571429   0.555556  0.714286  0.625000
# 10           11  0.547619   0.533333  0.400000  0.457143
# 11           12  0.571429   0.642857  0.409091  0.500000
# 12           13  0.571429   0.523810  0.578947  0.550000
# 13           14  0.428571   0.450000  0.409091  0.428571
# 14           15  0.476190   0.478261  0.523810  0.500000
# 15           16  0.452381   0.500000  0.434783  0.465116
# 16           17  0.380952   0.400000  0.476190  0.434783
# 17           18  0.452381   0.423077  0.578947  0.488889

# %%
data_output_folder = 'lstm_individuals'
iteration_data_file_name = 'lstm_individuals_data.xlsx'

os.makedirs(data_output_folder, exist_ok=True)

df.to_excel(os.path.join(data_output_folder, iteration_data_file_name))
'Data from individuals successfully saved.'
# Out:
# 'Data from individuals successfully saved.'

# %%
# Create a dataframe with statistics
df_stats = pd.DataFrame({
    'average_accuracy': [df['accuracy'].mean()],
    'max_accuracy': [df['accuracy'].max()],
    'accuracy_std': [df['accuracy'].std()],
    'average_precision': [df['precision'].mean()],
    'max_precision': [df['precision'].max()],
    'average_recall': [df['recall'].mean()],
    'max_recall': [df['recall'].max()],
    'average_f1': [df['f1'].mean()],
    'max_f1': [df['f1'].max()],
})

df_stats
# Out:
#    average_accuracy  max_accuracy  accuracy_std  average_precision  \
# 0          0.500794      0.633333      0.074028           0.508948
#
#    max_precision  average_recall  max_recall  average_f1    max_f1
# 0       0.684211        0.527154        0.75    0.509401  0.702703

# %%
# Save the dataframe
stats_file_name = 'lstm_individuals_stats.xlsx'
df_stats.to_excel(os.path.join(data_output_folder, stats_file_name))
'Stats successfully saved.'
# Out:
# 'Stats successfully saved.'

# %%
utils.print_confusion_matrices(results)
# Out:
# Confusion matrices for the ANN:
# [[ 6  6]
#  [ 5 13]]
#
# [[ 4 18]
#  [ 5 15]]
#
# [[17  4]
#  [13  8]]
#
# [[ 8 14]
#  [11  9]]
#
# [[10 12]
#  [13  7]]
#
# [[ 9 10]
#  [10 13]]
#
# [[ 8 13]
#  [ 9 12]]
#
# [[10 12]
#  [ 7 13]]
#
# [[11 10]
#  [10 11]]
#
# [[ 9 12]
#  [ 6 15]]
#
# [[15  7]
#  [12  8]]
#
# [[15  5]
#  [13  9]]
#
# [[13 10]
#  [ 8 11]]
#
# [[ 9 11]
#  [13  9]]
#
# [[ 9 12]
#  [10 11]]
#
# [[ 9 10]
#  [13 10]]
#
# [[ 6 15]
#  [11 10]]
#
# [[ 8 15]
#  [ 8 11]]
